# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt

# import pydot
# import graphviz
# import math
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator

import time
import random

# %%
tf.keras.backend.set_floatx('float64')

# %%
def rklv(constants, t_start, t_end, t_step_size) :
    
    [x0, y0, a, b, c, d] = constants
        
    def rk4(r, t, h):                    #edited; no need for input f
            """ Runge-Kutta 4 method """
            k1 = h*f(r, t)
            k2 = h*f(r+0.5*k1, t+0.5*h)
            k3 = h*f(r+0.5*k2, t+0.5*h)
            k4 = h*f(r+k3, t+h)
            return (k1 + 2*k2 + 2*k3 + k4)/6

    def f(r, t):
            x, y = r[0], r[1]
            fxd = a*x - b*x*y
            fyd = c*x*y - d*y
            return np.array([fxd, fyd], float)

    h = t_step_size                           
    tpoints = np.arange(t_start, t_end + h, h)        
    xpoints, ypoints  = [], []
    r = np.array([x0, y0], float)
    for t in tpoints:
            xpoints.append(r[0])         
            ypoints.append(r[1])         
            r += rk4(r, t, h)        
            
#     plt.plot(np.log(xpoints), np.log(ypoints))
#     plt.xlabel("x")
#     plt.ylabel("y")
#     plt.show()

    tarr = np.asarray(tpoints)
    xarr = np.asarray(xpoints)
    yarr = np.asarray(ypoints)

    points = np.vstack((tarr, xarr, yarr))

    return points

# %%
def define_collocation_points(t_bdry, N_points=100):

    colloc_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_points)

    return colloc_points

# %%
M = 6
N = 5
P = 100


t0 = 0.0
tfinal = 10.0
t_step = 0.01

# %%
def build_branch(num_layers = 4, num_units = 40, summary = False) :

    inp_br = b = tf.keras.layers.Input(shape = (M,), name = "Input_br")
    
    for i in range(num_layers) :
        
        b = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_br_" + str(i))(b)
        
    out_br = tf.keras.layers.Dense(p, activation = 'linear', name = "output_br")(b)
    
    model = tf.keras.models.Model(inp_br, out_br)
    
    if summary :
        
        model.summary()
        
    return model

# %%
# branch = build_branch(summary = True)
# tf.keras.utils.plot_model(branch, to_file = 'branch_net.png')

# %%
def build_trunk(num_layers = 4, num_units = 40, summary = False) :
    
    inp_tr = b = tf.keras.layers.Input(shape = (1,), name = "Input_tr")
    
    for i in range(num_layers) :
        
        b = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_tr_" + str(i))(b)
        
    out_tr = tf.keras.layers.Dense(p, activation = 'linear', name = "output_tr")(b)

    model = tf.keras.models.Model(inp_tr, out_tr)
    
    if summary :
        
        model.summary()
        
    return model

# %%
# trunk = build_trunk(summary = True)
# tf.keras.utils.plot_model(trunk, to_file = 'trunk_net.png')

# %%
def build_model(num_layers = 4, num_units = 60, summary = False) :
    
    inp_br = br = tf.keras.layers.Input(shape = (M,), name = "Input_br")
    
    for i in range(num_layers) :
        
        br = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_br_" + str(i))(br)
        
    out_br_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_x")(br)
    out_br_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_y")(br)
    
    
    inp_tr = tr = tf.keras.layers.Input(shape = (1,), name = "Input_tr")
    
    for i in range(num_layers) :
        
        tr = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_tr_" + str(i))(tr)
        
    out_tr_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_x")(tr)
    out_tr_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_y")(tr)

    mult_x = tf.keras.layers.Multiply(name = "multiply_x")([out_br_x, out_tr_x])
    mult_y = tf.keras.layers.Multiply(name = "multiply_y")([out_br_y, out_tr_y])
    
    out_x = tf.keras.layers.Dense(1, name = "output_x")(mult_x)
    out_y = tf.keras.layers.Dense(1, name = "output_y")(mult_y)
    
    model = tf.keras.models.Model([inp_br, inp_tr], [out_x, out_y])
    
    if summary :
        
        model.summary()
        
    return model

# %%
model = build_model(summary = True)
tf.keras.utils.plot_model(model, to_file = 'DeepOnet.png')
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_br (InputLayer)          [(None, 6)]          0           []
#
#  Input_tr (InputLayer)          [(None, 1)]          0           []
#
#  Hidden_br_0 (Dense)            (None, 60)           420         ['Input_br[0][0]']
#
#  Hidden_tr_0 (Dense)            (None, 60)           120         ['Input_tr[0][0]']
#
#  Hidden_br_1 (Dense)            (None, 60)           3660        ['Hidden_br_0[0][0]']
#
#  Hidden_tr_1 (Dense)            (None, 60)           3660        ['Hidden_tr_0[0][0]']
#
#  Hidden_br_2 (Dense)            (None, 60)           3660        ['Hidden_br_1[0][0]']
#
#  Hidden_tr_2 (Dense)            (None, 60)           3660        ['Hidden_tr_1[0][0]']
#
#  Hidden_br_3 (Dense)            (None, 60)           3660        ['Hidden_br_2[0][0]']
#
#  Hidden_tr_3 (Dense)            (None, 60)           3660        ['Hidden_tr_2[0][0]']
#
#  output_br_x (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_x (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  output_br_y (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_y (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  multiply_x (Multiply)          (None, 1)            0           ['output_br_x[0][0]',
#                                                                   'output_tr_x[0][0]']
#
#  multiply_y (Multiply)          (None, 1)            0           ['output_br_y[0][0]',
#                                                                   'output_tr_y[0][0]']
#
#  output_x (Dense)               (None, 1)            2           ['multiply_x[0][0]']
#
#  output_y (Dense)               (None, 1)            2           ['multiply_y[0][0]']
#
# ==================================================================================================
# Total params: 22,748
# Trainable params: 22,748
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
u_data = np.random.rand(N, M)

# %%
def clone_u_data (data) :
    
    new_data = np.zeros((N*P, M))
    
    for i in range(N) :
        
        data_row = data[i]
        
        cloned_data = np.tile(data_row, (P,1))
        
        new_data[i*P:(i + 1)*P, :] = cloned_data
        
    return new_data

# %%
def clone_t_data (data) :
    
    new_data = np.tile(data, (N,1))
    
    return new_data

# %%
print(u_data.shape)
u_data = clone_u_data(u_data)
print(u_data.shape)

u_train = u_data
# Out:
# (5, 6)
# (500, 6)

# %%
colloc = define_collocation_points([t0, tfinal], P)
plt.plot(colloc[:,0], 0 * colloc[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
t_init = np.zeros((N*P, 1))

# %%
decimal_p = int((np.floor(np.log10(1/t_step))))
print(decimal_p)
# Out:
# 2

# %%
t_data = colloc
print(t_data.shape)
t_data = clone_t_data(t_data)
print(t_data.shape)

t_data = np.around(t_data, decimal_p)
t_train = t_data
# Out:
# (100, 1)
# (500, 1)

# %%
true_data = np.zeros((N*P, 2))

for i in range(N*P) :
    
    u = u_train[i]
    t = t_train[i]
    
    sol_points = rklv(u, t0, tfinal, t_step)
    
    t_sol = sol_points[0]
    t_sol = np.around(t_sol, decimal_p)
    
    x_sol = sol_points[1]
    y_sol = sol_points[2]
    
    index = np.where(t_sol == t)
    
    true_data[i][0] = x_sol[index][0]
    true_data[i][1] = y_sol[index][0]

# %%
u_train[:, :2] = np.log(u_train[:, :2])
true_data = np.log(true_data)

# %%
# The main training function
@tf.function
def train_network(model, u, t, x_true, y_true, x_init, y_init, V, a, b, c, d, alpha, beta, gamma, delta):

    with tf.GradientTape() as tape1:

        with tf.GradientTape(persistent=True) as tape2:
            
            tape2.watch(t)
            [x, y] = model([u, t], training=True)
        

        xt = tape2.gradient(x, t)
        yt = tape2.gradient(y, t)
 
        Gloss = tf.reduce_mean(tf.square(x - x_true) + tf.square(y - y_true))
        
        eqn1 = xt - a + b*(tf.math.exp(y))
        eqn2 = yt - c*(tf.math.exp(x)) + d
        DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
        [x_init_pred, y_init_pred] = model([u, t_init], training=True)
        IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
        v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
        Vloss = tf.reduce_mean(tf.square(v - V))
        
        loss = alpha*Gloss + beta*DEloss + gamma*IVloss + delta*Vloss

    grads = tape1.gradient(loss, model.trainable_variables)
    
    return Gloss, DEloss, IVloss, Vloss, grads

# %%
def DeepONet_train(model, u, t, G_true, epochs, alpha_val, beta_val, gamma_val, delta_val):

    lr_model = 1e-3
    
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val
    delta = delta_val
    
    x_init = u[:, 0]
    y_init = u[:, 1]
    
    a = u[:, 2]
    b = u[:, 3]
    c = u[:, 4]
    d = u[:, 5]
    
    V = (c * (np.exp(x_init))) - (d * x_init) + (b * np.exp(y_init)) - (a * y_init)
      
    x_true = G_true[:, 0]
    y_true = G_true[:, 1]

    epoch_loss = np.zeros(epochs)
    
    opt = tf.keras.optimizers.Adam(lr_model)

    for i in range(epochs):

        Gloss, DEloss, IVloss, Vloss, grads = train_network(model, u, t, x_true, y_true, x_init, y_init, V, 
                                                            a, b, c, d, alpha, beta, gamma, delta)

        opt.apply_gradients(zip(grads, model.trainable_variables))
      
        epoch_loss[i] += alpha*Gloss + beta*DEloss + gamma*IVloss + delta*Vloss

    
        if (np.mod(i, 100)==0):
       
            print("Gloss, DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(
                i, Gloss, DEloss, IVloss, Vloss))

    return epoch_loss, model

# %%
alpha = 10
beta = 12
gamma = 1.2
delta = 100

epochs = 10000

# %%
model = build_model()

loss, model = DeepONet_train(model, u_train, t_train, true_data, epochs, alpha, beta, gamma, delta)
# Out:
# Gloss, DE loss, IV loss, Vloss in 0th epoch:  4.9871,  0.2696,  6.9123,  1.1053.
# Gloss, DE loss, IV loss, Vloss in 100th epoch:  4.9207,  0.2892,  2.9058,  0.5360.
# Gloss, DE loss, IV loss, Vloss in 200th epoch:  4.9161,  0.2860,  2.9147,  0.5365.
# Gloss, DE loss, IV loss, Vloss in 300th epoch:  4.9166,  0.2838,  2.9157,  0.5365.
# Gloss, DE loss, IV loss, Vloss in 400th epoch:  4.9172,  0.2820,  2.9155,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 500th epoch:  4.9162,  0.2823,  2.9138,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 600th epoch:  4.9173,  0.2808,  2.9147,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 700th epoch:  4.9177,  0.2797,  2.9150,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 800th epoch:  4.9179,  0.2788,  2.9153,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 900th epoch:  4.9156,  0.2829,  2.9125,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 1000th epoch:  4.9173,  0.2805,  2.9129,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 1100th epoch:  4.9177,  0.2794,  2.9135,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 1200th epoch:  4.9179,  0.2787,  2.9138,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 1300th epoch:  4.9180,  0.2781,  2.9141,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 1400th epoch:  4.9181,  0.2776,  2.9142,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 1500th epoch:  4.9182,  0.2772,  2.9142,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 1600th epoch:  5.0412,  0.2807,  3.0917,  0.5268.
# Gloss, DE loss, IV loss, Vloss in 1700th epoch:  4.9168,  0.2805,  2.9110,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 1800th epoch:  4.9177,  0.2788,  2.9121,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 1900th epoch:  4.9180,  0.2778,  2.9126,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 2000th epoch:  4.9181,  0.2772,  2.9130,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 2100th epoch:  4.9183,  0.2768,  2.9132,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 2200th epoch:  4.9183,  0.2764,  2.9134,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 2300th epoch:  4.9279,  0.2756,  2.9148,  0.5358.
# Gloss, DE loss, IV loss, Vloss in 2400th epoch:  4.9183,  0.2759,  2.9138,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 2500th epoch:  4.9185,  0.2756,  2.9139,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 2600th epoch:  4.9185,  0.2753,  2.9141,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 2700th epoch:  4.9185,  0.2750,  2.9143,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 2800th epoch:  4.9190,  0.2753,  2.9139,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 2900th epoch:  4.9185,  0.2748,  2.9139,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 3000th epoch:  4.8770,  0.2724,  2.9090,  0.5416.
# Gloss, DE loss, IV loss, Vloss in 3100th epoch:  4.9187,  0.2741,  2.9145,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 3200th epoch:  4.9185,  0.2738,  2.9146,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 3300th epoch:  4.9185,  0.2736,  2.9148,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 3400th epoch:  4.9058,  0.2725,  2.9154,  0.5381.
# Gloss, DE loss, IV loss, Vloss in 3500th epoch:  4.9181,  0.2734,  2.9151,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 3600th epoch:  4.9181,  0.2734,  2.9153,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 3700th epoch:  4.9180,  0.2734,  2.9153,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 3800th epoch:  4.9199,  0.2731,  2.9174,  0.5364.
# Gloss, DE loss, IV loss, Vloss in 3900th epoch:  4.9180,  0.2735,  2.9151,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 4000th epoch:  5.0013,  0.2770,  2.9170,  0.5292.
# Gloss, DE loss, IV loss, Vloss in 4100th epoch:  4.9178,  0.2734,  2.9151,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 4200th epoch:  4.9179,  0.2734,  2.9150,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 4300th epoch:  4.9179,  0.2734,  2.9148,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 4400th epoch:  4.9424,  0.2714,  2.9396,  0.5343.
# Gloss, DE loss, IV loss, Vloss in 4500th epoch:  4.9179,  0.2734,  2.9146,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 4600th epoch:  4.9179,  0.2734,  2.9144,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 4700th epoch:  4.9179,  0.2734,  2.9142,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 4800th epoch:  4.9266,  0.2728,  2.9244,  0.5357.
# Gloss, DE loss, IV loss, Vloss in 4900th epoch:  4.9179,  0.2735,  2.9140,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 5000th epoch:  4.8194,  0.2668,  2.9281,  0.5498.
# Gloss, DE loss, IV loss, Vloss in 5100th epoch:  4.9177,  0.2735,  2.9137,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 5200th epoch:  4.9179,  0.2735,  2.9134,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 5300th epoch:  4.9179,  0.2735,  2.9132,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 5400th epoch:  4.9161,  0.2733,  2.9133,  0.5368.
# Gloss, DE loss, IV loss, Vloss in 5500th epoch:  4.9179,  0.2735,  2.9130,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 5600th epoch:  4.9179,  0.2735,  2.9128,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 5700th epoch:  4.9179,  0.2735,  2.9127,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 5800th epoch:  4.9166,  0.2736,  2.9115,  0.5367.
# Gloss, DE loss, IV loss, Vloss in 5900th epoch:  4.9153,  0.2734,  2.9128,  0.5368.
# Gloss, DE loss, IV loss, Vloss in 6000th epoch:  4.9180,  0.2735,  2.9125,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 6100th epoch:  4.9124,  0.2729,  2.9147,  0.5372.
# Gloss, DE loss, IV loss, Vloss in 6200th epoch:  4.9178,  0.2735,  2.9124,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 6300th epoch:  4.9179,  0.2735,  2.9123,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 6400th epoch:  4.9179,  0.2735,  2.9122,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 6500th epoch:  4.9232,  0.2738,  2.9119,  0.5360.
# Gloss, DE loss, IV loss, Vloss in 6600th epoch:  4.9179,  0.2735,  2.9121,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 6700th epoch:  4.9183,  0.2735,  2.9124,  0.5365.
# Gloss, DE loss, IV loss, Vloss in 6800th epoch:  4.9179,  0.2735,  2.9120,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 6900th epoch:  4.9179,  0.2735,  2.9120,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 7000th epoch:  4.9194,  0.2736,  2.9119,  0.5364.
# Gloss, DE loss, IV loss, Vloss in 7100th epoch:  4.9180,  0.2735,  2.9123,  0.5365.
# Gloss, DE loss, IV loss, Vloss in 7200th epoch:  4.9178,  0.2735,  2.9123,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 7300th epoch:  4.9179,  0.2736,  2.9118,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 7400th epoch:  4.8347,  0.2676,  2.9291,  0.5473.
# Gloss, DE loss, IV loss, Vloss in 7500th epoch:  4.9182,  0.2736,  2.9116,  0.5365.
# Gloss, DE loss, IV loss, Vloss in 7600th epoch:  4.9178,  0.2735,  2.9117,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 7700th epoch:  4.9179,  0.2736,  2.9115,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 7800th epoch:  4.9177,  0.2736,  2.9114,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 7900th epoch:  4.9169,  0.2736,  2.9107,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 8000th epoch:  4.9172,  0.2734,  2.9122,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 8100th epoch:  4.9174,  0.2736,  2.9101,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 8200th epoch:  4.9177,  0.2738,  2.9080,  0.5365.
# Gloss, DE loss, IV loss, Vloss in 8300th epoch:  4.9166,  0.2741,  2.9011,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 8400th epoch:  4.9140,  0.2745,  2.8646,  0.5366.
# Gloss, DE loss, IV loss, Vloss in 8500th epoch:  4.9177,  0.2862,  2.6981,  0.5347.
# Gloss, DE loss, IV loss, Vloss in 8600th epoch:  4.9167,  0.2833,  2.6462,  0.5348.
# Gloss, DE loss, IV loss, Vloss in 8700th epoch:  4.9176,  0.2827,  2.6427,  0.5347.
# Gloss, DE loss, IV loss, Vloss in 8800th epoch:  4.9175,  0.2827,  2.6413,  0.5347.
# Gloss, DE loss, IV loss, Vloss in 8900th epoch:  4.9282,  0.2795,  2.6518,  0.5340.
# Gloss, DE loss, IV loss, Vloss in 9000th epoch:  4.9175,  0.2826,  2.6408,  0.5347.
# Gloss, DE loss, IV loss, Vloss in 9100th epoch:  4.9173,  0.2826,  2.6400,  0.5347.
# Gloss, DE loss, IV loss, Vloss in 9200th epoch:  4.9177,  0.2825,  2.6420,  0.5346.
# Gloss, DE loss, IV loss, Vloss in 9300th epoch:  4.9173,  0.2826,  2.6401,  0.5346.
# Gloss, DE loss, IV loss, Vloss in 9400th epoch:  4.8920,  0.2784,  2.6483,  0.5381.
# Gloss, DE loss, IV loss, Vloss in 9500th epoch:  4.9174,  0.2825,  2.6400,  0.5346.
# Gloss, DE loss, IV loss, Vloss in 9600th epoch:  4.9171,  0.2826,  2.6391,  0.5346.
# Gloss, DE loss, IV loss, Vloss in 9700th epoch:  4.9175,  0.2823,  2.6408,  0.5346.
# Gloss, DE loss, IV loss, Vloss in 9800th epoch:  4.9172,  0.2825,  2.6394,  0.5346.
# Gloss, DE loss, IV loss, Vloss in 9900th epoch:  4.8989,  0.2839,  2.6420,  0.5367.

# %%
test_u = np.array([[np.log(0.9), np.log(0.9), 2/3, 4/3, 1, 1]])

test_t = np.arange(t0, tfinal + t_step, t_step)

print(test_u.shape)
print(test_t.shape)
# Out:
# (1, 6)
# (1001,)

# %%
[test_x, test_y] = model([test_u, test_t], training=True)

test_x = np.exp(test_x)
test_y = np.exp(test_y)

plt.plot(test_x, test_y)
