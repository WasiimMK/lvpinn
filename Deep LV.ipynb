# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt

# import pydot
# import graphviz
# import math
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator

import time
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 from pyDOE import lhs
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
tf.keras.backend.set_floatx('float64')

# %%
def rklv(constants, t_start, t_end, t_step_size) :
    
    [x0, y0, a, b, c, d] = constants
        
    def rk4(r, t, h):                    #edited; no need for input f
            """ Runge-Kutta 4 method """
            k1 = h*f(r, t)
            k2 = h*f(r+0.5*k1, t+0.5*h)
            k3 = h*f(r+0.5*k2, t+0.5*h)
            k4 = h*f(r+k3, t+h)
            return (k1 + 2*k2 + 2*k3 + k4)/6

    def f(r, t):
            x, y = r[0], r[1]
            fxd = a*x - b*x*y
            fyd = c*x*y - d*y
            return np.array([fxd, fyd], float)

    h = t_step_size                           
    tpoints = np.arange(t_start, t_end + h, h)        
    xpoints, ypoints  = [], []
    r = np.array([x0, y0], float)
    for t in tpoints:
            xpoints.append(r[0])         
            ypoints.append(r[1])         
            r += rk4(r, t, h)        
            
#     plt.plot(np.log(xpoints), np.log(ypoints))
#     plt.xlabel("x")
#     plt.ylabel("y")
#     plt.show()

    tarr = np.asarray(tpoints)
    xarr = np.asarray(xpoints)
    yarr = np.asarray(ypoints)

    points = np.vstack((tarr, xarr, yarr))

    return points

# %%
def define_collocation_points(t_bdry, N_points=100):

    colloc_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_points)

    return colloc_points

# %%
M = 6
N = 10
P = 100


t0 = 0.0
tfinal = 10.0
t_step = 0.01

# %%
def build_branch(num_layers = 4, num_units = 40, summary = False) :

    inp_br = b = tf.keras.layers.Input(shape = (M,), name = "Input_br")
    
    for i in range(num_layers) :
        
        b = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_br_" + str(i))(b)
        
    out_br = tf.keras.layers.Dense(p, activation = 'linear', name = "output_br")(b)
    
    model = tf.keras.models.Model(inp_br, out_br)
    
    if summary :
        
        model.summary()
        
    return model

# %%
# branch = build_branch(summary = True)
# tf.keras.utils.plot_model(branch, to_file = 'branch_net.png')

# %%
def build_trunk(num_layers = 4, num_units = 40, summary = False) :
    
    inp_tr = b = tf.keras.layers.Input(shape = (1,), name = "Input_tr")
    
    for i in range(num_layers) :
        
        b = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_tr_" + str(i))(b)
        
    out_tr = tf.keras.layers.Dense(p, activation = 'linear', name = "output_tr")(b)

    model = tf.keras.models.Model(inp_tr, out_tr)
    
    if summary :
        
        model.summary()
        
    return model

# %%
# trunk = build_trunk(summary = True)
# tf.keras.utils.plot_model(trunk, to_file = 'trunk_net.png')

# %%
def build_model(num_layers = 4, num_units = 60, summary = False) :
    
    inp_br = br = tf.keras.layers.Input(shape = (M,), name = "Input_br")
    
    for i in range(num_layers) :
        
        br = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_br_" + str(i))(br)
        
    out_br_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_x")(br)
    out_br_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_y")(br)
    
    
    inp_tr = tr = tf.keras.layers.Input(shape = (1,), name = "Input_tr")
    
    for i in range(num_layers) :
        
        tr = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_tr_" + str(i))(tr)
        
    out_tr_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_x")(tr)
    out_tr_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_y")(tr)

    mult_x = tf.keras.layers.Multiply(name = "multiply_x")([out_br_x, out_tr_x])
    mult_y = tf.keras.layers.Multiply(name = "multiply_y")([out_br_y, out_tr_y])
    
    out_x = tf.keras.layers.Dense(1, name = "output_x")(mult_x)
    out_y = tf.keras.layers.Dense(1, name = "output_y")(mult_y)
    
    model = tf.keras.models.Model([inp_br, inp_tr], [out_x, out_y])
    
    if summary :
        
        model.summary()
        
    return model

# %%
model = build_model(summary = True)
tf.keras.utils.plot_model(model, to_file = 'DeepOnet.png')
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_br (InputLayer)          [(None, 6)]          0           []
#
#  Input_tr (InputLayer)          [(None, 1)]          0           []
#
#  Hidden_br_0 (Dense)            (None, 60)           420         ['Input_br[0][0]']
#
#  Hidden_tr_0 (Dense)            (None, 60)           120         ['Input_tr[0][0]']
#
#  Hidden_br_1 (Dense)            (None, 60)           3660        ['Hidden_br_0[0][0]']
#
#  Hidden_tr_1 (Dense)            (None, 60)           3660        ['Hidden_tr_0[0][0]']
#
#  Hidden_br_2 (Dense)            (None, 60)           3660        ['Hidden_br_1[0][0]']
#
#  Hidden_tr_2 (Dense)            (None, 60)           3660        ['Hidden_tr_1[0][0]']
#
#  Hidden_br_3 (Dense)            (None, 60)           3660        ['Hidden_br_2[0][0]']
#
#  Hidden_tr_3 (Dense)            (None, 60)           3660        ['Hidden_tr_2[0][0]']
#
#  output_br_x (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_x (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  output_br_y (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_y (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  multiply_x (Multiply)          (None, 1)            0           ['output_br_x[0][0]',
#                                                                   'output_tr_x[0][0]']
#
#  multiply_y (Multiply)          (None, 1)            0           ['output_br_y[0][0]',
#                                                                   'output_tr_y[0][0]']
#
#  output_x (Dense)               (None, 1)            2           ['multiply_x[0][0]']
#
#  output_y (Dense)               (None, 1)            2           ['multiply_y[0][0]']
#
# ==================================================================================================
# Total params: 22,748
# Trainable params: 22,748
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
u_data = np.random.rand(N, M)

# %%
def clone_u_data (data) :
    
    new_data = np.zeros((N*P, M))
    
    for i in range(N) :
        
        data_row = data[i]
        
        cloned_data = np.tile(data_row, (P,1))
        
        new_data[i*P:(i + 1)*P, :] = cloned_data
        
    return new_data

# %%
def clone_t_data (data) :
    
    new_data = np.tile(data, (N,1))
    
    return new_data

# %%
print(u_data.shape)
u_data = clone_u_data(u_data)
print(u_data.shape)

u_train = u_data
# Out:
# (10, 6)
# (1000, 6)

# %%
colloc = define_collocation_points([t0, tfinal], P)
plt.plot(colloc[:,0], 0 * colloc[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
t_init = np.zeros((N*P, 1))

# %%
decimal_p = int((np.floor(np.log10(1/t_step))))
print(decimal_p)
# Out:
# 2

# %%
t_data = colloc
print(t_data.shape)
t_data = clone_t_data(t_data)
print(t_data.shape)

t_data = np.around(t_data, decimal_p)
t_train = t_data
# Out:
# (100, 1)
# (1000, 1)

# %%
true_data = np.zeros((N*P, 2))

for i in range(N*P) :
    
    u = u_train[i]
    t = t_train[i]
    
    sol_points = rklv(u, t0, tfinal, t_step)
    
    t_sol = sol_points[0]
    t_sol = np.around(t_sol, decimal_p)
    
    x_sol = sol_points[1]
    y_sol = sol_points[2]
    
    index = np.where(t_sol == t)
    
    true_data[i][0] = x_sol[index][0]
    true_data[i][1] = y_sol[index][0]

# %%
u_train[:, :2] = np.log(u_train[:, :2])
true_data = np.log(true_data)

# %%
# The main training function
@tf.function
def train_network(model, u, t, x_true, y_true, x_init, y_init, V, a, b, c, d, alpha, beta, gamma, delta):

    with tf.GradientTape() as tape1:

        with tf.GradientTape(persistent=True) as tape2:
            
            tape2.watch(t)
            [x, y] = model([u, t], training=True)
        

        xt = tape2.gradient(x, t)
        yt = tape2.gradient(y, t)
 
        Gloss = tf.reduce_mean(tf.square(x - x_true) + tf.square(y - y_true))
        
        eqn1 = xt - a + b*(tf.math.exp(y))
        eqn2 = yt - c*(tf.math.exp(x)) + d
        DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
        [x_init_pred, y_init_pred] = model([u, t_init], training=True)
        IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
        v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
        Vloss = tf.reduce_mean(tf.square(v - V))
        
        loss = alpha*Gloss + beta*DEloss + gamma*IVloss + delta*Vloss

    grads = tape1.gradient(loss, model.trainable_variables)
    
    return Gloss, DEloss, IVloss, Vloss, grads

# %%
def DeepONet_train(model, u, t, G_true, epochs, alpha_val, beta_val, gamma_val, delta_val):

    lr_model = 1e-3
    
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val
    delta = delta_val
    
    x_init = u[:, 0]
    y_init = u[:, 1]
    
    a = u[:, 2]
    b = u[:, 3]
    c = u[:, 4]
    d = u[:, 5]
    
    V = (c * (np.exp(x_init))) - (d * x_init) + (b * np.exp(y_init)) - (a * y_init)
      
    x_true = G_true[:, 0]
    y_true = G_true[:, 1]

    epoch_loss = np.zeros(epochs)
    
    opt = tf.keras.optimizers.Adam(lr_model)

    for i in range(epochs):

        Gloss, DEloss, IVloss, Vloss, grads = train_network(model, u, t, x_true, y_true, x_init, y_init, V, 
                                                            a, b, c, d, alpha, beta, gamma, delta)

        opt.apply_gradients(zip(grads, model.trainable_variables))
      
        epoch_loss[i] += alpha*Gloss + beta*DEloss + gamma*IVloss + delta*Vloss

    
        if (np.mod(i, 100)==0):
       
            print("Gloss, DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(
                i, Gloss, DEloss, IVloss, Vloss))

    return epoch_loss, model

# %%
alpha = 10
beta = 12
gamma = 1.2
delta = 100

epochs = 10000

# %%
model = build_model()

loss, model = DeepONet_train(model, u_train, t_train, true_data, epochs, alpha, beta, gamma, delta)
# Out:
# Gloss, DE loss, IV loss, Vloss in 0th epoch:  8.5799,  0.3968,  2.7946,  0.6073.
# Gloss, DE loss, IV loss, Vloss in 100th epoch:  7.1233,  0.3491,  1.0997,  0.0938.
# Gloss, DE loss, IV loss, Vloss in 200th epoch:  7.1150,  0.3464,  1.1223,  0.0926.
# Gloss, DE loss, IV loss, Vloss in 300th epoch:  7.1155,  0.3435,  1.1279,  0.0926.
# Gloss, DE loss, IV loss, Vloss in 400th epoch:  7.1157,  0.3423,  1.1300,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 500th epoch:  7.1159,  0.3415,  1.1303,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 600th epoch:  7.1161,  0.3408,  1.1302,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 700th epoch:  7.1163,  0.3400,  1.1300,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 800th epoch:  7.1166,  0.3392,  1.1297,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 900th epoch:  7.1169,  0.3384,  1.1294,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1000th epoch:  7.1172,  0.3376,  1.1291,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1100th epoch:  7.1175,  0.3368,  1.1289,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1200th epoch:  7.1161,  0.3361,  1.1290,  0.0927.
# Gloss, DE loss, IV loss, Vloss in 1300th epoch:  7.1182,  0.3356,  1.1289,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1400th epoch:  7.1184,  0.3349,  1.1288,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1500th epoch:  7.1185,  0.3343,  1.1288,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1600th epoch:  7.1187,  0.3338,  1.1289,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1700th epoch:  7.1188,  0.3334,  1.1290,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1800th epoch:  7.1188,  0.3331,  1.1292,  0.0925.
# Gloss, DE loss, IV loss, Vloss in 1900th epoch:  7.1188,  0.3330,  1.1293,  0.0925.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 3
#       1 model = build_model()
# ----> 3 loss, model = DeepONet_train(model, u_train, t_train, true_data, epochs, alpha, beta, gamma, delta)
#
# Cell In[78], line 32, in DeepONet_train(model, u, t, G_true, epochs, alpha_val, beta_val, gamma_val, delta_val)
#      27 for i in range(epochs):
#      29     Gloss, DEloss, IVloss, Vloss, grads = train_network(model, u, t, x_true, y_true, x_init, y_init, V,
#      30                                                         a, b, c, d, alpha, beta, gamma, delta)
# ---> 32     opt.apply_gradients(zip(grads, model.trainable_variables))
#      34     epoch_loss[i] += alpha*Gloss + beta*DEloss + gamma*IVloss + delta*Vloss
#      37     if (np.mod(i, 100)==0):
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1140, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1138 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1139     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1140 return super().apply_gradients(grads_and_vars, name=name)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:634, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     632 self._apply_weight_decay(trainable_variables)
#     633 grads_and_vars = list(zip(grads, trainable_variables))
# --> 634 iteration = self._internal_apply_gradients(grads_and_vars)
#     636 # Apply variable constraints after applying gradients.
#     637 for variable in trainable_variables:
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1166, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1165 def _internal_apply_gradients(self, grads_and_vars):
# -> 1166     return tf.__internal__.distribute.interim.maybe_merge_call(
#    1167         self._distributed_apply_gradients_fn,
#    1168         self._distribution_strategy,
#    1169         grads_and_vars,
#    1170     )
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribution_strategy_context.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1216, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1213         return self._update_step(grad, var)
#    1215 for grad, var in grads_and_vars:
# -> 1216     distribution.extended.update(
#    1217         var, apply_grad_to_update_var, args=(grad,), group=False
#    1218     )
#    1220 if self.use_ema:
#    1221     _, var_list = zip(*grads_and_vars)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2637, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2634   fn = autograph.tf_convert(
#    2635       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2636   with self._container_strategy().scope():
# -> 2637     return self._update(var, fn, args, kwargs, group)
#    2638 else:
#    2639   return self._replica_ctx_update(
#    2640       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3710, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    3707 def _update(self, var, fn, args, kwargs, group):
#    3708   # The implementations of _update() and _update_non_slot() are identical
#    3709   # except _update() passes `var` as the first argument to `fn()`.
# -> 3710   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3716, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    3712 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    3713   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    3714   # once that value is used for something.
#    3715   with UpdateContext(colocate_with):
# -> 3716     result = fn(*args, **kwargs)
#    3717     if should_group:
#    3718       return result
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1213, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1211     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1212 else:
# -> 1213     return self._update_step(grad, var)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:224, in _BaseOptimizer._update_step(self, gradient, variable)
#     215 if self._var_key(variable) not in self._index_dict:
#     216     raise KeyError(
#     217         f"The optimizer cannot recognize variable {variable.name}. "
#     218         "This usually means you are trying to call the optimizer to "
#    (...)
#     222         "`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     223     )
# --> 224 self.update_step(gradient, variable)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\adam.py:170, in Adam.update_step(self, gradient, variable)
#     167 m = self._momentums[self._index_dict[var_key]]
#     168 v = self._velocities[self._index_dict[var_key]]
# --> 170 alpha = lr * tf.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     172 if isinstance(gradient, tf.IndexedSlices):
#     173     # Sparse gradients.
#     174     m.assign_add(-m * (1 - self.beta_1))
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\math_ops.py:1442, in _OverrideBinaryOperatorHelper.<locals>.r_binary_op_wrapper(y, x)
#    1438 with ops.name_scope(None, op_name, [x, y]) as name:
#    1439   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1440   #   r_binary_op_wrapper use different force_same_dtype values.
#    1441   y, x = maybe_promote_tensors(y, x, force_same_dtype=True)
# -> 1442   return func(x, y, name=name)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\math_ops.py:548, in subtract(x, y, name)
#     544 @tf_export("math.subtract", "subtract")
#     545 @dispatch.register_binary_elementwise_api
#     546 @dispatch.add_dispatch_support
#     547 def subtract(x, y, name=None):
# --> 548   return gen_math_ops.sub(x, y, name)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:12391, in sub(x, y, name)
#   12389 if tld.is_eager:
#   12390   try:
# > 12391     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   12392       _ctx, "Sub", name, x, y)
#   12393     return _result
#   12394   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
test_u = np.array([[np.log(0.9), np.log(0.9), 2/3, 4/3, 1, 1]])

test_t = np.arange(t0, tfinal + t_step, t_step)

print(test_u.shape)
print(test_t.shape)

# %%
[test_x, test_y] = model([test_u, test_t], training=True)

test_x = np.exp(test_x)
test_y = np.exp(test_y)

plt.plot(test_x, test_y)
