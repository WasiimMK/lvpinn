# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt

# import pydot
# import graphviz
# import math
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator

import time
import random

# %%
tf.keras.backend.set_floatx('float64')

# %%
def rklv(constants, t_start, t_end, t_step_size) :
    
    [x0, y0, a, b, c, d] = constants
        
    def rk4(r, t, h):                    #edited; no need for input f
            """ Runge-Kutta 4 method """
            k1 = h*f(r, t)
            k2 = h*f(r+0.5*k1, t+0.5*h)
            k3 = h*f(r+0.5*k2, t+0.5*h)
            k4 = h*f(r+k3, t+h)
            return (k1 + 2*k2 + 2*k3 + k4)/6

    def f(r, t):
            x, y = r[0], r[1]
            fxd = a*x - b*x*y
            fyd = c*x*y - d*y
            return np.array([fxd, fyd], float)

    h = t_step_size                           
    tpoints = np.arange(t_start, t_end + h, h)        
    xpoints, ypoints  = [], []
    r = np.array([x0, y0], float)
    for t in tpoints:
            xpoints.append(r[0])         
            ypoints.append(r[1])         
            r += rk4(r, t, h)        
            
#     plt.plot(xpoints, ypoints)
#     plt.xlabel("x")
#     plt.ylabel("y")
#     plt.show()

    tarr = np.asarray(tpoints)
    xarr = np.asarray(xpoints)
    yarr = np.asarray(ypoints)

    points = np.vstack((tarr, xarr, yarr))

    return points

# %%
def define_collocation_points(t_bdry, N_points=100):

    colloc_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_points)

    return colloc_points

# %%
M = 6
N = 10
P = 100


t0 = 0.0
tfinal = 10.0
t_step = 0.01

# %%
def build_branch(num_layers = 4, num_units = 40, summary = False) :

    inp_br = b = tf.keras.layers.Input(shape = (M,), name = "Input_br")
    
    for i in range(num_layers) :
        
        b = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_br_" + str(i))(b)
        
    out_br = tf.keras.layers.Dense(p, activation = 'linear', name = "output_br")(b)
    
    model = tf.keras.models.Model(inp_br, out_br)
    
    if summary :
        
        model.summary()
        
    return model

# %%
# branch = build_branch(summary = True)
# tf.keras.utils.plot_model(branch, to_file = 'branch_net.png')

# %%
def build_trunk(num_layers = 4, num_units = 40, summary = False) :
    
    inp_tr = b = tf.keras.layers.Input(shape = (1,), name = "Input_tr")
    
    for i in range(num_layers) :
        
        b = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_tr_" + str(i))(b)
        
    out_tr = tf.keras.layers.Dense(p, activation = 'linear', name = "output_tr")(b)

    model = tf.keras.models.Model(inp_tr, out_tr)
    
    if summary :
        
        model.summary()
        
    return model

# %%
# trunk = build_trunk(summary = True)
# tf.keras.utils.plot_model(trunk, to_file = 'trunk_net.png')

# %%
def build_model(num_layers = 4, num_units = 60, summary = False) :
    
    inp_br_init = tf.keras.layers.Input(shape = (2,), name = "Input_br_init")
    inp_br_param = tf.keras.layers.Input(shape = (4,), name = "Input_br_param")
    
    br = tf.keras.layers.Concatenate()([inp_br_init, inp_br_param])
    
    for i in range(num_layers) :
        
        br = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_br_" + str(i))(br)
        
    out_br_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_x")(br)
    out_br_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_y")(br)
    
    
    inp_tr = tr = tf.keras.layers.Input(shape = (1,), name = "Input_tr")
    
    for i in range(num_layers) :
        
        tr = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_tr_" + str(i))(tr)
        
    out_tr_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_x")(tr)
    out_tr_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_y")(tr)

    mult_x = tf.keras.layers.Multiply(name = "multiply_x")([out_br_x, out_tr_x])
    mult_y = tf.keras.layers.Multiply(name = "multiply_y")([out_br_y, out_tr_y])
    
    out_x = tf.keras.layers.Dense(1, name = "output_x")(mult_x)
    out_y = tf.keras.layers.Dense(1, name = "output_y")(mult_y)
    
    model = tf.keras.models.Model([inp_br_init, inp_br_param, inp_tr], [out_x, out_y])
    
    if summary :
        
        model.summary()
        
    return model

# %%
model = build_model(summary = True)
tf.keras.utils.plot_model(model, to_file = 'DeepOnet.png')
# Out:
# Model: "model_41"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_br_init (InputLayer)     [(None, 2)]          0           []
#
#  Input_br_param (InputLayer)    [(None, 4)]          0           []
#
#  concatenate_43 (Concatenate)   (None, 6)            0           ['Input_br_init[0][0]',
#                                                                   'Input_br_param[0][0]']
#
#  Input_tr (InputLayer)          [(None, 1)]          0           []
#
#  Hidden_br_0 (Dense)            (None, 60)           420         ['concatenate_43[0][0]']
#
#  Hidden_tr_0 (Dense)            (None, 60)           120         ['Input_tr[0][0]']
#
#  Hidden_br_1 (Dense)            (None, 60)           3660        ['Hidden_br_0[0][0]']
#
#  Hidden_tr_1 (Dense)            (None, 60)           3660        ['Hidden_tr_0[0][0]']
#
#  Hidden_br_2 (Dense)            (None, 60)           3660        ['Hidden_br_1[0][0]']
#
#  Hidden_tr_2 (Dense)            (None, 60)           3660        ['Hidden_tr_1[0][0]']
#
#  Hidden_br_3 (Dense)            (None, 60)           3660        ['Hidden_br_2[0][0]']
#
#  Hidden_tr_3 (Dense)            (None, 60)           3660        ['Hidden_tr_2[0][0]']
#
#  output_br_x (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_x (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  output_br_y (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_y (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  multiply_x (Multiply)          (None, 1)            0           ['output_br_x[0][0]',
#                                                                   'output_tr_x[0][0]']
#
#  multiply_y (Multiply)          (None, 1)            0           ['output_br_y[0][0]',
#                                                                   'output_tr_y[0][0]']
#
#  output_x (Dense)               (None, 1)            2           ['multiply_x[0][0]']
#
#  output_y (Dense)               (None, 1)            2           ['multiply_y[0][0]']
#
# ==================================================================================================
# Total params: 22,748
# Trainable params: 22,748
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
u_data = np.random.rand(N, M)

# %%
print(u_data)
print(t)
# Out:
# [[0.82530493 0.70190139 0.35146847 0.06107092 0.30865573 0.27744365]
#  [0.92102829 0.94073629 0.04765056 0.46248871 0.54404979 0.86492878]
#  [0.78050648 0.37397897 0.36151301 0.16857043 0.40948046 0.66807807]
#  [0.10117977 0.08245493 0.34891169 0.18341569 0.27201411 0.07414033]
#  [0.95387795 0.51763864 0.99311089 0.16780554 0.37717272 0.1778516 ]
#  [0.30566399 0.47464085 0.92643062 0.31833818 0.52619781 0.30943884]
#  [0.56263719 0.09865498 0.92608874 0.77836303 0.37495055 0.33729425]
#  [0.52411013 0.37753127 0.71367152 0.27072948 0.96633992 0.17123281]
#  [0.55249345 0.2932286  0.65141716 0.31923516 0.66412074 0.14276763]
#  [0.53271079 0.40915416 0.38146661 0.9398552  0.75028998 0.98349305]]
# [1.93]

# %%
def clone_u_data (data) :
    
    new_data = np.zeros((N*P, M))
    
    for i in range(N) :
        
        data_row = data[i]
        
        cloned_data = np.tile(data_row, (P,1))
        
        new_data[i*P:(i + 1)*P, :] = cloned_data
        
    return new_data

# %%
def clone_t_data (data) :
    
    new_data = np.tile(data, (N,1))
    
    return new_data

# %%
print(u_data.shape)
u_data = clone_u_data(u_data)
print(u_data.shape)

u_train = u_data
# Out:
# (10, 6)
# (1000, 6)

# %%
colloc = define_collocation_points([t0, tfinal], P)
plt.plot(colloc[:,0], 0 * colloc[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
t_init = np.zeros((N*P, 1))

# %%
decimal_p = int((np.floor(np.log10(1/t_step))))
print(decimal_p)
# Out:
# 2

# %%
t_data = colloc
print(t_data.shape)
t_data = clone_t_data(t_data)
print(t_data.shape)

t_data = np.around(t_data, decimal_p)
t_train = t_data
# Out:
# (100, 1)
# (1000, 1)

# %%
true_data = np.zeros((N*P, 2))

for i in range(N*P) :
    
    u = u_train[i]
    t = t_train[i]
    
    sol_points = rklv(u, t0, tfinal, t_step)
    
    t_sol = sol_points[0]
    t_sol = np.around(t_sol, decimal_p)
    
    x_sol = sol_points[1]
    y_sol = sol_points[2]
    
    index = np.where(t_sol == t)
    
    true_data[i][0] = x_sol[index][0]
    true_data[i][1] = y_sol[index][0]

# %%
u_train[:, :2] = np.log(u_train[:, :2])
true_data = np.log(true_data)

# %%
# The main training function
@tf.function
def train_network(model, u_cond, u_param, t, x_true, y_true, x_init, y_init, V, a, b, c, d, alpha, beta, gamma, delta):

    with tf.GradientTape() as tape1:

        with tf.GradientTape(persistent=True) as tape2:
            
            tape2.watch(t)
            [x, y] = model([u_cond, u_param, t], training=True)
        

        xt = tape2.gradient(x, t)
        yt = tape2.gradient(y, t)
 
        Gloss = tf.reduce_mean(tf.square(x - x_true) + tf.square(y - y_true))
        
        eqn1 = xt - a + b*(tf.math.exp(y))
        eqn2 = yt - c*(tf.math.exp(x)) + d
        DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
        [x_init_pred, y_init_pred] = model([u_cond, u_param, t_init], training=True)
        IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
        v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
        Vloss = tf.reduce_mean(tf.square(v - V))
        
        loss = alpha*Gloss + beta*DEloss + gamma*IVloss + delta*Vloss

    grads = tape1.gradient(loss, model.trainable_variables)
    
    return Gloss, DEloss, IVloss, Vloss, grads

# %%
def DeepONet_train(model, u, t, G_true, epochs, alpha_val, beta_val, gamma_val, delta_val):

    lr_model = 1e-3
    
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val
    delta = delta_val
    
    u_cond = u[:, :2]
    u_param = u[:, 2:]
    
    x_init = u[:, 0].reshape(-1, 1)
    y_init = u[:, 1].reshape(-1, 1)
    
    a = u[:, 2].reshape(-1, 1)
    b = u[:, 3].reshape(-1, 1)
    c = u[:, 4].reshape(-1, 1)
    d = u[:, 5].reshape(-1, 1)
    
    V = (c * (np.exp(x_init))) - (d * x_init) + (b * np.exp(y_init)) - (a * y_init)
      
    x_true = G_true[:, 0].reshape(-1, 1)
    y_true = G_true[:, 1].reshape(-1, 1)
    
    print(u_cond.shape, u_param.shape, x_init.shape, y_init.shape, 
          a.shape, b.shape, c.shape, d.shape, V.shape, x_true.shape, y_true.shape)

    epoch_loss = np.zeros(epochs)
    
    opt = tf.keras.optimizers.Adam(lr_model)

    for i in range(epochs):

        Gloss, DEloss, IVloss, Vloss, grads = train_network(model, u_cond, u_param, t, x_true, y_true, x_init, y_init, V, 
                                                            a, b, c, d, alpha, beta, gamma, delta)

        opt.apply_gradients(zip(grads, model.trainable_variables))
      
        epoch_loss[i] += alpha*Gloss + beta*DEloss + gamma*IVloss + delta*Vloss

    
        if (np.mod(i, 100)==0):
       
            print("Gloss, DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(
                i, Gloss, DEloss, IVloss, Vloss))

    return epoch_loss, model

# %%
alpha = 0.0
beta = 1
gamma = 1
delta = 1

epochs = 10000

# %%
model = build_model()

loss, model = DeepONet_train(model, u_train, t_train, true_data, epochs, alpha, beta, gamma, delta)
# Out:
# (1000, 2) (1000, 4) (1000, 1) (1000, 1) (1000, 1) (1000, 1) (1000, 1) (1000, 1) (1000, 1) (1000, 1) (1000, 1)
# Gloss, DE loss, IV loss, Vloss in 0th epoch:  12.6566,  0.3652,  2.5187,  0.3793.
# Gloss, DE loss, IV loss, Vloss in 100th epoch:  13.4072,  0.3372,  0.0145,  0.0094.
# Gloss, DE loss, IV loss, Vloss in 200th epoch:  13.4124,  0.3320,  0.0120,  0.0090.
# Gloss, DE loss, IV loss, Vloss in 300th epoch:  13.4006,  0.3298,  0.0117,  0.0089.
# Gloss, DE loss, IV loss, Vloss in 400th epoch:  13.4019,  0.3283,  0.0116,  0.0090.
# Gloss, DE loss, IV loss, Vloss in 500th epoch:  13.4104,  0.3270,  0.0116,  0.0092.
# Gloss, DE loss, IV loss, Vloss in 600th epoch:  13.4222,  0.3258,  0.0117,  0.0093.
# Gloss, DE loss, IV loss, Vloss in 700th epoch:  13.4351,  0.3247,  0.0118,  0.0095.
# Gloss, DE loss, IV loss, Vloss in 800th epoch:  13.4482,  0.3236,  0.0119,  0.0097.
# Gloss, DE loss, IV loss, Vloss in 900th epoch:  13.4637,  0.3227,  0.0120,  0.0097.
# Gloss, DE loss, IV loss, Vloss in 1000th epoch:  13.4751,  0.3218,  0.0121,  0.0099.
# Gloss, DE loss, IV loss, Vloss in 1100th epoch:  13.4853,  0.3208,  0.0122,  0.0101.
# Gloss, DE loss, IV loss, Vloss in 1200th epoch:  13.4977,  0.3199,  0.0124,  0.0103.
# Gloss, DE loss, IV loss, Vloss in 1300th epoch:  13.5101,  0.3190,  0.0125,  0.0104.
# Gloss, DE loss, IV loss, Vloss in 1400th epoch:  13.5226,  0.3182,  0.0126,  0.0106.
# Gloss, DE loss, IV loss, Vloss in 1500th epoch:  13.5347,  0.3174,  0.0127,  0.0107.
# Gloss, DE loss, IV loss, Vloss in 1600th epoch:  13.5495,  0.3173,  0.0132,  0.0100.
# Gloss, DE loss, IV loss, Vloss in 1700th epoch:  13.5550,  0.3160,  0.0130,  0.0109.
# Gloss, DE loss, IV loss, Vloss in 1800th epoch:  13.5646,  0.3154,  0.0131,  0.0110.
# Gloss, DE loss, IV loss, Vloss in 1900th epoch:  13.5738,  0.3148,  0.0132,  0.0111.
# Gloss, DE loss, IV loss, Vloss in 2000th epoch:  13.5824,  0.3143,  0.0133,  0.0112.
# Gloss, DE loss, IV loss, Vloss in 2100th epoch:  13.5907,  0.3138,  0.0134,  0.0113.
# Gloss, DE loss, IV loss, Vloss in 2200th epoch:  13.6092,  0.3131,  0.0130,  0.0124.
# Gloss, DE loss, IV loss, Vloss in 2300th epoch:  13.6042,  0.3129,  0.0136,  0.0114.
# Gloss, DE loss, IV loss, Vloss in 2400th epoch:  13.6111,  0.3125,  0.0137,  0.0115.
# Gloss, DE loss, IV loss, Vloss in 2500th epoch:  13.6176,  0.3121,  0.0138,  0.0116.
# Gloss, DE loss, IV loss, Vloss in 2600th epoch:  13.6238,  0.3118,  0.0139,  0.0116.
# Gloss, DE loss, IV loss, Vloss in 2700th epoch:  13.6462,  0.3117,  0.0131,  0.0131.
# Gloss, DE loss, IV loss, Vloss in 2800th epoch:  13.6330,  0.3111,  0.0141,  0.0117.
# Gloss, DE loss, IV loss, Vloss in 2900th epoch:  13.6391,  0.3108,  0.0141,  0.0118.
# Gloss, DE loss, IV loss, Vloss in 3000th epoch:  13.6442,  0.3105,  0.0142,  0.0118.
# Gloss, DE loss, IV loss, Vloss in 3100th epoch:  13.6491,  0.3102,  0.0143,  0.0119.
# Gloss, DE loss, IV loss, Vloss in 3200th epoch:  13.6539,  0.3099,  0.0144,  0.0119.
# Gloss, DE loss, IV loss, Vloss in 3300th epoch:  13.6258,  0.3096,  0.0147,  0.0119.
# Gloss, DE loss, IV loss, Vloss in 3400th epoch:  13.6620,  0.3095,  0.0145,  0.0120.
# Gloss, DE loss, IV loss, Vloss in 3500th epoch:  13.6662,  0.3092,  0.0145,  0.0120.
# Gloss, DE loss, IV loss, Vloss in 3600th epoch:  13.6704,  0.3090,  0.0146,  0.0121.
# Gloss, DE loss, IV loss, Vloss in 3700th epoch:  13.6747,  0.3087,  0.0147,  0.0121.
# Gloss, DE loss, IV loss, Vloss in 3800th epoch:  13.6807,  0.3085,  0.0147,  0.0122.
# Gloss, DE loss, IV loss, Vloss in 3900th epoch:  13.6807,  0.3082,  0.0149,  0.0121.
# Gloss, DE loss, IV loss, Vloss in 4000th epoch:  13.6867,  0.3080,  0.0148,  0.0122.
# Gloss, DE loss, IV loss, Vloss in 4100th epoch:  13.6919,  0.3076,  0.0149,  0.0122.
# Gloss, DE loss, IV loss, Vloss in 4200th epoch:  13.7022,  0.3065,  0.0150,  0.0122.
# Gloss, DE loss, IV loss, Vloss in 4300th epoch:  13.7214,  0.3040,  0.0152,  0.0121.
# Gloss, DE loss, IV loss, Vloss in 4400th epoch:  13.8927,  0.2824,  0.0174,  0.0117.
# Gloss, DE loss, IV loss, Vloss in 4500th epoch:  14.4125,  0.2393,  0.0285,  0.0171.
# Gloss, DE loss, IV loss, Vloss in 4600th epoch:  14.7277,  0.2166,  0.0364,  0.0211.
# Gloss, DE loss, IV loss, Vloss in 4700th epoch:  14.7837,  0.2137,  0.0379,  0.0219.
# Gloss, DE loss, IV loss, Vloss in 4800th epoch:  14.8032,  0.2128,  0.0384,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 4900th epoch:  14.8236,  0.2119,  0.0389,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 5000th epoch:  14.8456,  0.2109,  0.0395,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 5100th epoch:  14.8698,  0.2099,  0.0401,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 5200th epoch:  14.8963,  0.2087,  0.0407,  0.0221.
# Gloss, DE loss, IV loss, Vloss in 5300th epoch:  14.9257,  0.2076,  0.0415,  0.0221.
# Gloss, DE loss, IV loss, Vloss in 5400th epoch:  14.9583,  0.2063,  0.0422,  0.0221.
# Gloss, DE loss, IV loss, Vloss in 5500th epoch:  14.9946,  0.2049,  0.0431,  0.0221.
# Gloss, DE loss, IV loss, Vloss in 5600th epoch:  15.0394,  0.2036,  0.0451,  0.0223.
# Gloss, DE loss, IV loss, Vloss in 5700th epoch:  15.0763,  0.2021,  0.0449,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 5800th epoch:  15.1203,  0.2006,  0.0459,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 5900th epoch:  15.1694,  0.1991,  0.0469,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 6000th epoch:  15.2222,  0.1976,  0.0480,  0.0219.
# Gloss, DE loss, IV loss, Vloss in 6100th epoch:  15.2727,  0.1961,  0.0490,  0.0219.
# Gloss, DE loss, IV loss, Vloss in 6200th epoch:  15.3316,  0.1947,  0.0500,  0.0218.
# Gloss, DE loss, IV loss, Vloss in 6300th epoch:  15.3848,  0.1935,  0.0509,  0.0218.
# Gloss, DE loss, IV loss, Vloss in 6400th epoch:  15.4473,  0.1928,  0.0515,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 6500th epoch:  15.4751,  0.1916,  0.0522,  0.0217.
# Gloss, DE loss, IV loss, Vloss in 6600th epoch:  15.5206,  0.1912,  0.0527,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 6700th epoch:  15.5366,  0.1906,  0.0530,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 6800th epoch:  15.5439,  0.1904,  0.0532,  0.0217.
# Gloss, DE loss, IV loss, Vloss in 6900th epoch:  15.4954,  0.1905,  0.0530,  0.0220.
# Gloss, DE loss, IV loss, Vloss in 7000th epoch:  15.5523,  0.1907,  0.0532,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 7100th epoch:  15.5733,  0.1907,  0.0532,  0.0213.
# Gloss, DE loss, IV loss, Vloss in 7200th epoch:  15.5254,  0.1905,  0.0531,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 7300th epoch:  15.6019,  0.1898,  0.0538,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 7400th epoch:  15.5970,  0.1898,  0.0538,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 7500th epoch:  15.6044,  0.1897,  0.0538,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 7600th epoch:  15.5623,  0.1903,  0.0544,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 7700th epoch:  15.5694,  0.1900,  0.0536,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 7800th epoch:  15.6172,  0.1898,  0.0538,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 7900th epoch:  15.5893,  0.1897,  0.0537,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 8000th epoch:  15.5810,  0.1899,  0.0538,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 8100th epoch:  15.5889,  0.1898,  0.0537,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 8200th epoch:  15.6009,  0.1897,  0.0538,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 8300th epoch:  15.5801,  0.1897,  0.0536,  0.0217.
# Gloss, DE loss, IV loss, Vloss in 8400th epoch:  15.5943,  0.1897,  0.0537,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 8500th epoch:  15.5854,  0.1899,  0.0536,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 8600th epoch:  15.5242,  0.1897,  0.0536,  0.0223.
# Gloss, DE loss, IV loss, Vloss in 8700th epoch:  15.5578,  0.1902,  0.0537,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 8800th epoch:  15.5997,  0.1897,  0.0537,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 8900th epoch:  15.5919,  0.1899,  0.0535,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 9000th epoch:  15.5950,  0.1900,  0.0538,  0.0217.
# Gloss, DE loss, IV loss, Vloss in 9100th epoch:  15.4563,  0.1905,  0.0563,  0.0223.
# Gloss, DE loss, IV loss, Vloss in 9200th epoch:  15.5930,  0.1897,  0.0536,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 9300th epoch:  15.6290,  0.1900,  0.0537,  0.0214.
# Gloss, DE loss, IV loss, Vloss in 9400th epoch:  15.5932,  0.1897,  0.0536,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 9500th epoch:  15.5880,  0.1897,  0.0536,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 9600th epoch:  15.5924,  0.1897,  0.0536,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 9700th epoch:  15.5926,  0.1897,  0.0536,  0.0216.
# Gloss, DE loss, IV loss, Vloss in 9800th epoch:  15.5913,  0.1898,  0.0536,  0.0215.
# Gloss, DE loss, IV loss, Vloss in 9900th epoch:  15.6098,  0.1900,  0.0538,  0.0215.

# %%
test_u = np.array([0.9, 0.9, 2/3, 4/3, 1, 1])

sol = rklv(test_u, t0, tfinal, t_step)
x_sol = sol[1]
y_sol = sol[2]

test_u_cond = np.log(test_u[:2]).reshape(1, -1)
test_u_param = test_u[2:].reshape(1, -1)
test_t = np.arange(0, tfinal + t_step, t_step).reshape(-1, 1)

print(test_u_cond.shape)
print(test_u_param.shape)
print(test_t.shape)
# Out:
# (1, 2)
# (1, 4)
# (1001, 1)

# %%
[test_x, test_y] = model([test_u_cond, test_u_param, test_t], training=True)

test_x = np.exp(test_x)
test_y = np.exp(test_y)

plt.figure()
plt.plot(test_x, test_y)
plt.plot(x_sol, y_sol)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[629], line 1
# ----> 1 [test_x, test_y] = model([test_u_cond, test_u_param, test_t], training=True)
#       3 test_x = np.exp(test_x)
#       4 test_y = np.exp(test_y)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\engine\input_spec.py:250, in assert_input_compatibility(input_spec, inputs, layer_name)
#     248     ndim = x.shape.rank
#     249     if ndim is not None and ndim < spec.min_ndim:
# --> 250         raise ValueError(
#     251             f'Input {input_index} of layer "{layer_name}" '
#     252             "is incompatible with the layer: "
#     253             f"expected min_ndim={spec.min_ndim}, "
#     254             f"found ndim={ndim}. "
#     255             f"Full shape received: {tuple(shape)}"
#     256         )
#     257 # Check dtype.
#     258 if spec.dtype is not None:
#
# ValueError: Exception encountered when calling layer 'model_42' (type Functional).
#
# Input 0 of layer "Hidden_br_0" is incompatible with the layer: expected min_ndim=2, found ndim=1. Full shape received: (6,)
#
# Call arguments received by layer 'model_42' (type Functional):
#   • inputs=['tf.Tensor(shape=(2,), dtype=float64)', 'tf.Tensor(shape=(4,), dtype=float64)', 'tf.Tensor(shape=(1001,), dtype=float64)']
#   • training=True
#   • mask=None
