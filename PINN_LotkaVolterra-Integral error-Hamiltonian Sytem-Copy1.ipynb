# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11596280045614734732
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 24

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 24 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
#model = build_model(summary = True)

# %%
#tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 200)

# %%
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(odes, inits, model, gamma, epsilon):

    # DE collocation points
    t_de = odes[:,:1]
    t_de = de_points_tensor

    # Initial value points
    t_init, x_init, y_init = inits[:1], inits[1:2], inits[2:]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
      
      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
      Vloss = tf.math.reduce_mean(tf.square(tf.boolean_mask(v, tf.math.is_finite(v))) - v0)
    
      # Composite loss function
      loss = 12*DEloss + gamma*IVloss + epsilon*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val):

  # Total number of collocation points
  N_de = len(de_points)

  # Batch size
  bs_de = N_de//10

  # Weight factors
  gamma = gamma_val
  epsilon = epsilon_val

  # Learning rate
  lr_model = 1e-3

  # Initial value
  t_init = np.array([t0]).astype(np.float32)
  x_init = np.array([x0]).astype(np.float32)
  y_init = np.array([y0]).astype(np.float32)

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Generate the tf.Dataset for the initial collocation points
  inits = np.column_stack([t_init, x_init, y_init])
  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache()


  # Generate the tf.Dataset for the differential equations points
  ds_ode = tf.data.Dataset.from_tensor_slices(de_points.astype(np.float32))
  ds_ode = ds_ode.cache().shuffle(N_de).batch(bs_de)

  # Generate entire dataset
  ds = tf.data.Dataset.zip((ds_ode, ds_init))

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  # Generate the model
  opt = tf.keras.optimizers.Adam(lr_model)
  model = build_model() 

  # Main training loop
  for i in range(epochs):

    # Training for that epoch
    for (des, inits) in ds:

      # Train the network
      DEloss, IVloss, Vloss, grads = train_network(des, inits, model, gamma, epsilon)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))
      
      epoch_loss[i] += DEloss + gamma*IVloss + epsilon*Vloss
      nr_batches = nr_batches + 1

    # Get total epoch loss
    epoch_loss[i] = epoch_loss[i]/nr_batches
    nr_batches = 0

    
    if (np.mod(i, 100)==0):
      print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

  return epoch_loss, model

# %%
error_dict = {}

# %%
def train_plot(epochs, gamma, epsilon) :
    
    loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon)
    
    # Grid where to evaluate the model
    step_size = 0.005
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.plot(loss)

    # Model prediction
    [x, y] = model(t)
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", gamma = " + str(gamma) + ", epsilon = " + str(epsilon))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)  
      
    plt.figure(3)
    
    plt.scatter(epochs, error)
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x)
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y)

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 10000

train_plot(epochs, 1.2, 0.000001)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_246/Tanh:0', description="created by layer 'dense_246'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_247/Tanh:0', description="created by layer 'dense_247'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_248/Tanh:0', description="created by layer 'dense_248'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_249/Tanh:0', description="created by layer 'dense_249'")
# DE loss, IV loss, Vloss in 0th epoch:  0.6672,  0.2029,  3.4929.
# DE loss, IV loss, Vloss in 100th epoch:  0.0070,  0.1097,  2.2766.
# DE loss, IV loss, Vloss in 200th epoch:  0.0061,  0.0621,  2.2747.
# DE loss, IV loss, Vloss in 300th epoch:  0.0066,  0.0477,  2.2779.
# DE loss, IV loss, Vloss in 400th epoch:  0.0065,  0.0443,  2.2792.
# DE loss, IV loss, Vloss in 500th epoch:  0.0066,  0.0424,  2.2797.
# DE loss, IV loss, Vloss in 600th epoch:  0.0065,  0.0410,  2.2800.
# DE loss, IV loss, Vloss in 700th epoch:  0.0065,  0.0395,  2.2802.
# DE loss, IV loss, Vloss in 800th epoch:  0.0064,  0.0373,  2.2803.
# DE loss, IV loss, Vloss in 900th epoch:  0.0058,  0.0317,  2.2794.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0044,  0.0171,  2.2769.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0034,  0.0089,  2.2781.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0023,  0.0038,  2.2951.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0020,  0.0022,  2.3071.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0018,  0.0017,  2.3131.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0016,  0.0014,  2.3193.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0015,  0.0012,  2.3246.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0015,  0.0010,  2.3299.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0014,  0.0009,  2.3340.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0014,  0.0008,  2.3373.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0014,  0.0008,  2.3396.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0013,  0.0008,  2.3414.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0013,  0.0007,  2.3429.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0013,  0.0007,  2.3440.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0013,  0.0007,  2.3454.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0013,  0.0008,  2.3466.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0012,  0.0006,  2.3482.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0012,  0.0006,  2.3499.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0012,  0.0007,  2.3518.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0011,  0.0006,  2.3547.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0011,  0.0005,  2.3577.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0011,  0.0005,  2.3609.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0011,  0.0004,  2.3648.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0010,  0.0004,  2.3685.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0010,  0.0008,  2.3720.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0010,  0.0004,  2.3756.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0010,  0.0007,  2.3774.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0009,  0.0003,  2.3809.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0009,  0.0004,  2.3833.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0009,  0.0005,  2.3853.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0009,  0.0003,  2.3882.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0009,  0.0002,  2.3903.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0009,  0.0004,  2.3921.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0009,  0.0003,  2.3941.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0009,  0.0003,  2.3957.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0009,  0.0003,  2.3971.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0008,  0.0003,  2.3982.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0009,  0.0005,  2.3994.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0008,  0.0003,  2.4001.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0008,  0.0003,  2.4013.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0008,  0.0002,  2.4020.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0008,  0.0002,  2.4030.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0009,  0.0009,  2.4027.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0008,  0.0003,  2.4046.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0008,  0.0002,  2.4055.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0008,  0.0003,  2.4062.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0008,  0.0002,  2.4073.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0008,  0.0002,  2.4083.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0008,  0.0002,  2.4094.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0008,  0.0003,  2.4108.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0008,  0.0007,  2.4109.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0008,  0.0002,  2.4131.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0008,  0.0009,  2.4133.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0009,  0.0011,  2.4167.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0007,  0.0002,  2.4175.
# DE loss, IV loss, Vloss in 6500th epoch:  0.0007,  0.0002,  2.4190.
# DE loss, IV loss, Vloss in 6600th epoch:  0.0007,  0.0002,  2.4212.
# DE loss, IV loss, Vloss in 6700th epoch:  0.0007,  0.0002,  2.4230.
# DE loss, IV loss, Vloss in 6800th epoch:  0.0008,  0.0007,  2.4236.
# DE loss, IV loss, Vloss in 6900th epoch:  0.0007,  0.0002,  2.4268.
# DE loss, IV loss, Vloss in 7000th epoch:  0.0007,  0.0002,  2.4287.
# DE loss, IV loss, Vloss in 7100th epoch:  0.0007,  0.0002,  2.4308.
# DE loss, IV loss, Vloss in 7200th epoch:  0.0008,  0.0001,  2.4334.
# DE loss, IV loss, Vloss in 7300th epoch:  0.0007,  0.0002,  2.4352.
# DE loss, IV loss, Vloss in 7400th epoch:  0.0007,  0.0002,  2.4373.
# DE loss, IV loss, Vloss in 7500th epoch:  0.0007,  0.0002,  2.4395.
# DE loss, IV loss, Vloss in 7600th epoch:  0.0012,  0.0036,  2.4397.
# DE loss, IV loss, Vloss in 7700th epoch:  0.0006,  0.0002,  2.4436.
# DE loss, IV loss, Vloss in 7800th epoch:  0.0006,  0.0001,  2.4458.
# DE loss, IV loss, Vloss in 7900th epoch:  0.0006,  0.0002,  2.4481.
# DE loss, IV loss, Vloss in 8000th epoch:  0.0006,  0.0002,  2.4500.
# DE loss, IV loss, Vloss in 8100th epoch:  0.0006,  0.0001,  2.4525.
# DE loss, IV loss, Vloss in 8200th epoch:  0.0006,  0.0001,  2.4550.
# DE loss, IV loss, Vloss in 8300th epoch:  0.0006,  0.0001,  2.4573.
# DE loss, IV loss, Vloss in 8400th epoch:  0.0006,  0.0001,  2.4600.
# DE loss, IV loss, Vloss in 8500th epoch:  0.0006,  0.0001,  2.4630.
# DE loss, IV loss, Vloss in 8600th epoch:  0.0006,  0.0001,  2.4656.
# DE loss, IV loss, Vloss in 8700th epoch:  0.0006,  0.0001,  2.4689.
# DE loss, IV loss, Vloss in 8800th epoch:  0.0006,  0.0001,  2.4725.
# DE loss, IV loss, Vloss in 8900th epoch:  0.0006,  0.0000,  2.4766.
# DE loss, IV loss, Vloss in 9000th epoch:  0.0005,  0.0001,  2.4796.
# DE loss, IV loss, Vloss in 9100th epoch:  0.0005,  0.0001,  2.4839.
# DE loss, IV loss, Vloss in 9200th epoch:  0.0005,  0.0001,  2.4874.
# DE loss, IV loss, Vloss in 9300th epoch:  0.0005,  0.0002,  2.4913.
# DE loss, IV loss, Vloss in 9400th epoch:  0.0005,  0.0000,  2.4970.
# DE loss, IV loss, Vloss in 9500th epoch:  0.0005,  0.0001,  2.5020.
# DE loss, IV loss, Vloss in 9600th epoch:  0.0005,  0.0001,  2.5075.
# DE loss, IV loss, Vloss in 9700th epoch:  0.0004,  0.0001,  2.5144.
# DE loss, IV loss, Vloss in 9800th epoch:  0.0004,  0.0001,  2.5220.
# DE loss, IV loss, Vloss in 9900th epoch:  0.0004,  0.0001,  2.5299.
# 4800

# %%
end = time.time()

print((end-start)/60)
# Out:
# 3.5393736084302265

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma
