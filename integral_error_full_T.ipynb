# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11758664948059405551
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = 0.9, 0.9


# Boundaries of the computational domain
t0, tfinal = 0.0, 12

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * x0) - (d * np.log(x0)) + (b * y0) - (a * np.log(y0))
print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 12 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
#model = build_model(summary = True)

# %%
#tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 100)
print(de_points)
# Out:
# [[7.69008310e+00]
#  [5.17676238e+00]
#  [7.21649416e+00]
#  [1.10307096e+01]
#  [8.49826418e+00]
#  [1.81274581e+00]
#  [2.66714410e+00]
#  [1.00538389e+01]
#  [4.47388989e+00]
#  [3.06502542e+00]
#  [2.15476027e+00]
#  [1.25240721e+00]
#  [1.19048304e+01]
#  [3.81098465e-01]
#  [1.04209351e+00]
#  [4.04241033e+00]
#  [5.86862133e-01]
#  [1.45958951e+00]
#  [6.81031723e+00]
#  [6.19253394e+00]
#  [4.71518777e+00]
#  [9.63130136e+00]
#  [2.30595286e-01]
#  [8.97615131e+00]
#  [8.56733281e+00]
#  [1.18112600e+01]
#  [6.54702756e+00]
#  [1.07555813e+01]
#  [1.02655479e+01]
#  [1.39783102e+00]
#  [5.34449484e+00]
#  [6.85814038e+00]
#  [8.26205345e+00]
#  [7.05920016e+00]
#  [4.66484446e+00]
#  [8.32017411e+00]
#  [9.78030067e+00]
#  [6.35934671e+00]
#  [1.11177530e+01]
#  [1.14347707e+00]
#  [9.91932624e+00]
#  [6.01525329e+00]
#  [3.45036172e+00]
#  [1.04251055e+01]
#  [2.00550129e+00]
#  [7.46522021e+00]
#  [4.86338245e+00]
#  [1.05621029e+01]
#  [5.48367481e+00]
#  [8.65385237e+00]
#  [8.07358096e+00]
#  [1.12131295e+01]
#  [1.08027461e+01]
#  [7.83702622e+00]
#  [3.28547219e+00]
#  [1.05272061e+01]
#  [2.61290025e-01]
#  [4.94560519e+00]
#  [1.13008637e+01]
#  [9.38223500e+00]
#  [9.74321184e-04]
#  [2.60493035e+00]
#  [4.13993685e+00]
#  [2.34814311e+00]
#  [1.17047085e+01]
#  [4.26209070e+00]
#  [7.43463820e+00]
#  [3.90060265e+00]
#  [7.61246230e+00]
#  [4.39616289e+00]
#  [1.01701851e+01]
#  [9.38628918e-01]
#  [9.29518386e+00]
#  [5.56859132e+00]
#  [3.78254849e+00]
#  [7.96043015e+00]
#  [1.70651946e+00]
#  [6.67487781e+00]
#  [9.14847738e+00]
#  [3.66318065e+00]
#  [2.81357658e+00]
#  [2.19004548e+00]
#  [7.76590864e-01]
#  [5.83001036e+00]
#  [6.91049258e-01]
#  [1.57574964e+00]
#  [5.64056499e+00]
#  [5.14062169e+00]
#  [2.94652651e+00]
#  [8.82337312e+00]
#  [9.52906265e+00]
#  [5.93171041e+00]
#  [3.53134954e+00]
#  [9.04048477e+00]
#  [1.15892774e+01]
#  [2.42060458e+00]
#  [6.43005598e+00]
#  [1.14192932e+01]
#  [3.13427451e+00]
#  [7.13149746e+00]]

# %%
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(odes, inits, model, gamma, epsilon):

    # DE collocation points
    #t_de = odes[:,:1]
    
    #t_de = tf.random.uniform(shape=[300, 1], minval=0, maxval=tfinal, dtype=tf.float32)
    t_de = de_points_tensor
    

    # Initial value points
    t_init, x_init, y_init = inits[:1], inits[1:2], inits[2:]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        
        
        V = (c * (tf.math.exp(model(t_de, training=True)[0]))) - (d * model(t_de, training=True)[0]) + (b * tf.math.exp(model(t_de, training=True)[1])) - (a * model(t_de, training=True)[1])

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
        

      # Define the differential equation loss  
      eqn1 = xt - (a*x - b*x*y)
      eqn2 = yt - (c*x*y - d*y)
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
      #Implicit integration loss
      v = (c * x) - (d * tf.math.log(x)) + (b * y) - (a * tf.math.log(y))
    
      Vloss = tf.square(tf.reduce_mean(tf.boolean_mask(v, tf.math.is_finite(v))) - v0)         
    
      # Composite loss function
      loss = 12*DEloss + gamma*IVloss + epsilon*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val):

  # Total number of collocation points
  N_de = len(de_points)

  # Batch size
  bs_de = N_de//10

  # Weight factors
  gamma = gamma_val
  epsilon = epsilon_val

  # Learning rate
  lr_model = 1e-3

  # Initial value
  t_init = np.array([t0]).astype(np.float32)
  x_init = np.array([x0]).astype(np.float32)
  y_init = np.array([y0]).astype(np.float32)

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Generate the tf.Dataset for the initial collocation points
  inits = np.column_stack([t_init, x_init, y_init])
  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache()


  # Generate the tf.Dataset for the differential equations points
  ds_ode = tf.data.Dataset.from_tensor_slices(de_points.astype(np.float32))
  ds_ode = ds_ode.cache().shuffle(N_de).batch(bs_de)

  # Generate entire dataset
  ds = tf.data.Dataset.zip((ds_ode, ds_init))

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  # Generate the model
  opt = tf.keras.optimizers.Adam(lr_model)
  model = build_model() 

  # Main training loop
  for i in range(epochs):

    # Training for that epoch
    for (des, inits) in ds:

      # Train the network
      DEloss, IVloss, Vloss, grads = train_network(des, inits, model, gamma, epsilon)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))
      
      epoch_loss[i] += DEloss + gamma*IVloss + epsilon*Vloss
      nr_batches = nr_batches + 1

    # Get total epoch loss
    epoch_loss[i] = epoch_loss[i]/nr_batches
    nr_batches = 0

    
    if (np.mod(i, 100)==0):
      print("Dloss, Iloss, Closs in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

  return epoch_loss, model

# %%
error_dict = {}

def train_plot(epochs, gamma, epsilon) :


    loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon)
    
    # Grid where to evaluate the model
    step_size = 0.005
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.semilogy(loss)

    # Model prediction
    [x, y] = model(t)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)

    if epsilon in error_dict.keys() :
        
        error_dict[epsilon] = error_dict[epsilon] + error
        
    else :
        
        error_dict[epsilon] = error
        
        
    plt.figure(3)
    plt.xscale('symlog', linthresh = 0.0001)
    plt.scatter(epsilon, error)
    plt.xlabel("epoch number")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x)
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y)
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 15000


train_plot(epochs, 1.2, 0.001)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_66/Tanh:0', description="created by layer 'dense_66'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_67/Tanh:0', description="created by layer 'dense_67'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_68/Tanh:0', description="created by layer 'dense_68'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_69/Tanh:0', description="created by layer 'dense_69'")
# Dloss, Iloss, Closs in 0th epoch:  0.0239,  2.0467,    nan.
# Dloss, Iloss, Closs in 100th epoch:  0.0262,  0.0304,  0.2472.
# Dloss, Iloss, Closs in 200th epoch:  0.0256,  0.0292,  0.3100.
# Dloss, Iloss, Closs in 300th epoch:  0.0222,  0.0194,  0.4338.
# Dloss, Iloss, Closs in 400th epoch:  0.0047,  0.0513,  0.0186.
# Dloss, Iloss, Closs in 500th epoch:  0.0037,  0.0201,  0.0178.
# Dloss, Iloss, Closs in 600th epoch:  0.0031,  0.0125,  0.0176.
# Dloss, Iloss, Closs in 700th epoch:  0.0027,  0.0075,  0.0166.
# Dloss, Iloss, Closs in 800th epoch:  0.0023,  0.0049,  0.0154.
# Dloss, Iloss, Closs in 900th epoch:  0.0021,  0.0033,  0.0144.
# Dloss, Iloss, Closs in 1000th epoch:  0.0019,  0.0025,  0.0140.
# Dloss, Iloss, Closs in 1100th epoch:  0.0018,  0.0020,  0.0139.
# Dloss, Iloss, Closs in 1200th epoch:  0.0017,  0.0016,  0.0137.
# Dloss, Iloss, Closs in 1300th epoch:  0.0016,  0.0014,  0.0136.
# Dloss, Iloss, Closs in 1400th epoch:  0.0015,  0.0012,  0.0136.
# Dloss, Iloss, Closs in 1500th epoch:  0.0015,  0.0011,  0.0135.
# Dloss, Iloss, Closs in 1600th epoch:  0.0015,  0.0010,  0.0134.
# Dloss, Iloss, Closs in 1700th epoch:  0.0014,  0.0010,  0.0134.
# Dloss, Iloss, Closs in 1800th epoch:  0.0014,  0.0009,  0.0133.
# Dloss, Iloss, Closs in 1900th epoch:  0.0014,  0.0009,  0.0132.
# Dloss, Iloss, Closs in 2000th epoch:  0.0013,  0.0008,  0.0131.
# Dloss, Iloss, Closs in 2100th epoch:  0.0019,  0.0009,  0.0130.
# Dloss, Iloss, Closs in 2200th epoch:  0.0012,  0.0007,  0.0127.
# Dloss, Iloss, Closs in 2300th epoch:  0.0012,  0.0007,  0.0125.
# Dloss, Iloss, Closs in 2400th epoch:  0.0011,  0.0006,  0.0123.
# Dloss, Iloss, Closs in 2500th epoch:  0.0011,  0.0006,  0.0119.
# Dloss, Iloss, Closs in 2600th epoch:  0.0010,  0.0005,  0.0116.
# Dloss, Iloss, Closs in 2700th epoch:  0.0010,  0.0005,  0.0113.
# Dloss, Iloss, Closs in 2800th epoch:  0.0009,  0.0004,  0.0110.
# Dloss, Iloss, Closs in 2900th epoch:  0.0009,  0.0004,  0.0107.
# Dloss, Iloss, Closs in 3000th epoch:  0.0010,  0.0003,  0.0105.
# Dloss, Iloss, Closs in 3100th epoch:  0.0008,  0.0003,  0.0102.
# Dloss, Iloss, Closs in 3200th epoch:  0.0008,  0.0003,  0.0098.
# Dloss, Iloss, Closs in 3300th epoch:  0.0007,  0.0003,  0.0095.
# Dloss, Iloss, Closs in 3400th epoch:  0.0007,  0.0003,  0.0090.
# Dloss, Iloss, Closs in 3500th epoch:  0.0006,  0.0002,  0.0083.
# Dloss, Iloss, Closs in 3600th epoch:  0.0005,  0.0002,  0.0076.
# Dloss, Iloss, Closs in 3700th epoch:  0.0004,  0.0002,  0.0065.
# Dloss, Iloss, Closs in 3800th epoch:  0.0003,  0.0001,  0.0054.
# Dloss, Iloss, Closs in 3900th epoch:  0.0003,  0.0001,  0.0041.
# Dloss, Iloss, Closs in 4000th epoch:  0.0002,  0.0001,  0.0031.
# Dloss, Iloss, Closs in 4100th epoch:  0.0002,  0.0001,  0.0022.
# Dloss, Iloss, Closs in 4200th epoch:  0.0002,  0.0002,  0.0019.
# Dloss, Iloss, Closs in 4300th epoch:  0.0001,  0.0000,  0.0013.
# Dloss, Iloss, Closs in 4400th epoch:  0.0001,  0.0000,  0.0010.
# Dloss, Iloss, Closs in 4500th epoch:  0.0001,  0.0000,  0.0010.
# Dloss, Iloss, Closs in 4600th epoch:  0.0001,  0.0000,  0.0007.
# Dloss, Iloss, Closs in 4700th epoch:  0.0001,  0.0000,  0.0006.
# Dloss, Iloss, Closs in 4800th epoch:  0.0001,  0.0000,  0.0006.
# Dloss, Iloss, Closs in 4900th epoch:  0.0001,  0.0000,  0.0005.
# Dloss, Iloss, Closs in 5000th epoch:  0.0001,  0.0001,  0.0004.
# Dloss, Iloss, Closs in 5100th epoch:  0.0000,  0.0000,  0.0004.
# Dloss, Iloss, Closs in 5200th epoch:  0.0000,  0.0000,  0.0003.
# Dloss, Iloss, Closs in 5300th epoch:  0.0000,  0.0000,  0.0004.
# Dloss, Iloss, Closs in 5400th epoch:  0.0000,  0.0000,  0.0003.
# Dloss, Iloss, Closs in 5500th epoch:  0.0000,  0.0000,  0.0002.
# Dloss, Iloss, Closs in 5600th epoch:  0.0000,  0.0000,  0.0003.
# Dloss, Iloss, Closs in 5700th epoch:  0.0000,  0.0000,  0.0002.
# Dloss, Iloss, Closs in 5800th epoch:  0.0000,  0.0000,  0.0002.
# Dloss, Iloss, Closs in 5900th epoch:  0.0000,  0.0000,  0.0002.
# Dloss, Iloss, Closs in 6000th epoch:  0.0004,  0.0003,  0.0001.
# Dloss, Iloss, Closs in 6100th epoch:  0.0000,  0.0000,  0.0002.
# Dloss, Iloss, Closs in 6200th epoch:  0.0000,  0.0000,  0.0002.
# Dloss, Iloss, Closs in 6300th epoch:  0.0001,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 6400th epoch:  0.0005,  0.0003,  0.0002.
# Dloss, Iloss, Closs in 6500th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 6600th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 6700th epoch:  0.0001,  0.0000,  0.0002.
# Dloss, Iloss, Closs in 6800th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 6900th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7000th epoch:  0.0001,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7100th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7200th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7300th epoch:  0.0001,  0.0001,  0.0001.
# Dloss, Iloss, Closs in 7400th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7500th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7600th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7700th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7800th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 7900th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 8000th epoch:  0.0002,  0.0004,  0.0000.
# Dloss, Iloss, Closs in 8100th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 8200th epoch:  0.0001,  0.0001,  0.0001.
# Dloss, Iloss, Closs in 8300th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 8400th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 8500th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 8600th epoch:  0.0001,  0.0001,  0.0000.
# Dloss, Iloss, Closs in 8700th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 8800th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 8900th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 9000th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 9100th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 9200th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 9300th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 9400th epoch:  0.0001,  0.0001,  0.0001.
# Dloss, Iloss, Closs in 9500th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 9600th epoch:  0.0000,  0.0000,  0.0001.
# Dloss, Iloss, Closs in 9700th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 9800th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 9900th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10000th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10100th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10200th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10300th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10400th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10500th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10600th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10700th epoch:  0.0002,  0.0001,  0.0001.
# Dloss, Iloss, Closs in 10800th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 10900th epoch:  0.0001,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11000th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11100th epoch:  0.0000,  0.0001,  0.0000.
# Dloss, Iloss, Closs in 11200th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11300th epoch:  0.0001,  0.0001,  0.0000.
# Dloss, Iloss, Closs in 11400th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11500th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11600th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11700th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11800th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 11900th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12000th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12100th epoch:  0.0001,  0.0001,  0.0000.
# Dloss, Iloss, Closs in 12200th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12300th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12400th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12500th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12600th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12700th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12800th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 12900th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13000th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13100th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13200th epoch:  0.0001,  0.0002,  0.0000.
# Dloss, Iloss, Closs in 13300th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13400th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13500th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13600th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13700th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13800th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 13900th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14000th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14100th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14200th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14300th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14400th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14500th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14600th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14700th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14800th epoch:  0.0000,  0.0000,  0.0000.
# Dloss, Iloss, Closs in 14900th epoch:  0.0000,  0.0000,  0.0000.
# 2400

# %%
print(error_dict)
# Out:
# {0.001: array([7.868688], dtype=float32)}

# %%
#{0.0: array([1366.8411], dtype=float32), 0.1: array([800.3307], dtype=float32), 0.01: array([1240.6304], dtype=float32), 0.001: array([1053.9727], dtype=float32), 0.0001: array([2357.2754], dtype=float32)}

# %%
end = time.time()

print((end-start)/60)
# Out:
# 5.922644829750061

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma
