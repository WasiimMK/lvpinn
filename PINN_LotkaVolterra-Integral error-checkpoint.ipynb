# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7953501057046514498
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = 0.9, 0.9


# Boundaries of the computational domain
t0, tfinal = 0.0, 12

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * x0) - (d * np.log(x0)) + (b * y0) - (a * np.log(y0))
print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 12 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
model = build_model(summary = True)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_192/Tanh:0', description="created by layer 'dense_192'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_193/Tanh:0', description="created by layer 'dense_193'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_194/Tanh:0', description="created by layer 'dense_194'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_195/Tanh:0', description="created by layer 'dense_195'")
# Model: "model_32"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_33 (InputLayer)          [(None, 1)]          0           []
#
#  normalize_65 (Normalize)       (None, 1)            0           ['input_33[0][0]']
#
#  dense_192 (Dense)              (None, 40)           80          ['normalize_65[0][0]']
#
#  dense_193 (Dense)              (None, 40)           1640        ['dense_192[0][0]']
#
#  dense_194 (Dense)              (None, 40)           1640        ['dense_193[0][0]']
#
#  dense_195 (Dense)              (None, 40)           1640        ['dense_194[0][0]']
#
#  dense_196 (Dense)              (None, 1)            41          ['dense_195[0][0]']
#
#  dense_197 (Dense)              (None, 1)            41          ['dense_195[0][0]']
#
# ==================================================================================================
# Total params: 5,082
# Trainable params: 5,082
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 100)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(odes, inits, model, gamma, epsilon):

    # DE collocation points
    t_de = odes[:,:1]

    # Initial value points
    t_init, x_init, y_init = inits[:1], inits[1:2], inits[2:]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
      
      # Define the differential equation loss  
      eqn1 = xt - (a*x - b*x*y)
      eqn2 = yt - (c*x*y - d*y)
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * x) - (d * tf.math.log(x)) + (b * y) - (a * tf.math.log(y))
      Vloss = tf.math.abs(tf.reduce_mean(tf.boolean_mask(v, tf.math.is_finite(v))) - v0)
    
      # Composite loss function
      loss = 12*DEloss + gamma*IVloss + epsilon*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val):

  # Total number of collocation points
  N_de = len(de_points)

  # Batch size
  bs_de = N_de//10

  # Weight factors
  gamma = gamma_val
  epsilon = epsilon_val

  # Learning rate
  lr_model = 1e-3

  # Initial value
  t_init = np.array([t0]).astype(np.float32)
  x_init = np.array([x0]).astype(np.float32)
  y_init = np.array([y0]).astype(np.float32)

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Generate the tf.Dataset for the initial collocation points
  inits = np.column_stack([t_init, x_init, y_init])
  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache()


  # Generate the tf.Dataset for the differential equations points
  ds_ode = tf.data.Dataset.from_tensor_slices(de_points.astype(np.float32))
  ds_ode = ds_ode.cache().shuffle(N_de).batch(bs_de)

  # Generate entire dataset
  ds = tf.data.Dataset.zip((ds_ode, ds_init))

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  # Generate the model
  opt = tf.keras.optimizers.Adam(lr_model)
  model = build_model() 

  # Main training loop
  for i in range(epochs):

    # Training for that epoch
    for (des, inits) in ds:

      # Train the network
      DEloss, IVloss, Vloss, grads = train_network(des, inits, model, gamma, epsilon)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))
      
      epoch_loss[i] += DEloss + gamma*IVloss + epsilon*Vloss
      nr_batches = nr_batches + 1

    # Get total epoch loss
    epoch_loss[i] = epoch_loss[i]/nr_batches
    nr_batches = 0

    
    if (np.mod(i, 100)==0):
      print("DE loss, IV loss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

  return epoch_loss, model

# %%
def train_plot(epochs, gamma, epsilon) :
    
    loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon)
    
    # Grid where to evaluate the model
    step_size = 0.005
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.plot(loss)

    # Model prediction
    [x, y] = model(t)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", gamma = " + str(gamma) + ", epsilon = " + str(epsilon))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)    
    
    plt.figure(3)
    plt.scatter(epochs, error)
    plt.xlabel("epoch number")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x)
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 4000



for i in range(1, 11) :
    
    train_plot(i*1000, 1.2, 0.0001)
    train_plot(i*1000, 1.2, 0.0001)
    train_plot(i*1000, 1.2, 0.0001)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_198/Tanh:0', description="created by layer 'dense_198'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_199/Tanh:0', description="created by layer 'dense_199'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_200/Tanh:0', description="created by layer 'dense_200'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_201/Tanh:0', description="created by layer 'dense_201'")
# DE loss, IV loss in 0th epoch:  0.0076,  2.0489,  12.8869.
# DE loss, IV loss in 100th epoch:  0.0213,  0.0424,  0.1416.
# DE loss, IV loss in 200th epoch:  0.0257,  0.0179,  0.9698.
# DE loss, IV loss in 300th epoch:  0.0291,  0.0108,  0.8758.
# DE loss, IV loss in 400th epoch:  0.0143,  0.0376,  0.0737.
# DE loss, IV loss in 500th epoch:  0.0216,  0.0365,  1.0085.
# DE loss, IV loss in 600th epoch:  0.0270,  0.0238,  1.2751.
# DE loss, IV loss in 700th epoch:  0.0289,  0.0128,  0.1460.
# DE loss, IV loss in 800th epoch:  0.0109,  0.0126,  3.0113.
# DE loss, IV loss in 900th epoch:  0.0166,  0.0073,  1.4122.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_204/Tanh:0', description="created by layer 'dense_204'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_205/Tanh:0', description="created by layer 'dense_205'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_206/Tanh:0', description="created by layer 'dense_206'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_207/Tanh:0', description="created by layer 'dense_207'")
# DE loss, IV loss in 0th epoch:  0.0181,  2.3123,  3.7368.
# DE loss, IV loss in 100th epoch:  0.0293,  0.0240,  0.4299.
# DE loss, IV loss in 200th epoch:  0.0320,  0.0498,  0.2961.
# DE loss, IV loss in 300th epoch:  0.0258,  0.0258,  0.5363.
# DE loss, IV loss in 400th epoch:  0.0333,  0.0198,  0.4645.
# DE loss, IV loss in 500th epoch:  0.0173,  0.0158,  1.1150.
# DE loss, IV loss in 600th epoch:  0.0077,  0.0430,  1.5270.
# DE loss, IV loss in 700th epoch:  0.0091,  0.0148,  2.4242.
# DE loss, IV loss in 800th epoch:  0.0062,  0.0057,  1.9549.
# DE loss, IV loss in 900th epoch:  0.0139,  0.0050,  2.6860.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_210/Tanh:0', description="created by layer 'dense_210'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_211/Tanh:0', description="created by layer 'dense_211'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_212/Tanh:0', description="created by layer 'dense_212'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_213/Tanh:0', description="created by layer 'dense_213'")
# DE loss, IV loss in 0th epoch:  0.0333,  2.2453,  4.4777.
# DE loss, IV loss in 100th epoch:  0.0282,  0.0282,  0.1648.
# DE loss, IV loss in 200th epoch:  0.0368,  0.0210,  0.5569.
# DE loss, IV loss in 300th epoch:  0.0272,  0.0300,  0.7222.
# DE loss, IV loss in 400th epoch:  0.0218,  0.0325,  0.5390.
# DE loss, IV loss in 500th epoch:  0.0281,  0.0273,  0.5595.
# DE loss, IV loss in 600th epoch:  0.0182,  0.0110,  1.0973.
# DE loss, IV loss in 700th epoch:  0.0074,  0.0086,  2.2313.
# DE loss, IV loss in 800th epoch:  0.0135,  0.0032,  1.3219.
# DE loss, IV loss in 900th epoch:  0.0046,  0.0101,  2.3553.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_216/Tanh:0', description="created by layer 'dense_216'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_217/Tanh:0', description="created by layer 'dense_217'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_218/Tanh:0', description="created by layer 'dense_218'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_219/Tanh:0', description="created by layer 'dense_219'")
# DE loss, IV loss in 0th epoch:  0.0678,  0.6202,  1.8531.
# DE loss, IV loss in 100th epoch:  0.0217,  0.0334,  0.1791.
# DE loss, IV loss in 200th epoch:  0.0333,  0.0245,  0.5741.
# DE loss, IV loss in 300th epoch:  0.0288,  0.0217,  0.2209.
# DE loss, IV loss in 400th epoch:  0.0319,  0.0316,  0.6804.
# DE loss, IV loss in 500th epoch:  0.0193,  0.0185,  0.9492.
# DE loss, IV loss in 600th epoch:  0.0266,  0.0286,  0.3851.
# DE loss, IV loss in 700th epoch:  0.0210,  0.0214,  0.1481.
# DE loss, IV loss in 800th epoch:  0.0325,  0.0201,  0.0977.
# DE loss, IV loss in 900th epoch:  0.0045,  0.0048,  3.4167.
# DE loss, IV loss in 1000th epoch:  0.0055,  0.0179,  2.9001.
# DE loss, IV loss in 1100th epoch:  0.0069,  0.0065,  3.0461.
# DE loss, IV loss in 1200th epoch:  0.0098,  0.0064,  2.0572.
# DE loss, IV loss in 1300th epoch:  0.0089,  0.0079,  1.9439.
# DE loss, IV loss in 1400th epoch:  0.0057,  0.0069,  3.5211.
# DE loss, IV loss in 1500th epoch:  0.0117,  0.0060,  2.1409.
# DE loss, IV loss in 1600th epoch:  0.0067,  0.0054,  3.7036.
# DE loss, IV loss in 1700th epoch:  0.0096,  0.0150,  1.3506.
# DE loss, IV loss in 1800th epoch:  0.0053,  0.0078,  3.4656.
# DE loss, IV loss in 1900th epoch:  0.0030,  0.0075,  2.6668.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_222/Tanh:0', description="created by layer 'dense_222'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_223/Tanh:0', description="created by layer 'dense_223'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_224/Tanh:0', description="created by layer 'dense_224'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_225/Tanh:0', description="created by layer 'dense_225'")
# DE loss, IV loss in 0th epoch:  0.0101,  1.9932,  2.9744.
# DE loss, IV loss in 100th epoch:  0.0234,  0.0205,  0.5988.
# DE loss, IV loss in 200th epoch:  0.0257,  0.0452,  0.6072.
# DE loss, IV loss in 300th epoch:  0.0315,  0.0515,  0.2384.
# DE loss, IV loss in 400th epoch:  0.0100,  0.0489,  1.7251.
# DE loss, IV loss in 500th epoch:  0.0206,  0.0101,  0.2053.
# DE loss, IV loss in 600th epoch:  0.0129,  0.0106,  1.5916.
# DE loss, IV loss in 700th epoch:  0.0061,  0.0235,  1.6107.
# DE loss, IV loss in 800th epoch:  0.0152,  0.0109,  2.2744.
# DE loss, IV loss in 900th epoch:  0.0093,  0.0060,  2.8913.
# DE loss, IV loss in 1000th epoch:  0.0113,  0.0083,  0.4251.
# DE loss, IV loss in 1100th epoch:  0.0068,  0.0114,  2.0809.
# DE loss, IV loss in 1200th epoch:  0.0096,  0.0061,  1.9237.
# DE loss, IV loss in 1300th epoch:  0.0132,  0.0018,  1.8557.
# DE loss, IV loss in 1400th epoch:  0.0088,  0.0028,  2.5071.
# DE loss, IV loss in 1500th epoch:  0.0044,  0.0024,  2.5552.
# DE loss, IV loss in 1600th epoch:  0.0076,  0.0046,  2.6331.
# DE loss, IV loss in 1700th epoch:  0.0095,  0.0046,  2.9067.
# DE loss, IV loss in 1800th epoch:  0.0134,  0.0041,  0.6584.
# DE loss, IV loss in 1900th epoch:  0.0037,  0.0048,  0.1129.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_228/Tanh:0', description="created by layer 'dense_228'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_229/Tanh:0', description="created by layer 'dense_229'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_230/Tanh:0', description="created by layer 'dense_230'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_231/Tanh:0', description="created by layer 'dense_231'")
# DE loss, IV loss in 0th epoch:  0.0990,  2.7663,  2.2108.
# DE loss, IV loss in 100th epoch:  0.0349,  0.0228,  1.4436.
# DE loss, IV loss in 200th epoch:  0.0230,  0.0341,  0.6626.
# DE loss, IV loss in 300th epoch:  0.0338,  0.0244,  0.8484.
# DE loss, IV loss in 400th epoch:  0.0195,  0.0248,  0.1540.
# DE loss, IV loss in 500th epoch:  0.0242,  0.0182,  0.3670.
# DE loss, IV loss in 600th epoch:  0.0112,  0.0023,  1.9055.
# DE loss, IV loss in 700th epoch:  0.0134,  0.0012,  1.2794.
# DE loss, IV loss in 800th epoch:  0.0028,  0.0051,  2.8455.
# DE loss, IV loss in 900th epoch:  0.0061,  0.0043,  1.5386.
# DE loss, IV loss in 1000th epoch:  0.0038,  0.0105,  3.1646.
# DE loss, IV loss in 1100th epoch:  0.0095,  0.0033,  0.0755.
# DE loss, IV loss in 1200th epoch:  0.0069,  0.0081,  2.1076.
# DE loss, IV loss in 1300th epoch:  0.0170,  0.0050,  1.3453.
# DE loss, IV loss in 1400th epoch:  0.0085,  0.0139,  2.0468.
# DE loss, IV loss in 1500th epoch:  0.0113,  0.0098,  2.2491.
# DE loss, IV loss in 1600th epoch:  0.0106,  0.0134,  1.2113.
# DE loss, IV loss in 1700th epoch:  0.0035,  0.0057,  2.4885.
# DE loss, IV loss in 1800th epoch:  0.0066,  0.0039,  0.9030.
# DE loss, IV loss in 1900th epoch:  0.0133,  0.0060,  2.5079.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_234/Tanh:0', description="created by layer 'dense_234'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_235/Tanh:0', description="created by layer 'dense_235'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_236/Tanh:0', description="created by layer 'dense_236'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_237/Tanh:0', description="created by layer 'dense_237'")
# DE loss, IV loss in 0th epoch:  0.0975,  0.7266,  2.7633.
# DE loss, IV loss in 100th epoch:  0.0337,  0.0401,  0.5356.
# DE loss, IV loss in 200th epoch:  0.0304,  0.0131,  0.1547.
# DE loss, IV loss in 300th epoch:  0.0195,  0.0123,  1.2290.
# DE loss, IV loss in 400th epoch:  0.0164,  0.0406,  0.3775.
# DE loss, IV loss in 500th epoch:  0.0109,  0.0141,  2.9243.
# DE loss, IV loss in 600th epoch:  0.0065,  0.0059,  4.7744.
# DE loss, IV loss in 700th epoch:  0.0151,  0.0118,  2.2131.
# DE loss, IV loss in 800th epoch:  0.0173,  0.0046,  2.8649.
# DE loss, IV loss in 900th epoch:  0.0093,  0.0047,  1.3959.
# DE loss, IV loss in 1000th epoch:  0.0041,  0.0130,  0.1176.
# DE loss, IV loss in 1100th epoch:  0.0019,  0.0071,  0.1333.
# DE loss, IV loss in 1200th epoch:  0.0005,  0.0105,  0.1218.
# DE loss, IV loss in 1300th epoch:  0.0010,  0.0023,  0.1339.
# DE loss, IV loss in 1400th epoch:  0.0014,  0.0012,  0.1191.
# DE loss, IV loss in 1500th epoch:  0.0012,  0.0019,  0.1307.
# DE loss, IV loss in 1600th epoch:  0.0031,  0.0028,  0.1110.
# DE loss, IV loss in 1700th epoch:  0.0016,  0.0019,  0.1338.
# DE loss, IV loss in 1800th epoch:  0.0008,  0.0013,  0.1337.
# DE loss, IV loss in 1900th epoch:  0.0012,  0.0005,  0.1411.
# DE loss, IV loss in 2000th epoch:  0.0020,  0.0049,  0.1153.
# DE loss, IV loss in 2100th epoch:  0.0018,  0.0028,  0.1077.
# DE loss, IV loss in 2200th epoch:  0.0010,  0.0029,  0.1186.
# DE loss, IV loss in 2300th epoch:  0.0011,  0.0018,  0.0964.
# DE loss, IV loss in 2400th epoch:  0.0015,  0.0018,  0.1140.
# DE loss, IV loss in 2500th epoch:  0.0011,  0.0003,  0.1248.
# DE loss, IV loss in 2600th epoch:  0.0024,  0.0018,  0.1209.
# DE loss, IV loss in 2700th epoch:  0.0017,  0.0022,  0.1163.
# DE loss, IV loss in 2800th epoch:  0.0025,  0.0042,  0.1080.
# DE loss, IV loss in 2900th epoch:  0.0027,  0.0006,  0.1208.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_240/Tanh:0', description="created by layer 'dense_240'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_241/Tanh:0', description="created by layer 'dense_241'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_242/Tanh:0', description="created by layer 'dense_242'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_243/Tanh:0', description="created by layer 'dense_243'")
# DE loss, IV loss in 0th epoch:  0.0352,  1.1790,  3.2734.
# DE loss, IV loss in 100th epoch:  0.0276,  0.0470,  0.1666.
# DE loss, IV loss in 200th epoch:  0.0262,  0.0324,  0.2777.
# DE loss, IV loss in 300th epoch:  0.0213,  0.0319,  0.3576.
# DE loss, IV loss in 400th epoch:  0.0142,  0.0144,  0.5267.
# DE loss, IV loss in 500th epoch:  0.0152,  0.0004,  0.6274.
# DE loss, IV loss in 600th epoch:  0.0088,  0.0015,  1.7204.
# DE loss, IV loss in 700th epoch:  0.0149,  0.0251,  0.6593.
# DE loss, IV loss in 800th epoch:  0.0167,  0.0148,  0.9068.
# DE loss, IV loss in 900th epoch:  0.0071,  0.0076,  0.8898.
# DE loss, IV loss in 1000th epoch:  0.0155,  0.0029,  2.4177.
# DE loss, IV loss in 1100th epoch:  0.0195,  0.0007,  1.9723.
# DE loss, IV loss in 1200th epoch:  0.0178,  0.0123,  1.2923.
# DE loss, IV loss in 1300th epoch:  0.0026,  0.0035,  1.9939.
# DE loss, IV loss in 1400th epoch:  0.0093,  0.0066,  1.3129.
# DE loss, IV loss in 1500th epoch:  0.0043,  0.0050,  3.1806.
# DE loss, IV loss in 1600th epoch:  0.0026,  0.0082,  3.3307.
# DE loss, IV loss in 1700th epoch:  0.0093,  0.0035,  2.2368.
# DE loss, IV loss in 1800th epoch:  0.0023,  0.0084,  3.0757.
# DE loss, IV loss in 1900th epoch:  0.0100,  0.0026,  2.7934.
# DE loss, IV loss in 2000th epoch:  0.0045,  0.0081,  0.1084.
# DE loss, IV loss in 2100th epoch:  0.0015,  0.0043,  0.1250.
# DE loss, IV loss in 2200th epoch:  0.0036,  0.0008,  0.1305.
# DE loss, IV loss in 2300th epoch:  0.0016,  0.0013,  0.1282.
# DE loss, IV loss in 2400th epoch:  0.0019,  0.0004,  0.1383.
# DE loss, IV loss in 2500th epoch:  0.0015,  0.0022,  0.1266.
# DE loss, IV loss in 2600th epoch:  0.0009,  0.0018,  0.1329.
# DE loss, IV loss in 2700th epoch:  0.0017,  0.0019,  0.1050.
# DE loss, IV loss in 2800th epoch:  0.0008,  0.0011,  0.1341.
# DE loss, IV loss in 2900th epoch:  0.0011,  0.0020,  0.1289.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_246/Tanh:0', description="created by layer 'dense_246'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_247/Tanh:0', description="created by layer 'dense_247'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_248/Tanh:0', description="created by layer 'dense_248'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_249/Tanh:0', description="created by layer 'dense_249'")
# DE loss, IV loss in 0th epoch:  0.0449,  2.4124,    nan.
# DE loss, IV loss in 100th epoch:  0.0254,  0.0659,  0.6510.
# DE loss, IV loss in 200th epoch:  0.0331,  0.0441,  0.1342.
# DE loss, IV loss in 300th epoch:  0.0181,  0.0271,  0.2112.
# DE loss, IV loss in 400th epoch:  0.0289,  0.0211,  1.1257.
# DE loss, IV loss in 500th epoch:  0.0219,  0.0078,  1.4105.
# DE loss, IV loss in 600th epoch:  0.0078,  0.0150,  2.4356.
# DE loss, IV loss in 700th epoch:  0.0031,  0.0053,  2.1054.
# DE loss, IV loss in 800th epoch:  0.0189,  0.0071,  0.9044.
# DE loss, IV loss in 900th epoch:  0.0215,  0.0019,  1.6321.
# DE loss, IV loss in 1000th epoch:  0.0030,  0.0074,  1.2296.
# DE loss, IV loss in 1100th epoch:  0.0045,  0.0055,  2.9717.
# DE loss, IV loss in 1200th epoch:  0.0158,  0.0060,  0.2803.
# DE loss, IV loss in 1300th epoch:  0.0067,  0.0112,  2.1299.
# DE loss, IV loss in 1400th epoch:  0.0083,  0.0025,  2.2390.
# DE loss, IV loss in 1500th epoch:  0.0050,  0.0075,  3.1873.
# DE loss, IV loss in 1600th epoch:  0.0024,  0.0073,  4.7659.
# DE loss, IV loss in 1700th epoch:  0.0076,  0.0011,  1.1233.
# DE loss, IV loss in 1800th epoch:  0.0122,  0.0070,  1.0003.
# DE loss, IV loss in 1900th epoch:  0.0079,  0.0166,  2.5836.
# DE loss, IV loss in 2000th epoch:  0.0022,  0.0077,  3.9241.
# DE loss, IV loss in 2100th epoch:  0.0138,  0.0021,  1.7026.
# DE loss, IV loss in 2200th epoch:  0.0073,  0.0166,  1.2976.
# DE loss, IV loss in 2300th epoch:  0.0079,  0.0053,  2.8558.
# DE loss, IV loss in 2400th epoch:  0.0043,  0.0017,  0.8492.
# DE loss, IV loss in 2500th epoch:  0.0081,  0.0127,  3.0156.
# DE loss, IV loss in 2600th epoch:  0.0118,  0.0079,  1.7387.
# DE loss, IV loss in 2700th epoch:  0.0108,  0.0032,  0.9660.
# DE loss, IV loss in 2800th epoch:  0.0044,  0.0048,  1.7035.
# DE loss, IV loss in 2900th epoch:  0.0053,  0.0148,  2.8010.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_252/Tanh:0', description="created by layer 'dense_252'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_253/Tanh:0', description="created by layer 'dense_253'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_254/Tanh:0', description="created by layer 'dense_254'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_255/Tanh:0', description="created by layer 'dense_255'")
# DE loss, IV loss in 0th epoch:  0.0149,  2.2997,  3.1731.
# DE loss, IV loss in 100th epoch:  0.0254,  0.0338,  1.1529.
# DE loss, IV loss in 200th epoch:  0.0248,  0.0494,  0.2726.
# DE loss, IV loss in 300th epoch:  0.0328,  0.0112,  0.4056.
# DE loss, IV loss in 400th epoch:  0.0218,  0.0493,  0.3762.
# DE loss, IV loss in 500th epoch:  0.0288,  0.0282,  0.6598.
# DE loss, IV loss in 600th epoch:  0.0276,  0.0295,  0.4490.
# DE loss, IV loss in 700th epoch:  0.0243,  0.0253,  0.9580.
# DE loss, IV loss in 800th epoch:  0.0073,  0.0090,  2.4892.
# DE loss, IV loss in 900th epoch:  0.0133,  0.0035,  3.6903.
# DE loss, IV loss in 1000th epoch:  0.0132,  0.0116,  2.9198.
# DE loss, IV loss in 1100th epoch:  0.0114,  0.0102,  0.7759.
# DE loss, IV loss in 1200th epoch:  0.0157,  0.0036,  1.9270.
# DE loss, IV loss in 1300th epoch:  0.0109,  0.0053,  0.6199.
# DE loss, IV loss in 1400th epoch:  0.0085,  0.0079,  3.1779.
# DE loss, IV loss in 1500th epoch:  0.0133,  0.0019,  3.0067.
# DE loss, IV loss in 1600th epoch:  0.0320,  0.0096,  0.0684.
# DE loss, IV loss in 1700th epoch:  0.0027,  0.0036,  0.1234.
# DE loss, IV loss in 1800th epoch:  0.0013,  0.0035,  0.1318.
# DE loss, IV loss in 1900th epoch:  0.0024,  0.0020,  0.1193.
# DE loss, IV loss in 2000th epoch:  0.0019,  0.0012,  0.1339.
# DE loss, IV loss in 2100th epoch:  0.0014,  0.0038,  0.1085.
# DE loss, IV loss in 2200th epoch:  0.0012,  0.0003,  0.1373.
# DE loss, IV loss in 2300th epoch:  0.0018,  0.0017,  0.1319.
# DE loss, IV loss in 2400th epoch:  0.0011,  0.0027,  0.1157.
# DE loss, IV loss in 2500th epoch:  0.0024,  0.0009,  0.1166.
# DE loss, IV loss in 2600th epoch:  0.0012,  0.0050,  0.1178.
# DE loss, IV loss in 2700th epoch:  0.0009,  0.0008,  0.1291.
# DE loss, IV loss in 2800th epoch:  0.0018,  0.0009,  0.1111.
# DE loss, IV loss in 2900th epoch:  0.0016,  0.0011,  0.1058.
# DE loss, IV loss in 3000th epoch:  0.0011,  0.0013,  0.1209.
# DE loss, IV loss in 3100th epoch:  0.0026,  0.0004,  0.1351.
# DE loss, IV loss in 3200th epoch:  0.0009,  0.0006,  0.1204.
# DE loss, IV loss in 3300th epoch:  0.0016,  0.0006,  0.1186.
# DE loss, IV loss in 3400th epoch:  0.0033,  0.0001,  0.1072.
# DE loss, IV loss in 3500th epoch:  0.0021,  0.0020,  0.1171.
# DE loss, IV loss in 3600th epoch:  0.0021,  0.0010,  0.1129.
# DE loss, IV loss in 3700th epoch:  0.0016,  0.0009,  0.1115.
# DE loss, IV loss in 3800th epoch:  0.0021,  0.0006,  0.1164.
# DE loss, IV loss in 3900th epoch:  0.0014,  0.0017,  0.1315.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_258/Tanh:0', description="created by layer 'dense_258'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_259/Tanh:0', description="created by layer 'dense_259'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_260/Tanh:0', description="created by layer 'dense_260'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_261/Tanh:0', description="created by layer 'dense_261'")
# DE loss, IV loss in 0th epoch:  0.0115,  2.1284,    nan.
# DE loss, IV loss in 100th epoch:  0.0254,  0.0701,  0.6213.
# DE loss, IV loss in 200th epoch:  0.0231,  0.0353,  1.4509.
# DE loss, IV loss in 300th epoch:  0.0249,  0.0194,  0.3190.
# DE loss, IV loss in 400th epoch:  0.0169,  0.0176,  0.8412.
# DE loss, IV loss in 500th epoch:  0.0185,  0.0110,  0.6001.
# DE loss, IV loss in 600th epoch:  0.0163,  0.0170,  0.6732.
# DE loss, IV loss in 700th epoch:  0.0236,  0.0317,  1.2321.
# DE loss, IV loss in 800th epoch:  0.0176,  0.0043,  1.7567.
# DE loss, IV loss in 900th epoch:  0.0099,  0.0111,  1.6471.
# DE loss, IV loss in 1000th epoch:  0.0064,  0.0027,  4.1411.
# DE loss, IV loss in 1100th epoch:  0.0108,  0.0063,  2.2217.
# DE loss, IV loss in 1200th epoch:  0.0042,  0.0125,  2.9912.
# DE loss, IV loss in 1300th epoch:  0.0076,  0.0134,  2.2365.
# DE loss, IV loss in 1400th epoch:  0.0097,  0.0114,  2.0087.
# DE loss, IV loss in 1500th epoch:  0.0115,  0.0218,  1.3149.
# DE loss, IV loss in 1600th epoch:  0.0094,  0.0049,  3.3224.
# DE loss, IV loss in 1700th epoch:  0.0093,  0.0076,  0.4622.
# DE loss, IV loss in 1800th epoch:  0.0076,  0.0064,  3.8196.
# DE loss, IV loss in 1900th epoch:  0.0074,  0.0065,  3.2056.
# DE loss, IV loss in 2000th epoch:  0.0043,  0.0132,  2.0064.
# DE loss, IV loss in 2100th epoch:  0.0089,  0.0159,  1.0917.
# DE loss, IV loss in 2200th epoch:  0.0101,  0.0119,  2.0639.
# DE loss, IV loss in 2300th epoch:  0.0024,  0.0103,  3.5392.
# DE loss, IV loss in 2400th epoch:  0.0136,  0.0070,  1.3038.
# DE loss, IV loss in 2500th epoch:  0.0031,  0.0064,  3.6991.
# DE loss, IV loss in 2600th epoch:  0.0090,  0.0073,  2.0057.
# DE loss, IV loss in 2700th epoch:  0.0093,  0.0079,  2.5817.
# DE loss, IV loss in 2800th epoch:  0.0134,  0.0040,  1.8120.
# DE loss, IV loss in 2900th epoch:  0.0148,  0.0038,  1.6209.
# DE loss, IV loss in 3000th epoch:  0.0057,  0.0083,  3.6586.
# DE loss, IV loss in 3100th epoch:  0.0071,  0.0077,  1.3385.
# DE loss, IV loss in 3200th epoch:  0.0074,  0.0100,  1.8266.
# DE loss, IV loss in 3300th epoch:  0.0090,  0.0037,  3.0866.
# DE loss, IV loss in 3400th epoch:  0.0015,  0.0056,  3.9428.
# DE loss, IV loss in 3500th epoch:  0.0052,  0.0145,  2.8070.
# DE loss, IV loss in 3600th epoch:  0.0110,  0.0078,  0.8295.
# DE loss, IV loss in 3700th epoch:  0.0059,  0.0228,  2.6763.
# DE loss, IV loss in 3800th epoch:  0.0041,  0.0135,  4.1095.
# DE loss, IV loss in 3900th epoch:  0.0107,  0.0104,  0.8320.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_264/Tanh:0', description="created by layer 'dense_264'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_265/Tanh:0', description="created by layer 'dense_265'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_266/Tanh:0', description="created by layer 'dense_266'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_267/Tanh:0', description="created by layer 'dense_267'")
# DE loss, IV loss in 0th epoch:  0.1131,  0.6810,  1.8309.
# DE loss, IV loss in 100th epoch:  0.0284,  0.0637,  0.1042.
# DE loss, IV loss in 200th epoch:  0.0264,  0.0377,  0.6249.
# DE loss, IV loss in 300th epoch:  0.0246,  0.0414,  0.9068.
# DE loss, IV loss in 400th epoch:  0.0306,  0.0116,  0.5507.
# DE loss, IV loss in 500th epoch:  0.0078,  0.0227,  3.1382.
# DE loss, IV loss in 600th epoch:  0.0075,  0.0086,  2.6347.
# DE loss, IV loss in 700th epoch:  0.0054,  0.0106,  0.3195.
# DE loss, IV loss in 800th epoch:  0.0054,  0.0047,  2.9400.
# DE loss, IV loss in 900th epoch:  0.0072,  0.0144,  3.1126.
# DE loss, IV loss in 1000th epoch:  0.0145,  0.0011,  0.0614.
# DE loss, IV loss in 1100th epoch:  0.0031,  0.0067,  0.1280.
# DE loss, IV loss in 1200th epoch:  0.0021,  0.0130,  0.1364.
# DE loss, IV loss in 1300th epoch:  0.0014,  0.0049,  0.1369.
# DE loss, IV loss in 1400th epoch:  0.0017,  0.0021,  0.1204.
# DE loss, IV loss in 1500th epoch:  0.0010,  0.0017,  0.1343.
# DE loss, IV loss in 1600th epoch:  0.0013,  0.0031,  0.1396.
# DE loss, IV loss in 1700th epoch:  0.0030,  0.0021,  0.1182.
# DE loss, IV loss in 1800th epoch:  0.0020,  0.0009,  0.1247.
# DE loss, IV loss in 1900th epoch:  0.0016,  0.0040,  0.1251.
# DE loss, IV loss in 2000th epoch:  0.0020,  0.0017,  0.1207.
# DE loss, IV loss in 2100th epoch:  0.0023,  0.0018,  0.1298.
# DE loss, IV loss in 2200th epoch:  0.0025,  0.0013,  0.1184.
# DE loss, IV loss in 2300th epoch:  0.0007,  0.0015,  0.1179.
# DE loss, IV loss in 2400th epoch:  0.0034,  0.0005,  0.0821.
# DE loss, IV loss in 2500th epoch:  0.0017,  0.0042,  0.1343.
# DE loss, IV loss in 2600th epoch:  0.0008,  0.0013,  0.1051.
# DE loss, IV loss in 2700th epoch:  0.0026,  0.0017,  0.1227.
# DE loss, IV loss in 2800th epoch:  0.0010,  0.0019,  0.1201.
# DE loss, IV loss in 2900th epoch:  0.0008,  0.0020,  0.1152.
# DE loss, IV loss in 3000th epoch:  0.0042,  0.0014,  0.1084.
# DE loss, IV loss in 3100th epoch:  0.0026,  0.0006,  0.1114.
# DE loss, IV loss in 3200th epoch:  0.0013,  0.0020,  0.0979.
# DE loss, IV loss in 3300th epoch:  0.0014,  0.0017,  0.1387.
# DE loss, IV loss in 3400th epoch:  0.0024,  0.0013,  0.1047.
# DE loss, IV loss in 3500th epoch:  0.0014,  0.0004,  0.1122.
# DE loss, IV loss in 3600th epoch:  0.0011,  0.0011,  0.1418.
# DE loss, IV loss in 3700th epoch:  0.0023,  0.0009,  0.0970.
# DE loss, IV loss in 3800th epoch:  0.0013,  0.0021,  0.1327.
# DE loss, IV loss in 3900th epoch:  0.0016,  0.0020,  0.1022.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_270/Tanh:0', description="created by layer 'dense_270'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_271/Tanh:0', description="created by layer 'dense_271'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_272/Tanh:0', description="created by layer 'dense_272'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_273/Tanh:0', description="created by layer 'dense_273'")
# DE loss, IV loss in 0th epoch:  0.0048,  1.1708,  3.9485.
# DE loss, IV loss in 100th epoch:  0.0224,  0.0405,  1.0883.
# DE loss, IV loss in 200th epoch:  0.0226,  0.0377,  0.5923.
# DE loss, IV loss in 300th epoch:  0.0263,  0.0317,  0.1079.
# DE loss, IV loss in 400th epoch:  0.0212,  0.0310,  0.0079.
# DE loss, IV loss in 500th epoch:  0.0230,  0.0451,  0.3439.
# DE loss, IV loss in 600th epoch:  0.0207,  0.0218,  0.5020.
# DE loss, IV loss in 700th epoch:  0.0057,  0.0176,  1.3189.
# DE loss, IV loss in 800th epoch:  0.0096,  0.0131,  2.0898.
# DE loss, IV loss in 900th epoch:  0.0100,  0.0625,  1.1107.
# DE loss, IV loss in 1000th epoch:  0.0163,  0.0067,  1.8895.
# DE loss, IV loss in 1100th epoch:  0.0115,  0.0056,  1.8739.
# DE loss, IV loss in 1200th epoch:  0.0088,  0.0231,  0.7469.
# DE loss, IV loss in 1300th epoch:  0.0121,  0.0028,  2.3751.
# DE loss, IV loss in 1400th epoch:  0.0051,  0.0148,  1.8725.
# DE loss, IV loss in 1500th epoch:  0.0031,  0.0029,  2.0154.
# DE loss, IV loss in 1600th epoch:  0.0208,  0.0070,  1.1455.
# DE loss, IV loss in 1700th epoch:  0.0136,  0.0049,  0.9231.
# DE loss, IV loss in 1800th epoch:  0.0105,  0.0022,  3.2869.
# DE loss, IV loss in 1900th epoch:  0.0034,  0.0029,  4.5490.
# DE loss, IV loss in 2000th epoch:  0.0126,  0.0026,  1.7984.
# DE loss, IV loss in 2100th epoch:  0.0078,  0.0061,  2.1582.
# DE loss, IV loss in 2200th epoch:  0.0056,  0.0037,  2.0163.
# DE loss, IV loss in 2300th epoch:  0.0017,  0.0052,  3.3289.
# DE loss, IV loss in 2400th epoch:  0.0077,  0.0084,  2.2775.
# DE loss, IV loss in 2500th epoch:  0.0103,  0.0082,  2.1063.
# DE loss, IV loss in 2600th epoch:  0.0062,  0.0090,  0.8055.
# DE loss, IV loss in 2700th epoch:  0.0072,  0.0081,  1.1172.
# DE loss, IV loss in 2800th epoch:  0.0080,  0.0216,  0.3490.
# DE loss, IV loss in 2900th epoch:  0.0105,  0.0020,  0.5155.
# DE loss, IV loss in 3000th epoch:  0.0146,  0.0110,  0.4186.
# DE loss, IV loss in 3100th epoch:  0.0048,  0.0079,  3.6487.
# DE loss, IV loss in 3200th epoch:  0.0089,  0.0098,  2.4250.
# DE loss, IV loss in 3300th epoch:  0.0036,  0.0038,  3.4248.
# DE loss, IV loss in 3400th epoch:  0.0076,  0.0098,  3.6266.
# DE loss, IV loss in 3500th epoch:  0.0084,  0.0056,  1.3540.
# DE loss, IV loss in 3600th epoch:  0.0089,  0.0017,  1.7437.
# DE loss, IV loss in 3700th epoch:  0.0026,  0.0097,  2.1057.
# DE loss, IV loss in 3800th epoch:  0.0033,  0.0747,  0.1093.
# DE loss, IV loss in 3900th epoch:  0.0019,  0.0043,  0.1330.
# DE loss, IV loss in 4000th epoch:  0.0019,  0.0048,  0.1297.
# DE loss, IV loss in 4100th epoch:  0.0025,  0.0030,  0.1245.
# DE loss, IV loss in 4200th epoch:  0.0017,  0.0060,  0.1215.
# DE loss, IV loss in 4300th epoch:  0.0032,  0.0042,  0.1067.
# DE loss, IV loss in 4400th epoch:  0.0005,  0.0019,  0.1444.
# DE loss, IV loss in 4500th epoch:  0.0029,  0.0015,  0.1073.
# DE loss, IV loss in 4600th epoch:  0.0025,  0.0006,  0.1185.
# DE loss, IV loss in 4700th epoch:  0.0010,  0.0016,  0.1230.
# DE loss, IV loss in 4800th epoch:  0.0009,  0.0007,  0.1418.
# DE loss, IV loss in 4900th epoch:  0.0028,  0.0002,  0.1206.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_276/Tanh:0', description="created by layer 'dense_276'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_277/Tanh:0', description="created by layer 'dense_277'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_278/Tanh:0', description="created by layer 'dense_278'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_279/Tanh:0', description="created by layer 'dense_279'")
# DE loss, IV loss in 0th epoch:  0.0355,  2.4218,  2.6205.
# DE loss, IV loss in 100th epoch:  0.0274,  0.0338,  0.3236.
# DE loss, IV loss in 200th epoch:  0.0328,  0.0161,  0.0384.
# DE loss, IV loss in 300th epoch:  0.0309,  0.0314,  0.6659.
# DE loss, IV loss in 400th epoch:  0.0276,  0.0369,  0.5641.
# DE loss, IV loss in 500th epoch:  0.0293,  0.0327,  0.4939.
# DE loss, IV loss in 600th epoch:  0.0261,  0.0201,  0.8257.
# DE loss, IV loss in 700th epoch:  0.0097,  0.0178,  1.8599.
# DE loss, IV loss in 800th epoch:  0.0070,  0.0675,  3.4397.
# DE loss, IV loss in 900th epoch:  0.0102,  0.0070,  1.6767.
# DE loss, IV loss in 1000th epoch:  0.0069,  0.0018,  3.2251.
# DE loss, IV loss in 1100th epoch:  0.0108,  0.0070,  1.4205.
# DE loss, IV loss in 1200th epoch:  0.0096,  0.0023,  1.7688.
# DE loss, IV loss in 1300th epoch:  0.0089,  0.0038,  2.3348.
# DE loss, IV loss in 1400th epoch:  0.0097,  0.0082,  0.9226.
# DE loss, IV loss in 1500th epoch:  0.0147,  0.0069,  2.5442.
# DE loss, IV loss in 1600th epoch:  0.0043,  0.0041,  2.2301.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 8
#       5 for i in range(1, 11) :
#       7     train_plot(i*1000, 1.2, 0.0001)
# ----> 8     train_plot(i*1000, 1.2, 0.0001)
#       9     train_plot(i*1000, 1.2, 0.0001)
#
# Cell In[63], line 3, in train_plot(epochs, gamma, epsilon)
#       1 def train_plot(epochs, gamma, epsilon) :
# ----> 3     loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon)
#       5     # Grid where to evaluate the model
#       6     step_size = 0.005
#
# Cell In[62], line 47, in PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val)
#      43 # Main training loop
#      44 for i in range(epochs):
#      45
#      46   # Training for that epoch
# ---> 47   for (des, inits) in ds:
#      48
#      49     # Train the network
#      50     DEloss, IVloss, Vloss, grads = train_network(des, inits, model, gamma, epsilon)
#      52     # Gradient step
#
# KeyboardInterrupt:

# %%
end = time.time()

print((end-start)/60)

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

step = 0.001

# Make data.
x = np.arange(step, 3, step)
y = np.arange(step, 3, step)
x, y = np.meshgrid(x, y)

V_loss = (c * x) - (d * np.log(x)) + (b * y) - (a * np.log(y))

#V_loss = np.sqrt(x**2 + y**2)

z = np.abs(V_loss - v0)

# Plot the surface.

plt.plot(xpoints, ypoints, [-1]*len(xpoints), color = 'black')
surf = ax.plot_surface(x, y, z, cmap=cm.coolwarm, linewidth=0, antialiased=False)


ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

# Customize the z axis.
ax.set_zlim(-1, 5)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
