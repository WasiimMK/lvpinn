# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
tf.keras.backend.set_floatx('float64')

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6635369719603988959
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 36

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 36 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,), name = "Input_t")
  b = Normalize(t0, tfinal)(b)
  Normalize.name  = "Normalize"

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh', name = "Hidden_" + str(i))(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear', name = "Output_x")(b)
  outy = tf.keras.layers.Dense(1, activation='linear', name = "Output_y")(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
model = build_model(summary = True)
tf.keras.utils.plot_model(model)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# Model: "model_47"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_t (InputLayer)           [(None, 1)]          0           []
#
#  Normalize (Normalize)          (None, 1)            0           ['Input_t[0][0]']
#
#  Hidden_0 (Dense)               (None, 40)           80          ['Normalize[0][0]']
#
#  Hidden_1 (Dense)               (None, 40)           1640        ['Hidden_0[0][0]']
#
#  Hidden_2 (Dense)               (None, 40)           1640        ['Hidden_1[0][0]']
#
#  Hidden_3 (Dense)               (None, 40)           1640        ['Hidden_2[0][0]']
#
#  Output_x (Dense)               (None, 1)            41          ['Hidden_3[0][0]']
#
#  Output_y (Dense)               (None, 1)            41          ['Hidden_3[0][0]']
#
# ==================================================================================================
# Total params: 5,082
# Trainable params: 5,082
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points

de_points = defineCollocationPoints([t0, tfinal], 100)
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(model, t, inits, alpha, beta, gamma):

    t_de = t

    # Initial value points
    t_init, x_init, y_init = inits[:, 0], inits[:, 1], inits[:, 2]
    

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        
      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)

      #xt = tf.cast(xt, tf.float32)
      #yt = tf.cast(yt, tf.float32)
        

      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
      Vloss = tf.square(tf.math.reduce_mean(v) - v0)           
    
      # Composite loss function
      loss = alpha*DEloss + beta*IVloss + gamma*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(custom_model, custom_t, x0, y0, epochs, alpha_val, beta_val, gamma_val):

    # Weight factors
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val

    # Learning rate
    lr_model = 1e-2

    # Initial value
    t_init = np.array([t0]).astype(np.float64)
    x_init = np.array([x0]).astype(np.float64)
    y_init = np.array([y0]).astype(np.float64)
                                                                    
    
    inits = np.column_stack([t_init, x_init, y_init])

    epoch_loss = np.zeros(epochs)

    # Generate the model
    opt = tf.keras.optimizers.Adam(lr_model)

    # Main training loop
    for i in range(epochs):

        # Train the network
        DEloss, IVloss, Vloss, grads = train_network(custom_model, custom_t, inits, alpha, beta, gamma)

        # Gradient step
        opt.apply_gradients(zip(grads, custom_model.trainable_variables))
      
        epoch_loss[i] += alpha*DEloss + beta*IVloss + gamma*Vloss

        if (np.mod(i, 100)==0) :
            
            print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

    return epoch_loss, custom_model

# %%
colloc_points_per_cycle = 100
step_size = 0.001

# %%
def train_plot_sequential(custom_model, t_start, t_end, epochs, cycles, alpha, beta, gamma) :
    
    empty_arr = np.array([[]])
    
    x = tf.reshape(tf.convert_to_tensor(empty_arr, dtype=tf.float64), [0, 1])
    y = tf.reshape(tf.convert_to_tensor(empty_arr, dtype=tf.float64), [0, 1])

    t = np.arange(t_start, t_end, step_size)
    t = np.round(t, decimal_p)
    num_t = len(t)
    print("num t", num_t)
    
    delta_t = int((t_end - t_start)/cycles)
    
    print("colloc_points_per_cycle", colloc_points_per_cycle)
    print("delta_t", delta_t)

    loss_vals = np.zeros(epochs * cycles)
    next_model = custom_model
    
    next_x0 = x0
    next_y0 = y0
    
    custom_t = defineCollocationPoints([0.0, delta_t], colloc_points_per_cycle)
    
    t_pred = np.arange(0.0, delta_t, step_size)
    t_pred = np.round(t_pred, decimal_p)
    
    for i in range(cycles) :

        loss, model = PINNtrain(next_model, custom_t, next_x0, next_y0, epochs, alpha, beta, gamma)
        loss_vals[i*epochs : (i+1)*epochs] = loss
        
        [next_x, next_y] = model(t_pred, training=True)
        
        x = tf.concat([x, next_x], axis = 0)
        y = tf.concat([y, next_y], axis = 0)
        
        t_delta_t = np.array([delta_t]).astype(np.float64)
        
        [next_x0, next_y0] = model(t_delta_t, training=True)
        
        next_x0 = next_x0.numpy()[0][0]
        next_y0 = next_y0.numpy()[0][0]

        next_model = tf.keras.models.clone_model(model)
        next_model.build((None, 1))
        next_model.set_weights(model.get_weights())
        

    plt.figure(1)
    plt.semilogy(loss_vals)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", cycles = " + str(cycles))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    plt.xlabel("x")
    plt.ylabel("y")
    
    error = calc_err(t, x, y)
    print("error", error)
    print("error mean", error/num_t)
    
    plt.figure(3)
    plt.scatter(cycles, error/num_t)
    plt.xlabel("number of cycles")
    plt.ylabel("error")
    new_list = range(1, 4)
    plt.xticks(new_list)

    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x, label = "e = " + str(epochs) + ", cycles = " + str(cycles))
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y, label = "e = " + str(epochs) + ", cycles = " + str(cycles))
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = math.sqrt((x_preds[i] - xpoints[t_i])**2 + (y_preds[i] - ypoints[t_i])**2)
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
# epochs = 500
# cycles = 4

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 8000, 1, 12, 1.2, 100.0)

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 2000, 4, 12, 1.2, 100.0)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# num t 36000
# colloc_points_per_cycle 100
# delta_t 36
# DE loss, IV loss, Vloss in 0th epoch:  0.4576,  0.0022,  0.0036.
# DE loss, IV loss, Vloss in 100th epoch:  0.0874,  0.0322,  0.0010.
# DE loss, IV loss, Vloss in 200th epoch:  0.0831,  0.0536,  0.0008.
# DE loss, IV loss, Vloss in 300th epoch:  0.0883,  0.0385,  0.0089.
# DE loss, IV loss, Vloss in 400th epoch:  0.0530,  0.0323,  0.0003.
# DE loss, IV loss, Vloss in 500th epoch:  0.0240,  0.0062,  0.0002.
# DE loss, IV loss, Vloss in 600th epoch:  0.0158,  0.0064,  0.0001.
# DE loss, IV loss, Vloss in 700th epoch:  0.0127,  0.0067,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0109,  0.0060,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0096,  0.0055,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0087,  0.0052,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0081,  0.0051,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0077,  0.0049,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0077,  0.0271,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0069,  0.0043,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0066,  0.0041,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0063,  0.0038,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0060,  0.0037,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0055,  0.0042,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0050,  0.0037,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0045,  0.0027,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0043,  0.0041,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0038,  0.0037,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0035,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0033,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0031,  0.0010,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0031,  0.0036,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0027,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0027,  0.0032,  0.0000.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0038,  0.0051,  0.0000.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0024,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0024,  0.0026,  0.0000.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0021,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0026,  0.0049,  0.0000.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0021,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0026,  0.0065,  0.0000.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0020,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0027,  0.0029,  0.0000.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0020,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0021,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0022,  0.0034,  0.0000.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0066,  0.0064,  0.0000.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0019,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0021,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0017,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0017,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0037,  0.0080,  0.0000.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0016,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0026,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0019,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0015,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0020,  0.0017,  0.0000.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0016,  0.0020,  0.0000.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0015,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0015,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0023,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0015,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0019,  0.0027,  0.0000.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0015,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0017,  0.0037,  0.0000.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0015,  0.0022,  0.0000.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0014,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0015,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0016,  0.0043,  0.0000.
# DE loss, IV loss, Vloss in 6500th epoch:  0.0013,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 6600th epoch:  0.0012,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 6700th epoch:  0.0012,  0.0010,  0.0000.
# DE loss, IV loss, Vloss in 6800th epoch:  0.0011,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 6900th epoch:  0.0019,  0.0044,  0.0000.
# DE loss, IV loss, Vloss in 7000th epoch:  0.0010,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 7100th epoch:  0.0029,  0.0027,  0.0000.
# DE loss, IV loss, Vloss in 7200th epoch:  0.0010,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 7300th epoch:  0.0012,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 7400th epoch:  0.0025,  0.0024,  0.0000.
# DE loss, IV loss, Vloss in 7500th epoch:  0.0013,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7600th epoch:  0.0011,  0.0034,  0.0000.
# DE loss, IV loss, Vloss in 7700th epoch:  0.0017,  0.0089,  0.0000.
# DE loss, IV loss, Vloss in 7800th epoch:  0.0011,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 7900th epoch:  0.0013,  0.0017,  0.0000.
# 36000
# error 7695.682862301083
# error mean 0.21376896839725232
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# num t 36000
# colloc_points_per_cycle 100
# delta_t 9
# DE loss, IV loss, Vloss in 0th epoch:  0.1040,  0.0915,  0.0081.
# DE loss, IV loss, Vloss in 100th epoch:  0.0980,  0.0101,  0.0019.
# DE loss, IV loss, Vloss in 200th epoch:  0.0786,  0.0336,  0.0011.
# DE loss, IV loss, Vloss in 300th epoch:  0.0599,  0.0506,  0.0006.
# DE loss, IV loss, Vloss in 400th epoch:  0.0419,  0.0103,  0.0002.
# DE loss, IV loss, Vloss in 500th epoch:  0.0246,  0.0212,  0.0001.
# DE loss, IV loss, Vloss in 600th epoch:  0.0193,  0.0071,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0125,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0068,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0828,  0.0054,  0.0030.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0181,  0.0248,  0.0001.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0073,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0044,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0029,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0020,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0015,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0012,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0010,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0008,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0007,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 0th epoch:  0.0006,  0.1637,  0.0000.
# DE loss, IV loss, Vloss in 100th epoch:  0.0578,  0.0011,  0.0004.
# DE loss, IV loss, Vloss in 200th epoch:  0.0369,  0.0081,  0.0002.
# DE loss, IV loss, Vloss in 300th epoch:  0.0118,  0.0062,  0.0000.
# DE loss, IV loss, Vloss in 400th epoch:  0.0047,  0.0022,  0.0000.
# DE loss, IV loss, Vloss in 500th epoch:  0.0012,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0013,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0003,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0181,  0.0132,  0.0001.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 0th epoch:  0.0000,  0.2241,  0.0000.
# DE loss, IV loss, Vloss in 100th epoch:  0.0004,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 200th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0000,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0001,  0.0017,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0000,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0003,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0005,  0.0062,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0001,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0001,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 0th epoch:  0.0026,  0.2103,  0.0000.
# DE loss, IV loss, Vloss in 100th epoch:  0.0134,  0.0096,  0.0000.
# DE loss, IV loss, Vloss in 200th epoch:  0.0003,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 400th epoch:  0.0001,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0000,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0000,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0000,  0.0001,  0.0000.
# 36000
# error 3559.583704961492
# error mean 0.09887732513781922

# %%
end = time.time()

print((end-start)/60)
# Out:
# 5.9381987373034155

# %%
#     2 3 4

# 20 0.05328786159898205, 0.03248169943505809, 0.014598205832759456
# 30 0.060848330988604774, 0.019430389301504553, 0.0069668703920268285
# 40 0.03672581839745748, 0.00413 ,0.004484866589899533
