# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
tf.keras.backend.set_floatx('float64')

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5241045610008964288
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = 0.9, 0.9


# Boundaries of the computational domain
t0, tfinal = 0.0, 12

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * x0) - (d * np.log(x0)) + (b * y0) - (a * np.log(y0))

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 12 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,), name = "Input_t")
  b = Normalize(t0, tfinal)(b)
  Normalize.name  = "Normalize"

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh', name = "Hidden_" + str(i))(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear', name = "Output_x")(b)
  outy = tf.keras.layers.Dense(1, activation='linear', name = "Output_y")(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
model = build_model(summary = True)
tf.keras.utils.plot_model(model)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# Model: "model_48"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_t (InputLayer)           [(None, 1)]          0           []
#
#  Normalize (Normalize)          (None, 1)            0           ['Input_t[0][0]']
#
#  Hidden_0 (Dense)               (None, 40)           80          ['Normalize[0][0]']
#
#  Hidden_1 (Dense)               (None, 40)           1640        ['Hidden_0[0][0]']
#
#  Hidden_2 (Dense)               (None, 40)           1640        ['Hidden_1[0][0]']
#
#  Hidden_3 (Dense)               (None, 40)           1640        ['Hidden_2[0][0]']
#
#  Output_x (Dense)               (None, 1)            41          ['Hidden_3[0][0]']
#
#  Output_y (Dense)               (None, 1)            41          ['Hidden_3[0][0]']
#
# ==================================================================================================
# Total params: 5,082
# Trainable params: 5,082
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points

de_points = defineCollocationPoints([t0, tfinal], 100)
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(model, t, inits, alpha, beta, gamma):

    t_de = t

    # Initial value points
    t_init, x_init, y_init = inits[:, 0], inits[:, 1], inits[:, 2]
    

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        
      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)

      #xt = tf.cast(xt, tf.float32)
      #yt = tf.cast(yt, tf.float32)
        

      # Define the differential equation loss  
      eqn1 = xt - (a*x - b*x*y)
      eqn2 = yt - (c*x*y - d*y)
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * x) - (d * tf.math.log(x)) + (b * y) - (a * tf.math.log(y))
    
      Vloss = tf.square(tf.reduce_mean(tf.boolean_mask(v, tf.math.is_finite(v))) - v0) 
    
      #tf.print(Vloss)
    
      # Composite loss function
      loss = alpha*DEloss + beta*IVloss + gamma*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(custom_model, custom_t, x0, y0, epochs, alpha_val, beta_val, gamma_val):

    # Weight factors
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val

    # Learning rate
    lr_model = 1e-2

    # Initial value
    t_init = np.array([t0]).astype(np.float64)
    x_init = np.array([x0]).astype(np.float64)
    y_init = np.array([y0]).astype(np.float64)
                                                                    
    
    inits = np.column_stack([t_init, x_init, y_init])

    epoch_loss = np.zeros(epochs)

    # Generate the model
    opt = tf.keras.optimizers.Adam(lr_model)

    # Main training loop
    for i in range(epochs):

        # Train the network
        DEloss, IVloss, Vloss, grads = train_network(custom_model, custom_t, inits, alpha, beta, gamma)

        # Gradient step
        opt.apply_gradients(zip(grads, custom_model.trainable_variables))
      
        epoch_loss[i] += alpha*DEloss + beta*IVloss + gamma*Vloss

        if (np.mod(i, 100)==0) :
            
            print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

    return epoch_loss, custom_model

# %%
colloc_points_per_cycle = 100
step_size = 0.001

# %%
def train_plot_sequential(custom_model, t_start, t_end, epochs, cycles, alpha, beta, gamma) :
    
    empty_arr = np.array([[]])
    
    x = tf.reshape(tf.convert_to_tensor(empty_arr, dtype=tf.float64), [0, 1])
    y = tf.reshape(tf.convert_to_tensor(empty_arr, dtype=tf.float64), [0, 1])

    t = np.arange(t_start, t_end, step_size)
    t = np.round(t, decimal_p)
    num_t = len(t)
    print("num t", num_t)
    
    delta_t = int((t_end - t_start)/cycles)
    
    print("colloc_points_per_cycle", colloc_points_per_cycle)
    print("delta_t", delta_t)

    loss_vals = np.zeros(epochs * cycles)
    next_model = custom_model
    
    next_x0 = x0
    next_y0 = y0
    
    custom_t = defineCollocationPoints([0.0, delta_t], colloc_points_per_cycle)
    
    t_pred = np.arange(0.0, delta_t, step_size)
    t_pred = np.round(t_pred, decimal_p)
    
    for i in range(cycles) :

        loss, model = PINNtrain(next_model, custom_t, next_x0, next_y0, epochs, alpha, beta, gamma)
        loss_vals[i*epochs : (i+1)*epochs] = loss
        
        [next_x, next_y] = model(t_pred, training=True)
        
        x = tf.concat([x, next_x], axis = 0)
        y = tf.concat([y, next_y], axis = 0)
        
        t_delta_t = np.array([delta_t]).astype(np.float64)
        
        [next_x0, next_y0] = model(t_delta_t, training=True)
        
        next_x0 = next_x0.numpy()[0][0]
        next_y0 = next_y0.numpy()[0][0]

        next_model = tf.keras.models.clone_model(model)
        next_model.build((None, 1))
        next_model.set_weights(model.get_weights())
        

    plt.figure(1)
    plt.semilogy(loss_vals)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    #plt.plot(x, y, label = "e = " + str(epochs) + ", cycles = " + str(cycles))
    plt.plot(x, y, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    plt.xlabel("x")
    plt.ylabel("y")
    
    error = calc_err(t, x, y)
    print("error", error)
    print("error mean", error/num_t)
    
    plt.figure(3)
    plt.scatter(cycles, error)
    plt.xlabel("number of cycles")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = math.sqrt((x_preds[i] - xpoints[t_i])**2 + (y_preds[i] - ypoints[t_i])**2)
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
# epochs = 500
# cycles = 4

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 4000, 1, 12, 1.2, 0.001)

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 8000, 1, 12, 1.2, 0.001)

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 12000, 1, 12, 1.2, 0.001)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# num t 12000
# colloc_points_per_cycle 100
# delta_t 12
# DE loss, IV loss, Vloss in 0th epoch:  0.0044,  1.3625,  19.4760.
# DE loss, IV loss, Vloss in 100th epoch:  0.0030,  0.1031,  0.0207.
# DE loss, IV loss, Vloss in 200th epoch:  0.0029,  0.1010,  0.0207.
# DE loss, IV loss, Vloss in 300th epoch:  0.0040,  0.0431,  0.0190.
# DE loss, IV loss, Vloss in 400th epoch:  0.0048,  0.0296,  0.0179.
# DE loss, IV loss, Vloss in 500th epoch:  0.0044,  0.0498,  0.0190.
# DE loss, IV loss, Vloss in 600th epoch:  0.0041,  0.0385,  0.0187.
# DE loss, IV loss, Vloss in 700th epoch:  0.0033,  0.0109,  0.0126.
# DE loss, IV loss, Vloss in 800th epoch:  0.0159,  0.0361,  0.0180.
# DE loss, IV loss, Vloss in 900th epoch:  0.0028,  0.0119,  0.0142.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0020,  0.0033,  0.0137.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0017,  0.0017,  0.0140.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0015,  0.0012,  0.0138.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0014,  0.0011,  0.0134.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0013,  0.0008,  0.0132.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0012,  0.0008,  0.0130.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0012,  0.0007,  0.0129.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0012,  0.0007,  0.0127.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0037,  0.0021,  0.0124.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0011,  0.0006,  0.0126.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0011,  0.0006,  0.0123.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0010,  0.0006,  0.0120.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0042,  0.0047,  0.0142.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0011,  0.0006,  0.0123.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0010,  0.0005,  0.0117.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0009,  0.0004,  0.0111.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0007,  0.0003,  0.0101.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0006,  0.0002,  0.0085.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0010,  0.0005,  0.0121.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0008,  0.0004,  0.0110.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0007,  0.0003,  0.0095.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0005,  0.0002,  0.0076.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0173,  0.0375,  0.0045.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0006,  0.0003,  0.0088.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0004,  0.0001,  0.0063.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0002,  0.0001,  0.0041.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0003,  0.0002,  0.0061.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0002,  0.0001,  0.0034.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0018,  0.0008,  0.0052.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0002,  0.0000,  0.0029.
# 12000
# error 991.9565590199551
# error mean 0.08266304658499625
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# num t 12000
# colloc_points_per_cycle 100
# delta_t 12
# DE loss, IV loss, Vloss in 0th epoch:  0.0083,  1.6153,    nan.
# DE loss, IV loss, Vloss in 100th epoch:  0.0029,  0.0969,  0.0208.
# DE loss, IV loss, Vloss in 200th epoch:  0.0055,  0.0505,  0.0196.
# DE loss, IV loss, Vloss in 300th epoch:  0.0030,  0.0084,  0.0178.
# DE loss, IV loss, Vloss in 400th epoch:  0.0112,  0.0060,  0.0150.
# DE loss, IV loss, Vloss in 500th epoch:  0.0017,  0.0022,  0.0146.
# DE loss, IV loss, Vloss in 600th epoch:  0.0014,  0.0010,  0.0134.
# DE loss, IV loss, Vloss in 700th epoch:  0.0013,  0.0007,  0.0128.
# DE loss, IV loss, Vloss in 800th epoch:  0.0011,  0.0005,  0.0123.
# DE loss, IV loss, Vloss in 900th epoch:  0.0012,  0.0009,  0.0129.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0010,  0.0005,  0.0119.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0009,  0.0004,  0.0110.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0418,  0.0054,  0.0756.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0025,  0.0514,  0.0199.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0033,  0.0118,  0.0189.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0030,  0.0090,  0.0182.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0028,  0.0078,  0.0178.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0027,  0.0070,  0.0176.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0025,  0.0061,  0.0172.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0022,  0.0048,  0.0165.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0020,  0.0027,  0.0155.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0018,  0.0019,  0.0151.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0018,  0.0016,  0.0149.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0017,  0.0015,  0.0147.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0017,  0.0014,  0.0146.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0016,  0.0013,  0.0145.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0016,  0.0012,  0.0145.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0016,  0.0012,  0.0144.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0015,  0.0012,  0.0144.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0015,  0.0012,  0.0143.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0014,  0.0011,  0.0143.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0014,  0.0011,  0.0141.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0013,  0.0010,  0.0139.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0012,  0.0009,  0.0137.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0012,  0.0008,  0.0134.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0011,  0.0007,  0.0130.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0011,  0.0007,  0.0127.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0011,  0.0006,  0.0124.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0010,  0.0005,  0.0122.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0010,  0.0005,  0.0120.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0010,  0.0005,  0.0119.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0010,  0.0004,  0.0117.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0010,  0.0004,  0.0116.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0009,  0.0004,  0.0116.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0009,  0.0004,  0.0116.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0007,  0.0005,  0.0112.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0007,  0.0002,  0.0104.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0005,  0.0004,  0.0094.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0004,  0.0002,  0.0081.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0003,  0.0001,  0.0062.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0002,  0.0001,  0.0050.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0001,  0.0001,  0.0033.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0001,  0.0000,  0.0023.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0001,  0.0000,  0.0017.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0040,  0.0050,  0.0001.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0000,  0.0000,  0.0011.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0000,  0.0000,  0.0008.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0000,  0.0000,  0.0006.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0000,  0.0000,  0.0004.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0000,  0.0000,  0.0005.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0000,  0.0000,  0.0003.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0027,  0.0045,  0.0000.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0000,  0.0000,  0.0003.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 6500th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 6600th epoch:  0.0000,  0.0000,  0.0003.
# DE loss, IV loss, Vloss in 6700th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 6800th epoch:  0.0001,  0.0000,  0.0004.
# DE loss, IV loss, Vloss in 6900th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 7000th epoch:  0.0001,  0.0000,  0.0003.
# DE loss, IV loss, Vloss in 7100th epoch:  0.0001,  0.0000,  0.0003.
# DE loss, IV loss, Vloss in 7200th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 7300th epoch:  0.0000,  0.0000,  0.0003.
# DE loss, IV loss, Vloss in 7400th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 7500th epoch:  0.0000,  0.0006,  0.0002.
# DE loss, IV loss, Vloss in 7600th epoch:  0.0003,  0.0004,  0.0004.
# DE loss, IV loss, Vloss in 7700th epoch:  0.0001,  0.0001,  0.0003.
# DE loss, IV loss, Vloss in 7800th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 7900th epoch:  0.0004,  0.0002,  0.0002.
# 12000
# error 271.9685035266075
# error mean 0.022664041960550625
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# num t 12000
# colloc_points_per_cycle 100
# delta_t 12
# DE loss, IV loss, Vloss in 0th epoch:  0.0469,  2.8136,  4.0377.
# DE loss, IV loss, Vloss in 100th epoch:  0.0029,  0.0973,  0.0207.
# DE loss, IV loss, Vloss in 200th epoch:  0.0035,  0.0378,  0.0185.
# DE loss, IV loss, Vloss in 300th epoch:  0.0021,  0.0031,  0.0143.
# DE loss, IV loss, Vloss in 400th epoch:  0.0015,  0.0013,  0.0136.
# DE loss, IV loss, Vloss in 500th epoch:  0.0018,  0.0038,  0.0123.
# DE loss, IV loss, Vloss in 600th epoch:  0.0012,  0.0009,  0.0129.
# DE loss, IV loss, Vloss in 700th epoch:  0.0017,  0.0118,  0.0132.
# DE loss, IV loss, Vloss in 800th epoch:  0.0011,  0.0006,  0.0124.
# DE loss, IV loss, Vloss in 900th epoch:  0.0009,  0.0004,  0.0114.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0115,  0.0094,  6.1355.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0141,  0.0095,  1.1121.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0084,  0.0083,  9.5758.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0030,  0.0216,  0.0173.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0015,  0.0013,  0.0146.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0014,  0.0008,  0.0134.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0013,  0.0007,  0.0130.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0012,  0.0006,  0.0125.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0011,  0.0005,  0.0120.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0010,  0.0004,  0.0116.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0064,  0.0326,  0.0097.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0009,  0.0004,  0.0115.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0008,  0.0003,  0.0102.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0006,  0.0002,  0.0086.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0008,  0.0003,  0.0104.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0006,  0.0002,  0.0083.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0004,  0.0001,  0.0062.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0005,  0.0002,  0.0082.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0003,  0.0001,  0.0048.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0003,  0.0001,  0.0049.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0001,  0.0001,  0.0025.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0002,  0.0003,  0.0031.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0001,  0.0001,  0.0011.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0003,  0.0007,  0.0005.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0001,  0.0000,  0.0005.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0001,  0.0001,  0.0004.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0001,  0.0004,  0.0002.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0000,  0.0004,  0.0003.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0002,  0.0007,  0.0005.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0000,  0.0003,  0.0002.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0000,  0.0004,  0.0001.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0000,  0.0003,  0.0002.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0000,  0.0002,  0.0001.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0000,  0.0003,  0.0001.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0001,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0000,  0.0002,  0.0001.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0010,  0.0007,  0.0002.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0001,  0.0019,  0.0008.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0002,  0.0013,  0.0001.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0000,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0000,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0002,  0.0005,  0.0001.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0001,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0001,  0.0013,  0.0003.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0002,  0.0002,  0.0001.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0001,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0001,  0.0010,  0.0006.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0000,  0.0001,  0.0001.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0000,  0.0007,  0.0002.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0000,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 6500th epoch:  0.0001,  0.0006,  0.0001.
# DE loss, IV loss, Vloss in 6600th epoch:  0.0001,  0.0001,  0.0001.
# DE loss, IV loss, Vloss in 6700th epoch:  0.0000,  0.0009,  0.0001.
# DE loss, IV loss, Vloss in 6800th epoch:  0.0000,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 6900th epoch:  0.0000,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 7000th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 7100th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 7200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 7300th epoch:  0.0000,  0.0006,  0.0002.
# DE loss, IV loss, Vloss in 7400th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 7500th epoch:  0.0000,  0.0001,  0.0001.
# DE loss, IV loss, Vloss in 7600th epoch:  0.0047,  0.0073,  0.0112.
# DE loss, IV loss, Vloss in 7700th epoch:  0.0004,  0.0001,  0.0065.
# DE loss, IV loss, Vloss in 7800th epoch:  0.0002,  0.0001,  0.0033.
# DE loss, IV loss, Vloss in 7900th epoch:  0.0001,  0.0000,  0.0019.
# DE loss, IV loss, Vloss in 8000th epoch:  0.0001,  0.0000,  0.0012.
# DE loss, IV loss, Vloss in 8100th epoch:  0.0001,  0.0000,  0.0008.
# DE loss, IV loss, Vloss in 8200th epoch:  0.0000,  0.0000,  0.0005.
# DE loss, IV loss, Vloss in 8300th epoch:  0.0000,  0.0000,  0.0003.
# DE loss, IV loss, Vloss in 8400th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 8500th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 8600th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 8700th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 8800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 8900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9200th epoch:  0.0003,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 9300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9800th epoch:  0.0003,  0.0000,  0.0004.
# DE loss, IV loss, Vloss in 9900th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 10000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 10100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 10200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 10300th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 10400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 10500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 10600th epoch:  0.0000,  0.0000,  0.0006.
# DE loss, IV loss, Vloss in 10700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 10800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 10900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 11000th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 11100th epoch:  0.0000,  0.0007,  0.0001.
# DE loss, IV loss, Vloss in 11200th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 11300th epoch:  0.0001,  0.0001,  0.0002.
# DE loss, IV loss, Vloss in 11400th epoch:  0.0000,  0.0000,  0.0002.
# DE loss, IV loss, Vloss in 11500th epoch:  0.0000,  0.0000,  0.0001.
# DE loss, IV loss, Vloss in 11600th epoch:  0.0000,  0.0000,  0.0004.
# DE loss, IV loss, Vloss in 11700th epoch:  0.0002,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 11800th epoch:  0.0002,  0.0001,  0.0001.
# DE loss, IV loss, Vloss in 11900th epoch:  0.0000,  0.0000,  0.0001.
# 12000
# error 290.2155970955071
# error mean 0.02418463309129226

# %%
end = time.time()

print((end-start)/60)
# Out:
# 10.478007046381633

# %%
#     2 3 4

# 20 0.05328786159898205, 0.03248169943505809, 0.014598205832759456
# 30 0.060848330988604774, 0.019430389301504553, 0.0069668703920268285
# 40 0.03672581839745748, 0.00413 ,0.004484866589899533
