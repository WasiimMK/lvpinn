# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3900429814659359120
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 12

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 12 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
#model = build_model(summary = True)

# %%
#tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 100)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(odes, inits, model, gamma, epsilon, phi):

    # DE collocation points
    t_de = odes[:,:1]

    # Initial value points
    t_init, x_init, y_init = inits[:1], inits[1:2], inits[2:]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
      
      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
      vt = (c * (tf.math.exp(x)) * xt) - (d * xt) + (b * tf.math.exp(y) * yt) - (a * yt)
        
      Vloss = tf.math.reduce_mean(tf.square(tf.boolean_mask(v, tf.math.is_finite(v))) - v0)
      Vtloss = tf.math.reduce_mean(tf.math.square(vt))
    
      new = (yt * (b*(tf.math.exp(y)) - a)) + (xt * (c*(tf.math.exp(x)) - d))
      newloss = tf.reduce_mean(tf.math.square(new))
    
      #tf.print(newloss)
    
      Vtloss = newloss

      #tf.print(newloss)
    
      # Composite loss function
      loss = phi*DEloss + gamma*IVloss + epsilon*Vloss + 0*Vtloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, Vtloss, grads

# %%
def PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val, phi_val):

  # Total number of collocation points
  N_de = len(de_points)

  # Batch size
  bs_de = N_de//10

  # Weight factors
  gamma = gamma_val
  epsilon = epsilon_val
  phi = phi_val

  # Learning rate
  lr_model = 1e-3

  # Initial value
  t_init = np.array([t0]).astype(np.float32)
  x_init = np.array([x0]).astype(np.float32)
  y_init = np.array([y0]).astype(np.float32)

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Generate the tf.Dataset for the initial collocation points
  inits = np.column_stack([t_init, x_init, y_init])
  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache()


  # Generate the tf.Dataset for the differential equations points
  ds_ode = tf.data.Dataset.from_tensor_slices(de_points.astype(np.float32))
  ds_ode = ds_ode.cache().shuffle(N_de).batch(bs_de)

  # Generate entire dataset
  ds = tf.data.Dataset.zip((ds_ode, ds_init))

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  # Generate the model
  opt = tf.keras.optimizers.Adam(lr_model)
  model = build_model() 

  # Main training loop
  for i in range(epochs):

    # Training for that epoch
    for (des, inits) in ds:

      # Train the network
      DEloss, IVloss, Vloss, Vtloss, grads = train_network(des, inits, model, gamma, epsilon, phi)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))
      
      epoch_loss[i] += DEloss + gamma*IVloss + epsilon*Vloss + phi*Vtloss
      nr_batches = nr_batches + 1

    # Get total epoch loss
    epoch_loss[i] = epoch_loss[i]/nr_batches
    nr_batches = 0

    
    if (np.mod(i, 100)==0):
      print("DE loss, IV loss, Vloss, Vtloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}, {: 6.8f}.".format(i, DEloss, IVloss, Vloss, Vtloss))

  return epoch_loss, model

# %%
def train_plot(epochs, gamma, epsilon, phi) :
    
    loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon, phi)
    
    # Grid where to evaluate the model
    step_size = 0.005
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.plot(loss)

    # Model prediction
    [x, y] = model(t)
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", gamma = " + str(gamma) + ", epsilon = " + str(epsilon)  + ", phi = " + str(phi))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)    
    
    plt.figure(3)
    
    plt.scatter(phi, error)
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x)
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y)

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 8000


train_plot(8000, 1.2, 0.0001, 0.0)
train_plot(10000, 1.2, 0.0001, 0.0)
train_plot(12000, 1.2, 0.0001, 0.0)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1302/Tanh:0', description="created by layer 'dense_1302'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1303/Tanh:0', description="created by layer 'dense_1303'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1304/Tanh:0', description="created by layer 'dense_1304'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1305/Tanh:0', description="created by layer 'dense_1305'")
# DE loss, IV loss, Vloss, Vtloss in 0th epoch:  0.4732,  0.0623,  3.1813,  0.00030835.
# DE loss, IV loss, Vloss, Vtloss in 100th epoch:  0.0607,  0.0040,  2.4358,  0.00045138.
# DE loss, IV loss, Vloss, Vtloss in 200th epoch:  0.0144,  0.0070,  2.3363,  0.00008520.
# DE loss, IV loss, Vloss, Vtloss in 300th epoch:  0.0160,  0.0115,  2.3370,  0.00021119.
# DE loss, IV loss, Vloss, Vtloss in 400th epoch:  0.0324,  0.0021,  2.3744,  0.00091321.
# DE loss, IV loss, Vloss, Vtloss in 500th epoch:  0.0036,  0.0005,  2.2981,  0.00004256.
# DE loss, IV loss, Vloss, Vtloss in 600th epoch:  0.0329,  0.0002,  2.4168,  0.00229830.
# DE loss, IV loss, Vloss, Vtloss in 700th epoch:  0.0034,  0.0011,  2.3120,  0.00015743.
# DE loss, IV loss, Vloss, Vtloss in 800th epoch:  0.0037,  0.0003,  2.3321,  0.00021763.
# DE loss, IV loss, Vloss, Vtloss in 900th epoch:  0.0120,  0.0017,  2.3707,  0.00116899.
# DE loss, IV loss, Vloss, Vtloss in 1000th epoch:  0.0042,  0.0002,  2.3892,  0.00034988.
# DE loss, IV loss, Vloss, Vtloss in 1100th epoch:  0.0090,  0.0013,  2.4202,  0.00111255.
# DE loss, IV loss, Vloss, Vtloss in 1200th epoch:  0.0041,  0.0004,  2.3455,  0.00017246.
# DE loss, IV loss, Vloss, Vtloss in 1300th epoch:  0.0088,  0.0009,  2.3922,  0.00119462.
# DE loss, IV loss, Vloss, Vtloss in 1400th epoch:  0.0044,  0.0001,  2.3521,  0.00027955.
# DE loss, IV loss, Vloss, Vtloss in 1500th epoch:  0.0031,  0.0000,  2.3856,  0.00018205.
# DE loss, IV loss, Vloss, Vtloss in 1600th epoch:  0.0045,  0.0007,  2.3927,  0.00051466.
# DE loss, IV loss, Vloss, Vtloss in 1700th epoch:  0.0030,  0.0004,  2.3809,  0.00019880.
# DE loss, IV loss, Vloss, Vtloss in 1800th epoch:  0.0031,  0.0006,  2.4118,  0.00014329.
# DE loss, IV loss, Vloss, Vtloss in 1900th epoch:  0.0032,  0.0007,  2.4353,  0.00037190.
# DE loss, IV loss, Vloss, Vtloss in 2000th epoch:  0.0034,  0.0000,  2.5036,  0.00043699.
# DE loss, IV loss, Vloss, Vtloss in 2100th epoch:  0.0056,  0.0001,  2.4193,  0.00050372.
# DE loss, IV loss, Vloss, Vtloss in 2200th epoch:  0.0028,  0.0003,  2.4036,  0.00017983.
# DE loss, IV loss, Vloss, Vtloss in 2300th epoch:  0.0048,  0.0000,  2.3782,  0.00023524.
# DE loss, IV loss, Vloss, Vtloss in 2400th epoch:  0.0024,  0.0001,  2.3766,  0.00010590.
# DE loss, IV loss, Vloss, Vtloss in 2500th epoch:  0.0054,  0.0004,  2.5338,  0.00043662.
# DE loss, IV loss, Vloss, Vtloss in 2600th epoch:  0.0033,  0.0001,  2.4207,  0.00017976.
# DE loss, IV loss, Vloss, Vtloss in 2700th epoch:  0.0039,  0.0001,  2.5071,  0.00059147.
# DE loss, IV loss, Vloss, Vtloss in 2800th epoch:  0.0030,  0.0002,  2.4280,  0.00051461.
# DE loss, IV loss, Vloss, Vtloss in 2900th epoch:  0.0032,  0.0007,  2.4149,  0.00020401.
# DE loss, IV loss, Vloss, Vtloss in 3000th epoch:  0.0027,  0.0000,  2.3550,  0.00011729.
# DE loss, IV loss, Vloss, Vtloss in 3100th epoch:  0.0038,  0.0005,  2.4820,  0.00018818.
# DE loss, IV loss, Vloss, Vtloss in 3200th epoch:  0.0038,  0.0006,  2.3463,  0.00014557.
# DE loss, IV loss, Vloss, Vtloss in 3300th epoch:  0.0038,  0.0001,  2.6131,  0.00036657.
# DE loss, IV loss, Vloss, Vtloss in 3400th epoch:  0.0042,  0.0000,  2.4613,  0.00049248.
# DE loss, IV loss, Vloss, Vtloss in 3500th epoch:  0.0037,  0.0007,  2.4770,  0.00023520.
# DE loss, IV loss, Vloss, Vtloss in 3600th epoch:  0.0025,  0.0009,  2.4718,  0.00013843.
# DE loss, IV loss, Vloss, Vtloss in 3700th epoch:  0.0042,  0.0001,  2.5705,  0.00064680.
# DE loss, IV loss, Vloss, Vtloss in 3800th epoch:  0.0042,  0.0002,  2.5555,  0.00062286.
# DE loss, IV loss, Vloss, Vtloss in 3900th epoch:  0.0050,  0.0000,  2.5535,  0.00043643.
# DE loss, IV loss, Vloss, Vtloss in 4000th epoch:  0.0028,  0.0001,  2.3727,  0.00013010.
# DE loss, IV loss, Vloss, Vtloss in 4100th epoch:  0.0017,  0.0002,  2.4319,  0.00009878.
# DE loss, IV loss, Vloss, Vtloss in 4200th epoch:  0.0024,  0.0003,  2.4749,  0.00020789.
# DE loss, IV loss, Vloss, Vtloss in 4300th epoch:  0.0031,  0.0003,  2.5602,  0.00021750.
# DE loss, IV loss, Vloss, Vtloss in 4400th epoch:  0.0019,  0.0001,  2.4982,  0.00017073.
# DE loss, IV loss, Vloss, Vtloss in 4500th epoch:  0.0029,  0.0001,  2.4726,  0.00025670.
# DE loss, IV loss, Vloss, Vtloss in 4600th epoch:  0.0019,  0.0003,  2.4750,  0.00015891.
# DE loss, IV loss, Vloss, Vtloss in 4700th epoch:  0.0034,  0.0001,  2.5829,  0.00034611.
# DE loss, IV loss, Vloss, Vtloss in 4800th epoch:  0.0037,  0.0000,  2.4447,  0.00022753.
# DE loss, IV loss, Vloss, Vtloss in 4900th epoch:  0.0026,  0.0003,  2.4444,  0.00011148.
# DE loss, IV loss, Vloss, Vtloss in 5000th epoch:  0.0025,  0.0002,  2.4577,  0.00015398.
# DE loss, IV loss, Vloss, Vtloss in 5100th epoch:  0.0028,  0.0001,  2.4387,  0.00009562.
# DE loss, IV loss, Vloss, Vtloss in 5200th epoch:  0.0018,  0.0000,  2.4550,  0.00012246.
# DE loss, IV loss, Vloss, Vtloss in 5300th epoch:  0.0015,  0.0001,  2.5147,  0.00013576.
# DE loss, IV loss, Vloss, Vtloss in 5400th epoch:  0.0019,  0.0001,  2.5388,  0.00013197.
# DE loss, IV loss, Vloss, Vtloss in 5500th epoch:  0.0023,  0.0000,  2.5125,  0.00020055.
# DE loss, IV loss, Vloss, Vtloss in 5600th epoch:  0.0018,  0.0002,  2.4954,  0.00012345.
# DE loss, IV loss, Vloss, Vtloss in 5700th epoch:  0.0017,  0.0000,  2.4706,  0.00011383.
# DE loss, IV loss, Vloss, Vtloss in 5800th epoch:  0.0018,  0.0001,  2.4986,  0.00009263.
# DE loss, IV loss, Vloss, Vtloss in 5900th epoch:  0.0025,  0.0002,  2.4904,  0.00012052.
# DE loss, IV loss, Vloss, Vtloss in 6000th epoch:  0.0020,  0.0001,  2.5077,  0.00015463.
# DE loss, IV loss, Vloss, Vtloss in 6100th epoch:  0.0012,  0.0003,  2.5699,  0.00009385.
# DE loss, IV loss, Vloss, Vtloss in 6200th epoch:  0.0015,  0.0004,  2.6640,  0.00020146.
# DE loss, IV loss, Vloss, Vtloss in 6300th epoch:  0.0019,  0.0001,  2.6062,  0.00029820.
# DE loss, IV loss, Vloss, Vtloss in 6400th epoch:  0.0020,  0.0001,  2.4833,  0.00010113.
# DE loss, IV loss, Vloss, Vtloss in 6500th epoch:  0.0022,  0.0000,  2.5186,  0.00025554.
# DE loss, IV loss, Vloss, Vtloss in 6600th epoch:  0.0029,  0.0001,  2.6381,  0.00038272.
# DE loss, IV loss, Vloss, Vtloss in 6700th epoch:  0.0013,  0.0003,  2.5868,  0.00012084.
# DE loss, IV loss, Vloss, Vtloss in 6800th epoch:  0.0018,  0.0000,  2.6846,  0.00022703.
# DE loss, IV loss, Vloss, Vtloss in 6900th epoch:  0.0016,  0.0002,  2.5795,  0.00012032.
# DE loss, IV loss, Vloss, Vtloss in 7000th epoch:  0.0008,  0.0002,  2.6190,  0.00008527.
# DE loss, IV loss, Vloss, Vtloss in 7100th epoch:  0.0013,  0.0000,  2.6435,  0.00012484.
# DE loss, IV loss, Vloss, Vtloss in 7200th epoch:  0.0013,  0.0002,  2.5566,  0.00012758.
# DE loss, IV loss, Vloss, Vtloss in 7300th epoch:  0.0005,  0.0004,  2.7188,  0.00008516.
# DE loss, IV loss, Vloss, Vtloss in 7400th epoch:  0.0010,  0.0000,  2.7022,  0.00008877.
# DE loss, IV loss, Vloss, Vtloss in 7500th epoch:  0.0004,  0.0001,  2.6866,  0.00005015.
# DE loss, IV loss, Vloss, Vtloss in 7600th epoch:  0.0005,  0.0001,  2.7410,  0.00004782.
# DE loss, IV loss, Vloss, Vtloss in 7700th epoch:  0.0004,  0.0001,  2.7361,  0.00005454.
# DE loss, IV loss, Vloss, Vtloss in 7800th epoch:  0.0004,  0.0002,  2.7740,  0.00005260.
# DE loss, IV loss, Vloss, Vtloss in 7900th epoch:  0.0009,  0.0002,  2.7949,  0.00011159.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1308/Tanh:0', description="created by layer 'dense_1308'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1309/Tanh:0', description="created by layer 'dense_1309'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1310/Tanh:0', description="created by layer 'dense_1310'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1311/Tanh:0', description="created by layer 'dense_1311'")
# DE loss, IV loss, Vloss, Vtloss in 0th epoch:  0.6242,  0.1186,  3.3373,  0.00063201.
# DE loss, IV loss, Vloss, Vtloss in 100th epoch:  0.0540,  0.0013,  2.4179,  0.00041636.
# DE loss, IV loss, Vloss, Vtloss in 200th epoch:  0.0218,  0.0002,  2.3447,  0.00033942.
# DE loss, IV loss, Vloss, Vtloss in 300th epoch:  0.0306,  0.0039,  2.3656,  0.00066732.
# DE loss, IV loss, Vloss, Vtloss in 400th epoch:  0.0030,  0.0028,  2.3147,  0.00001876.
# DE loss, IV loss, Vloss, Vtloss in 500th epoch:  0.0164,  0.0004,  2.3740,  0.00069813.
# DE loss, IV loss, Vloss, Vtloss in 600th epoch:  0.0042,  0.0007,  2.3765,  0.00013501.
# DE loss, IV loss, Vloss, Vtloss in 700th epoch:  0.0223,  0.0040,  2.4476,  0.00147802.
# DE loss, IV loss, Vloss, Vtloss in 800th epoch:  0.0040,  0.0011,  2.3390,  0.00006765.
# DE loss, IV loss, Vloss, Vtloss in 900th epoch:  0.0127,  0.0003,  2.4190,  0.00107850.
# DE loss, IV loss, Vloss, Vtloss in 1000th epoch:  0.0082,  0.0012,  2.3914,  0.00069502.
# DE loss, IV loss, Vloss, Vtloss in 1100th epoch:  0.0022,  0.0004,  2.3717,  0.00010535.
# DE loss, IV loss, Vloss, Vtloss in 1200th epoch:  0.0056,  0.0017,  2.3953,  0.00032145.
# DE loss, IV loss, Vloss, Vtloss in 1300th epoch:  0.0117,  0.0002,  2.4152,  0.00144227.
# DE loss, IV loss, Vloss, Vtloss in 1400th epoch:  0.0019,  0.0001,  2.3106,  0.00004065.
# DE loss, IV loss, Vloss, Vtloss in 1500th epoch:  0.0064,  0.0005,  2.3514,  0.00068670.
# DE loss, IV loss, Vloss, Vtloss in 1600th epoch:  0.0038,  0.0001,  2.3589,  0.00021678.
# DE loss, IV loss, Vloss, Vtloss in 1700th epoch:  0.0038,  0.0014,  2.4043,  0.00023660.
# DE loss, IV loss, Vloss, Vtloss in 1800th epoch:  0.0042,  0.0007,  2.4185,  0.00037130.
# DE loss, IV loss, Vloss, Vtloss in 1900th epoch:  0.0041,  0.0003,  2.3987,  0.00058260.
# DE loss, IV loss, Vloss, Vtloss in 2000th epoch:  0.0046,  0.0002,  2.5433,  0.00065784.
# DE loss, IV loss, Vloss, Vtloss in 2100th epoch:  0.0030,  0.0002,  2.4526,  0.00022115.
# DE loss, IV loss, Vloss, Vtloss in 2200th epoch:  0.0028,  0.0000,  2.4096,  0.00020421.
# DE loss, IV loss, Vloss, Vtloss in 2300th epoch:  0.0080,  0.0002,  2.4825,  0.00113634.
# DE loss, IV loss, Vloss, Vtloss in 2400th epoch:  0.0035,  0.0003,  2.4814,  0.00023700.
# DE loss, IV loss, Vloss, Vtloss in 2500th epoch:  0.0039,  0.0002,  2.4610,  0.00028266.
# DE loss, IV loss, Vloss, Vtloss in 2600th epoch:  0.0021,  0.0003,  2.4465,  0.00012652.
# DE loss, IV loss, Vloss, Vtloss in 2700th epoch:  0.0042,  0.0001,  2.5271,  0.00064004.
# DE loss, IV loss, Vloss, Vtloss in 2800th epoch:  0.0027,  0.0006,  2.4010,  0.00016083.
# DE loss, IV loss, Vloss, Vtloss in 2900th epoch:  0.0028,  0.0003,  2.3586,  0.00016106.
# DE loss, IV loss, Vloss, Vtloss in 3000th epoch:  0.0020,  0.0001,  2.3876,  0.00011429.
# DE loss, IV loss, Vloss, Vtloss in 3100th epoch:  0.0024,  0.0005,  2.3319,  0.00008601.
# DE loss, IV loss, Vloss, Vtloss in 3200th epoch:  0.0037,  0.0000,  2.4477,  0.00027636.
# DE loss, IV loss, Vloss, Vtloss in 3300th epoch:  0.0017,  0.0000,  2.4281,  0.00010337.
# DE loss, IV loss, Vloss, Vtloss in 3400th epoch:  0.0038,  0.0001,  2.4252,  0.00038698.
# DE loss, IV loss, Vloss, Vtloss in 3500th epoch:  0.0020,  0.0001,  2.4778,  0.00016931.
# DE loss, IV loss, Vloss, Vtloss in 3600th epoch:  0.0022,  0.0005,  2.4645,  0.00013784.
# DE loss, IV loss, Vloss, Vtloss in 3700th epoch:  0.0018,  0.0001,  2.4433,  0.00011429.
# DE loss, IV loss, Vloss, Vtloss in 3800th epoch:  0.0018,  0.0001,  2.4421,  0.00010689.
# DE loss, IV loss, Vloss, Vtloss in 3900th epoch:  0.0031,  0.0001,  2.4610,  0.00030904.
# DE loss, IV loss, Vloss, Vtloss in 4000th epoch:  0.0028,  0.0003,  2.4953,  0.00019887.
# DE loss, IV loss, Vloss, Vtloss in 4100th epoch:  0.0035,  0.0002,  2.4587,  0.00039429.
# DE loss, IV loss, Vloss, Vtloss in 4200th epoch:  0.0022,  0.0003,  2.5314,  0.00024126.
# DE loss, IV loss, Vloss, Vtloss in 4300th epoch:  0.0022,  0.0004,  2.5751,  0.00020910.
# DE loss, IV loss, Vloss, Vtloss in 4400th epoch:  0.0024,  0.0001,  2.4441,  0.00017696.
# DE loss, IV loss, Vloss, Vtloss in 4500th epoch:  0.0023,  0.0002,  2.5129,  0.00020414.
# DE loss, IV loss, Vloss, Vtloss in 4600th epoch:  0.0017,  0.0004,  2.5918,  0.00016599.
# DE loss, IV loss, Vloss, Vtloss in 4700th epoch:  0.0022,  0.0000,  2.4629,  0.00017428.
# DE loss, IV loss, Vloss, Vtloss in 4800th epoch:  0.0025,  0.0002,  2.4867,  0.00019852.
# DE loss, IV loss, Vloss, Vtloss in 4900th epoch:  0.0018,  0.0001,  2.5145,  0.00015151.
# DE loss, IV loss, Vloss, Vtloss in 5000th epoch:  0.0019,  0.0003,  2.4654,  0.00010502.
# DE loss, IV loss, Vloss, Vtloss in 5100th epoch:  0.0024,  0.0001,  2.6653,  0.00019471.
# DE loss, IV loss, Vloss, Vtloss in 5200th epoch:  0.0035,  0.0001,  2.4744,  0.00049760.
# DE loss, IV loss, Vloss, Vtloss in 5300th epoch:  0.0012,  0.0006,  2.5376,  0.00012428.
# DE loss, IV loss, Vloss, Vtloss in 5400th epoch:  0.0022,  0.0001,  2.5179,  0.00017369.
# DE loss, IV loss, Vloss, Vtloss in 5500th epoch:  0.0019,  0.0002,  2.5137,  0.00016853.
# DE loss, IV loss, Vloss, Vtloss in 5600th epoch:  0.0020,  0.0000,  2.5889,  0.00019241.
# DE loss, IV loss, Vloss, Vtloss in 5700th epoch:  0.0015,  0.0005,  2.4402,  0.00005829.
# DE loss, IV loss, Vloss, Vtloss in 5800th epoch:  0.0028,  0.0001,  2.5441,  0.00040863.
# DE loss, IV loss, Vloss, Vtloss in 5900th epoch:  0.0031,  0.0000,  2.5946,  0.00046756.
# DE loss, IV loss, Vloss, Vtloss in 6000th epoch:  0.0015,  0.0003,  2.5443,  0.00014138.
# DE loss, IV loss, Vloss, Vtloss in 6100th epoch:  0.0031,  0.0002,  2.5187,  0.00018958.
# DE loss, IV loss, Vloss, Vtloss in 6200th epoch:  0.0013,  0.0000,  2.5799,  0.00011346.
# DE loss, IV loss, Vloss, Vtloss in 6300th epoch:  0.0021,  0.0000,  2.5601,  0.00017273.
# DE loss, IV loss, Vloss, Vtloss in 6400th epoch:  0.0018,  0.0002,  2.4763,  0.00013555.
# DE loss, IV loss, Vloss, Vtloss in 6500th epoch:  0.0019,  0.0000,  2.6743,  0.00024667.
# DE loss, IV loss, Vloss, Vtloss in 6600th epoch:  0.0014,  0.0001,  2.4576,  0.00010391.
# DE loss, IV loss, Vloss, Vtloss in 6700th epoch:  0.0017,  0.0000,  2.5759,  0.00011755.
# DE loss, IV loss, Vloss, Vtloss in 6800th epoch:  0.0018,  0.0000,  2.6256,  0.00020214.
# DE loss, IV loss, Vloss, Vtloss in 6900th epoch:  0.0019,  0.0005,  2.6031,  0.00026232.
# DE loss, IV loss, Vloss, Vtloss in 7000th epoch:  0.0028,  0.0005,  2.5436,  0.00018884.
# DE loss, IV loss, Vloss, Vtloss in 7100th epoch:  0.0015,  0.0002,  2.6687,  0.00016510.
# DE loss, IV loss, Vloss, Vtloss in 7200th epoch:  0.0009,  0.0001,  2.6185,  0.00007708.
# DE loss, IV loss, Vloss, Vtloss in 7300th epoch:  0.0016,  0.0001,  2.5963,  0.00013634.
# DE loss, IV loss, Vloss, Vtloss in 7400th epoch:  0.0006,  0.0001,  2.5939,  0.00005156.
# DE loss, IV loss, Vloss, Vtloss in 7500th epoch:  0.0009,  0.0001,  2.6535,  0.00009537.
# DE loss, IV loss, Vloss, Vtloss in 7600th epoch:  0.0012,  0.0002,  2.7342,  0.00019983.
# DE loss, IV loss, Vloss, Vtloss in 7700th epoch:  0.0005,  0.0002,  2.7148,  0.00003989.
# DE loss, IV loss, Vloss, Vtloss in 7800th epoch:  0.0004,  0.0001,  2.7098,  0.00004001.
# DE loss, IV loss, Vloss, Vtloss in 7900th epoch:  0.0012,  0.0000,  2.7045,  0.00010085.
# DE loss, IV loss, Vloss, Vtloss in 8000th epoch:  0.0003,  0.0002,  2.7206,  0.00003464.
# DE loss, IV loss, Vloss, Vtloss in 8100th epoch:  0.0004,  0.0004,  2.7701,  0.00002746.
# DE loss, IV loss, Vloss, Vtloss in 8200th epoch:  0.0003,  0.0000,  2.8001,  0.00003700.
# DE loss, IV loss, Vloss, Vtloss in 8300th epoch:  0.0004,  0.0001,  2.7891,  0.00002418.
# DE loss, IV loss, Vloss, Vtloss in 8400th epoch:  0.0002,  0.0001,  2.7937,  0.00002721.
# DE loss, IV loss, Vloss, Vtloss in 8500th epoch:  0.0001,  0.0000,  2.8325,  0.00001080.
# DE loss, IV loss, Vloss, Vtloss in 8600th epoch:  0.0001,  0.0002,  2.8238,  0.00001666.
# DE loss, IV loss, Vloss, Vtloss in 8700th epoch:  0.0004,  0.0000,  2.8306,  0.00004312.
# DE loss, IV loss, Vloss, Vtloss in 8800th epoch:  0.0005,  0.0000,  2.8425,  0.00004382.
# DE loss, IV loss, Vloss, Vtloss in 8900th epoch:  0.0001,  0.0000,  2.8340,  0.00000668.
# DE loss, IV loss, Vloss, Vtloss in 9000th epoch:  0.0001,  0.0000,  2.8521,  0.00001711.
# DE loss, IV loss, Vloss, Vtloss in 9100th epoch:  0.0004,  0.0000,  2.8598,  0.00006193.
# DE loss, IV loss, Vloss, Vtloss in 9200th epoch:  0.0001,  0.0001,  2.8639,  0.00001337.
# DE loss, IV loss, Vloss, Vtloss in 9300th epoch:  0.0001,  0.0000,  2.8613,  0.00000736.
# DE loss, IV loss, Vloss, Vtloss in 9400th epoch:  0.0001,  0.0000,  2.8522,  0.00000588.
# DE loss, IV loss, Vloss, Vtloss in 9500th epoch:  0.0002,  0.0000,  2.8746,  0.00002080.
# DE loss, IV loss, Vloss, Vtloss in 9600th epoch:  0.0001,  0.0000,  2.8714,  0.00001298.
# DE loss, IV loss, Vloss, Vtloss in 9700th epoch:  0.0001,  0.0000,  2.8638,  0.00000845.
# DE loss, IV loss, Vloss, Vtloss in 9800th epoch:  0.0002,  0.0001,  2.8632,  0.00001993.
# DE loss, IV loss, Vloss, Vtloss in 9900th epoch:  0.0002,  0.0003,  2.8757,  0.00002151.
# 2400
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1314/Tanh:0', description="created by layer 'dense_1314'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1315/Tanh:0', description="created by layer 'dense_1315'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1316/Tanh:0', description="created by layer 'dense_1316'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1317/Tanh:0', description="created by layer 'dense_1317'")
# DE loss, IV loss, Vloss, Vtloss in 0th epoch:  0.4404,  0.1924,  3.2052,  0.00066533.
# DE loss, IV loss, Vloss, Vtloss in 100th epoch:  0.0235,  0.0106,  2.3359,  0.00012218.
# DE loss, IV loss, Vloss, Vtloss in 200th epoch:  0.0195,  0.0023,  2.3235,  0.00018864.
# DE loss, IV loss, Vloss, Vtloss in 300th epoch:  0.0081,  0.0052,  2.2977,  0.00010830.
# DE loss, IV loss, Vloss, Vtloss in 400th epoch:  0.0164,  0.0002,  2.3181,  0.00053757.
# DE loss, IV loss, Vloss, Vtloss in 500th epoch:  0.0014,  0.0023,  2.2924,  0.00000299.
# DE loss, IV loss, Vloss, Vtloss in 600th epoch:  0.0099,  0.0024,  2.3471,  0.00064891.
# DE loss, IV loss, Vloss, Vtloss in 700th epoch:  0.0122,  0.0019,  2.3589,  0.00080999.
# DE loss, IV loss, Vloss, Vtloss in 800th epoch:  0.0055,  0.0030,  2.2921,  0.00002374.
# DE loss, IV loss, Vloss, Vtloss in 900th epoch:  0.0023,  0.0001,  2.3089,  0.00004473.
# DE loss, IV loss, Vloss, Vtloss in 1000th epoch:  0.0106,  0.0001,  2.3839,  0.00121807.
# DE loss, IV loss, Vloss, Vtloss in 1100th epoch:  0.0063,  0.0003,  2.3879,  0.00066894.
# DE loss, IV loss, Vloss, Vtloss in 1200th epoch:  0.0036,  0.0000,  2.4051,  0.00021704.
# DE loss, IV loss, Vloss, Vtloss in 1300th epoch:  0.0030,  0.0002,  2.3813,  0.00024333.
# DE loss, IV loss, Vloss, Vtloss in 1400th epoch:  0.0020,  0.0003,  2.3006,  0.00004185.
# DE loss, IV loss, Vloss, Vtloss in 1500th epoch:  0.0061,  0.0015,  2.3705,  0.00048633.
# DE loss, IV loss, Vloss, Vtloss in 1600th epoch:  0.0033,  0.0002,  2.3996,  0.00023355.
# DE loss, IV loss, Vloss, Vtloss in 1700th epoch:  0.0033,  0.0004,  2.3560,  0.00010806.
# DE loss, IV loss, Vloss, Vtloss in 1800th epoch:  0.0030,  0.0004,  2.3874,  0.00015762.
# DE loss, IV loss, Vloss, Vtloss in 1900th epoch:  0.0033,  0.0008,  2.3128,  0.00011981.
# DE loss, IV loss, Vloss, Vtloss in 2000th epoch:  0.0031,  0.0001,  2.3703,  0.00018982.
# DE loss, IV loss, Vloss, Vtloss in 2100th epoch:  0.0033,  0.0009,  2.4159,  0.00017327.
# DE loss, IV loss, Vloss, Vtloss in 2200th epoch:  0.0037,  0.0002,  2.4607,  0.00034898.
# DE loss, IV loss, Vloss, Vtloss in 2300th epoch:  0.0015,  0.0000,  2.3210,  0.00003847.
# DE loss, IV loss, Vloss, Vtloss in 2400th epoch:  0.0027,  0.0000,  2.3578,  0.00014268.
# DE loss, IV loss, Vloss, Vtloss in 2500th epoch:  0.0039,  0.0003,  2.3549,  0.00012012.
# DE loss, IV loss, Vloss, Vtloss in 2600th epoch:  0.0040,  0.0002,  2.4424,  0.00031073.
# DE loss, IV loss, Vloss, Vtloss in 2700th epoch:  0.0049,  0.0001,  2.4270,  0.00090302.
# DE loss, IV loss, Vloss, Vtloss in 2800th epoch:  0.0032,  0.0008,  2.3868,  0.00018252.
# DE loss, IV loss, Vloss, Vtloss in 2900th epoch:  0.0027,  0.0004,  2.4317,  0.00019760.
# DE loss, IV loss, Vloss, Vtloss in 3000th epoch:  0.0022,  0.0001,  2.4445,  0.00011649.
# DE loss, IV loss, Vloss, Vtloss in 3100th epoch:  0.0028,  0.0004,  2.4456,  0.00018909.
# DE loss, IV loss, Vloss, Vtloss in 3200th epoch:  0.0034,  0.0003,  2.4326,  0.00018635.
# DE loss, IV loss, Vloss, Vtloss in 3300th epoch:  0.0024,  0.0001,  2.4519,  0.00022087.
# DE loss, IV loss, Vloss, Vtloss in 3400th epoch:  0.0054,  0.0002,  2.4782,  0.00053550.
# DE loss, IV loss, Vloss, Vtloss in 3500th epoch:  0.0040,  0.0003,  2.4825,  0.00041891.
# DE loss, IV loss, Vloss, Vtloss in 3600th epoch:  0.0033,  0.0002,  2.5572,  0.00043740.
# DE loss, IV loss, Vloss, Vtloss in 3700th epoch:  0.0028,  0.0001,  2.4852,  0.00034585.
# DE loss, IV loss, Vloss, Vtloss in 3800th epoch:  0.0024,  0.0004,  2.4062,  0.00031043.
# DE loss, IV loss, Vloss, Vtloss in 3900th epoch:  0.0034,  0.0001,  2.5197,  0.00021591.
# DE loss, IV loss, Vloss, Vtloss in 4000th epoch:  0.0021,  0.0002,  2.4161,  0.00011010.
# DE loss, IV loss, Vloss, Vtloss in 4100th epoch:  0.0016,  0.0001,  2.4400,  0.00012460.
# DE loss, IV loss, Vloss, Vtloss in 4200th epoch:  0.0029,  0.0001,  2.4600,  0.00021137.
# DE loss, IV loss, Vloss, Vtloss in 4300th epoch:  0.0032,  0.0000,  2.4748,  0.00059350.
# DE loss, IV loss, Vloss, Vtloss in 4400th epoch:  0.0028,  0.0000,  2.3803,  0.00019446.
# DE loss, IV loss, Vloss, Vtloss in 4500th epoch:  0.0020,  0.0001,  2.4332,  0.00012394.
# DE loss, IV loss, Vloss, Vtloss in 4600th epoch:  0.0017,  0.0004,  2.4785,  0.00014454.
# DE loss, IV loss, Vloss, Vtloss in 4700th epoch:  0.0024,  0.0002,  2.3718,  0.00012465.
# DE loss, IV loss, Vloss, Vtloss in 4800th epoch:  0.0019,  0.0001,  2.4523,  0.00018914.
# DE loss, IV loss, Vloss, Vtloss in 4900th epoch:  0.0025,  0.0005,  2.4466,  0.00024364.
# DE loss, IV loss, Vloss, Vtloss in 5000th epoch:  0.0025,  0.0000,  2.4382,  0.00015257.
# DE loss, IV loss, Vloss, Vtloss in 5100th epoch:  0.0014,  0.0001,  2.4482,  0.00008616.
# DE loss, IV loss, Vloss, Vtloss in 5200th epoch:  0.0024,  0.0005,  2.5724,  0.00030251.
# DE loss, IV loss, Vloss, Vtloss in 5300th epoch:  0.0022,  0.0005,  2.5871,  0.00024487.
# DE loss, IV loss, Vloss, Vtloss in 5400th epoch:  0.0033,  0.0002,  2.4576,  0.00031322.
# DE loss, IV loss, Vloss, Vtloss in 5500th epoch:  0.0018,  0.0002,  2.5389,  0.00013533.
# DE loss, IV loss, Vloss, Vtloss in 5600th epoch:  0.0019,  0.0001,  2.6022,  0.00019907.
# DE loss, IV loss, Vloss, Vtloss in 5700th epoch:  0.0026,  0.0000,  2.6543,  0.00041620.
# DE loss, IV loss, Vloss, Vtloss in 5800th epoch:  0.0019,  0.0002,  2.4397,  0.00008385.
# DE loss, IV loss, Vloss, Vtloss in 5900th epoch:  0.0018,  0.0006,  2.5307,  0.00012349.
# DE loss, IV loss, Vloss, Vtloss in 6000th epoch:  0.0016,  0.0002,  2.4346,  0.00007241.
# DE loss, IV loss, Vloss, Vtloss in 6100th epoch:  0.0016,  0.0001,  2.5080,  0.00005147.
# DE loss, IV loss, Vloss, Vtloss in 6200th epoch:  0.0019,  0.0001,  2.5724,  0.00018395.
# DE loss, IV loss, Vloss, Vtloss in 6300th epoch:  0.0018,  0.0001,  2.5673,  0.00024976.
# DE loss, IV loss, Vloss, Vtloss in 6400th epoch:  0.0020,  0.0001,  2.6123,  0.00013039.
# DE loss, IV loss, Vloss, Vtloss in 6500th epoch:  0.0017,  0.0002,  2.5552,  0.00007227.
# DE loss, IV loss, Vloss, Vtloss in 6600th epoch:  0.0011,  0.0000,  2.5633,  0.00008886.
# DE loss, IV loss, Vloss, Vtloss in 6700th epoch:  0.0014,  0.0002,  2.5750,  0.00010342.
# DE loss, IV loss, Vloss, Vtloss in 6800th epoch:  0.0012,  0.0004,  2.6602,  0.00009450.
# DE loss, IV loss, Vloss, Vtloss in 6900th epoch:  0.0024,  0.0011,  2.6379,  0.00022865.
# DE loss, IV loss, Vloss, Vtloss in 7000th epoch:  0.0014,  0.0005,  2.6754,  0.00015947.
# DE loss, IV loss, Vloss, Vtloss in 7100th epoch:  0.0009,  0.0003,  2.5930,  0.00006491.
# DE loss, IV loss, Vloss, Vtloss in 7200th epoch:  0.0016,  0.0000,  2.6913,  0.00012875.
# DE loss, IV loss, Vloss, Vtloss in 7300th epoch:  0.0004,  0.0001,  2.6255,  0.00005386.
# DE loss, IV loss, Vloss, Vtloss in 7400th epoch:  0.0009,  0.0000,  2.6777,  0.00008024.
# DE loss, IV loss, Vloss, Vtloss in 7500th epoch:  0.0014,  0.0002,  2.7265,  0.00012383.
# DE loss, IV loss, Vloss, Vtloss in 7600th epoch:  0.0004,  0.0002,  2.7150,  0.00002049.
# DE loss, IV loss, Vloss, Vtloss in 7700th epoch:  0.0002,  0.0000,  2.7519,  0.00001386.
# DE loss, IV loss, Vloss, Vtloss in 7800th epoch:  0.0007,  0.0002,  2.7443,  0.00004777.
# DE loss, IV loss, Vloss, Vtloss in 7900th epoch:  0.0005,  0.0000,  2.7355,  0.00005519.
# DE loss, IV loss, Vloss, Vtloss in 8000th epoch:  0.0009,  0.0000,  2.8266,  0.00010054.
# DE loss, IV loss, Vloss, Vtloss in 8100th epoch:  0.0003,  0.0001,  2.8349,  0.00002618.
# DE loss, IV loss, Vloss, Vtloss in 8200th epoch:  0.0006,  0.0000,  2.8382,  0.00006355.
# DE loss, IV loss, Vloss, Vtloss in 8300th epoch:  0.0005,  0.0000,  2.8347,  0.00006567.
# DE loss, IV loss, Vloss, Vtloss in 8400th epoch:  0.0003,  0.0001,  2.8564,  0.00002033.
# DE loss, IV loss, Vloss, Vtloss in 8500th epoch:  0.0002,  0.0002,  2.8333,  0.00002964.
# DE loss, IV loss, Vloss, Vtloss in 8600th epoch:  0.0002,  0.0000,  2.8467,  0.00001239.
# DE loss, IV loss, Vloss, Vtloss in 8700th epoch:  0.0010,  0.0000,  2.8680,  0.00011476.
# DE loss, IV loss, Vloss, Vtloss in 8800th epoch:  0.0003,  0.0000,  2.8564,  0.00002140.
# DE loss, IV loss, Vloss, Vtloss in 8900th epoch:  0.0002,  0.0000,  2.8583,  0.00001853.
# DE loss, IV loss, Vloss, Vtloss in 9000th epoch:  0.0005,  0.0002,  2.8601,  0.00005303.
# DE loss, IV loss, Vloss, Vtloss in 9100th epoch:  0.0003,  0.0001,  2.8882,  0.00002046.
# DE loss, IV loss, Vloss, Vtloss in 9200th epoch:  0.0005,  0.0002,  2.8712,  0.00003996.
# DE loss, IV loss, Vloss, Vtloss in 9300th epoch:  0.0001,  0.0000,  2.8735,  0.00001412.
# DE loss, IV loss, Vloss, Vtloss in 9400th epoch:  0.0001,  0.0000,  2.8832,  0.00000288.
# DE loss, IV loss, Vloss, Vtloss in 9500th epoch:  0.0002,  0.0000,  2.8815,  0.00001927.
# DE loss, IV loss, Vloss, Vtloss in 9600th epoch:  0.0001,  0.0000,  2.8699,  0.00000959.
# DE loss, IV loss, Vloss, Vtloss in 9700th epoch:  0.0002,  0.0001,  2.8884,  0.00002493.
# DE loss, IV loss, Vloss, Vtloss in 9800th epoch:  0.0002,  0.0000,  2.8550,  0.00002522.
# DE loss, IV loss, Vloss, Vtloss in 9900th epoch:  0.0001,  0.0000,  2.8920,  0.00001526.
# DE loss, IV loss, Vloss, Vtloss in 10000th epoch:  0.0003,  0.0000,  2.8811,  0.00001559.
# DE loss, IV loss, Vloss, Vtloss in 10100th epoch:  0.0001,  0.0001,  2.8708,  0.00001459.
# DE loss, IV loss, Vloss, Vtloss in 10200th epoch:  0.0002,  0.0000,  2.8908,  0.00002148.
# DE loss, IV loss, Vloss, Vtloss in 10300th epoch:  0.0002,  0.0000,  2.8760,  0.00001555.
# DE loss, IV loss, Vloss, Vtloss in 10400th epoch:  0.0001,  0.0000,  2.8883,  0.00000832.
# DE loss, IV loss, Vloss, Vtloss in 10500th epoch:  0.0001,  0.0001,  2.8900,  0.00000530.
# DE loss, IV loss, Vloss, Vtloss in 10600th epoch:  0.0001,  0.0001,  2.8838,  0.00001071.
# DE loss, IV loss, Vloss, Vtloss in 10700th epoch:  0.0001,  0.0001,  2.8773,  0.00000652.
# DE loss, IV loss, Vloss, Vtloss in 10800th epoch:  0.0000,  0.0000,  2.8957,  0.00000118.
# DE loss, IV loss, Vloss, Vtloss in 10900th epoch:  0.0001,  0.0000,  2.8918,  0.00000550.
# DE loss, IV loss, Vloss, Vtloss in 11000th epoch:  0.0001,  0.0000,  2.8931,  0.00000322.
# DE loss, IV loss, Vloss, Vtloss in 11100th epoch:  0.0001,  0.0001,  2.8886,  0.00000657.
# DE loss, IV loss, Vloss, Vtloss in 11200th epoch:  0.0001,  0.0000,  2.8981,  0.00000986.
# DE loss, IV loss, Vloss, Vtloss in 11300th epoch:  0.0001,  0.0000,  2.8934,  0.00000615.
# DE loss, IV loss, Vloss, Vtloss in 11400th epoch:  0.0001,  0.0000,  2.8854,  0.00001333.
# DE loss, IV loss, Vloss, Vtloss in 11500th epoch:  0.0002,  0.0000,  2.8860,  0.00002018.
# DE loss, IV loss, Vloss, Vtloss in 11600th epoch:  0.0001,  0.0001,  2.8833,  0.00002163.
# DE loss, IV loss, Vloss, Vtloss in 11700th epoch:  0.0001,  0.0000,  2.8884,  0.00001660.
# DE loss, IV loss, Vloss, Vtloss in 11800th epoch:  0.0001,  0.0000,  2.8766,  0.00001082.
# DE loss, IV loss, Vloss, Vtloss in 11900th epoch:  0.0002,  0.0000,  2.8873,  0.00002049.
# 2400

# %%
end = time.time()

print((end-start)/60)
# Out:
# 10.554725297292073

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma
