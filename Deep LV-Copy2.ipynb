# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt

# import pydot
# import graphviz
# import math
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator

import time
import random

# %%
tf.keras.backend.set_floatx('float64')

# %%
def rklv(constants, t_start, t_end, t_step_size) :
    
    [x0, y0, a, b, c, d] = constants
        
    def rk4(r, t, h):                    #edited; no need for input f
            """ Runge-Kutta 4 method """
            k1 = h*f(r, t)
            k2 = h*f(r+0.5*k1, t+0.5*h)
            k3 = h*f(r+0.5*k2, t+0.5*h)
            k4 = h*f(r+k3, t+h)
            return (k1 + 2*k2 + 2*k3 + k4)/6

    def f(r, t):
            x, y = r[0], r[1]
            fxd = a*x - b*x*y
            fyd = c*x*y - d*y
            return np.array([fxd, fyd], float)

    h = t_step_size                           
    tpoints = np.arange(t_start, t_end + h, h)        
    xpoints, ypoints  = [], []
    r = np.array([x0, y0], float)
    for t in tpoints:
            xpoints.append(r[0])         
            ypoints.append(r[1])         
            r += rk4(r, t, h)        
            
#     plt.plot(xpoints, ypoints)
#     plt.xlabel("x")
#     plt.ylabel("y")
#     plt.show()

    tarr = np.asarray(tpoints)
    xarr = np.asarray(xpoints)
    yarr = np.asarray(ypoints)

    points = np.vstack((tarr, xarr, yarr))

    return points

# %%
def define_collocation_points(t_bdry, N_points=100):

    colloc_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_points)

    return colloc_points

# %%
M = 6
N = 10
P = 101


t0 = 0.0
tfinal = 10.0
t_step = 0.01

# %%
def build_model(num_layers = 4, num_units = 60, summary = False) :
    
    inp_br_init = tf.keras.layers.Input(shape = (2,), name = "Input_br_init")
    inp_br_param = tf.keras.layers.Input(shape = (4,), name = "Input_br_param")
    
    br = tf.keras.layers.Concatenate()([inp_br_init, inp_br_param])
    
    for i in range(num_layers) :
        
        br = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_br_" + str(i))(br)
        
    out_br_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_x")(br)
    out_br_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_br_y")(br)
    
    
    inp_tr = tr = tf.keras.layers.Input(shape = (1,), name = "Input_tr")
    
    for i in range(num_layers) :
        
        tr = tf.keras.layers.Dense(num_units, activation = 'tanh', name = "Hidden_tr_" + str(i))(tr)
        
    out_tr_x = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_x")(tr)
    out_tr_y = tf.keras.layers.Dense(1, activation = 'linear', name = "output_tr_y")(tr)

    mult_x = tf.keras.layers.Multiply(name = "multiply_x")([out_br_x, out_tr_x])
    mult_y = tf.keras.layers.Multiply(name = "multiply_y")([out_br_y, out_tr_y])
    
    out_x = tf.keras.layers.Dense(1, name = "output_x")(mult_x)
    out_y = tf.keras.layers.Dense(1, name = "output_y")(mult_y)
    
    model = tf.keras.models.Model([inp_br_init, inp_br_param, inp_tr], [out_x, out_y])
    
    if summary :
        
        model.summary()
        
    return model

# %%
model = build_model(summary = True)
tf.keras.utils.plot_model(model, to_file = 'DeepOnet.png')
# Out:
# Model: "model_48"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_br_init (InputLayer)     [(None, 2)]          0           []
#
#  Input_br_param (InputLayer)    [(None, 4)]          0           []
#
#  concatenate_48 (Concatenate)   (None, 6)            0           ['Input_br_init[0][0]',
#                                                                   'Input_br_param[0][0]']
#
#  Input_tr (InputLayer)          [(None, 1)]          0           []
#
#  Hidden_br_0 (Dense)            (None, 60)           420         ['concatenate_48[0][0]']
#
#  Hidden_tr_0 (Dense)            (None, 60)           120         ['Input_tr[0][0]']
#
#  Hidden_br_1 (Dense)            (None, 60)           3660        ['Hidden_br_0[0][0]']
#
#  Hidden_tr_1 (Dense)            (None, 60)           3660        ['Hidden_tr_0[0][0]']
#
#  Hidden_br_2 (Dense)            (None, 60)           3660        ['Hidden_br_1[0][0]']
#
#  Hidden_tr_2 (Dense)            (None, 60)           3660        ['Hidden_tr_1[0][0]']
#
#  Hidden_br_3 (Dense)            (None, 60)           3660        ['Hidden_br_2[0][0]']
#
#  Hidden_tr_3 (Dense)            (None, 60)           3660        ['Hidden_tr_2[0][0]']
#
#  output_br_x (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_x (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  output_br_y (Dense)            (None, 1)            61          ['Hidden_br_3[0][0]']
#
#  output_tr_y (Dense)            (None, 1)            61          ['Hidden_tr_3[0][0]']
#
#  multiply_x (Multiply)          (None, 1)            0           ['output_br_x[0][0]',
#                                                                   'output_tr_x[0][0]']
#
#  multiply_y (Multiply)          (None, 1)            0           ['output_br_y[0][0]',
#                                                                   'output_tr_y[0][0]']
#
#  output_x (Dense)               (None, 1)            2           ['multiply_x[0][0]']
#
#  output_y (Dense)               (None, 1)            2           ['multiply_y[0][0]']
#
# ==================================================================================================
# Total params: 22,748
# Trainable params: 22,748
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
u_data = np.random.rand(N, M)

# %%
def clone_u_data (data) :
    
    new_data = np.zeros((N*P, M))
    
    for i in range(N) :
        
        data_row = data[i]
        
        cloned_data = np.tile(data_row, (P,1))
        
        new_data[i*P:(i + 1)*P, :] = cloned_data
        
    return new_data

# %%
def clone_t_data (data) :
    
    new_data = np.tile(data, (N,1))
    
    return new_data

# %%
print(u_data.shape)
u_data = clone_u_data(u_data)
print(u_data.shape)

u_train = u_data
# Out:
# (10, 6)
# (1010, 6)

# %%
colloc = define_collocation_points([t0, tfinal], P)
plt.plot(colloc[:,0], 0 * colloc[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
t_init = np.zeros((N*P, 1))

# %%
decimal_p = int((np.floor(np.log10(1/t_step))))
print(decimal_p)
# Out:
# 2

# %%
t_data = colloc
print(t_data.shape)
t_data = clone_t_data(t_data)
print(t_data.shape)

t_data = np.around(t_data, decimal_p)
t_train = t_data
# Out:
# (101, 1)
# (1010, 1)

# %%
true_data = np.zeros((N*P, 2))

for i in range(N*P) :
    
    u = u_train[i]
    t = t_train[i]
    
    sol_points = rklv(u, t0, tfinal, t_step)
    
    t_sol = sol_points[0]
    t_sol = np.around(t_sol, decimal_p)
    
    x_sol = sol_points[1]
    y_sol = sol_points[2]
    
    index = np.where(t_sol == t)
    
    true_data[i][0] = x_sol[index][0]
    true_data[i][1] = y_sol[index][0]
    
print(true_data.shape)
# Out:
# (1010, 2)

# %%
u_train[:, :2] = np.log(u_train[:, :2])
true_data = np.log(true_data)

# %%
# The main training function
@tf.function
def train_network(model, u_cond, u_param, t, x_true, y_true, x_init, y_init, V, a, b, c, d, alpha, beta, gamma, delta):

    with tf.GradientTape() as tape1:

        with tf.GradientTape(persistent=True) as tape2:
            
            tape2.watch(t)
            [x, y] = model([u_cond, u_param, t], training=True)

        xt = tape2.gradient(x, t)
        yt = tape2.gradient(y, t)
        
        xt = tf.reshape(xt, [N*P, 1])
        yt = tf.reshape(yt, [N*P, 1])
 
        Gloss = tf.reduce_mean(tf.square(x - x_true) + tf.square(y - y_true))
        
        eqn1 = xt - a + b*(tf.math.exp(y))
        eqn2 = yt - c*(tf.math.exp(x)) + d
        print("eqn1", eqn1)
        print("eqn2", eqn2)
        DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
        [x_init_pred, y_init_pred] = model([u_cond, u_param, t_init], training=True)
        
        print("x_init", x_init)
        print("x_init", x_init)
        print("x_init_pred", x_init_pred)
        print("y_init_pred", y_init_pred)
        print("x", x)
        print("y", y)
        
        IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
        v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
        Vloss = tf.reduce_mean(tf.square(v - V))
        
        loss = beta*DEloss + gamma*IVloss + delta*Vloss

    grads = tape1.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def DeepONet_train(model, u, t, G_true, epochs, alpha_val, beta_val, gamma_val, delta_val):

    lr_model = 1e-3
    
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val
    delta = delta_val
    
    u_cond = u[:, :2]
    u_param = u[:, 2:]
    
    x_init = u[:, 0].reshape(-1, 1)
    y_init = u[:, 1].reshape(-1, 1)
    
    a = u[:, 2].reshape(-1, 1)
    b = u[:, 3].reshape(-1, 1)
    c = u[:, 4].reshape(-1, 1)
    d = u[:, 5].reshape(-1, 1)
    
    V = (c * (np.exp(x_init))) - (d * x_init) + (b * np.exp(y_init)) - (a * y_init)
      
    x_true = G_true[:, 0].reshape(-1, 1)
    y_true = G_true[:, 1].reshape(-1, 1)
    
    print(u_cond.shape, u_param.shape, x_init.shape, y_init.shape, 
          a.shape, b.shape, c.shape, d.shape, V.shape, x_true.shape, y_true.shape)

    epoch_loss = np.zeros(epochs)
    
    opt = tf.keras.optimizers.Adam(lr_model)

    for i in range(epochs):

        DEloss, IVloss, Vloss, grads = train_network(model, u_cond, u_param, t, x_true, y_true, x_init, y_init, V, 
                                                            a, b, c, d, alpha, beta, gamma, delta)

        opt.apply_gradients(zip(grads, model.trainable_variables))
      
        epoch_loss[i] += beta*DEloss + gamma*IVloss + delta*Vloss

    
        if (np.mod(i, 100)==0):
       
            print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(
                i, DEloss, IVloss, Vloss))

    return epoch_loss, model

# %%
alpha = 0.0
beta = 12
gamma = 1.2
delta = 100

epochs = 100000

# %%
model = build_model()

loss, model = DeepONet_train(model, u_train, t_train, true_data, epochs, alpha, beta, gamma, delta)
# Out:
# (1010, 2) (1010, 4) (1010, 1) (1010, 1) (1010, 1) (1010, 1) (1010, 1) (1010, 1) (1010, 1) (1010, 1) (1010, 1)
# eqn1 Tensor("add_1:0", shape=(1010, 1), dtype=float64)
# eqn2 Tensor("add_2:0", shape=(1010, 1), dtype=float64)
# x_init Tensor("x_init:0", shape=(1010, 1), dtype=float64)
# x_init Tensor("x_init:0", shape=(1010, 1), dtype=float64)
# x_init_pred Tensor("model_49/output_x/BiasAdd_1:0", shape=(1010, 1), dtype=float64)
# y_init_pred Tensor("model_49/output_y/BiasAdd_1:0", shape=(1010, 1), dtype=float64)
# x Tensor("model_49/output_x/BiasAdd:0", shape=(1010, 1), dtype=float64)
# y Tensor("model_49/output_y/BiasAdd:0", shape=(1010, 1), dtype=float64)
# DE loss, IV loss, Vloss in 0th epoch:  0.2464,  2.0089,  0.0549.
# DE loss, IV loss, Vloss in 100th epoch:  0.1430,  0.0563,  0.0014.
# DE loss, IV loss, Vloss in 200th epoch:  0.1309,  0.0777,  0.0011.
# DE loss, IV loss, Vloss in 300th epoch:  0.1239,  0.1199,  0.0011.
# DE loss, IV loss, Vloss in 400th epoch:  0.1225,  0.1223,  0.0012.
# DE loss, IV loss, Vloss in 500th epoch:  0.1218,  0.1221,  0.0012.
# DE loss, IV loss, Vloss in 600th epoch:  0.1216,  0.1139,  0.0013.
# DE loss, IV loss, Vloss in 700th epoch:  0.1214,  0.1209,  0.0012.
# DE loss, IV loss, Vloss in 800th epoch:  0.1212,  0.1211,  0.0012.
# DE loss, IV loss, Vloss in 900th epoch:  0.1211,  0.1211,  0.0012.
# DE loss, IV loss, Vloss in 1000th epoch:  0.1210,  0.1210,  0.0012.
# DE loss, IV loss, Vloss in 1100th epoch:  0.1209,  0.1210,  0.0012.
# DE loss, IV loss, Vloss in 1200th epoch:  0.1210,  0.1202,  0.0012.
# DE loss, IV loss, Vloss in 1300th epoch:  0.1207,  0.1209,  0.0012.
# DE loss, IV loss, Vloss in 1400th epoch:  0.1207,  0.1211,  0.0012.
# DE loss, IV loss, Vloss in 1500th epoch:  0.1206,  0.1209,  0.0012.
# DE loss, IV loss, Vloss in 1600th epoch:  0.1206,  0.1211,  0.0012.
# DE loss, IV loss, Vloss in 1700th epoch:  0.1209,  0.1209,  0.0012.
# DE loss, IV loss, Vloss in 1800th epoch:  0.1205,  0.1210,  0.0012.
# DE loss, IV loss, Vloss in 1900th epoch:  0.1202,  0.1203,  0.0013.
# DE loss, IV loss, Vloss in 2000th epoch:  0.1207,  0.1216,  0.0012.
# DE loss, IV loss, Vloss in 2100th epoch:  0.1221,  0.1280,  0.0011.
# DE loss, IV loss, Vloss in 2200th epoch:  0.1203,  0.1209,  0.0012.
# DE loss, IV loss, Vloss in 2300th epoch:  0.1201,  0.1208,  0.0012.
# DE loss, IV loss, Vloss in 2400th epoch:  0.1202,  0.1210,  0.0012.
# DE loss, IV loss, Vloss in 2500th epoch:  0.1199,  0.1205,  0.0012.
# DE loss, IV loss, Vloss in 2600th epoch:  0.1203,  0.1175,  0.0013.
# DE loss, IV loss, Vloss in 2700th epoch:  0.1200,  0.1208,  0.0012.
# DE loss, IV loss, Vloss in 2800th epoch:  0.1199,  0.1207,  0.0012.
# DE loss, IV loss, Vloss in 2900th epoch:  0.1204,  0.1222,  0.0012.
# DE loss, IV loss, Vloss in 3000th epoch:  0.1207,  0.1240,  0.0011.
# DE loss, IV loss, Vloss in 3100th epoch:  0.1190,  0.1233,  0.0013.
# DE loss, IV loss, Vloss in 3200th epoch:  0.1200,  0.1148,  0.0013.
# DE loss, IV loss, Vloss in 3300th epoch:  0.1199,  0.1213,  0.0012.
# DE loss, IV loss, Vloss in 3400th epoch:  0.1210,  0.1249,  0.0011.
# DE loss, IV loss, Vloss in 3500th epoch:  0.1195,  0.1208,  0.0012.
# DE loss, IV loss, Vloss in 3600th epoch:  0.1192,  0.1200,  0.0013.
# DE loss, IV loss, Vloss in 3700th epoch:  0.1195,  0.1206,  0.0012.
# DE loss, IV loss, Vloss in 3800th epoch:  0.1191,  0.1214,  0.0013.
# DE loss, IV loss, Vloss in 3900th epoch:  0.1189,  0.1182,  0.0013.
# DE loss, IV loss, Vloss in 4000th epoch:  0.1193,  0.1211,  0.0012.
# DE loss, IV loss, Vloss in 4100th epoch:  0.1192,  0.1209,  0.0013.
# DE loss, IV loss, Vloss in 4200th epoch:  0.1190,  0.1218,  0.0013.
# DE loss, IV loss, Vloss in 4300th epoch:  0.1190,  0.1204,  0.0013.
# DE loss, IV loss, Vloss in 4400th epoch:  0.1190,  0.1182,  0.0013.
# DE loss, IV loss, Vloss in 4500th epoch:  0.1190,  0.1210,  0.0013.
# DE loss, IV loss, Vloss in 4600th epoch:  0.1189,  0.1207,  0.0013.
# DE loss, IV loss, Vloss in 4700th epoch:  0.1189,  0.1209,  0.0013.
# DE loss, IV loss, Vloss in 4800th epoch:  0.1184,  0.1214,  0.0013.
# DE loss, IV loss, Vloss in 4900th epoch:  0.1189,  0.1206,  0.0013.
# DE loss, IV loss, Vloss in 5000th epoch:  0.1170,  0.1209,  0.0015.
# DE loss, IV loss, Vloss in 5100th epoch:  0.1187,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 5200th epoch:  0.1192,  0.1233,  0.0012.
# DE loss, IV loss, Vloss in 5300th epoch:  0.1176,  0.1177,  0.0015.
# DE loss, IV loss, Vloss in 5400th epoch:  0.1186,  0.1212,  0.0013.
# DE loss, IV loss, Vloss in 5500th epoch:  0.1188,  0.1220,  0.0013.
# DE loss, IV loss, Vloss in 5600th epoch:  0.1185,  0.1212,  0.0013.
# DE loss, IV loss, Vloss in 5700th epoch:  0.1186,  0.1214,  0.0013.
# DE loss, IV loss, Vloss in 5800th epoch:  0.1189,  0.1218,  0.0012.
# DE loss, IV loss, Vloss in 5900th epoch:  0.1182,  0.1209,  0.0013.
# DE loss, IV loss, Vloss in 6000th epoch:  0.1185,  0.1215,  0.0013.
# DE loss, IV loss, Vloss in 6100th epoch:  0.1188,  0.1221,  0.0012.
# DE loss, IV loss, Vloss in 6200th epoch:  0.1185,  0.1207,  0.0013.
# DE loss, IV loss, Vloss in 6300th epoch:  0.1174,  0.1195,  0.0014.
# DE loss, IV loss, Vloss in 6400th epoch:  0.1188,  0.1234,  0.0012.
# DE loss, IV loss, Vloss in 6500th epoch:  0.1184,  0.1217,  0.0013.
# DE loss, IV loss, Vloss in 6600th epoch:  0.1186,  0.1227,  0.0012.
# DE loss, IV loss, Vloss in 6700th epoch:  0.1191,  0.1225,  0.0012.
# DE loss, IV loss, Vloss in 6800th epoch:  0.1178,  0.1187,  0.0014.
# DE loss, IV loss, Vloss in 6900th epoch:  0.1181,  0.1212,  0.0013.
# DE loss, IV loss, Vloss in 7000th epoch:  0.1183,  0.1218,  0.0013.
# DE loss, IV loss, Vloss in 7100th epoch:  0.1185,  0.1233,  0.0012.
# DE loss, IV loss, Vloss in 7200th epoch:  0.1182,  0.1221,  0.0013.
# DE loss, IV loss, Vloss in 7300th epoch:  0.1179,  0.1233,  0.0013.
# DE loss, IV loss, Vloss in 7400th epoch:  0.1182,  0.1222,  0.0013.
# DE loss, IV loss, Vloss in 7500th epoch:  0.1178,  0.1241,  0.0013.
# DE loss, IV loss, Vloss in 7600th epoch:  0.1188,  0.1210,  0.0012.
# DE loss, IV loss, Vloss in 7700th epoch:  0.1181,  0.1233,  0.0013.
# DE loss, IV loss, Vloss in 7800th epoch:  0.1180,  0.1202,  0.0013.
# DE loss, IV loss, Vloss in 7900th epoch:  0.1197,  0.1318,  0.0011.
# DE loss, IV loss, Vloss in 8000th epoch:  0.1192,  0.1212,  0.0012.
# DE loss, IV loss, Vloss in 8100th epoch:  0.1179,  0.1233,  0.0013.
# DE loss, IV loss, Vloss in 8200th epoch:  0.1162,  0.1201,  0.0016.
# DE loss, IV loss, Vloss in 8300th epoch:  0.1176,  0.1167,  0.0015.
# DE loss, IV loss, Vloss in 8400th epoch:  0.1179,  0.1220,  0.0013.
# DE loss, IV loss, Vloss in 8500th epoch:  0.1179,  0.1224,  0.0013.
# DE loss, IV loss, Vloss in 8600th epoch:  0.1166,  0.1172,  0.0016.
# DE loss, IV loss, Vloss in 8700th epoch:  0.1190,  0.1280,  0.0012.
# DE loss, IV loss, Vloss in 8800th epoch:  0.1180,  0.1219,  0.0013.
# DE loss, IV loss, Vloss in 8900th epoch:  0.1180,  0.1224,  0.0013.
# DE loss, IV loss, Vloss in 9000th epoch:  0.1180,  0.1217,  0.0013.
# DE loss, IV loss, Vloss in 9100th epoch:  0.1183,  0.1249,  0.0012.
# DE loss, IV loss, Vloss in 9200th epoch:  0.1177,  0.1215,  0.0013.
# DE loss, IV loss, Vloss in 9300th epoch:  0.1169,  0.1204,  0.0014.
# DE loss, IV loss, Vloss in 9400th epoch:  0.1168,  0.1207,  0.0014.
# DE loss, IV loss, Vloss in 9500th epoch:  0.1176,  0.1216,  0.0013.
# DE loss, IV loss, Vloss in 9600th epoch:  0.1173,  0.1239,  0.0013.
# DE loss, IV loss, Vloss in 9700th epoch:  0.1178,  0.1210,  0.0013.
# DE loss, IV loss, Vloss in 9800th epoch:  0.1179,  0.1237,  0.0013.
# DE loss, IV loss, Vloss in 9900th epoch:  0.1181,  0.1184,  0.0013.
# DE loss, IV loss, Vloss in 10000th epoch:  0.1175,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 10100th epoch:  0.1178,  0.1227,  0.0013.
# DE loss, IV loss, Vloss in 10200th epoch:  0.1172,  0.1207,  0.0014.
# DE loss, IV loss, Vloss in 10300th epoch:  0.1172,  0.1251,  0.0013.
# DE loss, IV loss, Vloss in 10400th epoch:  0.1175,  0.1218,  0.0013.
# DE loss, IV loss, Vloss in 10500th epoch:  0.1175,  0.1204,  0.0013.
# DE loss, IV loss, Vloss in 10600th epoch:  0.1176,  0.1222,  0.0013.
# DE loss, IV loss, Vloss in 10700th epoch:  0.1197,  0.1230,  0.0011.
# DE loss, IV loss, Vloss in 10800th epoch:  0.1180,  0.1239,  0.0012.
# DE loss, IV loss, Vloss in 10900th epoch:  0.1175,  0.1224,  0.0013.
# DE loss, IV loss, Vloss in 11000th epoch:  0.1177,  0.1229,  0.0013.
# DE loss, IV loss, Vloss in 11100th epoch:  0.1175,  0.1219,  0.0013.
# DE loss, IV loss, Vloss in 11200th epoch:  0.1175,  0.1227,  0.0013.
# DE loss, IV loss, Vloss in 11300th epoch:  0.1174,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 11400th epoch:  0.1176,  0.1226,  0.0013.
# DE loss, IV loss, Vloss in 11500th epoch:  0.1159,  0.1210,  0.0015.
# DE loss, IV loss, Vloss in 11600th epoch:  0.1170,  0.1234,  0.0014.
# DE loss, IV loss, Vloss in 11700th epoch:  0.1173,  0.1221,  0.0013.
# DE loss, IV loss, Vloss in 11800th epoch:  0.1183,  0.1186,  0.0013.
# DE loss, IV loss, Vloss in 11900th epoch:  0.1176,  0.1231,  0.0013.
# DE loss, IV loss, Vloss in 12000th epoch:  0.1192,  0.1323,  0.0011.
# DE loss, IV loss, Vloss in 12100th epoch:  0.1165,  0.1238,  0.0014.
# DE loss, IV loss, Vloss in 12200th epoch:  0.1169,  0.1229,  0.0014.
# DE loss, IV loss, Vloss in 12300th epoch:  0.1191,  0.1290,  0.0011.
# DE loss, IV loss, Vloss in 12400th epoch:  0.1175,  0.1232,  0.0013.
# DE loss, IV loss, Vloss in 12500th epoch:  0.1182,  0.1212,  0.0012.
# DE loss, IV loss, Vloss in 12600th epoch:  0.1181,  0.1242,  0.0012.
# DE loss, IV loss, Vloss in 12700th epoch:  0.1177,  0.1252,  0.0012.
# DE loss, IV loss, Vloss in 12800th epoch:  0.1172,  0.1217,  0.0013.
# DE loss, IV loss, Vloss in 12900th epoch:  0.1175,  0.1215,  0.0013.
# DE loss, IV loss, Vloss in 13000th epoch:  0.1175,  0.1228,  0.0013.
# DE loss, IV loss, Vloss in 13100th epoch:  0.1175,  0.1235,  0.0013.
# DE loss, IV loss, Vloss in 13200th epoch:  0.1170,  0.1256,  0.0013.
# DE loss, IV loss, Vloss in 13300th epoch:  0.1174,  0.1230,  0.0013.
# DE loss, IV loss, Vloss in 13400th epoch:  0.1175,  0.1247,  0.0013.
# DE loss, IV loss, Vloss in 13500th epoch:  0.1189,  0.1297,  0.0011.
# DE loss, IV loss, Vloss in 13600th epoch:  0.1173,  0.1230,  0.0013.
# DE loss, IV loss, Vloss in 13700th epoch:  0.1178,  0.1191,  0.0013.
# DE loss, IV loss, Vloss in 13800th epoch:  0.1172,  0.1220,  0.0013.
# DE loss, IV loss, Vloss in 13900th epoch:  0.1173,  0.1228,  0.0013.
# DE loss, IV loss, Vloss in 14000th epoch:  0.1174,  0.1226,  0.0013.
# DE loss, IV loss, Vloss in 14100th epoch:  0.1173,  0.1228,  0.0013.
# DE loss, IV loss, Vloss in 14200th epoch:  0.1163,  0.1257,  0.0014.
# DE loss, IV loss, Vloss in 14300th epoch:  0.1173,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 14400th epoch:  0.1172,  0.1231,  0.0013.
# DE loss, IV loss, Vloss in 14500th epoch:  0.1169,  0.1208,  0.0014.
# DE loss, IV loss, Vloss in 14600th epoch:  0.1169,  0.1234,  0.0013.
# DE loss, IV loss, Vloss in 14700th epoch:  0.1176,  0.1250,  0.0012.
# DE loss, IV loss, Vloss in 14800th epoch:  0.1168,  0.1212,  0.0014.
# DE loss, IV loss, Vloss in 14900th epoch:  0.1174,  0.1238,  0.0013.
# DE loss, IV loss, Vloss in 15000th epoch:  0.1172,  0.1226,  0.0013.
# DE loss, IV loss, Vloss in 15100th epoch:  0.1171,  0.1231,  0.0013.
# DE loss, IV loss, Vloss in 15200th epoch:  0.1169,  0.1181,  0.0014.
# DE loss, IV loss, Vloss in 15300th epoch:  0.1173,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 15400th epoch:  0.1171,  0.1217,  0.0013.
# DE loss, IV loss, Vloss in 15500th epoch:  0.1170,  0.1234,  0.0013.
# DE loss, IV loss, Vloss in 15600th epoch:  0.1180,  0.1258,  0.0012.
# DE loss, IV loss, Vloss in 15700th epoch:  0.1171,  0.1199,  0.0014.
# DE loss, IV loss, Vloss in 15800th epoch:  0.1172,  0.1224,  0.0013.
# DE loss, IV loss, Vloss in 15900th epoch:  0.1174,  0.1223,  0.0013.
# DE loss, IV loss, Vloss in 16000th epoch:  0.1172,  0.1224,  0.0013.
# DE loss, IV loss, Vloss in 16100th epoch:  0.1172,  0.1240,  0.0013.
# DE loss, IV loss, Vloss in 16200th epoch:  0.1169,  0.1209,  0.0014.
# DE loss, IV loss, Vloss in 16300th epoch:  0.1172,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 16400th epoch:  0.1173,  0.1227,  0.0013.
# DE loss, IV loss, Vloss in 16500th epoch:  0.1172,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 16600th epoch:  0.1159,  0.1226,  0.0015.
# DE loss, IV loss, Vloss in 16700th epoch:  0.1172,  0.1226,  0.0013.
# DE loss, IV loss, Vloss in 16800th epoch:  0.1173,  0.1225,  0.0013.
# DE loss, IV loss, Vloss in 16900th epoch:  0.1172,  0.1221,  0.0013.
# DE loss, IV loss, Vloss in 17000th epoch:  0.1173,  0.1224,  0.0013.
# DE loss, IV loss, Vloss in 17100th epoch:  0.1166,  0.1229,  0.0014.
# DE loss, IV loss, Vloss in 17200th epoch:  0.1169,  0.1211,  0.0014.
# DE loss, IV loss, Vloss in 17300th epoch:  0.1174,  0.1228,  0.0013.
# DE loss, IV loss, Vloss in 17400th epoch:  0.1172,  0.1231,  0.0013.
# DE loss, IV loss, Vloss in 17500th epoch:  0.1179,  0.1231,  0.0012.
# DE loss, IV loss, Vloss in 17600th epoch:  0.1171,  0.1223,  0.0013.
# DE loss, IV loss, Vloss in 17700th epoch:  0.1174,  0.1204,  0.0013.
# DE loss, IV loss, Vloss in 17800th epoch:  0.1136,  0.1199,  0.0015.
# DE loss, IV loss, Vloss in 17900th epoch:  0.1092,  0.1200,  0.0017.
# DE loss, IV loss, Vloss in 18000th epoch:  0.1091,  0.1200,  0.0017.
# DE loss, IV loss, Vloss in 18100th epoch:  0.1090,  0.1202,  0.0017.
# DE loss, IV loss, Vloss in 18200th epoch:  0.1090,  0.1203,  0.0017.
# DE loss, IV loss, Vloss in 18300th epoch:  0.1088,  0.1208,  0.0017.
# DE loss, IV loss, Vloss in 18400th epoch:  0.1092,  0.1209,  0.0016.
# DE loss, IV loss, Vloss in 18500th epoch:  0.1087,  0.1214,  0.0017.
# DE loss, IV loss, Vloss in 18600th epoch:  0.1091,  0.1214,  0.0016.
# DE loss, IV loss, Vloss in 18700th epoch:  0.1085,  0.1220,  0.0017.
# DE loss, IV loss, Vloss in 18800th epoch:  0.1095,  0.1232,  0.0016.
# DE loss, IV loss, Vloss in 18900th epoch:  0.1083,  0.1226,  0.0017.
# DE loss, IV loss, Vloss in 19000th epoch:  0.1083,  0.1230,  0.0017.
# DE loss, IV loss, Vloss in 19100th epoch:  0.1082,  0.1232,  0.0017.
# DE loss, IV loss, Vloss in 19200th epoch:  0.1081,  0.1235,  0.0017.
# DE loss, IV loss, Vloss in 19300th epoch:  0.1083,  0.1237,  0.0017.
# DE loss, IV loss, Vloss in 19400th epoch:  0.1080,  0.1239,  0.0017.
# DE loss, IV loss, Vloss in 19500th epoch:  0.1079,  0.1242,  0.0017.
# DE loss, IV loss, Vloss in 19600th epoch:  0.1080,  0.1245,  0.0017.
# DE loss, IV loss, Vloss in 19700th epoch:  0.1096,  0.1247,  0.0015.
# DE loss, IV loss, Vloss in 19800th epoch:  0.1077,  0.1251,  0.0017.
# DE loss, IV loss, Vloss in 19900th epoch:  0.1079,  0.1253,  0.0017.
# DE loss, IV loss, Vloss in 20000th epoch:  0.1077,  0.1259,  0.0017.
# DE loss, IV loss, Vloss in 20100th epoch:  0.1066,  0.1258,  0.0018.
# DE loss, IV loss, Vloss in 20200th epoch:  0.1064,  0.1263,  0.0019.
# DE loss, IV loss, Vloss in 20300th epoch:  0.1075,  0.1274,  0.0017.
# DE loss, IV loss, Vloss in 20400th epoch:  0.1077,  0.1263,  0.0017.
# DE loss, IV loss, Vloss in 20500th epoch:  0.1072,  0.1280,  0.0017.
# DE loss, IV loss, Vloss in 20600th epoch:  0.1072,  0.1282,  0.0017.
# DE loss, IV loss, Vloss in 20700th epoch:  0.1074,  0.1286,  0.0017.
# DE loss, IV loss, Vloss in 20800th epoch:  0.1068,  0.1300,  0.0017.
# DE loss, IV loss, Vloss in 20900th epoch:  0.1067,  0.1313,  0.0018.
# DE loss, IV loss, Vloss in 21000th epoch:  0.1047,  0.1307,  0.0021.
# DE loss, IV loss, Vloss in 21100th epoch:  0.1073,  0.1309,  0.0016.
# DE loss, IV loss, Vloss in 21200th epoch:  0.1076,  0.1314,  0.0016.
# DE loss, IV loss, Vloss in 21300th epoch:  0.1064,  0.1328,  0.0017.
# DE loss, IV loss, Vloss in 21400th epoch:  0.1063,  0.1335,  0.0017.
# DE loss, IV loss, Vloss in 21500th epoch:  0.1062,  0.1339,  0.0017.
# DE loss, IV loss, Vloss in 21600th epoch:  0.1060,  0.1346,  0.0017.
# DE loss, IV loss, Vloss in 21700th epoch:  0.1058,  0.1354,  0.0017.
# DE loss, IV loss, Vloss in 21800th epoch:  0.1056,  0.1356,  0.0017.
# DE loss, IV loss, Vloss in 21900th epoch:  0.1049,  0.1369,  0.0018.
# DE loss, IV loss, Vloss in 22000th epoch:  0.1054,  0.1367,  0.0017.
# DE loss, IV loss, Vloss in 22100th epoch:  0.1059,  0.1372,  0.0017.
# DE loss, IV loss, Vloss in 22200th epoch:  0.1054,  0.1380,  0.0017.
# DE loss, IV loss, Vloss in 22300th epoch:  0.1051,  0.1386,  0.0017.
# DE loss, IV loss, Vloss in 22400th epoch:  0.1068,  0.1393,  0.0016.
# DE loss, IV loss, Vloss in 22500th epoch:  0.1053,  0.1392,  0.0017.
# DE loss, IV loss, Vloss in 22600th epoch:  0.1056,  0.1396,  0.0016.
# DE loss, IV loss, Vloss in 22700th epoch:  0.1051,  0.1398,  0.0017.
# DE loss, IV loss, Vloss in 22800th epoch:  0.1050,  0.1400,  0.0017.
# DE loss, IV loss, Vloss in 22900th epoch:  0.1052,  0.1401,  0.0017.
# DE loss, IV loss, Vloss in 23000th epoch:  0.1049,  0.1400,  0.0017.
# DE loss, IV loss, Vloss in 23100th epoch:  0.1050,  0.1405,  0.0017.
# DE loss, IV loss, Vloss in 23200th epoch:  0.1050,  0.1408,  0.0017.
# DE loss, IV loss, Vloss in 23300th epoch:  0.1059,  0.1418,  0.0016.
# DE loss, IV loss, Vloss in 23400th epoch:  0.1051,  0.1410,  0.0017.
# DE loss, IV loss, Vloss in 23500th epoch:  0.1052,  0.1412,  0.0017.
# DE loss, IV loss, Vloss in 23600th epoch:  0.1049,  0.1413,  0.0017.
# DE loss, IV loss, Vloss in 23700th epoch:  0.1036,  0.1406,  0.0019.
# DE loss, IV loss, Vloss in 23800th epoch:  0.1048,  0.1422,  0.0017.
# DE loss, IV loss, Vloss in 23900th epoch:  0.1042,  0.1415,  0.0018.
# DE loss, IV loss, Vloss in 24000th epoch:  0.1047,  0.1418,  0.0017.
# DE loss, IV loss, Vloss in 24100th epoch:  0.1048,  0.1422,  0.0017.
# DE loss, IV loss, Vloss in 24200th epoch:  0.1042,  0.1423,  0.0017.
# DE loss, IV loss, Vloss in 24300th epoch:  0.1049,  0.1420,  0.0017.
# DE loss, IV loss, Vloss in 24400th epoch:  0.1041,  0.1430,  0.0017.
# DE loss, IV loss, Vloss in 24500th epoch:  0.1041,  0.1431,  0.0017.
# DE loss, IV loss, Vloss in 24600th epoch:  0.1042,  0.1424,  0.0017.
# DE loss, IV loss, Vloss in 24700th epoch:  0.1043,  0.1430,  0.0017.
# DE loss, IV loss, Vloss in 24800th epoch:  0.1043,  0.1431,  0.0017.
# DE loss, IV loss, Vloss in 24900th epoch:  0.1050,  0.1430,  0.0016.
# DE loss, IV loss, Vloss in 25000th epoch:  0.1039,  0.1427,  0.0018.
# DE loss, IV loss, Vloss in 25100th epoch:  0.1042,  0.1435,  0.0017.
# DE loss, IV loss, Vloss in 25200th epoch:  0.1040,  0.1434,  0.0017.
# DE loss, IV loss, Vloss in 25300th epoch:  0.1042,  0.1436,  0.0017.
# DE loss, IV loss, Vloss in 25400th epoch:  0.1043,  0.1440,  0.0017.
# DE loss, IV loss, Vloss in 25500th epoch:  0.1039,  0.1433,  0.0017.
# DE loss, IV loss, Vloss in 25600th epoch:  0.1048,  0.1442,  0.0016.
# DE loss, IV loss, Vloss in 25700th epoch:  0.1040,  0.1445,  0.0017.
# DE loss, IV loss, Vloss in 25800th epoch:  0.1041,  0.1446,  0.0017.
# DE loss, IV loss, Vloss in 25900th epoch:  0.1041,  0.1449,  0.0017.
# DE loss, IV loss, Vloss in 26000th epoch:  0.1040,  0.1450,  0.0017.
# DE loss, IV loss, Vloss in 26100th epoch:  0.1061,  0.1447,  0.0015.
# DE loss, IV loss, Vloss in 26200th epoch:  0.1056,  0.1454,  0.0016.
# DE loss, IV loss, Vloss in 26300th epoch:  0.1034,  0.1464,  0.0017.
# DE loss, IV loss, Vloss in 26400th epoch:  0.1042,  0.1441,  0.0017.
# DE loss, IV loss, Vloss in 26500th epoch:  0.1035,  0.1462,  0.0017.
# DE loss, IV loss, Vloss in 26600th epoch:  0.1037,  0.1465,  0.0017.
# DE loss, IV loss, Vloss in 26700th epoch:  0.1034,  0.1466,  0.0017.
# DE loss, IV loss, Vloss in 26800th epoch:  0.1034,  0.1473,  0.0017.
# DE loss, IV loss, Vloss in 26900th epoch:  0.1041,  0.1452,  0.0017.
# DE loss, IV loss, Vloss in 27000th epoch:  0.1031,  0.1488,  0.0017.
# DE loss, IV loss, Vloss in 27100th epoch:  0.1028,  0.1472,  0.0018.
# DE loss, IV loss, Vloss in 27200th epoch:  0.1028,  0.1458,  0.0018.
# DE loss, IV loss, Vloss in 27300th epoch:  0.1036,  0.1481,  0.0017.
# DE loss, IV loss, Vloss in 27400th epoch:  0.1060,  0.1473,  0.0015.
# DE loss, IV loss, Vloss in 27500th epoch:  0.1041,  0.1470,  0.0017.
# DE loss, IV loss, Vloss in 27600th epoch:  0.1031,  0.1488,  0.0017.
# DE loss, IV loss, Vloss in 27700th epoch:  0.1031,  0.1487,  0.0017.
# DE loss, IV loss, Vloss in 27800th epoch:  0.1041,  0.1488,  0.0016.
# DE loss, IV loss, Vloss in 27900th epoch:  0.1036,  0.1470,  0.0017.
# DE loss, IV loss, Vloss in 28000th epoch:  0.1030,  0.1486,  0.0017.
# DE loss, IV loss, Vloss in 28100th epoch:  0.1025,  0.1493,  0.0018.
# DE loss, IV loss, Vloss in 28200th epoch:  0.1025,  0.1484,  0.0018.
# DE loss, IV loss, Vloss in 28300th epoch:  0.1040,  0.1488,  0.0016.
# DE loss, IV loss, Vloss in 28400th epoch:  0.1025,  0.1509,  0.0017.
# DE loss, IV loss, Vloss in 28500th epoch:  0.1026,  0.1509,  0.0017.
# DE loss, IV loss, Vloss in 28600th epoch:  0.1027,  0.1517,  0.0017.
# DE loss, IV loss, Vloss in 28700th epoch:  0.1025,  0.1517,  0.0017.
# DE loss, IV loss, Vloss in 28800th epoch:  0.1025,  0.1516,  0.0017.
# DE loss, IV loss, Vloss in 28900th epoch:  0.1024,  0.1507,  0.0017.
# DE loss, IV loss, Vloss in 29000th epoch:  0.1024,  0.1522,  0.0017.
# DE loss, IV loss, Vloss in 29100th epoch:  0.1026,  0.1512,  0.0017.
# DE loss, IV loss, Vloss in 29200th epoch:  0.1023,  0.1527,  0.0017.
# DE loss, IV loss, Vloss in 29300th epoch:  0.1022,  0.1531,  0.0017.
# DE loss, IV loss, Vloss in 29400th epoch:  0.1022,  0.1533,  0.0017.
# DE loss, IV loss, Vloss in 29500th epoch:  0.1020,  0.1538,  0.0017.
# DE loss, IV loss, Vloss in 29600th epoch:  0.1021,  0.1546,  0.0017.
# DE loss, IV loss, Vloss in 29700th epoch:  0.1034,  0.1519,  0.0016.
# DE loss, IV loss, Vloss in 29800th epoch:  0.1019,  0.1547,  0.0017.
# DE loss, IV loss, Vloss in 29900th epoch:  0.1021,  0.1541,  0.0017.
# DE loss, IV loss, Vloss in 30000th epoch:  0.1019,  0.1545,  0.0017.
# DE loss, IV loss, Vloss in 30100th epoch:  0.1018,  0.1550,  0.0017.
# DE loss, IV loss, Vloss in 30200th epoch:  0.1023,  0.1539,  0.0017.
# DE loss, IV loss, Vloss in 30300th epoch:  0.1018,  0.1550,  0.0017.
# DE loss, IV loss, Vloss in 30400th epoch:  0.1017,  0.1555,  0.0017.
# DE loss, IV loss, Vloss in 30500th epoch:  0.1007,  0.1560,  0.0019.
# DE loss, IV loss, Vloss in 30600th epoch:  0.1016,  0.1562,  0.0017.
# DE loss, IV loss, Vloss in 30700th epoch:  0.1019,  0.1563,  0.0017.
# DE loss, IV loss, Vloss in 30800th epoch:  0.1015,  0.1567,  0.0017.
# DE loss, IV loss, Vloss in 30900th epoch:  0.1015,  0.1568,  0.0017.
# DE loss, IV loss, Vloss in 31000th epoch:  0.1013,  0.1573,  0.0017.
# DE loss, IV loss, Vloss in 31100th epoch:  0.1013,  0.1575,  0.0017.
# DE loss, IV loss, Vloss in 31200th epoch:  0.1030,  0.1582,  0.0016.
# DE loss, IV loss, Vloss in 31300th epoch:  0.1014,  0.1575,  0.0017.
# DE loss, IV loss, Vloss in 31400th epoch:  0.1014,  0.1576,  0.0017.
# DE loss, IV loss, Vloss in 31500th epoch:  0.1015,  0.1575,  0.0017.
# DE loss, IV loss, Vloss in 31600th epoch:  0.1013,  0.1579,  0.0017.
# DE loss, IV loss, Vloss in 31700th epoch:  0.1013,  0.1581,  0.0017.
# DE loss, IV loss, Vloss in 31800th epoch:  0.1013,  0.1588,  0.0017.
# DE loss, IV loss, Vloss in 31900th epoch:  0.1010,  0.1578,  0.0018.
# DE loss, IV loss, Vloss in 32000th epoch:  0.1018,  0.1599,  0.0017.
# DE loss, IV loss, Vloss in 32100th epoch:  0.1012,  0.1586,  0.0017.
# DE loss, IV loss, Vloss in 32200th epoch:  0.1012,  0.1587,  0.0017.
# DE loss, IV loss, Vloss in 32300th epoch:  0.1013,  0.1590,  0.0017.
# DE loss, IV loss, Vloss in 32400th epoch:  0.1012,  0.1595,  0.0017.
# DE loss, IV loss, Vloss in 32500th epoch:  0.1010,  0.1595,  0.0017.
# DE loss, IV loss, Vloss in 32600th epoch:  0.1010,  0.1593,  0.0017.
# DE loss, IV loss, Vloss in 32700th epoch:  0.1009,  0.1605,  0.0017.
# DE loss, IV loss, Vloss in 32800th epoch:  0.1007,  0.1596,  0.0018.
# DE loss, IV loss, Vloss in 32900th epoch:  0.1010,  0.1600,  0.0017.
# DE loss, IV loss, Vloss in 33000th epoch:  0.1031,  0.1592,  0.0016.
# DE loss, IV loss, Vloss in 33100th epoch:  0.0998,  0.1601,  0.0021.
# DE loss, IV loss, Vloss in 33200th epoch:  0.1061,  0.1326,  0.0017.
# DE loss, IV loss, Vloss in 33300th epoch:  0.1047,  0.1387,  0.0017.
# DE loss, IV loss, Vloss in 33400th epoch:  0.1046,  0.1394,  0.0017.
# DE loss, IV loss, Vloss in 33500th epoch:  0.1045,  0.1396,  0.0017.
# DE loss, IV loss, Vloss in 33600th epoch:  0.1044,  0.1398,  0.0017.
# DE loss, IV loss, Vloss in 33700th epoch:  0.1044,  0.1400,  0.0017.
# DE loss, IV loss, Vloss in 33800th epoch:  0.1043,  0.1401,  0.0017.
# DE loss, IV loss, Vloss in 33900th epoch:  0.1043,  0.1401,  0.0017.
# DE loss, IV loss, Vloss in 34000th epoch:  0.1043,  0.1403,  0.0017.
# DE loss, IV loss, Vloss in 34100th epoch:  0.1042,  0.1404,  0.0017.
# DE loss, IV loss, Vloss in 34200th epoch:  0.1042,  0.1405,  0.0017.
# DE loss, IV loss, Vloss in 34300th epoch:  0.1042,  0.1404,  0.0017.
# DE loss, IV loss, Vloss in 34400th epoch:  0.1041,  0.1407,  0.0017.
# DE loss, IV loss, Vloss in 34500th epoch:  0.1041,  0.1408,  0.0017.
# DE loss, IV loss, Vloss in 34600th epoch:  0.1054,  0.1433,  0.0016.
# DE loss, IV loss, Vloss in 34700th epoch:  0.1040,  0.1410,  0.0017.
# DE loss, IV loss, Vloss in 34800th epoch:  0.1040,  0.1411,  0.0017.
# DE loss, IV loss, Vloss in 34900th epoch:  0.1038,  0.1412,  0.0018.
# DE loss, IV loss, Vloss in 35000th epoch:  0.1038,  0.1413,  0.0017.
# DE loss, IV loss, Vloss in 35100th epoch:  0.1038,  0.1415,  0.0017.
# DE loss, IV loss, Vloss in 35200th epoch:  0.1038,  0.1417,  0.0017.
# DE loss, IV loss, Vloss in 35300th epoch:  0.1037,  0.1417,  0.0018.
# DE loss, IV loss, Vloss in 35400th epoch:  0.1037,  0.1419,  0.0017.
# DE loss, IV loss, Vloss in 35500th epoch:  0.1038,  0.1400,  0.0018.
# DE loss, IV loss, Vloss in 35600th epoch:  0.1036,  0.1419,  0.0018.
# DE loss, IV loss, Vloss in 35700th epoch:  0.1036,  0.1419,  0.0018.
# DE loss, IV loss, Vloss in 35800th epoch:  0.1039,  0.1420,  0.0017.
# DE loss, IV loss, Vloss in 35900th epoch:  0.1036,  0.1422,  0.0017.
# DE loss, IV loss, Vloss in 36000th epoch:  0.1034,  0.1420,  0.0018.
# DE loss, IV loss, Vloss in 36100th epoch:  0.1036,  0.1424,  0.0017.
# DE loss, IV loss, Vloss in 36200th epoch:  0.1037,  0.1429,  0.0017.
# DE loss, IV loss, Vloss in 36300th epoch:  0.1038,  0.1424,  0.0017.
# DE loss, IV loss, Vloss in 36400th epoch:  0.1036,  0.1426,  0.0017.
# DE loss, IV loss, Vloss in 36500th epoch:  0.1037,  0.1425,  0.0017.
# DE loss, IV loss, Vloss in 36600th epoch:  0.1035,  0.1427,  0.0018.
# DE loss, IV loss, Vloss in 36700th epoch:  0.1037,  0.1428,  0.0017.
# DE loss, IV loss, Vloss in 36800th epoch:  0.1040,  0.1426,  0.0017.
# DE loss, IV loss, Vloss in 36900th epoch:  0.1039,  0.1438,  0.0017.
# DE loss, IV loss, Vloss in 37000th epoch:  0.1037,  0.1425,  0.0017.
# DE loss, IV loss, Vloss in 37100th epoch:  0.1040,  0.1427,  0.0017.
# DE loss, IV loss, Vloss in 37200th epoch:  0.1042,  0.1432,  0.0017.
# DE loss, IV loss, Vloss in 37300th epoch:  0.1036,  0.1430,  0.0017.
# DE loss, IV loss, Vloss in 37400th epoch:  0.1042,  0.1429,  0.0017.
# DE loss, IV loss, Vloss in 37500th epoch:  0.1040,  0.1445,  0.0017.
# DE loss, IV loss, Vloss in 37600th epoch:  0.1034,  0.1431,  0.0018.
# DE loss, IV loss, Vloss in 37700th epoch:  0.1023,  0.1417,  0.0020.
# DE loss, IV loss, Vloss in 37800th epoch:  0.1033,  0.1432,  0.0018.
# DE loss, IV loss, Vloss in 37900th epoch:  0.1034,  0.1434,  0.0018.
# DE loss, IV loss, Vloss in 38000th epoch:  0.1032,  0.1433,  0.0018.
# DE loss, IV loss, Vloss in 38100th epoch:  0.1023,  0.1416,  0.0019.
# DE loss, IV loss, Vloss in 38200th epoch:  0.1038,  0.1430,  0.0017.
# DE loss, IV loss, Vloss in 38300th epoch:  0.1034,  0.1435,  0.0018.
# DE loss, IV loss, Vloss in 38400th epoch:  0.1034,  0.1436,  0.0018.
# DE loss, IV loss, Vloss in 38500th epoch:  0.1032,  0.1430,  0.0018.
# DE loss, IV loss, Vloss in 38600th epoch:  0.1031,  0.1440,  0.0018.
# DE loss, IV loss, Vloss in 38700th epoch:  0.1038,  0.1439,  0.0017.
# DE loss, IV loss, Vloss in 38800th epoch:  0.1032,  0.1432,  0.0018.
# DE loss, IV loss, Vloss in 38900th epoch:  0.1039,  0.1447,  0.0017.
# DE loss, IV loss, Vloss in 39000th epoch:  0.1031,  0.1433,  0.0018.
# DE loss, IV loss, Vloss in 39100th epoch:  0.1058,  0.1482,  0.0016.
# DE loss, IV loss, Vloss in 39200th epoch:  0.1033,  0.1440,  0.0018.
# DE loss, IV loss, Vloss in 39300th epoch:  0.1038,  0.1438,  0.0017.
# DE loss, IV loss, Vloss in 39400th epoch:  0.1032,  0.1439,  0.0018.
# DE loss, IV loss, Vloss in 39500th epoch:  0.1035,  0.1440,  0.0017.
# DE loss, IV loss, Vloss in 39600th epoch:  0.1033,  0.1440,  0.0018.
# DE loss, IV loss, Vloss in 39700th epoch:  0.1040,  0.1446,  0.0017.
# DE loss, IV loss, Vloss in 39800th epoch:  0.1031,  0.1445,  0.0018.
# DE loss, IV loss, Vloss in 39900th epoch:  0.1032,  0.1444,  0.0018.
# DE loss, IV loss, Vloss in 40000th epoch:  0.1033,  0.1442,  0.0017.
# DE loss, IV loss, Vloss in 40100th epoch:  0.1033,  0.1445,  0.0017.
# DE loss, IV loss, Vloss in 40200th epoch:  0.1027,  0.1427,  0.0019.
# DE loss, IV loss, Vloss in 40300th epoch:  0.1035,  0.1442,  0.0017.
# DE loss, IV loss, Vloss in 40400th epoch:  0.1038,  0.1445,  0.0017.
# DE loss, IV loss, Vloss in 40500th epoch:  0.1027,  0.1441,  0.0018.
# DE loss, IV loss, Vloss in 40600th epoch:  0.1027,  0.1448,  0.0018.
# DE loss, IV loss, Vloss in 40700th epoch:  0.1037,  0.1445,  0.0017.
# DE loss, IV loss, Vloss in 40800th epoch:  0.1031,  0.1444,  0.0018.
# DE loss, IV loss, Vloss in 40900th epoch:  0.1031,  0.1441,  0.0018.
# DE loss, IV loss, Vloss in 41000th epoch:  0.1046,  0.1449,  0.0016.
# DE loss, IV loss, Vloss in 41100th epoch:  0.1031,  0.1442,  0.0018.
# DE loss, IV loss, Vloss in 41200th epoch:  0.1034,  0.1449,  0.0017.
# DE loss, IV loss, Vloss in 41300th epoch:  0.1033,  0.1445,  0.0017.
# DE loss, IV loss, Vloss in 41400th epoch:  0.1033,  0.1444,  0.0017.
# DE loss, IV loss, Vloss in 41500th epoch:  0.1040,  0.1447,  0.0017.
# DE loss, IV loss, Vloss in 41600th epoch:  0.1026,  0.1444,  0.0018.
# DE loss, IV loss, Vloss in 41700th epoch:  0.1034,  0.1452,  0.0017.
# DE loss, IV loss, Vloss in 41800th epoch:  0.1030,  0.1448,  0.0018.
# DE loss, IV loss, Vloss in 41900th epoch:  0.1030,  0.1443,  0.0018.
# DE loss, IV loss, Vloss in 42000th epoch:  0.1036,  0.1444,  0.0017.
# DE loss, IV loss, Vloss in 42100th epoch:  0.1034,  0.1451,  0.0017.
# DE loss, IV loss, Vloss in 42200th epoch:  0.1029,  0.1447,  0.0018.
# DE loss, IV loss, Vloss in 42300th epoch:  0.1028,  0.1451,  0.0018.
# DE loss, IV loss, Vloss in 42400th epoch:  0.1034,  0.1442,  0.0018.
# DE loss, IV loss, Vloss in 42500th epoch:  0.1030,  0.1448,  0.0018.
# DE loss, IV loss, Vloss in 42600th epoch:  0.1030,  0.1450,  0.0018.
# DE loss, IV loss, Vloss in 42700th epoch:  0.1027,  0.1455,  0.0018.
# DE loss, IV loss, Vloss in 42800th epoch:  0.1028,  0.1450,  0.0018.
# DE loss, IV loss, Vloss in 42900th epoch:  0.1033,  0.1449,  0.0017.
# DE loss, IV loss, Vloss in 43000th epoch:  0.1032,  0.1454,  0.0017.
# DE loss, IV loss, Vloss in 43100th epoch:  0.1034,  0.1453,  0.0017.
# DE loss, IV loss, Vloss in 43200th epoch:  0.1027,  0.1452,  0.0018.
# DE loss, IV loss, Vloss in 43300th epoch:  0.1028,  0.1453,  0.0018.
# DE loss, IV loss, Vloss in 43400th epoch:  0.1031,  0.1455,  0.0017.
# DE loss, IV loss, Vloss in 43500th epoch:  0.1031,  0.1450,  0.0017.
# DE loss, IV loss, Vloss in 43600th epoch:  0.1022,  0.1441,  0.0019.
# DE loss, IV loss, Vloss in 43700th epoch:  0.1030,  0.1456,  0.0018.
# DE loss, IV loss, Vloss in 43800th epoch:  0.1040,  0.1464,  0.0016.
# DE loss, IV loss, Vloss in 43900th epoch:  0.1032,  0.1456,  0.0017.
# DE loss, IV loss, Vloss in 44000th epoch:  0.1036,  0.1455,  0.0017.
# DE loss, IV loss, Vloss in 44100th epoch:  0.1030,  0.1444,  0.0018.
# DE loss, IV loss, Vloss in 44200th epoch:  0.1040,  0.1452,  0.0017.
# DE loss, IV loss, Vloss in 44300th epoch:  0.1028,  0.1449,  0.0018.
# DE loss, IV loss, Vloss in 44400th epoch:  0.1031,  0.1468,  0.0017.
# DE loss, IV loss, Vloss in 44500th epoch:  0.1021,  0.1459,  0.0018.
# DE loss, IV loss, Vloss in 44600th epoch:  0.1032,  0.1459,  0.0017.
# DE loss, IV loss, Vloss in 44700th epoch:  0.1022,  0.1456,  0.0018.
# DE loss, IV loss, Vloss in 44800th epoch:  0.1015,  0.1457,  0.0019.
# DE loss, IV loss, Vloss in 44900th epoch:  0.1017,  0.1453,  0.0019.
# DE loss, IV loss, Vloss in 45000th epoch:  0.1019,  0.1452,  0.0020.
# DE loss, IV loss, Vloss in 45100th epoch:  0.1019,  0.1464,  0.0018.
# DE loss, IV loss, Vloss in 45200th epoch:  0.1026,  0.1447,  0.0017.
# DE loss, IV loss, Vloss in 45300th epoch:  0.1012,  0.1467,  0.0018.
# DE loss, IV loss, Vloss in 45400th epoch:  0.1006,  0.1468,  0.0018.
# DE loss, IV loss, Vloss in 45500th epoch:  0.1008,  0.1485,  0.0018.
# DE loss, IV loss, Vloss in 45600th epoch:  0.1029,  0.1450,  0.0017.
# DE loss, IV loss, Vloss in 45700th epoch:  0.1027,  0.1459,  0.0017.
# DE loss, IV loss, Vloss in 45800th epoch:  0.1027,  0.1460,  0.0017.
# DE loss, IV loss, Vloss in 45900th epoch:  0.1020,  0.1466,  0.0018.
# DE loss, IV loss, Vloss in 46000th epoch:  0.1025,  0.1460,  0.0018.
# DE loss, IV loss, Vloss in 46100th epoch:  0.1035,  0.1465,  0.0016.
# DE loss, IV loss, Vloss in 46200th epoch:  0.1050,  0.1469,  0.0016.
# DE loss, IV loss, Vloss in 46300th epoch:  0.1028,  0.1462,  0.0018.
# DE loss, IV loss, Vloss in 46400th epoch:  0.1020,  0.1456,  0.0019.
# DE loss, IV loss, Vloss in 46500th epoch:  0.1026,  0.1461,  0.0018.
# DE loss, IV loss, Vloss in 46600th epoch:  0.1040,  0.1463,  0.0016.
# DE loss, IV loss, Vloss in 46700th epoch:  0.1030,  0.1461,  0.0017.
# DE loss, IV loss, Vloss in 46800th epoch:  0.1032,  0.1459,  0.0017.
# DE loss, IV loss, Vloss in 46900th epoch:  0.1026,  0.1460,  0.0018.
# DE loss, IV loss, Vloss in 47000th epoch:  0.1028,  0.1464,  0.0018.
# DE loss, IV loss, Vloss in 47100th epoch:  0.1039,  0.1455,  0.0017.
# DE loss, IV loss, Vloss in 47200th epoch:  0.1037,  0.1478,  0.0017.
# DE loss, IV loss, Vloss in 47300th epoch:  0.1026,  0.1464,  0.0018.
# DE loss, IV loss, Vloss in 47400th epoch:  0.1028,  0.1460,  0.0018.
# DE loss, IV loss, Vloss in 47500th epoch:  0.1029,  0.1460,  0.0018.
# DE loss, IV loss, Vloss in 47600th epoch:  0.1043,  0.1474,  0.0016.
# DE loss, IV loss, Vloss in 47700th epoch:  0.1029,  0.1468,  0.0017.
# DE loss, IV loss, Vloss in 47800th epoch:  0.1023,  0.1453,  0.0018.
# DE loss, IV loss, Vloss in 47900th epoch:  0.1028,  0.1465,  0.0018.
# DE loss, IV loss, Vloss in 48000th epoch:  0.1027,  0.1459,  0.0018.
# DE loss, IV loss, Vloss in 48100th epoch:  0.1025,  0.1463,  0.0018.
# DE loss, IV loss, Vloss in 48200th epoch:  0.1024,  0.1469,  0.0018.
# DE loss, IV loss, Vloss in 48300th epoch:  0.1033,  0.1473,  0.0017.
# DE loss, IV loss, Vloss in 48400th epoch:  0.1028,  0.1458,  0.0018.
# DE loss, IV loss, Vloss in 48500th epoch:  0.1026,  0.1468,  0.0018.
# DE loss, IV loss, Vloss in 48600th epoch:  0.1027,  0.1467,  0.0018.
# DE loss, IV loss, Vloss in 48700th epoch:  0.1025,  0.1474,  0.0018.
# DE loss, IV loss, Vloss in 48800th epoch:  0.1018,  0.1473,  0.0019.
# DE loss, IV loss, Vloss in 48900th epoch:  0.1028,  0.1465,  0.0018.
# DE loss, IV loss, Vloss in 49000th epoch:  0.1026,  0.1470,  0.0018.
# DE loss, IV loss, Vloss in 49100th epoch:  0.1028,  0.1470,  0.0018.
# DE loss, IV loss, Vloss in 49200th epoch:  0.1029,  0.1462,  0.0018.
# DE loss, IV loss, Vloss in 49300th epoch:  0.1028,  0.1470,  0.0017.
# DE loss, IV loss, Vloss in 49400th epoch:  0.1023,  0.1471,  0.0018.
# DE loss, IV loss, Vloss in 49500th epoch:  0.1029,  0.1473,  0.0017.
# DE loss, IV loss, Vloss in 49600th epoch:  0.1036,  0.1461,  0.0017.
# DE loss, IV loss, Vloss in 49700th epoch:  0.1018,  0.1478,  0.0018.
# DE loss, IV loss, Vloss in 49800th epoch:  0.1028,  0.1477,  0.0017.
# DE loss, IV loss, Vloss in 49900th epoch:  0.1010,  0.1497,  0.0018.
# DE loss, IV loss, Vloss in 50000th epoch:  0.1004,  0.1504,  0.0018.
# DE loss, IV loss, Vloss in 50100th epoch:  0.1003,  0.1516,  0.0018.
# DE loss, IV loss, Vloss in 50200th epoch:  0.1001,  0.1513,  0.0018.
# DE loss, IV loss, Vloss in 50300th epoch:  0.1000,  0.1515,  0.0018.
# DE loss, IV loss, Vloss in 50400th epoch:  0.1002,  0.1516,  0.0018.
# DE loss, IV loss, Vloss in 50500th epoch:  0.1000,  0.1519,  0.0018.
# DE loss, IV loss, Vloss in 50600th epoch:  0.0996,  0.1509,  0.0019.
# DE loss, IV loss, Vloss in 50700th epoch:  0.1004,  0.1516,  0.0017.
# DE loss, IV loss, Vloss in 50800th epoch:  0.1000,  0.1512,  0.0018.
# DE loss, IV loss, Vloss in 50900th epoch:  0.1000,  0.1520,  0.0018.
# DE loss, IV loss, Vloss in 51000th epoch:  0.0997,  0.1519,  0.0018.
# DE loss, IV loss, Vloss in 51100th epoch:  0.0997,  0.1515,  0.0018.
# DE loss, IV loss, Vloss in 51200th epoch:  0.1000,  0.1519,  0.0018.
# DE loss, IV loss, Vloss in 51300th epoch:  0.0989,  0.1516,  0.0019.
# DE loss, IV loss, Vloss in 51400th epoch:  0.1001,  0.1513,  0.0018.
# DE loss, IV loss, Vloss in 51500th epoch:  0.1000,  0.1520,  0.0018.
# DE loss, IV loss, Vloss in 51600th epoch:  0.1004,  0.1525,  0.0017.
# DE loss, IV loss, Vloss in 51700th epoch:  0.1000,  0.1522,  0.0018.
# DE loss, IV loss, Vloss in 51800th epoch:  0.1004,  0.1518,  0.0017.
# DE loss, IV loss, Vloss in 51900th epoch:  0.0999,  0.1520,  0.0018.
# DE loss, IV loss, Vloss in 52000th epoch:  0.0998,  0.1521,  0.0018.
# DE loss, IV loss, Vloss in 52100th epoch:  0.0996,  0.1539,  0.0018.
# DE loss, IV loss, Vloss in 52200th epoch:  0.1002,  0.1523,  0.0017.
# DE loss, IV loss, Vloss in 52300th epoch:  0.1004,  0.1526,  0.0017.
# DE loss, IV loss, Vloss in 52400th epoch:  0.0997,  0.1541,  0.0018.
# DE loss, IV loss, Vloss in 52500th epoch:  0.0994,  0.1549,  0.0018.
# DE loss, IV loss, Vloss in 52600th epoch:  0.0983,  0.1578,  0.0018.
# DE loss, IV loss, Vloss in 52700th epoch:  0.0983,  0.1607,  0.0018.
# DE loss, IV loss, Vloss in 52800th epoch:  0.0988,  0.1614,  0.0017.
# DE loss, IV loss, Vloss in 52900th epoch:  0.1105,  0.1260,  0.0015.
# DE loss, IV loss, Vloss in 53000th epoch:  0.1044,  0.1465,  0.0016.
# DE loss, IV loss, Vloss in 53100th epoch:  0.1020,  0.1559,  0.0017.
# DE loss, IV loss, Vloss in 53200th epoch:  0.1010,  0.1600,  0.0017.
# DE loss, IV loss, Vloss in 53300th epoch:  0.1006,  0.1598,  0.0017.
# DE loss, IV loss, Vloss in 53400th epoch:  0.0996,  0.1639,  0.0017.
# DE loss, IV loss, Vloss in 53500th epoch:  0.0993,  0.1653,  0.0017.
# DE loss, IV loss, Vloss in 53600th epoch:  0.0991,  0.1660,  0.0017.
# DE loss, IV loss, Vloss in 53700th epoch:  0.0994,  0.1681,  0.0016.
# DE loss, IV loss, Vloss in 53800th epoch:  0.0982,  0.1686,  0.0017.
# DE loss, IV loss, Vloss in 53900th epoch:  0.0979,  0.1681,  0.0017.
# DE loss, IV loss, Vloss in 54000th epoch:  0.0977,  0.1709,  0.0017.
# DE loss, IV loss, Vloss in 54100th epoch:  0.0950,  0.1747,  0.0021.
# DE loss, IV loss, Vloss in 54200th epoch:  0.0970,  0.1728,  0.0017.
# DE loss, IV loss, Vloss in 54300th epoch:  0.0969,  0.1732,  0.0017.
# DE loss, IV loss, Vloss in 54400th epoch:  0.0969,  0.1735,  0.0017.
# DE loss, IV loss, Vloss in 54500th epoch:  0.0968,  0.1739,  0.0017.
# DE loss, IV loss, Vloss in 54600th epoch:  0.0968,  0.1737,  0.0017.
# DE loss, IV loss, Vloss in 54700th epoch:  0.0956,  0.1739,  0.0019.
# DE loss, IV loss, Vloss in 54800th epoch:  0.0967,  0.1741,  0.0017.
# DE loss, IV loss, Vloss in 54900th epoch:  0.0966,  0.1742,  0.0018.
# DE loss, IV loss, Vloss in 55000th epoch:  0.0966,  0.1748,  0.0018.
# DE loss, IV loss, Vloss in 55100th epoch:  0.0965,  0.1744,  0.0018.
# DE loss, IV loss, Vloss in 55200th epoch:  0.0975,  0.1739,  0.0017.
# DE loss, IV loss, Vloss in 55300th epoch:  0.0965,  0.1746,  0.0018.
# DE loss, IV loss, Vloss in 55400th epoch:  0.0966,  0.1747,  0.0017.
# DE loss, IV loss, Vloss in 55500th epoch:  0.0966,  0.1748,  0.0017.
# DE loss, IV loss, Vloss in 55600th epoch:  0.0965,  0.1748,  0.0018.
# DE loss, IV loss, Vloss in 55700th epoch:  0.0966,  0.1748,  0.0017.
# DE loss, IV loss, Vloss in 55800th epoch:  0.0958,  0.1745,  0.0019.
# DE loss, IV loss, Vloss in 55900th epoch:  0.0962,  0.1755,  0.0018.
# DE loss, IV loss, Vloss in 56000th epoch:  0.0964,  0.1752,  0.0018.
# DE loss, IV loss, Vloss in 56100th epoch:  0.0964,  0.1752,  0.0018.
# DE loss, IV loss, Vloss in 56200th epoch:  0.0962,  0.1753,  0.0018.
# DE loss, IV loss, Vloss in 56300th epoch:  0.0962,  0.1754,  0.0018.
# DE loss, IV loss, Vloss in 56400th epoch:  0.0968,  0.1753,  0.0017.
# DE loss, IV loss, Vloss in 56500th epoch:  0.0965,  0.1756,  0.0017.
# DE loss, IV loss, Vloss in 56600th epoch:  0.0964,  0.1762,  0.0017.
# DE loss, IV loss, Vloss in 56700th epoch:  0.0963,  0.1761,  0.0017.
# DE loss, IV loss, Vloss in 56800th epoch:  0.0950,  0.1763,  0.0020.
# DE loss, IV loss, Vloss in 56900th epoch:  0.0961,  0.1766,  0.0018.
# DE loss, IV loss, Vloss in 57000th epoch:  0.0946,  0.1784,  0.0020.
# DE loss, IV loss, Vloss in 57100th epoch:  0.0962,  0.1747,  0.0018.
# DE loss, IV loss, Vloss in 57200th epoch:  0.0962,  0.1769,  0.0017.
# DE loss, IV loss, Vloss in 57300th epoch:  0.0962,  0.1768,  0.0017.
# DE loss, IV loss, Vloss in 57400th epoch:  0.0954,  0.1783,  0.0018.
# DE loss, IV loss, Vloss in 57500th epoch:  0.0963,  0.1760,  0.0017.
# DE loss, IV loss, Vloss in 57600th epoch:  0.0962,  0.1768,  0.0017.
# DE loss, IV loss, Vloss in 57700th epoch:  0.0956,  0.1776,  0.0018.
# DE loss, IV loss, Vloss in 57800th epoch:  0.0961,  0.1768,  0.0017.
# DE loss, IV loss, Vloss in 57900th epoch:  0.0962,  0.1771,  0.0017.
# DE loss, IV loss, Vloss in 58000th epoch:  0.0958,  0.1779,  0.0018.
# DE loss, IV loss, Vloss in 58100th epoch:  0.0963,  0.1748,  0.0018.
# DE loss, IV loss, Vloss in 58200th epoch:  0.0963,  0.1767,  0.0017.
# DE loss, IV loss, Vloss in 58300th epoch:  0.1020,  0.1965,  0.0034.
# DE loss, IV loss, Vloss in 58400th epoch:  0.0968,  0.1755,  0.0017.
# DE loss, IV loss, Vloss in 58500th epoch:  0.0963,  0.1774,  0.0017.
# DE loss, IV loss, Vloss in 58600th epoch:  0.0961,  0.1785,  0.0017.
# DE loss, IV loss, Vloss in 58700th epoch:  0.0964,  0.1742,  0.0018.
# DE loss, IV loss, Vloss in 58800th epoch:  0.0963,  0.1767,  0.0018.
# DE loss, IV loss, Vloss in 58900th epoch:  0.0962,  0.1775,  0.0017.
# DE loss, IV loss, Vloss in 59000th epoch:  0.0960,  0.1785,  0.0017.
# DE loss, IV loss, Vloss in 59100th epoch:  0.0959,  0.1797,  0.0017.
# DE loss, IV loss, Vloss in 59200th epoch:  0.0966,  0.1741,  0.0018.
# DE loss, IV loss, Vloss in 59300th epoch:  0.0963,  0.1760,  0.0018.
# DE loss, IV loss, Vloss in 59400th epoch:  0.0962,  0.1766,  0.0018.
# DE loss, IV loss, Vloss in 59500th epoch:  0.0962,  0.1770,  0.0018.
# DE loss, IV loss, Vloss in 59600th epoch:  0.0962,  0.1772,  0.0018.
# DE loss, IV loss, Vloss in 59700th epoch:  0.0961,  0.1775,  0.0018.
# DE loss, IV loss, Vloss in 59800th epoch:  0.0961,  0.1778,  0.0018.
# DE loss, IV loss, Vloss in 59900th epoch:  0.0960,  0.1783,  0.0017.
# DE loss, IV loss, Vloss in 60000th epoch:  0.0961,  0.1790,  0.0017.
# DE loss, IV loss, Vloss in 60100th epoch:  0.0958,  0.1799,  0.0017.
# DE loss, IV loss, Vloss in 60200th epoch:  0.0959,  0.1790,  0.0017.
# DE loss, IV loss, Vloss in 60300th epoch:  0.1196,  0.1671,  0.0018.
# DE loss, IV loss, Vloss in 60400th epoch:  0.0971,  0.1707,  0.0017.
# DE loss, IV loss, Vloss in 60500th epoch:  0.0963,  0.1760,  0.0018.
# DE loss, IV loss, Vloss in 60600th epoch:  0.0962,  0.1769,  0.0018.
# DE loss, IV loss, Vloss in 60700th epoch:  0.0961,  0.1771,  0.0018.
# DE loss, IV loss, Vloss in 60800th epoch:  0.0961,  0.1773,  0.0018.
# DE loss, IV loss, Vloss in 60900th epoch:  0.0961,  0.1775,  0.0018.
# DE loss, IV loss, Vloss in 61000th epoch:  0.0961,  0.1776,  0.0018.
# DE loss, IV loss, Vloss in 61100th epoch:  0.0961,  0.1777,  0.0018.
# DE loss, IV loss, Vloss in 61200th epoch:  0.0960,  0.1780,  0.0018.
# DE loss, IV loss, Vloss in 61300th epoch:  0.0960,  0.1779,  0.0018.
# DE loss, IV loss, Vloss in 61400th epoch:  0.0961,  0.1781,  0.0018.
# DE loss, IV loss, Vloss in 61500th epoch:  0.0960,  0.1781,  0.0018.
# DE loss, IV loss, Vloss in 61600th epoch:  0.0960,  0.1782,  0.0018.
# DE loss, IV loss, Vloss in 61700th epoch:  0.0958,  0.1782,  0.0018.
# DE loss, IV loss, Vloss in 61800th epoch:  0.0961,  0.1784,  0.0017.
# DE loss, IV loss, Vloss in 61900th epoch:  0.0969,  0.1784,  0.0017.
# DE loss, IV loss, Vloss in 62000th epoch:  0.0958,  0.1801,  0.0018.
# DE loss, IV loss, Vloss in 62100th epoch:  0.0958,  0.1809,  0.0017.
# DE loss, IV loss, Vloss in 62200th epoch:  0.0959,  0.1805,  0.0017.
# DE loss, IV loss, Vloss in 62300th epoch:  0.0957,  0.1813,  0.0017.
# DE loss, IV loss, Vloss in 62400th epoch:  0.0956,  0.1812,  0.0017.
# DE loss, IV loss, Vloss in 62500th epoch:  0.0957,  0.1812,  0.0017.
# DE loss, IV loss, Vloss in 62600th epoch:  0.0958,  0.1797,  0.0017.
# DE loss, IV loss, Vloss in 62700th epoch:  0.0976,  0.1816,  0.0016.
# DE loss, IV loss, Vloss in 62800th epoch:  0.0955,  0.1810,  0.0018.
# DE loss, IV loss, Vloss in 62900th epoch:  0.0954,  0.1826,  0.0017.
# DE loss, IV loss, Vloss in 63000th epoch:  0.0956,  0.1807,  0.0017.
# DE loss, IV loss, Vloss in 63100th epoch:  0.0949,  0.1838,  0.0018.
# DE loss, IV loss, Vloss in 63200th epoch:  0.0964,  0.1776,  0.0017.
# DE loss, IV loss, Vloss in 63300th epoch:  0.0952,  0.1841,  0.0017.
# DE loss, IV loss, Vloss in 63400th epoch:  0.1048,  0.1476,  0.0015.
# DE loss, IV loss, Vloss in 63500th epoch:  0.0971,  0.1746,  0.0017.
# DE loss, IV loss, Vloss in 63600th epoch:  0.0962,  0.1779,  0.0017.
# DE loss, IV loss, Vloss in 63700th epoch:  0.0959,  0.1792,  0.0018.
# DE loss, IV loss, Vloss in 63800th epoch:  0.0958,  0.1804,  0.0018.
# DE loss, IV loss, Vloss in 63900th epoch:  0.0956,  0.1815,  0.0017.
# DE loss, IV loss, Vloss in 64000th epoch:  0.0952,  0.1832,  0.0018.
# DE loss, IV loss, Vloss in 64100th epoch:  0.0956,  0.1842,  0.0017.
# DE loss, IV loss, Vloss in 64200th epoch:  0.0952,  0.1845,  0.0017.
# DE loss, IV loss, Vloss in 64300th epoch:  0.0952,  0.1819,  0.0018.
# DE loss, IV loss, Vloss in 64400th epoch:  0.0951,  0.1846,  0.0017.
# DE loss, IV loss, Vloss in 64500th epoch:  0.0950,  0.1861,  0.0017.
# DE loss, IV loss, Vloss in 64600th epoch:  0.0956,  0.1816,  0.0017.
# DE loss, IV loss, Vloss in 64700th epoch:  0.0951,  0.1851,  0.0017.
# DE loss, IV loss, Vloss in 64800th epoch:  0.0949,  0.1867,  0.0017.
# DE loss, IV loss, Vloss in 64900th epoch:  0.0971,  0.1844,  0.0016.
# DE loss, IV loss, Vloss in 65000th epoch:  0.0948,  0.1872,  0.0017.
# DE loss, IV loss, Vloss in 65100th epoch:  0.0987,  0.1794,  0.0016.
# DE loss, IV loss, Vloss in 65200th epoch:  0.0951,  0.1847,  0.0017.
# DE loss, IV loss, Vloss in 65300th epoch:  0.0948,  0.1873,  0.0017.
# DE loss, IV loss, Vloss in 65400th epoch:  0.0946,  0.1887,  0.0017.
# DE loss, IV loss, Vloss in 65500th epoch:  0.0942,  0.1874,  0.0018.
# DE loss, IV loss, Vloss in 65600th epoch:  0.0946,  0.1893,  0.0017.
# DE loss, IV loss, Vloss in 65700th epoch:  0.0945,  0.1903,  0.0017.
# DE loss, IV loss, Vloss in 65800th epoch:  0.0948,  0.1877,  0.0017.
# DE loss, IV loss, Vloss in 65900th epoch:  0.0945,  0.1900,  0.0017.
# DE loss, IV loss, Vloss in 66000th epoch:  0.0944,  0.1908,  0.0017.
# DE loss, IV loss, Vloss in 66100th epoch:  0.0985,  0.1921,  0.0015.
# DE loss, IV loss, Vloss in 66200th epoch:  0.0943,  0.1914,  0.0017.
# DE loss, IV loss, Vloss in 66300th epoch:  0.0934,  0.1888,  0.0019.
# DE loss, IV loss, Vloss in 66400th epoch:  0.0943,  0.1917,  0.0017.
# DE loss, IV loss, Vloss in 66500th epoch:  0.0947,  0.1897,  0.0018.
# DE loss, IV loss, Vloss in 66600th epoch:  0.0942,  0.1921,  0.0017.
# DE loss, IV loss, Vloss in 66700th epoch:  0.0940,  0.1915,  0.0018.
# DE loss, IV loss, Vloss in 66800th epoch:  0.0942,  0.1923,  0.0017.
# DE loss, IV loss, Vloss in 66900th epoch:  0.0943,  0.1918,  0.0017.
# DE loss, IV loss, Vloss in 67000th epoch:  0.0942,  0.1926,  0.0017.
# DE loss, IV loss, Vloss in 67100th epoch:  0.0946,  0.1920,  0.0017.
# DE loss, IV loss, Vloss in 67200th epoch:  0.0924,  0.1950,  0.0020.
# DE loss, IV loss, Vloss in 67300th epoch:  0.0942,  0.1922,  0.0017.
# DE loss, IV loss, Vloss in 67400th epoch:  0.0942,  0.1926,  0.0017.
# DE loss, IV loss, Vloss in 67500th epoch:  0.0942,  0.1928,  0.0017.
# DE loss, IV loss, Vloss in 67600th epoch:  0.0943,  0.1930,  0.0017.
# DE loss, IV loss, Vloss in 67700th epoch:  0.0941,  0.1930,  0.0017.
# DE loss, IV loss, Vloss in 67800th epoch:  0.0940,  0.1933,  0.0017.
# DE loss, IV loss, Vloss in 67900th epoch:  0.0941,  0.1932,  0.0017.
# DE loss, IV loss, Vloss in 68000th epoch:  0.0940,  0.1935,  0.0017.
# DE loss, IV loss, Vloss in 68100th epoch:  0.0942,  0.1934,  0.0017.
# DE loss, IV loss, Vloss in 68200th epoch:  0.0940,  0.1936,  0.0017.
# DE loss, IV loss, Vloss in 68300th epoch:  0.0945,  0.1934,  0.0017.
# DE loss, IV loss, Vloss in 68400th epoch:  0.0938,  0.1935,  0.0018.
# DE loss, IV loss, Vloss in 68500th epoch:  0.0948,  0.1928,  0.0017.
# DE loss, IV loss, Vloss in 68600th epoch:  0.0935,  0.1938,  0.0018.
# ...
# DE loss, IV loss, Vloss in 76900th epoch:  0.0927,  0.1988,  0.0017.
# DE loss, IV loss, Vloss in 77000th epoch:  0.0927,  0.1988,  0.0017.
# DE loss, IV loss, Vloss in 77100th epoch:  0.0927,  0.1989,  0.0017.
# DE loss, IV loss, Vloss in 77200th epoch:  0.0927,  0.1990,  0.0017.
# DE loss, IV loss, Vloss in 77300th epoch:  0.0928,  0.1990,  0.0017.
# DE loss, IV loss, Vloss in 77400th epoch:  0.0929,  0.1990,  0.0017.
# DE loss, IV loss, Vloss in 77500th epoch:  0.0926,  0.1988,  0.0017.
# DE loss, IV loss, Vloss in 77600th epoch:  0.0927,  0.1989,  0.0017.
# DE loss, IV loss, Vloss in 77700th epoch:  0.0926,  0.1992,  0.0017.
# DE loss, IV loss, Vloss in 77800th epoch:  0.0926,  0.1993,  0.0017.
# DE loss, IV loss, Vloss in 77900th epoch:  0.0927,  0.1993,  0.0017.
# DE loss, IV loss, Vloss in 78000th epoch:  0.0927,  0.1993,  0.0017.
# DE loss, IV loss, Vloss in 78100th epoch:  0.0929,  0.1994,  0.0017.
# DE loss, IV loss, Vloss in 78200th epoch:  0.0927,  0.1996,  0.0017.
# DE loss, IV loss, Vloss in 78300th epoch:  0.0928,  0.1994,  0.0017.
# DE loss, IV loss, Vloss in 78400th epoch:  0.0938,  0.2002,  0.0016.
# DE loss, IV loss, Vloss in 78500th epoch:  0.0925,  0.1997,  0.0017.
# DE loss, IV loss, Vloss in 78600th epoch:  0.0926,  0.1997,  0.0017.
# DE loss, IV loss, Vloss in 78700th epoch:  0.0923,  0.1999,  0.0018.
# DE loss, IV loss, Vloss in 78800th epoch:  0.0931,  0.1995,  0.0017.
# DE loss, IV loss, Vloss in 78900th epoch:  0.0922,  0.2002,  0.0018.
# DE loss, IV loss, Vloss in 79000th epoch:  0.0921,  0.2005,  0.0018.
# DE loss, IV loss, Vloss in 79100th epoch:  0.0924,  0.2002,  0.0018.
# DE loss, IV loss, Vloss in 79200th epoch:  0.0927,  0.2000,  0.0017.
# DE loss, IV loss, Vloss in 79300th epoch:  0.0926,  0.2000,  0.0017.
# DE loss, IV loss, Vloss in 79400th epoch:  0.0921,  0.2003,  0.0018.
# DE loss, IV loss, Vloss in 79500th epoch:  0.0916,  0.2010,  0.0018.
# DE loss, IV loss, Vloss in 79600th epoch:  0.0922,  0.2000,  0.0018.
# DE loss, IV loss, Vloss in 79700th epoch:  0.0926,  0.2003,  0.0017.
# DE loss, IV loss, Vloss in 79800th epoch:  0.0931,  0.2002,  0.0017.
# DE loss, IV loss, Vloss in 79900th epoch:  0.0927,  0.2000,  0.0017.
# DE loss, IV loss, Vloss in 80000th epoch:  0.0923,  0.2005,  0.0018.
# DE loss, IV loss, Vloss in 80100th epoch:  0.0928,  0.2004,  0.0017.
# DE loss, IV loss, Vloss in 80200th epoch:  0.0921,  0.2003,  0.0018.
# DE loss, IV loss, Vloss in 80300th epoch:  0.0934,  0.2006,  0.0016.
# DE loss, IV loss, Vloss in 80400th epoch:  0.0931,  0.2006,  0.0017.
# DE loss, IV loss, Vloss in 80500th epoch:  0.0921,  0.2010,  0.0018.
# DE loss, IV loss, Vloss in 80600th epoch:  0.0938,  0.2013,  0.0016.
# DE loss, IV loss, Vloss in 80700th epoch:  0.0920,  0.2012,  0.0018.
# DE loss, IV loss, Vloss in 80800th epoch:  0.0928,  0.2008,  0.0017.
# DE loss, IV loss, Vloss in 80900th epoch:  0.0927,  0.2009,  0.0017.
# DE loss, IV loss, Vloss in 81000th epoch:  0.0919,  0.2014,  0.0018.
# DE loss, IV loss, Vloss in 81100th epoch:  0.0924,  0.2011,  0.0017.
# DE loss, IV loss, Vloss in 81200th epoch:  0.0916,  0.2022,  0.0018.
# DE loss, IV loss, Vloss in 81300th epoch:  0.0926,  0.2010,  0.0017.
# DE loss, IV loss, Vloss in 81400th epoch:  0.0924,  0.2010,  0.0017.
# DE loss, IV loss, Vloss in 81500th epoch:  0.0923,  0.2017,  0.0017.
# DE loss, IV loss, Vloss in 81600th epoch:  0.0924,  0.2013,  0.0017.
# DE loss, IV loss, Vloss in 81700th epoch:  0.0930,  0.2016,  0.0017.
# DE loss, IV loss, Vloss in 81800th epoch:  0.0933,  0.2011,  0.0016.
# DE loss, IV loss, Vloss in 81900th epoch:  0.0920,  0.2018,  0.0018.
# DE loss, IV loss, Vloss in 82000th epoch:  0.0926,  0.2018,  0.0017.
# DE loss, IV loss, Vloss in 82100th epoch:  0.0928,  0.2018,  0.0017.
# DE loss, IV loss, Vloss in 82200th epoch:  0.0921,  0.2018,  0.0018.
# DE loss, IV loss, Vloss in 82300th epoch:  0.0925,  0.2020,  0.0017.
# DE loss, IV loss, Vloss in 82400th epoch:  0.0922,  0.2018,  0.0017.
# DE loss, IV loss, Vloss in 82500th epoch:  0.0940,  0.2017,  0.0016.
# DE loss, IV loss, Vloss in 82600th epoch:  0.0919,  0.2025,  0.0018.
# DE loss, IV loss, Vloss in 82700th epoch:  0.0923,  0.2019,  0.0017.
# DE loss, IV loss, Vloss in 82800th epoch:  0.0910,  0.2037,  0.0019.
# DE loss, IV loss, Vloss in 82900th epoch:  0.0922,  0.2020,  0.0017.
# DE loss, IV loss, Vloss in 83000th epoch:  0.0927,  0.2013,  0.0017.
# DE loss, IV loss, Vloss in 83100th epoch:  0.0925,  0.2020,  0.0017.
# DE loss, IV loss, Vloss in 83200th epoch:  0.1134,  0.1254,  0.0012.
# DE loss, IV loss, Vloss in 83300th epoch:  0.0978,  0.1724,  0.0015.
# DE loss, IV loss, Vloss in 83400th epoch:  0.0914,  0.1937,  0.0018.
# DE loss, IV loss, Vloss in 83500th epoch:  0.0915,  0.1926,  0.0018.
# DE loss, IV loss, Vloss in 83600th epoch:  0.0913,  0.1935,  0.0018.
# DE loss, IV loss, Vloss in 83700th epoch:  0.0915,  0.1946,  0.0018.
# DE loss, IV loss, Vloss in 83800th epoch:  0.0913,  0.1949,  0.0017.
# DE loss, IV loss, Vloss in 83900th epoch:  0.0908,  0.1959,  0.0018.
# DE loss, IV loss, Vloss in 84000th epoch:  0.0909,  0.1958,  0.0018.
# DE loss, IV loss, Vloss in 84100th epoch:  0.0909,  0.1980,  0.0017.
# DE loss, IV loss, Vloss in 84200th epoch:  0.0906,  0.1985,  0.0017.
# DE loss, IV loss, Vloss in 84300th epoch:  0.0906,  0.1992,  0.0017.
# DE loss, IV loss, Vloss in 84400th epoch:  0.0904,  0.2003,  0.0017.
# DE loss, IV loss, Vloss in 84500th epoch:  0.0903,  0.2009,  0.0017.
# DE loss, IV loss, Vloss in 84600th epoch:  0.0900,  0.2040,  0.0017.
# DE loss, IV loss, Vloss in 84700th epoch:  0.0899,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 84800th epoch:  0.0899,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 84900th epoch:  0.0899,  0.2044,  0.0017.
# DE loss, IV loss, Vloss in 85000th epoch:  0.0899,  0.2044,  0.0017.
# DE loss, IV loss, Vloss in 85100th epoch:  0.0904,  0.2040,  0.0017.
# DE loss, IV loss, Vloss in 85200th epoch:  0.0899,  0.2044,  0.0017.
# DE loss, IV loss, Vloss in 85300th epoch:  0.0899,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 85400th epoch:  0.0899,  0.2043,  0.0017.
# DE loss, IV loss, Vloss in 85500th epoch:  0.0899,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 85600th epoch:  0.0899,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 85700th epoch:  0.0899,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 85800th epoch:  0.0898,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 85900th epoch:  0.0899,  0.2046,  0.0017.
# DE loss, IV loss, Vloss in 86000th epoch:  0.0903,  0.2043,  0.0017.
# DE loss, IV loss, Vloss in 86100th epoch:  0.0899,  0.2045,  0.0017.
# DE loss, IV loss, Vloss in 86200th epoch:  0.0892,  0.2051,  0.0018.
# DE loss, IV loss, Vloss in 86300th epoch:  0.0899,  0.2047,  0.0017.
# DE loss, IV loss, Vloss in 86400th epoch:  0.0895,  0.2048,  0.0018.
# DE loss, IV loss, Vloss in 86500th epoch:  0.0898,  0.2047,  0.0017.
# DE loss, IV loss, Vloss in 86600th epoch:  0.0900,  0.2047,  0.0017.
# DE loss, IV loss, Vloss in 86700th epoch:  0.0898,  0.2048,  0.0017.
# DE loss, IV loss, Vloss in 86800th epoch:  0.0880,  0.2074,  0.0020.
# DE loss, IV loss, Vloss in 86900th epoch:  0.0898,  0.2049,  0.0017.
# DE loss, IV loss, Vloss in 87000th epoch:  0.0899,  0.2049,  0.0017.
# DE loss, IV loss, Vloss in 87100th epoch:  0.0899,  0.2049,  0.0017.
# DE loss, IV loss, Vloss in 87200th epoch:  0.0911,  0.2053,  0.0016.
# DE loss, IV loss, Vloss in 87300th epoch:  0.0898,  0.2050,  0.0017.
# DE loss, IV loss, Vloss in 87400th epoch:  0.0910,  0.2043,  0.0016.
# DE loss, IV loss, Vloss in 87500th epoch:  0.0898,  0.2051,  0.0017.
# DE loss, IV loss, Vloss in 87600th epoch:  0.0896,  0.2053,  0.0017.
# DE loss, IV loss, Vloss in 87700th epoch:  0.0900,  0.2052,  0.0017.
# DE loss, IV loss, Vloss in 87800th epoch:  0.0898,  0.2052,  0.0017.
# DE loss, IV loss, Vloss in 87900th epoch:  0.0897,  0.2053,  0.0017.
# DE loss, IV loss, Vloss in 88000th epoch:  0.0900,  0.2052,  0.0017.
# DE loss, IV loss, Vloss in 88100th epoch:  0.0897,  0.2054,  0.0017.
# DE loss, IV loss, Vloss in 88200th epoch:  0.0897,  0.2054,  0.0017.
# DE loss, IV loss, Vloss in 88300th epoch:  0.0894,  0.2055,  0.0018.
# DE loss, IV loss, Vloss in 88400th epoch:  0.0896,  0.2055,  0.0017.
# DE loss, IV loss, Vloss in 88500th epoch:  0.0897,  0.2055,  0.0017.
# DE loss, IV loss, Vloss in 88600th epoch:  0.0898,  0.2056,  0.0017.
# DE loss, IV loss, Vloss in 88700th epoch:  0.0894,  0.2059,  0.0018.
# DE loss, IV loss, Vloss in 88800th epoch:  0.0890,  0.2061,  0.0018.
# DE loss, IV loss, Vloss in 88900th epoch:  0.0894,  0.2059,  0.0018.
# DE loss, IV loss, Vloss in 89000th epoch:  0.0898,  0.2057,  0.0017.
# DE loss, IV loss, Vloss in 89100th epoch:  0.0897,  0.2057,  0.0017.
# DE loss, IV loss, Vloss in 89200th epoch:  0.0898,  0.2058,  0.0017.
# DE loss, IV loss, Vloss in 89300th epoch:  0.0898,  0.2059,  0.0017.
# DE loss, IV loss, Vloss in 89400th epoch:  0.0894,  0.2061,  0.0018.
# DE loss, IV loss, Vloss in 89500th epoch:  0.0900,  0.2058,  0.0017.
# DE loss, IV loss, Vloss in 89600th epoch:  0.0897,  0.2060,  0.0017.
# DE loss, IV loss, Vloss in 89700th epoch:  0.0897,  0.2060,  0.0017.
# DE loss, IV loss, Vloss in 89800th epoch:  0.0897,  0.2060,  0.0017.
# DE loss, IV loss, Vloss in 89900th epoch:  0.0896,  0.2062,  0.0017.
# DE loss, IV loss, Vloss in 90000th epoch:  0.0896,  0.2062,  0.0017.
# DE loss, IV loss, Vloss in 90100th epoch:  0.0896,  0.2061,  0.0017.
# DE loss, IV loss, Vloss in 90200th epoch:  0.0908,  0.2062,  0.0016.
# DE loss, IV loss, Vloss in 90300th epoch:  0.0891,  0.2065,  0.0018.
# DE loss, IV loss, Vloss in 90400th epoch:  0.0890,  0.2067,  0.0018.
# DE loss, IV loss, Vloss in 90500th epoch:  0.0895,  0.2069,  0.0017.
# DE loss, IV loss, Vloss in 90600th epoch:  0.0896,  0.2065,  0.0017.
# DE loss, IV loss, Vloss in 90700th epoch:  0.0897,  0.2064,  0.0017.
# DE loss, IV loss, Vloss in 90800th epoch:  0.0900,  0.2064,  0.0017.
# DE loss, IV loss, Vloss in 90900th epoch:  0.0898,  0.2066,  0.0017.
# DE loss, IV loss, Vloss in 91000th epoch:  0.0901,  0.2063,  0.0017.
# DE loss, IV loss, Vloss in 91100th epoch:  0.0890,  0.2070,  0.0018.
# DE loss, IV loss, Vloss in 91200th epoch:  0.0899,  0.2065,  0.0017.
# DE loss, IV loss, Vloss in 91300th epoch:  0.0899,  0.2067,  0.0017.
# DE loss, IV loss, Vloss in 91400th epoch:  0.0892,  0.2070,  0.0018.
# DE loss, IV loss, Vloss in 91500th epoch:  0.0896,  0.2067,  0.0017.
# DE loss, IV loss, Vloss in 91600th epoch:  0.0896,  0.2068,  0.0017.
# DE loss, IV loss, Vloss in 91700th epoch:  0.0896,  0.2067,  0.0017.
# DE loss, IV loss, Vloss in 91800th epoch:  0.0893,  0.2070,  0.0018.
# DE loss, IV loss, Vloss in 91900th epoch:  0.0905,  0.2065,  0.0016.
# DE loss, IV loss, Vloss in 92000th epoch:  0.0894,  0.2070,  0.0017.
# DE loss, IV loss, Vloss in 92100th epoch:  0.0896,  0.2069,  0.0017.
# DE loss, IV loss, Vloss in 92200th epoch:  0.0894,  0.2070,  0.0017.
# DE loss, IV loss, Vloss in 92300th epoch:  0.0897,  0.2070,  0.0017.
# DE loss, IV loss, Vloss in 92400th epoch:  0.0896,  0.2069,  0.0017.
# DE loss, IV loss, Vloss in 92500th epoch:  0.0895,  0.2072,  0.0017.
# DE loss, IV loss, Vloss in 92600th epoch:  0.0888,  0.2079,  0.0018.
# DE loss, IV loss, Vloss in 92700th epoch:  0.0896,  0.2071,  0.0017.
# DE loss, IV loss, Vloss in 92800th epoch:  0.0895,  0.2072,  0.0017.
# DE loss, IV loss, Vloss in 92900th epoch:  0.0893,  0.2076,  0.0017.
# DE loss, IV loss, Vloss in 93000th epoch:  0.0894,  0.2073,  0.0017.
# DE loss, IV loss, Vloss in 93100th epoch:  0.0897,  0.2073,  0.0017.
# DE loss, IV loss, Vloss in 93200th epoch:  0.0893,  0.2077,  0.0018.
# DE loss, IV loss, Vloss in 93300th epoch:  0.0894,  0.2073,  0.0017.
# DE loss, IV loss, Vloss in 93400th epoch:  0.0896,  0.2076,  0.0017.
# DE loss, IV loss, Vloss in 93500th epoch:  0.0895,  0.2078,  0.0017.
# DE loss, IV loss, Vloss in 93600th epoch:  0.0902,  0.2074,  0.0017.
# DE loss, IV loss, Vloss in 93700th epoch:  0.0894,  0.2078,  0.0017.
# DE loss, IV loss, Vloss in 93800th epoch:  0.0896,  0.2075,  0.0017.
# DE loss, IV loss, Vloss in 93900th epoch:  0.0896,  0.2072,  0.0017.
# DE loss, IV loss, Vloss in 94000th epoch:  0.0893,  0.2078,  0.0017.
# DE loss, IV loss, Vloss in 94100th epoch:  0.0889,  0.2082,  0.0018.
# DE loss, IV loss, Vloss in 94200th epoch:  0.0895,  0.2079,  0.0017.
# DE loss, IV loss, Vloss in 94300th epoch:  0.0893,  0.2079,  0.0017.
# DE loss, IV loss, Vloss in 94400th epoch:  0.0887,  0.2086,  0.0018.
# DE loss, IV loss, Vloss in 94500th epoch:  0.0892,  0.2081,  0.0018.
# DE loss, IV loss, Vloss in 94600th epoch:  0.0890,  0.2080,  0.0018.
# DE loss, IV loss, Vloss in 94700th epoch:  0.0890,  0.2085,  0.0018.
# DE loss, IV loss, Vloss in 94800th epoch:  0.0896,  0.2074,  0.0017.
# DE loss, IV loss, Vloss in 94900th epoch:  0.0893,  0.2082,  0.0017.
# DE loss, IV loss, Vloss in 95000th epoch:  0.0897,  0.2073,  0.0017.
# DE loss, IV loss, Vloss in 95100th epoch:  0.0891,  0.2086,  0.0018.
# DE loss, IV loss, Vloss in 95200th epoch:  0.0903,  0.2077,  0.0016.
# DE loss, IV loss, Vloss in 95300th epoch:  0.0886,  0.2090,  0.0018.
# DE loss, IV loss, Vloss in 95400th epoch:  0.0889,  0.2077,  0.0018.
# DE loss, IV loss, Vloss in 95500th epoch:  0.0895,  0.2084,  0.0017.
# DE loss, IV loss, Vloss in 95600th epoch:  0.0900,  0.2080,  0.0017.
# DE loss, IV loss, Vloss in 95700th epoch:  0.0895,  0.2069,  0.0017.
# DE loss, IV loss, Vloss in 95800th epoch:  0.0893,  0.2084,  0.0017.
# DE loss, IV loss, Vloss in 95900th epoch:  0.0893,  0.2081,  0.0017.
# DE loss, IV loss, Vloss in 96000th epoch:  0.0902,  0.2086,  0.0016.
# DE loss, IV loss, Vloss in 96100th epoch:  0.0894,  0.2079,  0.0017.
# DE loss, IV loss, Vloss in 96200th epoch:  0.0895,  0.2087,  0.0017.
# DE loss, IV loss, Vloss in 96300th epoch:  0.0893,  0.2091,  0.0017.
# DE loss, IV loss, Vloss in 96400th epoch:  0.1119,  0.1285,  0.0012.
# DE loss, IV loss, Vloss in 96500th epoch:  0.0889,  0.1939,  0.0016.
# DE loss, IV loss, Vloss in 96600th epoch:  0.0846,  0.2031,  0.0018.
# DE loss, IV loss, Vloss in 96700th epoch:  0.0842,  0.2041,  0.0018.
# DE loss, IV loss, Vloss in 96800th epoch:  0.0838,  0.2055,  0.0018.
# DE loss, IV loss, Vloss in 96900th epoch:  0.0838,  0.2058,  0.0018.
# DE loss, IV loss, Vloss in 97000th epoch:  0.0837,  0.2056,  0.0018.
# DE loss, IV loss, Vloss in 97100th epoch:  0.0837,  0.2056,  0.0018.
# DE loss, IV loss, Vloss in 97200th epoch:  0.0839,  0.2059,  0.0018.
# DE loss, IV loss, Vloss in 97300th epoch:  0.0836,  0.2056,  0.0018.
# DE loss, IV loss, Vloss in 97400th epoch:  0.0836,  0.2057,  0.0018.
# DE loss, IV loss, Vloss in 97500th epoch:  0.0838,  0.2059,  0.0018.
# DE loss, IV loss, Vloss in 97600th epoch:  0.0836,  0.2062,  0.0018.
# DE loss, IV loss, Vloss in 97700th epoch:  0.0837,  0.2068,  0.0018.
# DE loss, IV loss, Vloss in 97800th epoch:  0.0831,  0.2071,  0.0019.
# DE loss, IV loss, Vloss in 97900th epoch:  0.0835,  0.2069,  0.0018.
# DE loss, IV loss, Vloss in 98000th epoch:  0.0832,  0.2083,  0.0018.
# DE loss, IV loss, Vloss in 98100th epoch:  0.0828,  0.2086,  0.0019.
# DE loss, IV loss, Vloss in 98200th epoch:  0.0832,  0.2095,  0.0018.
# DE loss, IV loss, Vloss in 98300th epoch:  0.0827,  0.2103,  0.0018.
# DE loss, IV loss, Vloss in 98400th epoch:  0.0828,  0.2105,  0.0018.
# DE loss, IV loss, Vloss in 98500th epoch:  0.0832,  0.2107,  0.0017.
# DE loss, IV loss, Vloss in 98600th epoch:  0.0839,  0.2128,  0.0017.
# DE loss, IV loss, Vloss in 98700th epoch:  0.0826,  0.2127,  0.0018.
# DE loss, IV loss, Vloss in 98800th epoch:  0.0827,  0.2124,  0.0018.
# DE loss, IV loss, Vloss in 98900th epoch:  0.0828,  0.2134,  0.0017.
# DE loss, IV loss, Vloss in 99000th epoch:  0.0826,  0.2133,  0.0018.
# DE loss, IV loss, Vloss in 99100th epoch:  0.0826,  0.2132,  0.0017.
# DE loss, IV loss, Vloss in 99200th epoch:  0.0836,  0.2134,  0.0017.
# DE loss, IV loss, Vloss in 99300th epoch:  0.0827,  0.2129,  0.0017.
# DE loss, IV loss, Vloss in 99400th epoch:  0.0827,  0.2130,  0.0017.
# DE loss, IV loss, Vloss in 99500th epoch:  0.0830,  0.2135,  0.0017.
# DE loss, IV loss, Vloss in 99600th epoch:  0.0829,  0.2133,  0.0017.
# DE loss, IV loss, Vloss in 99700th epoch:  0.0827,  0.2138,  0.0017.
# DE loss, IV loss, Vloss in 99800th epoch:  0.0824,  0.2136,  0.0017.
# DE loss, IV loss, Vloss in 99900th epoch:  0.1194,  0.1304,  0.0011.

# %%
test_u = np.array([0.9, 0.9, 2/3, 1/3, 1, 1])
test_t = np.arange(0, tfinal + t_step, t_step)

sol = rklv(test_u, t0, tfinal, t_step)
x_sol = sol[1]
y_sol = sol[2]

test_u = np.tile(test_u, (len(test_t),1))
print(test_u.shape)

test_u_cond = np.log(test_u[:, :2])
test_u_param = test_u[:, 2:]

print(test_u_cond.shape)
print(test_u_param.shape)
print(test_t.shape)
# Out:
# (1001, 6)
# (1001, 2)
# (1001, 4)
# (1001,)

# %%
[test_x, test_y] = model([test_u_cond, test_u_param, test_t], training=True)

test_x = np.exp(test_x)
test_y = np.exp(test_y)

plt.figure()
plt.plot(test_x, test_y)
plt.plot(x_sol, y_sol)
