# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4830300497516813284
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 36

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 36 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
#model = build_model(summary = True)

# %%
#tf.keras.utils.plot_model(model)

# %%
def CollocPointsRandom(min, max, num_samples) :
    
    np.random.seed(45)
    random_points = max*np.random.rand(num_samples, 1)
    random_points_tensor = tf.convert_to_tensor(random_points, dtype=tf.float32)
    
    return random_points_tensor

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 200)

# %%
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(custom_t, inits, model, alpha, beta, gamma):

    t_de = custom_t

    # Initial value points
    t_init, x_init, y_init = inits[:, 0], inits[:, 1], inits[:, 2]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        
        
        V = (c * (tf.math.exp(model(t_de, training=True)[0]))) - (d * model(t_de, training=True)[0]) + (b * tf.math.exp(model(t_de, training=True)[1])) - (a * model(t_de, training=True)[1])

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
        

      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
      Vloss = tf.square(tf.math.reduce_mean(v) - v0)           
    
      # Composite loss function
      loss = alpha*DEloss + beta*IVloss + gamma*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(custom_t, x0, y0, epochs, alpha_val, beta_val, gamma_val):

    # Weight factors
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val

    # Learning rate
    lr_model = 1e-3

    # Initial value
    t_init = np.array([t0]).astype(np.float32)
    x_init = np.array([x0]).astype(np.float32)
    y_init = np.array([y0]).astype(np.float32)
    
    inits = np.column_stack([t_init, x_init, y_init])

    epoch_loss = np.zeros(epochs)

    # Generate the model
    opt = tf.keras.optimizers.Adam(lr_model)
    model = build_model() 

    # Main training loop
    for i in range(epochs):

        # Train the network
        DEloss, IVloss, Vloss, grads = train_network(custom_t, inits, model, alpha, beta, gamma)

        # Gradient step
        opt.apply_gradients(zip(grads, model.trainable_variables))
      
        epoch_loss[i] += alpha*DEloss + beta*IVloss + gamma*Vloss

        if (np.mod(i, 100)==0) :
            
            print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

    return epoch_loss, model

# %%
def train_plot(custom_t, epochs, alpha, beta, gamma) :


    loss, model = PINNtrain(custom_t, x0, y0, epochs, alpha, beta, gamma)
    
    # Grid where to evaluate the model
    step_size = 0.001
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.plot(loss)

    # Model prediction
    [x, y] = model(t)
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", alpha = " + str(alpha) +", beta = " + str(beta) + ", gamma = " + str(gamma))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)
        
    plt.figure(3)
    plt.xscale('symlog', linthresh = 0.0001)
    plt.scatter(gamma, error)
    plt.xlabel("gamma")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x)
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y)
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 20000

for i in range(5) :
    
    custom_t = de_points_tensor = tf.convert_to_tensor(defineCollocationPoints([t0, tfinal], 300), dtype=tf.float32)
    tf.print(custom_t)
    
    train_plot(custom_t, epochs, 12, 1.2, 100.0)
# Out:
# [[22.8662472]
#  [32.5562363]
#  [22.422081]
#  ...
#  [33.8640594]
#  [24.8452969]
#  [8.42120743]]
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_384/Tanh:0', description="created by layer 'dense_384'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_385/Tanh:0', description="created by layer 'dense_385'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_386/Tanh:0', description="created by layer 'dense_386'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_387/Tanh:0', description="created by layer 'dense_387'")
# DE loss, IV loss, Vloss in 0th epoch:  0.5868,  0.1001,  0.0087.
# DE loss, IV loss, Vloss in 100th epoch:  0.0887,  0.0053,  0.0030.
# DE loss, IV loss, Vloss in 200th epoch:  0.0897,  0.0260,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0895,  0.0255,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0890,  0.0244,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0886,  0.0238,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0883,  0.0239,  0.0010.
# DE loss, IV loss, Vloss in 700th epoch:  0.0879,  0.0246,  0.0010.
# DE loss, IV loss, Vloss in 800th epoch:  0.0870,  0.0262,  0.0010.
# DE loss, IV loss, Vloss in 900th epoch:  0.0768,  0.0173,  0.0006.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0655,  0.0110,  0.0003.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0613,  0.0057,  0.0003.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0482,  0.0165,  0.0002.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0306,  0.0217,  0.0001.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0200,  0.0200,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0159,  0.0194,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0139,  0.0166,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0125,  0.0156,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0116,  0.0149,  0.0000.
  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 18200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19000th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19100th epoch:  0.0001,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 19200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19900th epoch:  0.0000,  0.0000,  0.0000.
# 36000
# [[14.3178358]
#  [12.9004641]
#  [11.1166725]
#  ...
#  [11.5943127]
#  [12.6239605]
#  [22.2676487]]
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_390/Tanh:0', description="created by layer 'dense_390'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_391/Tanh:0', description="created by layer 'dense_391'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_392/Tanh:0', description="created by layer 'dense_392'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_393/Tanh:0', description="created by layer 'dense_393'")
# DE loss, IV loss, Vloss in 0th epoch:  0.6476,  0.5609,  0.0188.
# DE loss, IV loss, Vloss in 100th epoch:  0.1041,  0.0190,  0.0051.
# DE loss, IV loss, Vloss in 200th epoch:  0.0894,  0.0258,  0.0011.
# DE loss, IV loss, Vloss in 300th epoch:  0.0894,  0.0261,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0890,  0.0257,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0886,  0.0258,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0882,  0.0267,  0.0010.
# DE loss, IV loss, Vloss in 700th epoch:  0.0878,  0.0284,  0.0010.
# DE loss, IV loss, Vloss in 800th epoch:  0.0873,  0.0308,  0.0010.
# DE loss, IV loss, Vloss in 900th epoch:  0.0863,  0.0350,  0.0009.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0820,  0.0444,  0.0008.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0514,  0.0362,  0.0002.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0319,  0.0417,  0.0001.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0225,  0.0429,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0171,  0.0421,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0136,  0.0310,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0113,  0.0444,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0129,  0.0168,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0123,  0.0169,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0109,  0.0266,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0112,  0.0186,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0110,  0.0178,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0109,  0.0158,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0106,  0.0158,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0102,  0.0172,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0103,  0.0125,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0110,  0.0069,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0100,  0.0091,  0.0000.
")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_397/Tanh:0', description="created by layer 'dense_397'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_398/Tanh:0', description="created by layer 'dense_398'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_399/Tanh:0', description="created by layer 'dense_399'")
# DE loss, IV loss, Vloss in 0th epoch:  0.4773,  0.0181,  0.0043.
# DE loss, IV loss, Vloss in 100th epoch:  0.0906,  0.0347,  0.0009.
# DE loss, IV loss, Vloss in 200th epoch:  0.0895,  0.0252,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0890,  0.0236,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0885,  0.0231,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0878,  0.0240,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0814,  0.0188,  0.0008.
# DE loss, IV loss, Vloss in 700th epoch:  0.0697,  0.0185,  0.0004.
# DE loss, IV loss, Vloss in 800th epoch:  0.0626,  0.0069,  0.0002.
# DE loss, IV loss, Vloss in 900th epoch:  0.0459,  0.0199,  0.0001.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0211,  0.0532,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0166,  0.0337,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0136,  0.0303,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0132,  0.0187,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0118,  0.0233,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0116,  0.0211,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0114,  0.0210,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0122,  0.0131,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0111,  0.0189,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0109,  0.0183,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0108,  0.0170,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0108,  0.0153,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0103,  0.0188,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0102,  0.0154,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0100,  0.0146,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0095,  0.0159,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0096,  0.0103,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0089,  0.0115,  0.0000.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0087,  0.0241,  0.0000.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0078,  0.0096,  0.0000.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0085,  0.0032,  0.0000.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0070,  0.0077,  0.0000.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0066,  0.0069,  0.0000.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0063,  0.0070,  0.0000.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0062,  0.0058,  0.0000.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0060,  0.0054,  0.0000.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0082,  0.0020,  0.0000.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0058,  0.0050,  0.0000.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0057,  0.0047,  0.0000.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0056,  0.0051,  0.0000.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0056,  0.0044,  0.0000.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0059,  0.0048,  0.0000.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0054,  0.0050,  0.0000.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0053,  0.0046,  0.0000.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0053,  0.0037,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0052,  0.0037,  0.0000.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0051,  0.0054,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0050,  0.0032,  0.0000.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0058,  0.0026,  0.0000.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0048,  0.0042,  0.0000.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0052,  0.0028,  0.0000.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0046,  0.0027,  0.0000.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0045,  0.0022,  0.0000.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0043,  0.0021,  0.0000.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0042,  0.0017,  0.0000.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0041,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0040,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0039,  0.0012,  0.0000.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0045,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0038,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0037,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0036,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0036,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0036,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0035,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 6500th epoch:  0.0035,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 6600th epoch:  0.0035,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 6700th epoch:  0.0035,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 6800th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 6900th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7000th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7100th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7200th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7300th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7400th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7500th epoch:  0.0033,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in
  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 15900th epoch:  0.0026,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 16000th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16100th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16200th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16300th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16400th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16500th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16600th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16700th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16800th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 16900th epoch:  0.0023,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 17000th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 17100th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 17200th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 17300th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 17400th epoch:  0.0026,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 17500th epoch:  0.0021,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 17600th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 17700th epoch:  0.0019,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 17800th epoch:  0.0018,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 17900th epoch:  0.0016,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 18000th epoch:  0.0025,  0.0031,  0.0000.
# DE loss, IV loss, Vloss in 18100th epoch:  0.0013,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 18200th epoch:  0.0011,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 18300th epoch:  0.0012,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 18400th epoch:  0.0008,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 18500th epoch:  0.0009,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 18600th epoch:  0.0007,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 18700th epoch:  0.0004,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18800th epoch:  0.0005,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 18900th epoch:  0.0003,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19000th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19100th epoch:  0.0012,  0.0029,  0.0000.
# DE loss, IV loss, Vloss in 19200th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19300th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19400th epoch:  0.0002,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 19500th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19600th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19700th epoch:  0.0005,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 19800th epoch:  0.0001,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 19900th epoch:  0.0001,  0.0000,  0.0000.
# 36000
# [[17.7843323]
#  [5.84378433]
#  [17.0279121]
#  ...
#  [2.46360946]
#  [2.77610946]
#  [26.0203381]]
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_402/Tanh:0', description="created by layer 'dense_402'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_403/Tanh:0', description="created by layer 'dense_403'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_404/Tanh:0', description="created by layer 'dense_404'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_405/Tanh:0', description="created by layer 'dense_405'")
# DE loss, IV loss, Vloss in 0th epoch:  0.5614,  0.1708,  0.0074.
# DE loss, IV loss, Vloss in 100th epoch:  0.0871,  0.0191,  0.0016.
# DE loss, IV loss, Vloss in 200th epoch:  0.0894,  0.0270,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0887,  0.0256,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0884,  0.0254,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0881,  0.0259,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0879,  0.0266,  0.0010.
# DE loss, IV loss, Vloss in 700th epoch:  0.0877,  0.0276,  0.0010.
# DE loss, IV loss, Vloss in 800th epoch:  0.0873,  0.0297,  0.0010.
# DE loss, IV loss, Vloss in 900th epoch:  0.0861,  0.0362,  0.0009.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0537,  0.0782,  0.0003.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0251,  0.0456,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0199,  0.0496,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0175,  0.0302,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0123,  0.0214,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0109,  0.0134,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0101,  0.0103,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0092,  0.0103,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0088,  0.0064,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0084,  0.0049,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0079,  0.0046,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0075,  0.0041,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0071,  0.0036,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0066,  0.0030,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0061,  0.0029,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0056,  0.0025,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0051,  0.0019,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0047,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0044,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0043,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0042,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0041,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0040,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0038,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0038,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0039,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0037,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0036,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0037,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0035,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0034,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0033,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0033,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0033,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0032,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0032,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0032,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0031,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0031,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0031,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0033,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0036,  0.0022,  0.0000.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0030,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0029,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0029,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0028,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0028,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0028,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0028,  0.0004,  0.0000.
# ...
# DE loss, IV loss, Vloss in 17700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18600th epoch:  0.0000,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 18700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19300th epoch:  0.0004,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 19400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19900th epoch:  0.0000,  0.0000,  0.0000.
# 36000
# [[25.8807373]
#  [11.2327614]
#  [8.78713]
#  ...
#  [32.414093]
#  [0.942679226]
#  [18.6800194]]
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_408/Tanh:0', description="created by layer 'dense_408'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_409/Tanh:0', description="created by layer 'dense_409'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_410/Tanh:0', description="created by layer 'dense_410'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_411/Tanh:0', description="created by layer 'dense_411'")
# DE loss, IV loss, Vloss in 0th epoch:  0.5097,  0.2933,  0.0100.
# DE loss, IV loss, Vloss in 100th epoch:  0.1031,  0.0075,  0.0042.
# DE loss, IV loss, Vloss in 200th epoch:  0.0896,  0.0278,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0891,  0.0267,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0885,  0.0260,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0878,  0.0264,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0857,  0.0257,  0.0010.
# DE loss, IV loss, Vloss in 700th epoch:  0.0735,  0.0184,  0.0005.
# DE loss, IV loss, Vloss in 800th epoch:  0.0632,  0.0185,  0.0003.
# DE loss, IV loss, Vloss in 900th epoch:  0.0465,  0.0364,  0.0002.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0253,  0.0287,  0.0001.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0159,  0.0271,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0133,  0.0258,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0120,  0.0237,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0111,  0.0223,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0117,  0.0134,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0101,  0.0463,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0102,  0.0194,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0102,  0.0163,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0098,  0.0190,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0098,  0.0151,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0097,  0.0145,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0095,  0.0137,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0127,  0.0031,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0091,  0.0133,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0090,  0.0118,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0091,  0.0091,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0084,  0.0118,  0.0000.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0077,  0.0175,  0.0000.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0077,  0.0105,  0.0000.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0072,  0.0119,  0.0000.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0070,  0.0089,  0.0000.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0074,  0.0049,  0.0000.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0066,  0.0075,  0.0000.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0064,  0.0068,  0.0000.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0062,  0.0100,  0.0000.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0060,  0.0058,  0.0000.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0058,  0.0053,  0.0000.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0058,  0.0052,  0.0000.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0055,  0.0047,  0.0000.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0054,  0.0043,  0.0000.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0052,  0.0039,  0.0000.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0051,  0.0035,  0.0000.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0050,  0.0036,  0.0000.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0049,  0.0033,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0048,  0.0031,  0.0000.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0047,  0.0029,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0046,  0.0029,  0.0000.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0045,  0.0026,  0.0000.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0044,  0.0025,  0.0000.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0043,  0.0027,  0.0000.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0042,  0.0023,  0.0000.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0041,  0.0021,  0.0000.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0040,  0.0023,  0.0000.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0039,  0.0020,  0.0000.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0046,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0037,  0.0018,  0.0000.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0036,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0036,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0058,  0.0064,  0.0000.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0035,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0034,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0034,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0034,  0.0012,  0.0000.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0033,  0.0011,  0.0000.
  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 12200th epoch:  0.0018,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 12300th epoch:  0.0021,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 12400th epoch:  0.0017,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 12500th epoch:  0.0016,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 12600th epoch:  0.0023,  0.0021,  0.0000.
# DE loss, IV loss, Vloss in 12700th epoch:  0.0015,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 12800th epoch:  0.0014,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 12900th epoch:  0.0014,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 13000th epoch:  0.0013,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 13100th epoch:  0.0013,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 13200th epoch:  0.0012,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 13300th epoch:  0.0012,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 13400th epoch:  0.0011,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 13500th epoch:  0.0011,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 13600th epoch:  0.0010,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13700th epoch:  0.0010,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13800th epoch:  0.0010,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 13900th epoch:  0.0009,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14000th epoch:  0.0008,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14100th epoch:  0.0008,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14200th epoch:  0.0007,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14300th epoch:  0.0009,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 14400th epoch:  0.0007,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14500th epoch:  0.0006,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14600th epoch:  0.0006,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14700th epoch:  0.0005,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 14800th epoch:  0.0007,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14900th epoch:  0.0005,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 15000th epoch:  0.0004,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 15100th epoch:  0.0004,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 15200th epoch:  0.0004,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 15300th epoch:  0.0003,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 15400th epoch:  0.0003,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 15500th epoch:  0.0008,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 15600th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 15700th epoch:  0.0007,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 15800th epoch:  0.0004,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 15900th epoch:  0.0012,  0.0030,  0.0000.
# DE loss, IV loss, Vloss in 16000th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 16100th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 16200th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 16300th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 16400th epoch:  0.0001,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 16500th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 16600th epoch:  0.0001,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 16700th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 16800th epoch:  0.0010,  0.0024,  0.0000.
# DE loss, IV loss, Vloss in 16900th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17000th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17100th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17200th epoch:  0.0008,  0.0021,  0.0000.
# DE loss, IV loss, Vloss in 17300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17400th epoch:  0.0006,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 17500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 17800th epoch:  0.0001,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 17900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18000th epoch:  0.0001,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 18100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18200th epoch:  0.0013,  0.0045,  0.0000.
# DE loss, IV loss, Vloss in 18300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 18800th epoch:  0.0003,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 18900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19000th epoch:  0.0001,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 19100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19400th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19500th epoch:  0.0004,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 19600th epoch:  0.0008,  0.0028,  0.0000.
# DE loss, IV loss, Vloss in 19700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 19900th epoch:  0.0006,  0.0019,  0.0000.
# 36000

# %%
end = time.time()

print((end-start)/60)
# Out:
# 30.26275062163671

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma
