# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
tf.keras.backend.set_floatx('float64')

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16495205957736976945
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 36

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 36 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
# model = build_model(summary = True)
# tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
## Define the collocation points

# de_points = defineCollocationPoints([t0, tfinal], 200)
# de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)
# plt.plot(de_points[:,0], 0*de_points[:,0],'.')
# plt.xlabel('t')
# plt.title('Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(model, t, inits, alpha, beta, gamma):

    t_de = t

    # Initial value points
    t_init, x_init, y_init = inits[:, 0], inits[:, 1], inits[:, 2]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        
      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)

      #xt = tf.cast(xt, tf.float32)
      #yt = tf.cast(yt, tf.float32)
        

      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
      Vloss = tf.square(tf.math.reduce_mean(v) - v0)           
    
      # Composite loss function
      loss = alpha*DEloss + beta*IVloss + gamma*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(custom_model, custom_t, x0, y0, epochs, alpha_val, beta_val, gamma_val):

    # Weight factors
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val

    # Learning rate
    lr_model = 1e-3

    # Initial value
    t_init = np.array([t0]).astype(np.float64)
    x_init = np.array([x0]).astype(np.float64)
    y_init = np.array([y0]).astype(np.float64)
    
    inits = np.column_stack([t_init, x_init, y_init])

    epoch_loss = np.zeros(epochs)

    # Generate the model
    opt = tf.keras.optimizers.Adam(lr_model)

    # Main training loop
    for i in range(epochs):

        # Train the network
        DEloss, IVloss, Vloss, grads = train_network(custom_model, custom_t, inits, alpha, beta, gamma)

        # Gradient step
        opt.apply_gradients(zip(grads, custom_model.trainable_variables))
      
        epoch_loss[i] += alpha*DEloss + beta*IVloss + gamma*Vloss

        if (np.mod(i, 100)==0) :
            
            print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

    return epoch_loss, custom_model

# %%
def train_plot_sequential(custom_model, custom_t, epochs, cycles, alpha, beta, gamma) :

    loss_vals = np.zeros(epochs * cycles)
    next_model = custom_model
    
    for i in range(cycles) :

        loss, model = PINNtrain(next_model, custom_t, x0, y0, epochs, alpha, beta, gamma)
        loss_vals[i*epochs : (i+1)*epochs] = loss
        
        next_model = tf.keras.models.clone_model(model)
        next_model.build((None, 1))
        next_model.set_weights(model.get_weights())
        
        
    # Grid where to evaluate the model
    step_size = 0.001
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.semilogy(loss_vals)

    # Model prediction
    [x, y] = next_model(t)
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", cycles = " + str(cycles))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)
    
    plt.figure(3)
    plt.scatter(cycles, error)
    plt.xlabel("number of cycles")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x)
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y)
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 500
cycles = 4

custom_t = defineCollocationPoints([t0, tfinal], 300)

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, custom_t, 15000, 1, 12, 1.2, 100.0)

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, custom_t, 2500, 6, 12, 1.2, 100.0)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_234/Tanh:0', description="created by layer 'dense_234'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_235/Tanh:0', description="created by layer 'dense_235'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_236/Tanh:0', description="created by layer 'dense_236'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_237/Tanh:0', description="created by layer 'dense_237'")
# DE loss, IV loss, Vloss in 0th epoch:  0.6083,  0.2325,  0.0119.
# DE loss, IV loss, Vloss in 100th epoch:  0.0902,  0.0265,  0.0010.
# DE loss, IV loss, Vloss in 200th epoch:  0.0895,  0.0259,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0893,  0.0251,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0890,  0.0243,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0888,  0.0237,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0887,  0.0234,  0.0010.
# DE loss, IV loss, Vloss in 700th epoch:  0.0885,  0.0234,  0.0010.
# DE loss, IV loss, Vloss in 800th epoch:  0.0883,  0.0237,  0.0010.
# DE loss, IV loss, Vloss in 900th epoch:  0.0880,  0.0247,  0.0010.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0872,  0.0285,  0.0010.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0800,  0.0571,  0.0009.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0568,  0.0526,  0.0004.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0439,  0.0197,  0.0001.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0300,  0.0339,  0.0001.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0244,  0.0373,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0215,  0.0371,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0176,  0.0319,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0129,  0.0208,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0111,  0.0138,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0105,  0.0113,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0102,  0.0092,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0098,  0.0079,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0092,  0.0079,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0088,  0.0055,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0084,  0.0045,  0.0000.
  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 9800th epoch:  0.0024,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 9900th epoch:  0.0024,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10000th epoch:  0.0024,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10100th epoch:  0.0024,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10200th epoch:  0.0024,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10300th epoch:  0.0024,  0.0020,  0.0000.
# DE loss, IV loss, Vloss in 10400th epoch:  0.0023,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10500th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10600th epoch:  0.0023,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10700th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10800th epoch:  0.0023,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 10900th epoch:  0.0023,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 11000th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 11100th epoch:  0.0022,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11200th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 11300th epoch:  0.0023,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11400th epoch:  0.0021,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 11500th epoch:  0.0020,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11600th epoch:  0.0020,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 11700th epoch:  0.0018,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11800th epoch:  0.0015,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11900th epoch:  0.0013,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 12000th epoch:  0.0011,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12100th epoch:  0.0011,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 12200th epoch:  0.0009,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12300th epoch:  0.0012,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 12400th epoch:  0.0006,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12500th epoch:  0.0005,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12600th epoch:  0.0004,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12700th epoch:  0.0003,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12800th epoch:  0.0003,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 12900th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13000th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13100th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13200th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13300th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13600th epoch:  0.0005,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 13700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14000th epoch:  0.0000,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 14100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14300th epoch:  0.0000,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 14400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14800th epoch:  0.0001,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 14900th epoch:  0.0001,  0.0000,  0.0000.
# 36000
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_240/Tanh:0', description="created by layer 'dense_240'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_241/Tanh:0', description="created by layer 'dense_241'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_242/Tanh:0', description="created by layer 'dense_242'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='dense_243/Tanh:0', description="created by layer 'dense_243'")
# DE loss, IV loss, Vloss in 0th epoch:  0.4840,  0.0038,  0.0045.
# DE loss, IV loss, Vloss in 100th epoch:  0.0900,  0.0259,  0.0010.
# DE loss, IV loss, Vloss in 200th epoch:  0.0894,  0.0241,  0.0011.
# DE loss, IV loss, Vloss in 300th epoch:  0.0890,  0.0235,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0885,  0.0241,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0878,  0.0261,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0842,  0.0403,  0.0008.
# DE loss, IV loss, Vloss in 700th epoch:  0.0499,  0.0459,  0.0003.
# DE loss, IV loss, Vloss in 800th epoch:  0.0254,  0.0457,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0198,  0.0392,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0156,  0.0270,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0121,  0.0424,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0116,  0.0173,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0108,  0.0149,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0102,  0.0123,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0096,  0.0110,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0093,  0.0095,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0090,  0.0082,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0087,  0.0078,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0084,  0.0071,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0081,  0.0064,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0077,  0.0059,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0074,  0.0042,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0069,  0.0041,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0064,  0.0033,  0.0000.
# DE loss, IV loss, Vloss in 0th epoch:  0.0060,  0.0044,  0.0000.
# DE loss, IV loss, Vloss in 100th epoch:  0.0060,  0.0025,  0.0000.
# DE loss, IV loss, Vloss in 200th epoch:  0.0059,  0.0025,  0.0000.
# DE loss, IV loss, Vloss in 300th epoch:  0.0057,  0.0023,  0.0000.
# DE loss, IV loss, Vloss in 400th epoch:  0.0056,  0.0021,  0.0000.
# DE loss, IV loss, Vloss in 500th epoch:  0.0055,  0.0019,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0054,  0.0017,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0053,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0051,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0050,  0.0012,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0049,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0047,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0046,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0045,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0044,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0043,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0044,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0041,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0040,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0040,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0039,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0039,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0038,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0038,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0038,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 0th epoch:  0.0045,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 100th epoch:  0.0037,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 200th epoch:  0.0037,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 300th epoch:  0.0037,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 400th epoch:  0.0037,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 500th epoch:  0.0037,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0036,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0036,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0036,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0036,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0036,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0035,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in