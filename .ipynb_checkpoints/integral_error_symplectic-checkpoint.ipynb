# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time

# %%
tf.config.run_functions_eagerly(True)

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8699372261064102821
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = 0.9, 0.9


# Boundaries of the computational domain
t0, tfinal = 0.0, 12

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * x0) - (d * np.log(x0)) + (b * y0) - (a * np.log(y0))
print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 12 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
model = build_model(summary = True)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_312/Tanh:0', description="created by layer 'dense_312'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_313/Tanh:0', description="created by layer 'dense_313'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_314/Tanh:0', description="created by layer 'dense_314'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_315/Tanh:0', description="created by layer 'dense_315'")
# Model: "model_52"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_53 (InputLayer)          [(None, 1)]          0           []
#
#  normalize_105 (Normalize)      (None, 1)            0           ['input_53[0][0]']
#
#  dense_312 (Dense)              (None, 40)           80          ['normalize_105[0][0]']
#
#  dense_313 (Dense)              (None, 40)           1640        ['dense_312[0][0]']
#
#  dense_314 (Dense)              (None, 40)           1640        ['dense_313[0][0]']
#
#  dense_315 (Dense)              (None, 40)           1640        ['dense_314[0][0]']
#
#  dense_316 (Dense)              (None, 1)            41          ['dense_315[0][0]']
#
#  dense_317 (Dense)              (None, 1)            41          ['dense_315[0][0]']
#
# ==================================================================================================
# Total params: 5,082
# Trainable params: 5,082
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 100)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(odes, inits, model, gamma, epsilon, alpha):

    # DE collocation points
    t_de = odes[:,:1]

    # Initial value points
    t_init, x_init, y_init = inits[:1], inits[1:2], inits[2:]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

        # Inner gradient for derivatives of u wrt x and t
        with tf.GradientTape(persistent=True) as tape2:
            
            tape2.watch(t_de)
            #model(t_de, training=True)[0]
            #model(t_de, training=True)[1]
            [x, y] = model(t_de, training=True)
            

        # Derivative of the neural network solution
        xt = tape2.gradient(x, t_de)
        yt = tape2.gradient(y, t_de)
    
        yx = yt/xt
        xy = xt/yt
    
      
        # Define the differential equation loss  
        eqn1 = xt - (a*x - b*x*y)
        eqn2 = yt - (c*x*y - d*y)
        DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
        # Define the initial value loss
        [x_init_pred, y_init_pred] = model(t_init, training=True)
        IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
        #Implicit integration loss
        v = (c * x) - (d * tf.math.log(x)) + (b * y) - (a * tf.math.log(y))
        Vloss = tf.math.reduce_mean(tf.square(tf.boolean_mask(v, tf.math.is_finite(v))) - v0)
        
        V = (c * model(t_de, training=True)[0]) - (d * tf.math.log(model(t_de, training=True)[0])) + (b * model(t_de, training=True)[1]) - (a * tf.math.log(model(t_de, training=True)[1]))
        tf.print(V)
        
        
    
        # Composite loss function
        loss = DEloss + gamma*IVloss + epsilon*Vloss

        grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val, alpha_val):

  # Total number of collocation points
  N_de = len(de_points)

  # Batch size
  bs_de = N_de//10

  # Weight factors
  gamma = gamma_val
  epsilon = epsilon_val
  alpha = alpha_val

  # Learning rate
  lr_model = 1e-3

  # Initial value
  t_init = np.array([t0]).astype(np.float32)
  x_init = np.array([x0]).astype(np.float32)
  y_init = np.array([y0]).astype(np.float32)

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Generate the tf.Dataset for the initial collocation points
  inits = np.column_stack([t_init, x_init, y_init])
  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache()


  # Generate the tf.Dataset for the differential equations points
  ds_ode = tf.data.Dataset.from_tensor_slices(de_points.astype(np.float32))
  ds_ode = ds_ode.cache().shuffle(N_de).batch(bs_de)

  # Generate entire dataset
  ds = tf.data.Dataset.zip((ds_ode, ds_init))

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  # Generate the model
  opt = tf.keras.optimizers.Adam(lr_model)
  model = build_model() 

  # Main training loop
  for i in range(epochs):

    # Training for that epoch
    for (des, inits) in ds:

      # Train the network
      DEloss, IVloss, Vloss, grads = train_network(des, inits, model, gamma, epsilon, alpha)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))
      
      epoch_loss[i] += DEloss + gamma*IVloss + epsilon*Vloss
      nr_batches = nr_batches + 1

    # Get total epoch loss
    epoch_loss[i] = epoch_loss[i]/nr_batches
    nr_batches = 0

    
    if (np.mod(i, 100)==0):
      print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

  return epoch_loss, model

# %%
def train_plot(epochs, gamma, epsilon, alpha) :
    
    loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon, alpha)
    
    # Grid where to evaluate the model
    step_size = 0.005
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.plot(loss)

    # Model prediction
    [x, y] = model(t)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", gamma = " + str(gamma) + ", epsilon = " + str(epsilon) + ", alpha = " + str(alpha))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)    
    
    plt.figure(3)
    print(epsilon, error)
    plt.scatter(epsilon, error)

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 1000


# for epsilon_val in np.arange(0, 1.2, 0.2, dtype=np.float32) :
    
#     train_plot(epochs, 1, epsilon_val)


train_plot(epochs, 1.2, 0.0001, 0.0)
#train_plot(epochs, 1.2, 0.0001, 0.000001)
#train_plot(epochs, 1.2, 1)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_318/Tanh:0', description="created by layer 'dense_318'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_319/Tanh:0', description="created by layer 'dense_319'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_320/Tanh:0', description="created by layer 'dense_320'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_321/Tanh:0', description="created by layer 'dense_321'")
# [[-nan]
#  [-nan]
#  [-nan]
#  ...
#  [-nan]
#  [-nan]
#  [-nan]]
# DE loss, IV loss, Vloss in 0th epoch:  0.1315,  2.5834,    nan.
# [[6.75552177]
#  [-nan]
#  [-nan]
#  ...
#  [-nan]
#  [-nan]
#  [-nan]]
# [[6.29009628]
#  [-nan]
#  [5.80285263]
#  ...
#  [-nan]
#  [6.26507568]
#  [-nan]]
# [[-nan]
#  [-nan]
#  [-nan]
#  ...
#  [6.83808041]
#  [4.82635689]
#  [-nan]]
# [[-nan]
#  [3.13895035]
#  [3.68137431]
#  ...
#  [3.24760818]
#  [-nan]
#  [3.95590162]]
# [[-nan]
#  [-nan]
#  [-nan]
#  ...
#  [-nan]
#  [-nan]
#  [2.66632748]]
# [[-nan]
#  [3.00611639]
#  [-nan]
#  ...
#  [-nan]
#  [-nan]
#  [5.18777752]]
# [[3.08053589]
#  [-nan]
#  [-nan]
#  ...
#  [-nan]
#  [2.46016335]
#  [3.7543385]]
# [[2.39933729]
#  [-nan]
#  [2.30200839]
#  ...
#  [2.57397747]
#  [-nan]
#  [2.3279202]]
# [[-nan]
#  [-nan]
#  [3.53006983]
#  ...
#  [-nan]
#  [2.27356267]
#  [-nan]]
# [[2.28461313]
#  [2.30472374]
#  [2.86605048]
#  ...
#  [-nan]
#  [-nan]
#  [2.34607983]]
# [[-nan]
#  [2.27917457]
#  [4.67588902]
#  ...
#  [2.28234625]
#  [2.46986461]
#  [-nan]]
# [[-nan]
#  [2.36411953]
#  [2.5750041]
#  ...
#  [2.2655046]
#  [-nan]
#  [-nan]]
# [[-nan]
#  [-nan]
#  [2.28171587]
#  ...
#  [2.31095243]
#  [3.29078484]
#  [2.25755095]]
# [[2.30234194]
#  [2.29653287]
#  [2.29601836]
#  ...
#  [2.32681108]
#  [2.34025788]
#  [-nan]]
# [[2.26773429]
#  [3.11197567]
#  [2.30832386]
#  ...
#  [2.27372217]
#  [2.34362102]
#  [2.6361053]]
# [[3.82540369]
#  [-nan]
#  [2.55827069]
#  ...
#  [-nan]
#  [2.22654915]
#  [2.27225089]]
# [[2.30387235]
#  [2.29462194]
#  [2.22054887]
#  ...
#  [2.22862625]
#  [-nan]
#  [3.06670618]]
# [[-nan]
#  [2.21750593]
#  [2.37150812]
#  ...
#  [3.03417516]
#  [2.22158575]
#  [-nan]]
# [[3.31436729]
#  [-nan]
#  [-nan]
#  ...
#  [2.22400379]
#  [3.77296829]
#  [2.31489015]]
# [[3.66746068]
#  [-nan]
#  [2.25320578]
#  ...
#  [2.21285462]
#  [2.20950079]
#  [4.67999315]]
# [[2.2309494]
#  [-nan]
#  [2.21963191]
#  ...
#  [2.42230797]
#  [2.21403861]
#  [2.82314038]]
# [[-nan]
#  [2.24581099]
#  [-nan]
#  ...
#  [5.27057314]
#  [4.54766273]
#  [3.53892]]
# [[2.22419262]
#  [-nan]
#  [2.21952915]
#  ...
#  [2.25399637]
#  [2.62501073]
#  [-nan]]
# [[2.20976424]
#  [-nan]
#  [-nan]
#  ...
#  [2.23842335]
#  [2.46447206]
#  [2.59744406]]
# [[-nan]
#  [4.5248723]
#  [-nan]
#  ...
#  [-nan]
#  [-nan]
#  [-nan]]
# [[2.36717558]
#  [2.21860218]
#  [3.53610039]
#  ...
#  [2.91401815]
#  [2.2299695]
#  [2.21223688]]
# [[2.32181406]
#  [2.51305175]
#  [2.21668577]
#  ...
#  [-nan]
#  [-nan]
#  [2.39149332]]
# [[2.50469804]
#  [2.79174781]
#  [2.33423042]
#  ...
#  [-nan]
#  [2.24337173]
#  [2.8596704]]
# [[2.37764239]
#  [2.576756]
#  [3.02902842]
#  ...
#  [2.43875623]
#  [3.08644152]
#  [2.2253027]]
# [[2.23632908]
#  [2.68844557]
#  [2.28548193]
#  ...
#  [2.24811983]
#  [-nan]
#  [2.27509379]]
# [[2.25871086]
#  [2.23937678]
#  [2.26057673]
#  ...
#  [-nan]
#  [-nan]
#  [-nan]]
# [[-nan]
#  [-nan]
#  [2.28062391]
#  ...
#  [2.23361]
#  [2.26080799]
#  [2.81665182]]
# [[2.59174323]
#  [2.61858892]
#  [2.24142]
#  ...
#  [6.57397175]
#  [-nan]
#  [2.23358727]]
# [[2.26015472]
#  [-nan]
#  [2.24668384]
#  ...
#  [2.84031343]
#  [-nan]
#  [2.23990941]]
# [[2.78084636]
#  [3.54447842]
#  [2.51459479]
#  ...
#  [2.38145781]
#  [-nan]
#  [2.34630299]]
# [[-nan]
#  [2.98220253]
#  [3.77784228]
#  ...
#  [2.74825931]
#  [2.26341701]
#  [2.42805123]]
# [[-nan]
#  [2.22983098]
#  [2.23160696]
#  ...
#  [-nan]
#  [6.61473036]
#  [-nan]]
# [[-nan]
#  [-nan]
#  [-nan]
#  ...
#  [3.39845657]
#  [2.76218534]
#  [-nan]]
# [[8.25514317]
#  [2.32856607]
#  [2.22867656]
#  ...
#  [5.22083139]
#  [-nan]
#  [-nan]]
# [[2.76141334]
#  [2.46422791]
#  [2.32647228]
#  ...
#  [2.65149975]
#  [-nan]
#  [-nan]]
# [[-nan]
#  [2.250741]
#  [-nan]
#  ...
#  [2.46845961]
#  [2.23667502]
#  [2.23217034]]
# [[2.37847567]
#  [2.23357797]
#  [-nan]
#  ...
#  [-nan]
#  [2.76423311]
#  [2.67927265]]
# [[-nan]
#  [-nan]
#  [2.56258631]
#  ...
#  [-nan]
#  [-nan]
#  [2.28712654]]
# [[2.24151874]
#  [2.22474647]
#  [-nan]
#  ...
#  [2.24697638]
#  [3.37896919]
#  [2.22913742]]
# [[2.25105047]
#  [2.28483891]
#  [2.69956064]
#  ...
#  [-nan]
#  [2.23592448]
#  [2.22545648]]
# [[2.3157866]
#  [2.38770151]
#  [2.40682602]
#  ...
#  [3.17879629]
#  [2.2805233]
#  [2.23965645]]
# [[2.23262763]
#  [4.15535784]
#  [2.25699878]
#  ...
#  [2.4235878]
#  [2.22906661]
#  [2.32106924]]
# [[3.1353898]
#  [2.61291075]
#  [-nan]
#  ...
#  [-nan]
#  [2.52558017]
#  [2.33918667]]
# [[2.23724604]
#  [2.22131205]
#  [2.27271056]
#  ...
#  [2.47660708]
#  [2.24694777]
#  [7.00459433]]
# [[2.2194128]
#  [-nan]
#  [3.21911359]
#  ...
#  [2.73611951]
#  [2.25128078]
#  [5.3314929]]
# [[2.87593174]
#  [6.10432625]
#  [4.79849291]
#  ...
#  [2.33567071]
#  [-nan]
#  [2.21732473]]
# [[2.73108649]
#  [-nan]
#  [2.29622602]
#  ...
#  [2.22574925]
#  [3.30852938]
#  [3.53160214]]
# [[-nan]
#  [2.9307065]
#  [2.23141384]
#  ...
#  [2.24673653]
#  [2.21649575]
#  [2.83449793]]
# [[2.21671152]
#  [2.96410799]
#  [3.31737804]
#  ...
#  [3.41496611]
#  [2.22198]
#  [2.65103531]]
# [[-nan]
#  [2.42012668]
#  [5.27986383]
#  ...
#  [2.21504116]
#  [2.55867529]
#  [2.21473813]]
# [[2.21879387]
#  [2.24129462]
#  [2.23406315]
#  ...
#  [2.76842451]
#  [-nan]
#  [2.23152709]]
# [[3.77804184]
#  [-nan]
#  [2.21351624]
#  ...
#  [2.23353863]
#  [2.21439648]
#  [3.25861335]]
# [[2.3866179]
#  [-nan]
#  [2.45365238]
#  ...
#  [7.20184755]
#  [2.21657753]
#  [-nan]]
# [[3.05266619]
#  [2.31871557]
#  [2.2130475]
#  ...
#  [3.79540586]
#  [2.58842921]
#  [2.85767412]]
# [[2.22379684]
#  [2.2764895]
#  [2.2533772]
#  ...
#  [4.82683611]
#  [-nan]
#  [2.2170527]]
# [[9.67159939]
#  [2.21963072]
#  [-nan]
#  ...
#  [2.2328546]
#  [-nan]
#  [-nan]]
# [[2.38779283]
#  [2.93274546]
#  [3.24466538]
#  ...
#  [2.28493381]
#  [4.43245935]
#  [3.03236246]]
# [[-nan]
#  [3.38090324]
#  [2.2765696]
#  ...
#  [2.34488869]
#  [2.30939341]
#  [-nan]]
# [[2.23581839]
#  [5.02783489]
#  [2.3168695]
#  ...
#  [2.82632065]
#  [2.21799731]
#  [2.27191949]]
# [[2.2290566]
#  [2.25508404]
#  [-nan]
#  ...
#  [4.97641468]
#  [2.24717784]
#  [2.22329]]
# [[5.84508276]
#  [2.33581257]
#  [2.21946955]
#  ...
#  [2.22314119]
#  [6.77861547]
#  [2.2296102]]
# [[2.61362743]
#  [6.68794823]
#  [2.97715092]
#  ...
#  [2.21798205]
#  [2.21723318]
#  [4.09045839]]
# [[2.92481256]
#  [3.96475649]
#  [2.21641302]
#  ...
#  [-nan]
#  [2.52550554]
#  [6.77769756]]
# [[3.78525829]
#  [3.13324594]
#  [2.42244148]
#  ...
#  [2.21789455]
#  [2.36241794]
#  [2.21688414]]
# [[2.59710455]
#  [2.23747444]
#  [2.22962451]
#  ...
#  [2.32603645]
#  [2.75158167]
#  [-nan]]
# [[2.30485678]
#  [2.5121069]
#  [2.23232532]
#  ...
#  [-nan]
#  [6.69075537]
#  [2.59257913]]
# [[3.13574028]
#  [4.50633383]
#  [-nan]
#  ...
#  [2.53044987]
#  [2.34135103]
#  [2.23506904]]
# [[2.25222397]
#  [2.31686068]
#  [2.2178843]
#  ...
#  [2.30219316]
#  [2.65104699]
#  [4.42906713]]
# [[2.84143329]
#  [4.47799873]
#  [2.88893843]
#  ...
#  [2.21933508]
#  [-nan]
#  [3.73429203]]
# [[3.09521842]
#  [2.58083367]
#  [2.22781658]
#  ...
#  [-nan]
#  [2.22413635]
#  [2.22310948]]
# [[2.61535358]
#  [2.26562214]
#  [-nan]
#  ...
#  [-nan]
#  [4.7551136]
#  [-nan]]
# [[2.23489618]
#  [2.43457794]
#  [2.64388585]
#  ...
#  [2.24143434]
#  [2.52280521]
#  [2.23013568]]
# [[-nan]
#  [-nan]
#  [2.22323656]
#  ...
#  [2.24781]
#  [2.22095418]
#  [2.92371]]
# [[-nan]
#  [4.36793041]
#  [-nan]
#  ...
#  [2.225559]
#  [5.5249896]
#  [3.00583363]]
# [[2.33982158]
#  [-nan]
#  [2.23998404]
#  ...
#  [2.2213726]
#  [2.50375342]
#  [2.67981148]]
# [[6.31628036]
#  [2.2157557]
#  [4.35302353]
#  ...
#  [2.25847268]
#  [2.23492146]
#  [4.11932373]]
# [[5.49262714]
#  [2.4624126]
#  [2.23144364]
#  ...
#  [2.25854373]
#  [3.09118462]
#  [-nan]]
# [[3.39822173]
#  [2.21162724]
#  [2.41502118]
#  ...
#  [2.39119339]
#  [2.22518468]
#  [2.21434855]]
# [[3.50129557]
#  [2.40895033]
#  [6.3146286]
#  ...
#  [2.32569695]
#  [2.29824543]
#  [-nan]]
# [[2.41958809]
#  [2.21550298]
#  [2.22158861]
#  ...
#  [-nan]
#  [2.27992988]
#  [3.49882174]]
# [[4.64543962]
#  [2.32997394]
#  [2.30245519]
#  ...
#  [2.93281174]
#  [2.26109982]
#  [2.39754486]]
# [[2.32783723]
#  [2.51647043]
#  [-nan]
#  ...
#  [2.23253965]
#  [3.00881767]
#  [2.93030667]]
# [[-nan]
#  [2.22132158]
#  [2.24431109]
#  ...
#  [5.28470325]
#  [2.2264328]
#  [3.17796445]]
# [[2.23649669]
#  [2.22215605]
#  [2.73682714]
#  ...
#  [3.23032856]
#  [2.25366616]
#  [2.24191546]]
# [[2.83583283]
#  [3.0972147]
#  [2.23514104]
#  ...
#  [2.24180317]
#  [2.26818919]
#  [-nan]]
# [[2.26456594]
#  [2.42206168]
#  [2.22483754]
#  ...
#  [2.22660828]
#  [2.9160161]
#  [2.65089941]]
# [[2.26646709]
#  [-nan]
#  [2.29683471]
#  ...
#  [2.2380116]
#  [4.75854778]
#  [2.41670799]]
# [[2.66095972]
#  [2.22589827]
#  [2.24521]
#  ...
#  [-nan]
#  [2.22492051]
#  [-nan]]
# [[2.22889733]
#  [2.23647475]
#  [3.86723828]
#  ...
#  [2.24475193]
#  [2.69659114]
#  [2.30360317]]
# [[4.5482378]
#  [2.21959901]
#  [2.24240828]
#  ...
#  [3.83824921]
#  [2.21974301]
#  [2.31217432]]
# [[2.32838917]
#  [2.24570656]
#  [2.24699187]
#  ...
#  [2.2589767]
#  [3.33482099]
#  [3.24898577]]
# [[2.20914364]
#  [2.22006369]
#  [3.6831708]
#  ...
#  [2.22025585]
#  [3.06430101]
#  [3.11531448]]
# [[2.23100257]
#  [2.21179557]
#  [2.22859383]
#  ...
#  [-nan]
#  [4.98703194]
#  [2.21439719]]
# [[2.20509338]
#  [2.22831702]
#  [6.6273632]
#  ...
#  [2.20765829]
#  [2.21442628]
#  [2.56604719]]
# [[3.04821634]
#  [2.31580257]
#  [2.68588305]
#  ...
#  [2.22417903]
#  [2.34133959]
#  [2.23125505]]
# DE loss, IV loss, Vloss in 100th epoch:  0.0448,  0.0050,  4.2280.
# [[2.23078179]
#  [2.22753763]
#  [2.22564244]
#  ...
#  [-nan]
#  [2.21000838]
#  [2.22311068]]
# [[2.98209429]
#  [2.20853782]
#  [2.20779371]
#  ...
#  [2.20116949]
#  [2.4341352]
#  [2.32626843]]
# [[2.20742702]
#  [2.22267842]
#  [2.53052211]
#  ...
#  [2.19957614]
#  [2.82458496]
#  [2.2002759]]
# [[3.20706081]
#  [2.21772337]
#  [4.91442871]
#  ...
#  [2.46286917]
#  [2.37964058]
#  [-nan]]
# [[-nan]
#  [-nan]
#  [2.61715126]
#  ...
#  [2.20371675]
#  [2.37448621]
#  [2.21101141]]
# [[2.20648098]
#  [2.20800138]
#  [2.24108124]
#  ...
#  [4.11128426]
#  [2.88965511]
#  [2.23715758]]
# [[2.30623]
#  [3.61499286]
#  [2.21228576]
#  ...
#  [2.88853693]
#  [2.21792984]
#  [4.85910225]]
# [[5.56555414]
#  [-nan]
#  [2.24084091]
#  ...
#  [2.32532644]
#  [2.21807885]
#  [3.91306]]
# [[2.2149179]
#  [5.72157288]
#  [4.34317]
#  ...
#  [2.21737766]
#  [2.23275304]
#  [3.71506929]]
# [[2.2205162]
#  [2.78781843]
#  [2.61925387]
#  ...
#  [2.22006106]
#  [2.33815217]
#  [2.2687397]]
# [[-nan]
#  [2.23936868]
#  [3.30340958]
#  ...
#  [2.41089272]
#  [2.82131577]
#  [-nan]]
# [[2.2332809]
#  [2.25323892]
#  [2.25075698]
#  ...
#  [2.22093344]
#  [2.95113802]
#  [2.22017884]]
# [[2.2246747]
#  [2.78364182]
#  [2.94973087]
#  ...
#  [2.24417615]
#  [3.19102955]
#  [5.60722876]]
# [[2.56105328]
#  [3.30192304]
#  [2.23016548]
#  ...
#  [-nan]
#  [3.02766681]
#  [2.67931056]]
# [[-nan]
#  [2.2141068]
#  [2.3039856]
#  ...
#  [2.2807579]
#  [3.02768373]
#  [2.23520517]]
# [[2.25439429]
#  [2.71773243]
#  [2.2144618]
#  ...
#  [2.22855043]
#  [3.42156219]
#  [2.23617744]]
# [[2.21474576]
#  [2.46129274]
#  [2.94798422]
#  ...
#  [2.2198534]
#  [8.09243393]
#  [2.24204636]]
# [[2.55973768]
#  [2.24722362]
#  [2.21244669]
#  ...
#  [-nan]
#  [2.88361883]
#  [4.08955097]]
# [[3.61737394]
#  [2.46379042]
#  [2.21912789]
#  ...
#  [2.58656311]
#  [2.25272632]
#  [2.30271482]]
# [[2.7884829]
#  [3.54927254]
#  [2.21950078]
#  ...
#  [2.21888]
#  [2.21777415]
#  [3.92779779]]
# [[2.21790552]
#  [2.28156805]
#  [2.5364809]
#  ...
#  [2.62090707]
#  [2.89468765]
#  [2.28882957]]
# [[2.30432034]
#  [2.24011302]
#  [2.21358037]
#  ...
#  [3.32638407]
#  [2.21151423]
#  [2.22942257]]
# [[2.59900117]
#  [2.23474765]
#  [2.30627]
#  ...
#  [2.22043133]
#  [2.21192312]
#  [2.54282713]]
# [[2.30801296]
#  [2.21334314]
#  [2.97398806]
#  ...
#  [2.21409798]
#  [-nan]
#  [2.47631121]]
# [[4.92826319]
#  [2.67613578]
#  [2.54713464]
#  ...
#  [2.21490455]
#  [2.33061218]
#  [2.23065734]]
# [[3.96383381]
#  [5.67660713]
#  [2.21590686]
#  ...
#  [4.92761707]
#  [2.27136]
#  [2.28957105]]
# [[2.25373173]
#  [2.23834229]
#  [-nan]
#  ...
#  [3.34339905]
#  [2.31508207]
#  [2.24132061]]
# [[-nan]
#  [2.47910619]
#  [-nan]
#  ...
#  [2.60332274]
#  [-nan]
#  [2.21617055]]
# [[2.31156969]
#  [2.21798444]
#  [-nan]
#  ...
#  [2.57529664]
#  [2.24290085]
#  [2.22977519]]
# [[2.23223591]
#  [4.74144363]
#  [2.25778437]
#  ...
#  [2.22130632]
#  [3.27680349]
#  [4.06566191]]
# [[3.03142047]
#  [2.22002506]
#  [2.23246622]
#  ...
#  [2.23862314]
#  [5.24600315]
#  [7.21214533]]
# [[2.25621343]
#  [2.3918519]
#  [2.22677135]
#  ...
#  [2.25042033]
#  [4.27807474]
#  [2.56966066]]
# [[4.41024303]
#  [3.29105043]
#  [3.83228135]
#  ...
#  [3.18453765]
#  [-nan]
#  [2.22109985]]
# [[2.23840857]
#  [2.50225925]
#  [4.40243101]
#  ...
#  [2.22308874]
#  [2.24734831]
#  [2.21455646]]
# [[2.24525166]
#  [4.6701231]
#  [2.22139692]
#  ...
#  [2.46819496]
#  [2.21288419]
#  [2.25715756]]
# [[2.21405554]
#  [7.9372406]
#  [2.20772123]
#  ...
#  [5.30447102]
#  [2.21051812]
#  [2.217098]]
# [[2.34652472]
#  [-nan]
#  [2.6150682]
#  ...
#  [2.37661147]
#  [2.20416403]
#  [3.06841683]]
# [[2.20422387]
#  [2.49737477]
#  [2.2017889]
#  ...
#  [2.20320845]
#  [2.22722197]
#  [2.65659833]]
# [[2.46449733]
#  [4.41157103]
#  [2.25959277]
#  ...
#  [2.49718]
#  [3.8681829]
#  [2.22503257]]
# [[2.2115612]
#  [2.2270472]
#  [2.94699788]
#  ...
#  [2.65727615]
#  [2.40621042]
#  [2.37551069]]
# [[-nan]
#  [2.21614599]
#  [2.43902802]
#  ...
#  [4.72828293]
#  [2.81706142]
#  [5.77289963]]
# [[4.27754641]
#  [2.3787384]
#  [2.20906878]
#  ...
#  [5.22280931]
#  [2.26468658]
#  [2.21492529]]
# [[4.04105282]
#  [2.21465468]
#  [2.58979368]
#  ...
#  [2.23654485]
#  [2.23160625]
#  [2.21544433]]
# [[2.28661084]
#  [-nan]
#  [2.36842632]
#  ...
#  [4.28741455]
#  [2.53667235]
#  [2.43164396]]
# [[-nan]
#  [2.62005925]
#  [2.22428083]
#  ...
#  [3.41248918]
#  [2.25426149]
#  [3.07501984]]
# [[2.25566483]
#  [3.26801062]
#  [2.24185586]
#  ...
#  [4.29976845]
#  [2.24409032]
#  [2.49101496]]
# [[2.54155397]
#  [2.24949527]
#  [4.78412437]
#  ...
#  [3.60245419]
#  [2.23058128]
#  [2.79176974]]
# [[2.2579217]
#  [2.24687195]
#  [2.24060583]
#  ...
#  [2.33423924]
#  [3.31253791]
#  [2.2932446]]
# [[2.22804189]
#  [2.45396852]
#  [2.25611162]
#  ...
#  [2.57983685]
#  [5.96403885]
#  [9.1751461]]
# [[5.49652576]
#  [2.76965904]
#  [2.21261525]
#  ...
#  [2.22839308]
#  [2.23001385]
#  [4.83217716]]
# [[2.24840117]
#  [-nan]
#  [3.22562075]
#  ...
#  [2.21465659]
#  [2.22704268]
#  [3.94073343]]
# [[2.21324587]
#  [2.2220633]
#  [2.22061276]
#  ...
#  [2.20682359]
#  [5.56943035]
#  [2.85194182]]
# [[2.78208399]
#  [-nan]
#  [4.85612202]
#  ...
#  [-nan]
#  [2.2326653]
#  [2.64644051]]
# [[2.99682689]
#  [2.21568036]
#  [2.2084775]
#  ...
#  [-nan]
#  [2.59407]
#  [2.20476961]]
# [[2.23544741]
#  [2.21296144]
#  [3.25080824]
#  ...
#  [2.20326352]
#  [2.20483637]
#  [-nan]]
# [[2.49679971]
#  [2.20581055]
#  [2.25127339]
#  ...
#  [2.40132236]
#  [2.53155136]
#  [2.62615275]]
# [[3.2609663]
#  [2.20956063]
#  [2.22133589]
#  ...
#  [-nan]
#  [2.20878816]
#  [2.20986652]]
# [[2.50060987]
#  [2.22252965]
#  [2.21437287]
#  ...
#  [2.22260785]
#  [2.21502662]
#  [2.27020073]]
# [[2.22449398]
#  [3.63608932]
#  [2.24771094]
#  ...
#  [2.5727582]
#  [5.88442707]
#  [2.6312418]]
# [[2.23009872]
#  [2.21825266]
#  [2.94927692]
#  ...
#  [3.1033287]
#  [5.09889746]
#  [5.96283722]]
# [[2.24003482]
#  [4.2696991]
#  [2.24468]
#  ...
#  [3.10714102]
#  [3.3710494]
#  [2.22141266]]
# [[2.22788572]
#  [2.23095775]
#  [-nan]
#  ...
#  [2.66357636]
#  [3.41511607]
#  [2.23822141]]
# [[2.80938101]
#  [2.32110357]
#  [2.57479382]
#  ...
#  [3.42733812]
#  [2.25919604]
#  [2.30656767]]
# [[2.89242172]
#  [-nan]
#  [2.71381807]
#  ...
#  [2.24141526]
#  [6.20269]
#  [2.24362421]]
# [[2.2302165]
#  [2.23650646]
#  [2.225878]
#  ...
#  [2.4109931]
#  [2.22538757]
#  [2.23495412]]
# [[3.13621616]
#  [4.39217615]
#  [6.36184454]
#  ...
#  [2.21234846]
#  [-nan]
#  [2.22081137]]
# [[4.74443531]
#  [2.26265645]
#  [2.23794389]
#  ...
#  [2.20607]
#  [2.22959614]
#  [4.18744373]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[624], line 9
#       1 epochs = 1000
#       4 # for epsilon_val in np.arange(0, 1.2, 0.2, dtype=np.float32) :
#       5
#       6 #     train_plot(epochs, 1, epsilon_val)
# ----> 9 train_plot(epochs, 1.2, 0.0001, 0.0)
#      10 #train_plot(epochs, 1.2, 0.0001, 0.000001)
#      11 #train_plot(epochs, 1.2, 1)
#
# Cell In[621], line 3, in train_plot(epochs, gamma, epsilon, alpha)
#       1 def train_plot(epochs, gamma, epsilon, alpha) :
# ----> 3     loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon, alpha)
#       5     # Grid where to evaluate the model
#       6     step_size = 0.005
#
# Cell In[620], line 51, in PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val, alpha_val)
#      45 for i in range(epochs):
#      46
#      47   # Training for that epoch
#      48   for (des, inits) in ds:
#      49
#      50     # Train the network
# ---> 51     DEloss, IVloss, Vloss, grads = train_network(des, inits, model, gamma, epsilon, alpha)
#      53     # Gradient step
#      54     opt.apply_gradients(zip(grads, model.trainable_variables))
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function.__call__(self, *args, **kwds)
#     855 if self._run_functions_eagerly:
#     856   with trace.Trace(self._name, tf_function_call="eager"):
# --> 857     return self._python_function(*args, **kwds)
#     859 # Only count the statistics the first time, before initialization took
#     860 # place.
#     861 if self._created_variables is None:
#
# Cell In[619], line 52, in train_network(odes, inits, model, gamma, epsilon, alpha)
#      49     # Composite loss function
#      50     loss = DEloss + gamma*IVloss + epsilon*Vloss
# ---> 52     grads = tape.gradient(loss, model.trainable_variables)
#      54 return DEloss, IVloss, Vloss, grads
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\eager\backprop.py:1112, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1106   output_gradients = (
#    1107       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1108           output_gradients))
#    1109   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1110                       for x in output_gradients]
# -> 1112 flat_grad = imperative_grad.imperative_grad(
#    1113     self._tape,
#    1114     flat_targets,
#    1115     flat_sources,
#    1116     output_gradients=output_gradients,
#    1117     sources_raw=flat_sources_raw,
#    1118     unconnected_gradients=unconnected_gradients)
#    1120 if not self._persistent:
#    1121   # Keep track of watched variables before setting tape to None
#    1122   self._watched_variables = self._tape.watched_variables()
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\eager\backprop.py:157, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     155     gradient_name_scope += forward_pass_name_scope + "/"
#     156   with ops.name_scope(gradient_name_scope):
# --> 157     return grad_fn(mock_op, *out_grads)
#     158 else:
#     159   return grad_fn(mock_op, *out_grads)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\nn_grad.py:347, in _BiasAddGrad(op, received_grad)
#     344 except ValueError:
#     345   data_format = None
#     346 return (received_grad,
# --> 347         gen_nn_ops.bias_add_grad(
#     348             out_backprop=received_grad, data_format=data_format))
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py:984, in bias_add_grad(out_backprop, data_format, name)
#     982 if tld.is_eager:
#     983   try:
# --> 984     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     985       _ctx, "BiasAddGrad", name, out_backprop, "data_format", data_format)
#     986     return _result
#     987   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
end = time.time()

print((end-start)/60)

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

step = 0.001

# Make data.
x = np.arange(step, 3, step)
y = np.arange(step, 3, step)
x, y = np.meshgrid(x, y)

V_loss = (c * x) - (d * np.log(x)) + (b * y) - (a * np.log(y))

#V_loss = np.sqrt(x**2 + y**2)

z = np.abs(V_loss - v0)

# Plot the surface.

plt.plot(xpoints, ypoints, [-1]*len(xpoints), color = 'black')
surf = ax.plot_surface(x, y, z, cmap=cm.coolwarm, linewidth=0, antialiased=False)


ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

# Customize the z axis.
ax.set_zlim(-1, 5)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
