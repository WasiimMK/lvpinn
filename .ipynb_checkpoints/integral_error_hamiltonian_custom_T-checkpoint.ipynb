# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2839910027080912375
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 12

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 12 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
#model = build_model(summary = True)

# %%
#tf.keras.utils.plot_model(model)

# %%
def CollocPointsRandom(min, max, num_samples) :
    
    np.random.seed(45)
    random_points = max*np.random.rand(num_samples, 1)
    random_points_tensor = tf.convert_to_tensor(random_points, dtype=tf.float32)
    
    return random_points_tensor

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 200)

# %%
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(custom_t, inits, model, alpha, beta, gamma):

    t_de = custom_t

    # Initial value points
    t_init, x_init, y_init = inits[:, 0], inits[:, 1], inits[:, 2]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        
        
        V = (c * (tf.math.exp(model(t_de, training=True)[0]))) - (d * model(t_de, training=True)[0]) + (b * tf.math.exp(model(t_de, training=True)[1])) - (a * model(t_de, training=True)[1])

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
        

      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
      Vloss = tf.square(tf.math.reduce_mean(v) - v0)           
    
      # Composite loss function
      loss = alpha*DEloss + beta*IVloss + gamma*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(custom_t, x0, y0, epochs, alpha_val, beta_val, gamma_val):

    # Weight factors
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val

    # Learning rate
    lr_model = 1e-3

    # Initial value
    t_init = np.array([t0]).astype(np.float32)
    x_init = np.array([x0]).astype(np.float32)
    y_init = np.array([y0]).astype(np.float32)
    
    inits = np.column_stack([t_init, x_init, y_init])

    epoch_loss = np.zeros(epochs)

    # Generate the model
    opt = tf.keras.optimizers.Adam(lr_model)
    model = build_model() 

    # Main training loop
    for i in range(epochs):

        # Train the network
        DEloss, IVloss, Vloss, grads = train_network(custom_t, inits, model, alpha, beta, gamma)

        # Gradient step
        opt.apply_gradients(zip(grads, model.trainable_variables))
      
        epoch_loss[i] += alpha*DEloss + beta*IVloss + gamma*Vloss

        if (np.mod(i, 100)==0) :
            
            print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

    return epoch_loss, model

# %%
def train_plot(custom_t, epochs, alpha, beta, gamma) :


    loss, model = PINNtrain(custom_t, x0, y0, epochs, alpha, beta, gamma)
    
    # Grid where to evaluate the model
    step_size = 0.001
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    
    plt.figure(1)
    plt.plot(loss)

    # Model prediction
    [x, y] = model(t)
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", alpha = " + str(alpha) +", beta = " + str(beta) + ", gamma = " + str(gamma))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    error = calc_err(t, x, y)
        
    plt.figure(3)
    plt.xscale('symlog', linthresh = 0.0001)
    plt.scatter(gamma, error)
    plt.xlabel("gamma")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x)
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y)
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
epochs = 2500

for i in range(3) :
    
    custom_t = de_points_tensor = tf.convert_to_tensor(defineCollocationPoints([t0, tfinal], 100), dtype=tf.float32)
    tf.print(custom_t)
    
    train_plot(custom_t, epochs, 12, 1.2, 100.0)
# Out:
# [[9.06353569]
#  [11.1830587]
#  [6.66582775]
#  ...
#  [2.04790902]
#  [3.72903371]
#  [3.28595233]]
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense/Tanh:0', description="created by layer 'dense'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_1/Tanh:0', description="created by layer 'dense_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_2/Tanh:0', description="created by layer 'dense_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_3/Tanh:0', description="created by layer 'dense_3'")
# DE loss, IV loss, Vloss in 0th epoch:  0.4945,  0.0008,  0.0042.
# DE loss, IV loss, Vloss in 100th epoch:  0.0778,  0.0599,  0.0009.
# DE loss, IV loss, Vloss in 200th epoch:  0.0637,  0.0207,  0.0007.
# DE loss, IV loss, Vloss in 300th epoch:  0.0261,  0.0221,  0.0001.
# DE loss, IV loss, Vloss in 400th epoch:  0.0212,  0.0005,  0.0001.
# DE loss, IV loss, Vloss in 500th epoch:  0.0158,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0107,  0.0023,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0073,  0.0026,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0040,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0009,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0006,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0003,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0001,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0001,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0000,  0.0000,  0.0000.
# 12000
# [[6.12560749]
#  [3.48139644]
#  [4.47718573]
#  ...
#  [4.08164]
#  [4.76980257]
#  [6.75196266]]
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_6/Tanh:0', description="created by layer 'dense_6'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_7/Tanh:0', description="created by layer 'dense_7'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_8/Tanh:0', description="created by layer 'dense_8'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_9/Tanh:0', description="created by layer 'dense_9'")
# DE loss, IV loss, Vloss in 0th epoch:  0.4412,  0.4017,  0.0112.
# DE loss, IV loss, Vloss in 100th epoch:  0.0768,  0.0593,  0.0008.
# DE loss, IV loss, Vloss in 200th epoch:  0.0643,  0.0166,  0.0006.
# DE loss, IV loss, Vloss in 300th epoch:  0.0246,  0.0036,  0.0001.
# DE loss, IV loss, Vloss in 400th epoch:  0.0141,  0.0020,  0.0000.
# DE loss, IV loss, Vloss in 500th epoch:  0.0100,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0019,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0005,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0003,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0002,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0000,  0.0000,  0.0000.
# 12000
# [[3.7079289]
#  [4.16320181]
#  [1.15742183]
#  ...
#  [11.6483]
#  [9.52923393]
#  [3.85063958]]
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_12/Tanh:0', description="created by layer 'dense_12'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_13/Tanh:0', description="created by layer 'dense_13'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_14/Tanh:0', description="created by layer 'dense_14'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_15/Tanh:0', description="created by layer 'dense_15'")
# DE loss, IV loss, Vloss in 0th epoch:  0.4245,  0.0576,  0.0037.
# DE loss, IV loss, Vloss in 100th epoch:  0.0754,  0.0505,  0.0008.
# DE loss, IV loss, Vloss in 200th epoch:  0.0288,  0.0202,  0.0002.
# DE loss, IV loss, Vloss in 300th epoch:  0.0149,  0.0020,  0.0001.
# DE loss, IV loss, Vloss in 400th epoch:  0.0087,  0.0026,  0.0000.
# DE loss, IV loss, Vloss in 500th epoch:  0.0051,  0.0016,  0.0000.
# DE loss, IV loss, Vloss in 600th epoch:  0.0009,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 700th epoch:  0.0003,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 800th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 900th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0003,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0000,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0000,  0.0000,  0.0000.
# 12000

# %%
end = time.time()

print((end-start)/60)
# Out:
# 2.3046940922737122

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma
