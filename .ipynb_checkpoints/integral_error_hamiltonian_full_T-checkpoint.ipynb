# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1644615479875952655
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 36

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 36 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
#model = build_model(summary = True)

# %%
#tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 300)
print(de_points)
# Out:
# [[3.34125591e+01]
#  [2.33766223e+01]
#  [2.12562265e+01]
#  [3.38460751e+01]
#  [2.64572261e+00]
#  [1.75038133e+01]
#  [1.49956248e+01]
#  [1.36746097e+01]
#  [2.06877919e+01]
#  [2.44026851e+01]
#  [3.09936825e+01]
#  [3.45609950e+01]
#  [1.64368841e+01]
#  [3.02260724e+01]
#  [3.53906620e+01]
#  [3.18343869e+01]
#  [9.56739331e+00]
#  [3.31294711e+01]
#  [7.75547804e+00]
#  [2.51410455e+00]
#  [2.49174274e+01]
#  [3.22047831e+01]
#  [3.03354963e+01]
#  [4.73366387e+00]
#  [2.68241551e+01]
#  [1.85334979e+01]
#  [1.50243869e+00]
#  [1.96016346e+00]
#  [9.60521560e+00]
#  [3.77747746e+00]
#  [1.59673013e+01]
#  [4.58363237e+00]
#  [2.52700788e+01]
#  [1.24648551e+01]
#  [2.69541791e+01]
#  [1.19319566e+01]
#  [5.32808592e+00]
#  [2.78059840e+01]
#  [3.15797114e+00]
#  [1.17270695e+01]
#  [1.32167813e+01]
#  [4.45443593e+00]
#  [2.20279421e+01]
#  [3.05476762e+01]
#  [8.42116745e+00]
#  [3.47521577e+01]
#  [1.50325846e+01]
#  [1.69306614e+01]
#  [7.06113497e+00]
#  [1.36938871e+01]
#  [1.68438997e+01]
#  [2.58536662e+01]
#  [1.43638951e+01]
#  [2.13988657e+00]
#  [2.21851192e+01]
#  [2.87229286e+01]
#  [2.99580310e+00]
#  [5.92938117e+00]
#  [1.30831665e+01]
#  [2.75618624e+01]
#  [3.50806234e+01]
#  [7.45539696e+00]
#  [2.41509805e+01]
#  [3.91620284e+00]
#  [2.35934762e+00]
#  [2.29928948e+01]
#  [1.11225556e+00]
#  [3.51912851e+01]
#  [1.87838661e+01]
#  [2.74364893e+01]
#  [3.15504054e+01]
#  [5.15736128e+00]
#  [8.16818725e+00]
#  [3.05788691e+00]
#  [2.25225193e+01]
#  [1.05025594e+01]
#  [1.25249732e+01]
#  [2.70165192e+01]
#  [3.45263671e+01]
#  [1.58118004e+01]
#  [1.17735783e+01]
#  [2.26296417e+01]
#  [7.63771228e+00]
#  [1.14823268e+01]
#  [3.23458460e+01]
#  [2.65982068e+01]
#  [8.52995767e+00]
#  [1.53173275e+01]
#  [2.36022741e+01]
#  [1.20666850e+01]
#  [2.88406983e+01]
#  [3.20240349e+01]
#  [1.58978203e+01]
#  [2.82083942e+01]
#  [7.86423416e+00]
#  [3.56570385e+01]
#  [2.10149034e+01]
#  [1.70780985e+01]
#  [8.14555007e+00]
#  [3.67752776e+00]
#  [2.45811715e+01]
#  [1.65402255e+01]
#  [3.20443130e+01]
#  [2.37437892e+01]
#  [2.97218828e+01]
#  [1.54240093e-01]
#  [2.98797682e+01]
#  [2.22711409e+01]
#  [3.27121819e+01]
#  [3.58775508e+01]
#  [1.12293007e+01]
#  [3.44541214e+00]
#  [3.29686128e+01]
#  [1.01050906e+01]
#  [1.62758432e+01]
#  [1.47520057e+01]
#  [1.91561560e+01]
#  [5.46940913e+00]
#  [1.02547963e+01]
#  [4.15355494e+00]
#  [1.09074922e+01]
#  [2.19028623e+01]
#  [2.62799253e+01]
#  [1.83138330e+01]
#  [2.92881151e+01]
#  [1.67439631e+01]
#  [1.80871387e+01]
#  [3.00640536e+01]
#  [2.38083066e+01]
#  [1.42457929e+01]
#  [6.50186695e+00]
#  [2.63044206e+01]
#  [1.94790616e+01]
#  [3.06884644e+01]
#  [2.30802952e+01]
#  [3.44211003e+01]
#  [6.03726399e+00]
#  [3.24502883e+01]
#  [2.42631733e+01]
#  [3.09046547e+01]
#  [3.50880699e+00]
#  [2.23530837e+01]
#  [3.35573874e+00]
#  [1.44589585e+01]
#  [3.40717560e+01]
#  [2.59532412e+01]
#  [2.05781286e+01]
#  [2.01625234e+01]
#  [2.64697402e+01]
#  [6.26516266e-01]
#  [1.09295886e+01]
#  [2.76647990e+01]
#  [1.76830576e+01]
#  [1.89795040e+01]
#  [1.89204004e+01]
#  [9.25620071e+00]
#  [2.60835403e+01]
#  [2.25015202e+00]
#  [2.82060047e+00]
#  [2.98874838e+01]
#  [1.61648730e+01]
#  [1.04142112e+00]
#  [1.99810323e+01]
#  [1.29584368e+01]
#  [7.89706094e-01]
#  [3.49801454e+01]
#  [4.27291905e+00]
#  [1.26974486e+01]
#  [1.13869685e+01]
#  [2.54771336e+01]
#  [5.62938769e+00]
#  [1.98565215e+01]
#  [1.84149929e+01]
#  [2.95653976e+01]
#  [2.53974660e+01]
#  [2.16292809e+01]
#  [3.04132450e+01]
#  [1.92134495e+01]
#  [1.00015161e+01]
#  [6.60614974e+00]
#  [1.46113361e+01]
#  [2.50022537e+01]
#  [6.14338640e+00]
#  [2.91291684e+01]
#  [1.34569369e+01]
#  [2.51138871e-01]
#  [6.81420789e+00]
#  [5.77549295e+00]
#  [3.56165610e+01]
#  [2.01215170e+01]
#  [2.17800714e+01]
#  [3.42953391e+01]
#  [2.11673849e+01]
#  [2.27575458e+01]
#  [1.34007268e+01]
#  [2.40758541e+01]
#  [2.85065354e+01]
#  [2.92106813e+01]
#  [1.27440684e+01]
#  [2.09575868e+01]
#  [1.06100017e+01]
#  [7.19055953e+00]
#  [3.35661165e+01]
#  [9.75338163e+00]
#  [2.80090089e+01]
#  [2.14243487e+01]
#  [2.46658186e+01]
#  [1.82354784e+01]
#  [1.97613966e+01]
#  [2.51714300e+01]
#  [3.54174438e+01]
#  [2.78726876e+01]
#  [1.39333602e+01]
#  [2.84046672e+01]
#  [1.56002540e+01]
#  [1.79916786e+01]
#  [1.48645973e+01]
#  [7.97347969e+00]
#  [5.17973989e+00]
#  [2.86499318e+01]
#  [2.56430495e+00]
#  [2.56539130e+01]
#  [1.73419759e+01]
#  [1.52106445e+01]
#  [1.38920450e+01]
#  [4.32542072e+00]
#  [2.31833649e+01]
#  [2.71949933e+01]
#  [2.81234994e+01]
#  [6.27013847e+00]
#  [1.72686385e+01]
#  [2.02886576e+01]
#  [4.80190242e+00]
#  [2.28129639e+01]
#  [2.66509003e+01]
#  [3.13659840e+01]
#  [9.47185852e-01]
#  [1.79506351e+00]
#  [2.08308810e+01]
#  [2.94647169e+01]
#  [2.73302271e+01]
#  [2.39286085e+01]
#  [3.37896985e+01]
#  [1.21501737e+01]
#  [3.08363748e+01]
#  [3.36008471e+01]
#  [9.23568551e+00]
#  [1.40564822e+01]
#  [4.02127783e+00]
#  [2.34196954e+01]
#  [3.41879205e+01]
#  [1.10635713e+01]
#  [4.60509955e-03]
#  [7.30305917e+00]
#  [7.38544480e+00]
#  [8.30254476e+00]
#  [3.58967673e+01]
#  [8.81769998e+00]
#  [2.47566703e+01]
#  [1.96359775e+01]
#  [9.04233913e+00]
#  [1.86979034e+01]
#  [3.26243172e+01]
#  [2.15209525e+01]
#  [1.75242459e+01]
#  [1.22932305e+01]
#  [3.12213697e+01]
#  [6.40679004e+00]
#  [1.15527918e+01]
#  [2.89459874e+01]
#  [3.32537877e+01]
#  [1.04031838e+01]
#  [3.27649609e+01]
#  [1.39367409e+00]
#  [9.43611469e+00]
#  [1.78625619e+01]
#  [1.55717583e+01]
#  [3.15708264e+01]
#  [4.96894997e+00]
#  [1.21779223e+00]
#  [4.28573953e-01]
#  [3.17175613e+01]
#  [9.91063375e+00]
#  [1.53715899e+01]
#  [2.04973424e+01]
#  [1.94016889e+01]
#  [2.57374356e+01]
#  [8.99687809e+00]
#  [1.86380140e+00]
#  [3.30314663e+01]
#  [5.73631604e-01]
#  [5.69631276e+00]
#  [3.11005844e+01]
#  [3.48448032e+01]
#  [1.06810989e+01]
#  [6.89488305e+00]
#  [1.60640470e+00]
#  [8.68782332e+00]
#  [1.66111900e+01]
#  [1.30767445e+01]]

# %%
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(odes, inits, model, gamma, epsilon):

    # DE collocation points
    #t_de = odes[:,:1]
    
    #t_de = tf.random.uniform(shape=[300, 1], minval=0, maxval=tfinal, dtype=tf.float32)
    t_de = de_points_tensor
    

    # Initial value points
    t_init, x_init, y_init = inits[:1], inits[1:2], inits[2:]

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        
        
        V = (c * (tf.math.exp(model(t_de, training=True)[0]))) - (d * model(t_de, training=True)[0]) + (b * tf.math.exp(model(t_de, training=True)[1])) - (a * model(t_de, training=True)[1])

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
        

      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
      Vloss = tf.square(tf.math.reduce_mean(v) - v0)           
    
      # Composite loss function
      loss = 12*DEloss + gamma*IVloss + epsilon*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(de_points, x0, y0, epochs, gamma_val, epsilon_val):

  # Total number of collocation points
  N_de = len(de_points)

  # Batch size
  bs_de = N_de//10

  # Weight factors
  gamma = gamma_val
  epsilon = epsilon_val

  # Learning rate
  lr_model = 1e-3

  # Initial value
  t_init = np.array([t0]).astype(np.float32)
  x_init = np.array([x0]).astype(np.float32)
  y_init = np.array([y0]).astype(np.float32)

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Generate the tf.Dataset for the initial collocation points
  inits = np.column_stack([t_init, x_init, y_init])
  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache()


  # Generate the tf.Dataset for the differential equations points
  ds_ode = tf.data.Dataset.from_tensor_slices(de_points.astype(np.float32))
  ds_ode = ds_ode.cache().shuffle(N_de).batch(bs_de)

  # Generate entire dataset
  ds = tf.data.Dataset.zip((ds_ode, ds_init))

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  # Generate the model
  opt = tf.keras.optimizers.Adam(lr_model)
  model = build_model() 

  # Main training loop
  for i in range(epochs):

    # Training for that epoch
    for (des, inits) in ds:

      # Train the network
      DEloss, IVloss, Vloss, grads = train_network(des, inits, model, gamma, epsilon)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))
      
      epoch_loss[i] += DEloss + gamma*IVloss + epsilon*Vloss
      nr_batches = nr_batches + 1

    # Get total epoch loss
    epoch_loss[i] = epoch_loss[i]/nr_batches
    nr_batches = 0

    
    if (np.mod(i, 100)==0):
      print("DE loss, IV loss, Vloss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

  return epoch_loss, model

# %%
def train_plot(epochs, gamma, epsilon) :


    loss, model = PINNtrain(de_points, x0, y0, epochs, gamma, epsilon)
    
    # Grid where to evaluate the model
    step_size = 0.005
    t = np.arange(t0, tfinal, step_size)
    t = np.round(t, decimal_p)
    num_t = len(t)
    
    plt.figure(1)
    plt.semilogy(loss)
    plt.xlabel("epoch")
    plt.ylabel("loss")

    # Model prediction
    [x, y] = model(t)
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
        
    error = calc_err(t, x, y)
        
        
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    plt.xlabel("x")
    plt.ylabel("y")
    
    
    error = calc_err(t, x, y)
    
    plt.figure(3)
    plt.scatter(epochs, error)
    plt.xlabel("epoch number")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = np.abs(x_preds[i] - xpoints[t_i])  + np.abs(y_preds[i] - ypoints[t_i])
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
train_plot(5000, 1.2, 100.0)
train_plot(10000, 1.2, 100.0)
train_plot(15000, 1.2, 100.0)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_102/Tanh:0', description="created by layer 'dense_102'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_103/Tanh:0', description="created by layer 'dense_103'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_104/Tanh:0', description="created by layer 'dense_104'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_105/Tanh:0', description="created by layer 'dense_105'")
# DE loss, IV loss, Vloss in 0th epoch:  0.5251,  0.1601,  0.0060.
# DE loss, IV loss, Vloss in 100th epoch:  0.0888,  0.0221,  0.0014.
# DE loss, IV loss, Vloss in 200th epoch:  0.0895,  0.0261,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0890,  0.0248,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0884,  0.0238,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0881,  0.0243,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0878,  0.0252,  0.0010.
# DE loss, IV loss, Vloss in 700th epoch:  0.0874,  0.0265,  0.0010.
# DE loss, IV loss, Vloss in 800th epoch:  0.0866,  0.0286,  0.0009.
# DE loss, IV loss, Vloss in 900th epoch:  0.0638,  0.0680,  0.0007.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0338,  0.0384,  0.0001.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0211,  0.0482,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0144,  0.0359,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0130,  0.0154,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0114,  0.0184,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0111,  0.0152,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0106,  0.0132,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0099,  0.0135,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0095,  0.0122,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0091,  0.0115,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0089,  0.0096,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0085,  0.0088,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0082,  0.0086,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0079,  0.0073,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0076,  0.0069,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0073,  0.0059,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0069,  0.0051,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0064,  0.0045,  0.0000.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0058,  0.0033,  0.0000.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0055,  0.0019,  0.0000.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0050,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0047,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0046,  0.0044,  0.0000.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0044,  0.0010,  0.0000.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0043,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0040,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0039,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0038,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0037,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0036,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0035,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0034,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0034,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0033,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0033,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0032,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0031,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0031,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0031,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0030,  0.0004,  0.0000.
# 7200
# 7200
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_108/Tanh:0', description="created by layer 'dense_108'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_109/Tanh:0', description="created by layer 'dense_109'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_110/Tanh:0', description="created by layer 'dense_110'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_111/Tanh:0', description="created by layer 'dense_111'")
# DE loss, IV loss, Vloss in 0th epoch:  0.5541,  0.1373,  0.0084.
# DE loss, IV loss, Vloss in 100th epoch:  0.0905,  0.0287,  0.0010.
# DE loss, IV loss, Vloss in 200th epoch:  0.0893,  0.0264,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0888,  0.0254,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0884,  0.0260,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0880,  0.0275,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0871,  0.0320,  0.0009.
# DE loss, IV loss, Vloss in 700th epoch:  0.0767,  0.0805,  0.0005.
# DE loss, IV loss, Vloss in 800th epoch:  0.0337,  0.0518,  0.0001.
# DE loss, IV loss, Vloss in 900th epoch:  0.0246,  0.0432,  0.0000.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0202,  0.0400,  0.0000.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0161,  0.0271,  0.0000.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0125,  0.0157,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0110,  0.0119,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0103,  0.0082,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0096,  0.0077,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0091,  0.0058,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0084,  0.0059,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0080,  0.0039,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0075,  0.0032,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0074,  0.0019,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0063,  0.0017,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0057,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0053,  0.0010,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0049,  0.0008,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0047,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0045,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0043,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0042,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0040,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0039,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0038,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0037,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0036,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0035,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0035,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0034,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0034,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0033,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0033,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0040,  0.0035,  0.0000.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0032,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0032,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0032,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0031,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0031,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0030,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0030,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0030,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0032,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0029,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0029,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0029,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0031,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0030,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0027,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0032,  0.0026,  0.0000.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0027,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 6500th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 6600th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 6700th epoch:  0.0027,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 6800th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 6900th epoch:  0.0027,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 7000th epoch:  0.0026,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 7100th epoch:  0.0029,  0.0012,  0.0000.
# DE loss, IV loss, Vloss in 7200th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7300th epoch:  0.0027,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 7400th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7500th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7600th epoch:  0.0028,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 7700th epoch:  0.0025,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7800th epoch:  0.0026,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 7900th epoch:  0.0025,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8000th epoch:  0.0025,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 8100th epoch:  0.0025,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 8200th epoch:  0.0025,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 8300th epoch:  0.0024,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8400th epoch:  0.0024,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 8500th epoch:  0.0025,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 8600th epoch:  0.0023,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 8700th epoch:  0.0023,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8800th epoch:  0.0023,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 8900th epoch:  0.0022,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 9000th epoch:  0.0021,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 9100th epoch:  0.0019,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 9200th epoch:  0.0021,  0.0020,  0.0000.
# DE loss, IV loss, Vloss in 9300th epoch:  0.0013,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 9400th epoch:  0.0010,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 9500th epoch:  0.0009,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 9600th epoch:  0.0007,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 9700th epoch:  0.0005,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 9800th epoch:  0.0004,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9900th epoch:  0.0004,  0.0002,  0.0000.
# 7200
# 7200
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_114/Tanh:0', description="created by layer 'dense_114'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_115/Tanh:0', description="created by layer 'dense_115'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_116/Tanh:0', description="created by layer 'dense_116'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_117/Tanh:0', description="created by layer 'dense_117'")
# DE loss, IV loss, Vloss in 0th epoch:  0.6422,  0.4080,  0.0137.
# DE loss, IV loss, Vloss in 100th epoch:  0.1051,  0.0205,  0.0049.
# DE loss, IV loss, Vloss in 200th epoch:  0.0903,  0.0290,  0.0010.
# DE loss, IV loss, Vloss in 300th epoch:  0.0899,  0.0278,  0.0010.
# DE loss, IV loss, Vloss in 400th epoch:  0.0897,  0.0272,  0.0010.
# DE loss, IV loss, Vloss in 500th epoch:  0.0895,  0.0266,  0.0010.
# DE loss, IV loss, Vloss in 600th epoch:  0.0893,  0.0258,  0.0010.
# DE loss, IV loss, Vloss in 700th epoch:  0.0889,  0.0248,  0.0010.
# DE loss, IV loss, Vloss in 800th epoch:  0.0884,  0.0248,  0.0010.
# DE loss, IV loss, Vloss in 900th epoch:  0.0878,  0.0261,  0.0010.
# DE loss, IV loss, Vloss in 1000th epoch:  0.0868,  0.0303,  0.0009.
# DE loss, IV loss, Vloss in 1100th epoch:  0.0662,  0.0735,  0.0004.
# DE loss, IV loss, Vloss in 1200th epoch:  0.0263,  0.0430,  0.0000.
# DE loss, IV loss, Vloss in 1300th epoch:  0.0204,  0.0468,  0.0000.
# DE loss, IV loss, Vloss in 1400th epoch:  0.0169,  0.0399,  0.0000.
# DE loss, IV loss, Vloss in 1500th epoch:  0.0140,  0.0297,  0.0000.
# DE loss, IV loss, Vloss in 1600th epoch:  0.0118,  0.0234,  0.0000.
# DE loss, IV loss, Vloss in 1700th epoch:  0.0122,  0.0107,  0.0000.
# DE loss, IV loss, Vloss in 1800th epoch:  0.0101,  0.0130,  0.0000.
# DE loss, IV loss, Vloss in 1900th epoch:  0.0094,  0.0095,  0.0000.
# DE loss, IV loss, Vloss in 2000th epoch:  0.0089,  0.0073,  0.0000.
# DE loss, IV loss, Vloss in 2100th epoch:  0.0085,  0.0056,  0.0000.
# DE loss, IV loss, Vloss in 2200th epoch:  0.0082,  0.0049,  0.0000.
# DE loss, IV loss, Vloss in 2300th epoch:  0.0079,  0.0041,  0.0000.
# DE loss, IV loss, Vloss in 2400th epoch:  0.0075,  0.0046,  0.0000.
# DE loss, IV loss, Vloss in 2500th epoch:  0.0072,  0.0032,  0.0000.
# DE loss, IV loss, Vloss in 2600th epoch:  0.0067,  0.0029,  0.0000.
# DE loss, IV loss, Vloss in 2700th epoch:  0.0062,  0.0022,  0.0000.
# DE loss, IV loss, Vloss in 2800th epoch:  0.0057,  0.0018,  0.0000.
# DE loss, IV loss, Vloss in 2900th epoch:  0.0054,  0.0024,  0.0000.
# DE loss, IV loss, Vloss in 3000th epoch:  0.0051,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 3100th epoch:  0.0049,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 3200th epoch:  0.0047,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 3300th epoch:  0.0046,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 3400th epoch:  0.0044,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 3500th epoch:  0.0043,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 3600th epoch:  0.0042,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 3700th epoch:  0.0042,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 3800th epoch:  0.0041,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 3900th epoch:  0.0040,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4000th epoch:  0.0041,  0.0017,  0.0000.
# DE loss, IV loss, Vloss in 4100th epoch:  0.0038,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4200th epoch:  0.0038,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4300th epoch:  0.0037,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4400th epoch:  0.0036,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4500th epoch:  0.0039,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 4600th epoch:  0.0035,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4700th epoch:  0.0035,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 4800th epoch:  0.0034,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 4900th epoch:  0.0034,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5000th epoch:  0.0033,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5100th epoch:  0.0033,  0.0005,  0.0000.
# DE loss, IV loss, Vloss in 5200th epoch:  0.0033,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5300th epoch:  0.0033,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5400th epoch:  0.0032,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5500th epoch:  0.0032,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5600th epoch:  0.0031,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 5700th epoch:  0.0036,  0.0022,  0.0000.
# DE loss, IV loss, Vloss in 5800th epoch:  0.0031,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 5900th epoch:  0.0034,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 6000th epoch:  0.0030,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 6100th epoch:  0.0033,  0.0013,  0.0000.
# DE loss, IV loss, Vloss in 6200th epoch:  0.0031,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 6300th epoch:  0.0034,  0.0012,  0.0000.
# DE loss, IV loss, Vloss in 6400th epoch:  0.0030,  0.0010,  0.0000.
# DE loss, IV loss, Vloss in 6500th epoch:  0.0029,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 6600th epoch:  0.0029,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 6700th epoch:  0.0031,  0.0011,  0.0000.
# DE loss, IV loss, Vloss in 6800th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 6900th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7000th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7100th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7200th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7300th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7400th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7500th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7600th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7700th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7800th epoch:  0.0029,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 7900th epoch:  0.0028,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 8000th epoch:  0.0028,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8100th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8200th epoch:  0.0032,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 8300th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8400th epoch:  0.0030,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 8500th epoch:  0.0032,  0.0023,  0.0000.
# DE loss, IV loss, Vloss in 8600th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8700th epoch:  0.0028,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 8800th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 8900th epoch:  0.0031,  0.0018,  0.0000.
# DE loss, IV loss, Vloss in 9000th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 9100th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 9200th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 9300th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 9400th epoch:  0.0027,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 9500th epoch:  0.0032,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 9600th epoch:  0.0030,  0.0012,  0.0000.
# DE loss, IV loss, Vloss in 9700th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 9800th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 9900th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10000th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10100th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10200th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10300th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10400th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10500th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10600th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10700th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 10800th epoch:  0.0026,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 10900th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11000th epoch:  0.0025,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 11100th epoch:  0.0026,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11200th epoch:  0.0025,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11300th epoch:  0.0028,  0.0015,  0.0000.
# DE loss, IV loss, Vloss in 11400th epoch:  0.0025,  0.0004,  0.0000.
# DE loss, IV loss, Vloss in 11500th epoch:  0.0030,  0.0023,  0.0000.
# DE loss, IV loss, Vloss in 11600th epoch:  0.0024,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11700th epoch:  0.0023,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11800th epoch:  0.0023,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 11900th epoch:  0.0022,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 12000th epoch:  0.0022,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 12100th epoch:  0.0022,  0.0006,  0.0000.
# DE loss, IV loss, Vloss in 12200th epoch:  0.0029,  0.0022,  0.0000.
# DE loss, IV loss, Vloss in 12300th epoch:  0.0019,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 12400th epoch:  0.0017,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 12500th epoch:  0.0015,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 12600th epoch:  0.0013,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12700th epoch:  0.0011,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12800th epoch:  0.0009,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 12900th epoch:  0.0008,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13000th epoch:  0.0006,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13100th epoch:  0.0016,  0.0007,  0.0000.
# DE loss, IV loss, Vloss in 13200th epoch:  0.0004,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13300th epoch:  0.0003,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13400th epoch:  0.0012,  0.0014,  0.0000.
# DE loss, IV loss, Vloss in 13500th epoch:  0.0002,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13600th epoch:  0.0002,  0.0001,  0.0000.
# DE loss, IV loss, Vloss in 13700th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13800th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 13900th epoch:  0.0002,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14000th epoch:  0.0001,  0.0002,  0.0000.
# DE loss, IV loss, Vloss in 14100th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14200th epoch:  0.0002,  0.0003,  0.0000.
# DE loss, IV loss, Vloss in 14300th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14400th epoch:  0.0004,  0.0017,  0.0000.
# DE loss, IV loss, Vloss in 14500th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14600th epoch:  0.0003,  0.0009,  0.0000.
# DE loss, IV loss, Vloss in 14700th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14800th epoch:  0.0001,  0.0000,  0.0000.
# DE loss, IV loss, Vloss in 14900th epoch:  0.0001,  0.0000,  0.0000.
# 7200
# 7200

# %%
#{0.0: array([1366.8411], dtype=float32), 0.1: array([800.3307], dtype=float32), 0.01: array([1240.6304], dtype=float32), 0.001: array([1053.9727], dtype=float32), 0.0001: array([2357.2754], dtype=float32)}

# %%
end = time.time()

print((end-start)/60)
# Out:
# 13.587318277359008

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

#0.0001 epsilon seems best
#~1.2 gamma
