# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8309867496145796501
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = 0.9, 0.9

# Boundaries of the computational domain
t0, tfinal = 0.0, 7

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * x0) - (d * np.log(x0)) + (b * y0) - (a * np.log(y0))
print(v0)
# Out:
# 2.275600859429711

# %%
#a = 2/3, b = 4/3, c = 1, d = 1
#t0 = 0, tfinal = 12
#x0 = 0.9, y0 = 0.9

with open('LV 2,3 4,3 1 1 0.9 0.9 0 12 0.0001.npy', 'rb') as f:

    points = np.load(f)
    
xpoints = points[0]
ypoints = points[1]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,))
  b = Normalize(t0, tfinal)(b)

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh')(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear')(b)
  outy = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
inputs = tf.keras.layers.Input(shape=(3,))
outputs = tf.keras.layers.Dense(2)(inputs)
model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer="Adam", loss="mse", metrics=["mae"])
model.metrics_names

model.summary()
tf.keras.utils.plot_model(model)
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 3)]               0
#
#  dense_51 (Dense)            (None, 2)                 8
#
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = build_model(summary = True)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_52/Tanh:0', description="created by layer 'dense_52'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_53/Tanh:0', description="created by layer 'dense_53'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_54/Tanh:0', description="created by layer 'dense_54'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_55/Tanh:0', description="created by layer 'dense_55'")
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 1)]          0           []
#
#  normalize_17 (Normalize)       (None, 1)            0           ['input_13[0][0]']
#
#  dense_52 (Dense)               (None, 40)           80          ['normalize_17[0][0]']
#
#  dense_53 (Dense)               (None, 40)           1640        ['dense_52[0][0]']
#
#  dense_54 (Dense)               (None, 40)           1640        ['dense_53[0][0]']
#
#  dense_55 (Dense)               (None, 40)           1640        ['dense_54[0][0]']
#
#  dense_56 (Dense)               (None, 1)            41          ['dense_55[0][0]']
#
#  dense_57 (Dense)               (None, 1)            41          ['dense_55[0][0]']
#
# ==================================================================================================
# Total params: 5,082
# Trainable params: 5,082
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#tf.keras.utils.plot_model(model)

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points
de_points = defineCollocationPoints([t0, tfinal], 100)

# %%
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
plt.savefig('CollocationPoints1D.png')

# %%
# The main training function
@tf.function
def train_network(odes, inits, model, gamma):

    # DE collocation points
    t_de = odes[:,:1]
    #tf.print("t_de", t_de)

    # Initial value points
    t_init, x_init, y_init = inits[:1], inits[1:2], inits[2:]
    #tf.print(t_init, x_init, y_init)

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        print("START MODEL")
        [x, y] = model(t_de, training=True)
        print("END MODEL")

      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)
      
      # Define the differential equation loss  
      eqn1 = xt - (a*x - b*x*y)
      eqn2 = yt - (c*x*y - d*y)
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
      # Composite loss function
      loss = DEloss + gamma*IVloss

    grads = tape.gradient(loss, model.trainable_variables)
    return DEloss, IVloss, grads

# %%
def PINNtrain(de_points, x0, y0, epochs, gamma_val):

  # Total number of collocation points
  N_de = len(de_points)

  # Batch size
  bs_de = N_de//10

  # Weight factor gamma
  gamma = gamma_val

  # Learning rate
  lr_model = 1e-3

  # Initial value
  t_init = np.array([t0]).astype(np.float32)
  x_init = np.array([x0]).astype(np.float32)
  y_init = np.array([y0]).astype(np.float32)

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Generate the tf.Dataset for the initial collocation points
  inits = np.column_stack([t_init, x_init, y_init])
  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache()


  # Generate the tf.Dataset for the differential equations points
  ds_ode = tf.data.Dataset.from_tensor_slices(de_points.astype(np.float32))
  ds_ode = ds_ode.cache().shuffle(N_de).batch(bs_de)

  # Generate entire dataset
  ds = tf.data.Dataset.zip((ds_ode, ds_init))

  ds_list = ds.as_numpy_iterator()

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  # Generate the model
  opt = tf.keras.optimizers.Adam(lr_model)
  model = build_model() 

  # Main training loop
  for i in range(epochs):

    # Training for that epoch
    for (des, inits) in ds:

      # Train the network
      DEloss, IVloss, grads = train_network(des, inits, model, gamma)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))
      
      epoch_loss[i] += DEloss + gamma*IVloss
      nr_batches = nr_batches + 1

    # Get total epoch loss
    epoch_loss[i] = epoch_loss[i]/nr_batches
    nr_batches = 0

    if (np.mod(i, 100)==0):
      print("DE loss, IV loss in {}th epoch: {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss))

  return epoch_loss, model

# %%
def train_plot(epochs, gamma) :
    
    loss, model = PINNtrain(de_points, x0, y0, epochs, gamma)
    
    # Grid where to evaluate the model
    m = 1000
    t = np.linspace(t0, tfinal, m)
    
    plt.figure(1)
    plt.plot(loss)

    # Model prediction
    [x, y] = model(t)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    plt.plot(x, y, label = "e = " + str(epochs) + ", gamma = " + str(gamma))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    
    v = (c * x) - (d * np.log(x)) + (b * y) - (a * np.log(y))
    v = v - v0
    
    plt.figure(3)
    plt.plot([i for i in range(v.shape[0])], v)

# %%
epochs = 10000

train_plot(epochs, 1)
train_plot(epochs, 0.8)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_58/Tanh:0', description="created by layer 'dense_58'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_59/Tanh:0', description="created by layer 'dense_59'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_60/Tanh:0', description="created by layer 'dense_60'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_61/Tanh:0', description="created by layer 'dense_61'")
# START MODEL
# END MODEL
# DE loss, IV loss in 0th epoch:  0.0040,  1.8370.
# DE loss, IV loss in 100th epoch:  0.0332,  0.0009.
# DE loss, IV loss in 200th epoch:  0.0337,  0.0019.
# DE loss, IV loss in 300th epoch:  0.0250,  0.0025.
# DE loss, IV loss in 400th epoch:  0.0334,  0.0005.
# DE loss, IV loss in 500th epoch:  0.0329,  0.0002.
# DE loss, IV loss in 600th epoch:  0.0430,  0.0010.
# DE loss, IV loss in 700th epoch:  0.0372,  0.0013.
# DE loss, IV loss in 800th epoch:  0.0316,  0.0003.
# DE loss, IV loss in 900th epoch:  0.0376,  0.0001.
# DE loss, IV loss in 1000th epoch:  0.0310,  0.0007.
# DE loss, IV loss in 1100th epoch:  0.0166,  0.0023.
# DE loss, IV loss in 1200th epoch:  0.0256,  0.0001.
# DE loss, IV loss in 1300th epoch:  0.0175,  0.0000.
# DE loss, IV loss in 1400th epoch:  0.0191,  0.0004.
# DE loss, IV loss in 1500th epoch:  0.0131,  0.0002.
# DE loss, IV loss in 1600th epoch:  0.0125,  0.0016.
# DE loss, IV loss in 1700th epoch:  0.0187,  0.0011.
# DE loss, IV loss in 1800th epoch:  0.0145,  0.0004.
# DE loss, IV loss in 1900th epoch:  0.0208,  0.0004.
# DE loss, IV loss in 2000th epoch:  0.0144,  0.0003.
# DE loss, IV loss in 2100th epoch:  0.0198,  0.0005.
# DE loss, IV loss in 2200th epoch:  0.0032,  0.0001.
# DE loss, IV loss in 2300th epoch:  0.0022,  0.0000.
# DE loss, IV loss in 7000th epoch:  0.0002,  0.0005.
# DE loss, IV loss in 7100th epoch:  0.0004,  0.0003.
# DE loss, IV loss in 7200th epoch:  0.0002,  0.0000.
# DE loss, IV loss in 7300th epoch:  0.0003,  0.0001.
# DE loss, IV loss in 7400th epoch:  0.0003,  0.0000.
# DE loss, IV loss in 7500th epoch:  0.0004,  0.0003.
# DE loss, IV loss in 7600th epoch:  0.0001,  0.0000.
# DE loss, IV loss in 7700th epoch:  0.0002,  0.0001.
# DE loss, IV loss in 7800th epoch:  0.0001,  0.0000.
# DE loss, IV loss in 7900th epoch:  0.0001,  0.0000.
# DE loss, IV loss in 8000th epoch:  0.0003,  0.0000.
# DE loss, IV loss in 8100th epoch:  0.0001,  0.0000.
# DE loss, IV loss in 8200th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 8300th epoch:  0.0001,  0.0000.
# DE loss, IV loss in 8400th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 8500th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 8600th epoch:  0.0000,  0.0001.
# DE loss, IV loss in 8700th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 8800th epoch:  0.0001,  0.0003.
# DE loss, IV loss in 8900th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 9000th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 9100th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 9200th epoch:  0.0001,  0.0000.
# DE loss, IV loss in 9300th epoch:  0.0000,  0.0001.
# DE loss, IV loss in 9400th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 9500th epoch:  0.0003,  0.0003.
# DE loss, IV loss in 9600th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 9700th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 9800th epoch:  0.0000,  0.0000.
# DE loss, IV loss in 9900th epoch:  0.0000,  0.0000.
# 1000
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_64/Tanh:0', description="created by layer 'dense_64'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_65/Tanh:0', description="created by layer 'dense_65'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_66/Tanh:0', description="created by layer 'dense_66'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float32, name=None), name='dense_67/Tanh:0', description="created by layer 'dense_67'")
# START MODEL
# END MODEL
# DE loss, IV loss in 0th epoch:  0.0905,  1.6286.
# DE loss, IV loss in 100th epoch:  0.0499,  0.0027.
# DE loss, IV loss in 200th epoch:  0.0423,  0.0008.
# DE loss, IV loss in 300th epoch:  0.0367,  0.0017.
# DE loss, IV loss in 400th epoch:  0.0395,  0.0029.
# DE loss, IV loss in 500th epoch:  0.0279,  0.0023.
# DE loss, IV loss in 600th epoch:  0.0361,  0.0007.
# DE loss, IV loss in 700th epoch:  0.0180,  0.0004.
# DE loss, IV loss in 800th epoch:  0.0135,  0.0008.
# DE loss, IV loss in 900th epoch:  0.0172,  0.0007.
# DE loss, IV loss in 1000th epoch:  0.0060,  0.0002.
# DE loss, IV loss in 1100th epoch:  0.0198,  0.0004.
# DE loss, IV loss in 5800th epoch:  0.0025,  0.0000.
# DE loss, IV loss in 5900th epoch:  0.0019,  0.0000.
# DE loss, IV loss in 6000th epoch:  0.0040,  0.0000.
# DE loss, IV loss in 6100th epoch:  0.0035,  0.0000.
# DE loss, IV loss in 6200th epoch:  0.0018,  0.0001.
# DE loss, IV loss in 6300th epoch:  0.0021,  0.0003.
# DE loss, IV loss in 6400th epoch:  0.0035,  0.0003.
# DE loss, IV loss in 6500th epoch:  0.0031,  0.0000.
# DE loss, IV loss in 6600th epoch:  0.0018,  0.0001.
# DE loss, IV loss in 6700th epoch:  0.0020,  0.0001.
# DE loss, IV loss in 6800th epoch:  0.0018,  0.0001.
# DE loss, IV loss in 6900th epoch:  0.0014,  0.0003.
# DE loss, IV loss in 7000th epoch:  0.0016,  0.0001.
# DE loss, IV loss in 7100th epoch:  0.0020,  0.0001.
# DE loss, IV loss in 7200th epoch:  0.0014,  0.0003.
# DE loss, IV loss in 7300th epoch:  0.0025,  0.0001.
# DE loss, IV loss in 7400th epoch:  0.0033,  0.0001.
# DE loss, IV loss in 7500th epoch:  0.0021,  0.0003.
# DE loss, IV loss in 7600th epoch:  0.0020,  0.0000.
# DE loss, IV loss in 7700th epoch:  0.0018,  0.0001.
# DE loss, IV loss in 7800th epoch:  0.0013,  0.0000.
# DE loss, IV loss in 7900th epoch:  0.0031,  0.0000.
# DE loss, IV loss in 8000th epoch:  0.0017,  0.0001.
# DE loss, IV loss in 8100th epoch:  0.0013,  0.0002.
# DE loss, IV loss in 8200th epoch:  0.0025,  0.0003.
# DE loss, IV loss in 8300th epoch:  0.0020,  0.0001.
# DE loss, IV loss in 8400th epoch:  0.0013,  0.0003.
# DE loss, IV loss in 8500th epoch:  0.0015,  0.0000.
# DE loss, IV loss in 8600th epoch:  0.0007,  0.0001.
# DE loss, IV loss in 8700th epoch:  0.0010,  0.0001.
# DE loss, IV loss in 8800th epoch:  0.0005,  0.0000.
# DE loss, IV loss in 8900th epoch:  0.0004,  0.0000.
# DE loss, IV loss in 9000th epoch:  0.0007,  0.0002.
# DE loss, IV loss in 9100th epoch:  0.0003,  0.0001.
# DE loss, IV loss in 9200th epoch:  0.0003,  0.0000.
# DE loss, IV loss in 9300th epoch:  0.0002,  0.0000.
# DE loss, IV loss in 9400th epoch:  0.0002,  0.0000.
# DE loss, IV loss in 9500th epoch:  0.0001,  0.0000.
# DE loss, IV loss in 9600th epoch:  0.0003,  0.0000.
# DE loss, IV loss in 9700th epoch:  0.0003,  0.0000.
# DE loss, IV loss in 9800th epoch:  0.0001,  0.0001.
# DE loss, IV loss in 9900th epoch:  0.0002,  0.0000.
# 1000

# %%
#tfinal epoch first ~0,0 error

#5 4000
#7 8000
#7.5 10000
#8 20000

# %%
# Grid where to evaluate the model
m = 1000
t = np.linspace(t0, tfinal, m)

# Model prediction
[x, y] = model(t)

# %%
plt.plot(x, y)
