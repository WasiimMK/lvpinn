# %%
#!pip install pyDOE
#!pip install tensorflow
#!pip install pydot
#!pip install graphviz

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt
import pydot
import graphviz
import math
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import time
import random

# %%
tf.keras.backend.set_floatx('float64')

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.config.list_physical_devices('GPU')
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12953614516666950278
# xla_global_id: -1
# ]

# %%
# Initial condition
x0, y0 = np.log(0.9), np.log(0.9)


# Boundaries of the computational domain
t0, tfinal = 0.0, 36

# %%
decimal_p = 4

# %%
a = 2/3
b = 4/3
c = 1
d = 1

# %%
v0 = (c * (math.exp(x0))) - (d * x0) + (b * math.exp(y0)) - (a * y0)

print(v0)
# Out:
# 2.275600859429711

# %%
with open('LV 2,3 4,3 1 1 0.9 0.9 0 36 0.0001.npy', 'rb') as f:

    points = np.load(f)

tpoints = points[0]
tpoints = np.round(tpoints, decimal_p)
xpoints = points[1]
ypoints = points[2]

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %%
# Define the network
def build_model(nr_units=40, nr_layers=4, summary=False):

  inp = b = tf.keras.layers.Input(shape=(1,), name = "Input_t")
  b = Normalize(t0, tfinal)(b)
  Normalize.name  = "Normalize"

  for i in range(nr_layers):
    b = tf.keras.layers.Dense(nr_units, activation='tanh', name = "Hidden_" + str(i))(b)
    print("b", b)
  outx = tf.keras.layers.Dense(1, activation='linear', name = "Output_x")(b)
  outy = tf.keras.layers.Dense(1, activation='linear', name = "Output_y")(b)

  model = tf.keras.models.Model(inp, [outx, outy])
  
  if summary:
    model.summary()

  return model

# %%
model = build_model(summary = True)
tf.keras.utils.plot_model(model)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input_t (InputLayer)           [(None, 1)]          0           []
#
#  Normalize (Normalize)          (None, 1)            0           ['Input_t[0][0]']
#
#  Hidden_0 (Dense)               (None, 40)           80          ['Normalize[0][0]']
#
#  Hidden_1 (Dense)               (None, 40)           1640        ['Hidden_0[0][0]']
#
#  Hidden_2 (Dense)               (None, 40)           1640        ['Hidden_1[0][0]']
#
#  Hidden_3 (Dense)               (None, 40)           1640        ['Hidden_2[0][0]']
#
#  Output_x (Dense)               (None, 1)            41          ['Hidden_3[0][0]']
#
#  Output_y (Dense)               (None, 1)            41          ['Hidden_3[0][0]']
#
# ==================================================================================================
# Total params: 5,082
# Trainable params: 5,082
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Define the collocation points over the domain [t_0, t_1]
def defineCollocationPoints(t_bdry, N_pde=100):

    # Sample points where to evaluate the PDE
  ode_points = t_bdry[0] + (t_bdry[1] - t_bdry[0])*lhs(1, N_pde)

  return ode_points

# %%
# Define the collocation points

de_points = defineCollocationPoints([t0, tfinal], 100)
de_points_tensor = tf.convert_to_tensor(de_points, dtype=tf.float32)
plt.plot(de_points[:,0], 0*de_points[:,0],'.')
plt.xlabel('t')
plt.title('Collocation points being used')
# Out:
# Text(0.5, 1.0, 'Collocation points being used')

# %%
# The main training function
@tf.function
def train_network(model, t, inits, alpha, beta, gamma):

    t_de = t

    # Initial value points
    t_init, x_init, y_init = inits[:, 0], inits[:, 1], inits[:, 2]
    

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_de)
        [x, y] = model(t_de, training=True)
        v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
        
      # Derivative of the neural network solution
      xt = tape2.gradient(x, t_de)
      yt = tape2.gradient(y, t_de)

      #xt = tf.cast(xt, tf.float32)
      #yt = tf.cast(yt, tf.float32)
        

      # Define the differential equation loss  
      eqn1 = xt - a + b*(tf.math.exp(y))
      eqn2 = yt - c*(tf.math.exp(x)) + d
      DEloss = tf.reduce_mean(tf.square(eqn1) + tf.square(eqn2))
                         
      # Define the initial value loss
      [x_init_pred, y_init_pred] = model(t_init, training=True)
      IVloss = tf.reduce_mean(tf.square(x_init_pred - x_init) + tf.square(y_init_pred - y_init))
    
    
      #Implicit integration loss
      vt = tape2.gradient(v, t_de)
      tf.print(vt)
      #v = (c * (tf.math.exp(x))) - (d * x) + (b * tf.math.exp(y)) - (a * y)
    
      Vloss = tf.square(tf.math.reduce_mean(v) - v0)           
    
      # Composite loss function
      loss = alpha*DEloss + beta*IVloss + gamma*Vloss

    grads = tape.gradient(loss, model.trainable_variables)
    
    return DEloss, IVloss, Vloss, grads

# %%
def PINNtrain(custom_model, custom_t, x0, y0, epochs, alpha_val, beta_val, gamma_val):

    # Weight factors
    alpha = alpha_val
    beta = beta_val
    gamma = gamma_val

    # Learning rate
    lr_model = 1e-2

    # Initial value
    t_init = np.array([t0]).astype(np.float64)
    x_init = np.array([x0]).astype(np.float64)
    y_init = np.array([y0]).astype(np.float64)
                                                                    
    
    inits = np.column_stack([t_init, x_init, y_init])

    epoch_loss = np.zeros(epochs)

    # Generate the model
    opt = tf.keras.optimizers.Adam(lr_model)

    # Main training loop
    for i in range(epochs):

        # Train the network
        DEloss, IVloss, Vloss, grads = train_network(custom_model, custom_t, inits, alpha, beta, gamma)

        # Gradient step
        opt.apply_gradients(zip(grads, custom_model.trainable_variables))
      
        epoch_loss[i] += alpha*DEloss + beta*IVloss + gamma*Vloss

        if (np.mod(i, 100)==0) :
            
            print("Dloss, Iloss, Closs in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, DEloss, IVloss, Vloss))

    return epoch_loss, custom_model

# %%
colloc_points_per_cycle = 100
step_size = 0.001

# %%
def train_plot_sequential(custom_model, t_start, t_end, epochs, cycles, alpha, beta, gamma) :
    
    empty_arr = np.array([[]])
    
    x = tf.reshape(tf.convert_to_tensor(empty_arr, dtype=tf.float64), [0, 1])
    y = tf.reshape(tf.convert_to_tensor(empty_arr, dtype=tf.float64), [0, 1])

    t = np.arange(t_start, t_end, step_size)
    t = np.round(t, decimal_p)
    num_t = len(t)
    print("num t", num_t)
    
    delta_t = int((t_end - t_start)/cycles)
    
    print("colloc_points_per_cycle", colloc_points_per_cycle)
    print("delta_t", delta_t)

    loss_vals = np.zeros(epochs * cycles)
    next_model = custom_model
    
    next_x0 = x0
    next_y0 = y0
    
    custom_t = defineCollocationPoints([0.0, delta_t], colloc_points_per_cycle)
    
    t_pred = np.arange(0.0, delta_t, step_size)
    t_pred = np.round(t_pred, decimal_p)
    
    for i in range(cycles) :

        loss, model = PINNtrain(next_model, custom_t, next_x0, next_y0, epochs, alpha, beta, gamma)
        loss_vals[i*epochs : (i+1)*epochs] = loss
        
        [next_x, next_y] = model(t_pred, training=True)
        
        x = tf.concat([x, next_x], axis = 0)
        y = tf.concat([y, next_y], axis = 0)
        
        t_delta_t = np.array([delta_t]).astype(np.float64)
        
        [next_x0, next_y0] = model(t_delta_t, training=True)
        
        next_x0 = next_x0.numpy()[0][0]
        next_y0 = next_y0.numpy()[0][0]

        next_model = tf.keras.models.clone_model(model)
        next_model.build((None, 1))
        next_model.set_weights(model.get_weights())
        

    plt.figure(1)
    plt.semilogy(loss_vals)
    
    x = tf.math.exp(x)
    y = tf.math.exp(y)
    
    # Plot the solution
    print(len(x))
    
    plt.figure(2)
    #plt.plot(x, y, label = "e = " + str(epochs) + ", cycles = " + str(cycles))
    plt.plot(x, y, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.plot(xpoints, ypoints, color = 'black')
    plt.xlabel("x")
    plt.ylabel("y")
    
    error = calc_err(t, x, y)
    print("error", error)
    print("error mean", error/num_t)
    
    plt.figure(3)
    plt.scatter(cycles, error)
    plt.xlabel("number of cycles")
    plt.ylabel("error")
    
    plt.figure(4)
    plt.plot(tpoints, xpoints, color = 'black')
    plt.plot(t, x, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.xlabel("t")
    plt.ylabel("x")
    
    plt.figure(5)
    plt.plot(tpoints, ypoints, color = 'black')
    plt.plot(t, y, label = "e = " + str(epochs))
    plt.legend(loc='best')
    plt.xlabel("t")
    plt.ylabel("y")

# %%
def calc_err(t_preds, x_preds, y_preds) :
    
    error = 0
    
    for i in range(len(t_preds)) :
        
        t_i = np.where(tpoints == t_preds[i])
        
        err = math.sqrt((x_preds[i] - xpoints[t_i])**2 + (y_preds[i] - ypoints[t_i])**2)
        
        error = error + err
        
    return error

# %%
start = time.time()

# %%
# epochs = 500
# cycles = 4

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 5000, 1, 12, 1.2, 100.0)

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 10000, 1, 12, 1.2, 100.0)

custom_model = build_model(summary = False)
train_plot_sequential(custom_model, t0, tfinal, 15000, 1, 12, 1.2, 100.0)
# Out:
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_0/Tanh:0', description="created by layer 'Hidden_0'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_1/Tanh:0', description="created by layer 'Hidden_1'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_2/Tanh:0', description="created by layer 'Hidden_2'")
# b KerasTensor(type_spec=TensorSpec(shape=(None, 40), dtype=tf.float64, name=None), name='Hidden_3/Tanh:0', description="created by layer 'Hidden_3'")
# num t 36000
# colloc_points_per_cycle 100
# delta_t 36
# [[0.0027478244195755707]
#  [0.0015493707640463598]
#  [0.0018811321277922904]
#  ...
#  [0.0015237593421504841]
#  [0.0021935666402288015]
#  [0.0024896359450574113]]
# Dloss, Iloss, Closs in 0th epoch:  0.4503,  0.0086,  0.0035.
# [[-0.015562792325183455]
#  [-0.089231811461844848]
#  [0.018267327513768205]
#  ...
#  [-0.090118367213563769]
#  [-0.061155242636762475]
#  [0.0094729676602129439]]
# [[-0.0027469322180695478]
#  [-0.0065531465237695513]
#  [-0.00023644088043298835]
#  ...
#  [-0.0066049854075908715]
#  [-0.0050678086268313828]
#  [-0.0011400061192803543]]
# [[0.00084597019855950817]
#  [-0.00016753649589249349]
#  [0.0013174857395227859]
#  ...
#  [-0.00018228962848740595]
#  [0.00024047428386987863]
#  [0.0012006868506655056]]
# [[0.0024804337947764163]
#  [-0.00029970177085841972]
#  [0.0041729771837622784]
#  ...
#  [-0.00033319799958419214]
#  [0.0007146121715673146]
#  [0.0036806951468745107]]
# [[0.0026346331809036197]
#  [-0.0002631670229257503]
#  [0.0038374512171400134]
#  ...
#  [-0.00029975528215505563]
#  [0.00083634753086051471]
#  [0.0036353864339167979]]
# [[0.0011558364078509342]
#  [-0.00097602800416433314]
#  [0.0014224020422387614]
#  ...
#  [-0.0010040830240719317]
#  [-0.00012742439210072836]
#  [0.0016004113705201416]]
# [[-0.0014120744880454369]
#  [-0.0040800923742639076]
#  [-0.00010706086750706855]
#  ...
#  [-0.0041011438591810412]
#  [-0.0032497358997470591]
#  [-0.00034310867714939879]]
# [[-0.0044542823610938375]
#  [-0.0098402730709135459]
#  [0.00039035522681678942]
#  ...
#  [-0.009855821770578756]
#  [-0.00865112131963688]
#  [-0.0010493698387533123]]
# [[-0.0056472607866138395]
#  [-0.012638998689921884]
#  [0.0016162137660449859]
#  ...
#  [-0.012646316659847247]
#  [-0.011351123357837844]
#  [-0.00060599355844814145]]
# [[-0.0037326191734689137]
#  [-0.0090178363800477081]
#  [0.0020737507243398451]
#  ...
#  [-0.009023834821725871]
#  [-0.0080696367959380132]
#  [0.00026611655634542562]]
# [[-0.0010188482667226003]
#  [-0.0040924340155214615]
#  [0.0021556277173059631]
#  ...
#  [-0.0041028515138243288]
#  [-0.0034405731116921513]
# [[0.00056680202825809339]
#  [-0.0050751158630655642]
#  [0.02779005023885215]
#  ...
#  [-0.0061598435939581734]
#  [-0.00019918635476329447]
#  [0.019820672149899819]]
# [[0.00063870795958673827]
#  [-0.0059286138630391238]
#  [0.024819557451567852]
#  ...
#  [-0.0070011208291420749]
#  [-0.00016524059460614423]
#  [0.014030551798221448]]
# [[0.0005560936800840581]
#  [-0.0047421391281496908]
#  [0.029151792142919863]
#  ...
#  [-0.0057998230052387044]
#  [-0.00020526148012646074]
#  [0.021317986265347234]]
# [[0.00065375736806912914]
#  [-0.0060981409730159249]
#  [0.024097988022881076]
#  ...
#  [-0.0071681936348597817]
#  [-0.00015977040123434539]
#  [0.012937933660183655]]
# [[0.00054927811749456523]
#  [-0.0046260970989049225]
#  [0.0290700783010311]
#  ...
#  [-0.0056991004120941673]
#  [-0.00021391013083839116]
#  [0.022445545155192249]]
# [[0.00066315709704139222]
#  [-0.006409821005189679]
#  [0.022292986503755285]
#  ...
#  [-0.0075167131733423374]
#  [-0.00015940708759213263]
#  [0.011867998628264745]]
# [[0.00054482672552714822]
#  [-0.0047235326282753475]
#  [0.027943394223400066]
#  ...
#  [-0.0058466876203505441]
#  [-0.00022497449490176591]
#  [0.023011844884306094]]
# [[0.000661363210511649]
#  [-0.0068263452493462912]
#  [0.020377359984635694]
#  ...
#  [-0.00800233548168689]
#  [-0.00016795497430820033]
#  [0.011133852115133078]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 5
#       1 # epochs = 500
#       2 # cycles = 4
#       4 custom_model = build_model(summary = False)
# ----> 5 train_plot_sequential(custom_model, t0, tfinal, 5000, 1, 12, 1.2, 100.0)
#       7 custom_model = build_model(summary = False)
#       8 train_plot_sequential(custom_model, t0, tfinal, 10000, 1, 12, 1.2, 100.0)
#
# Cell In[60], line 31, in train_plot_sequential(custom_model, t_start, t_end, epochs, cycles, alpha, beta, gamma)
#      27 t_pred = np.round(t_pred, decimal_p)
#      29 for i in range(cycles) :
# ---> 31     loss, model = PINNtrain(next_model, custom_t, next_x0, next_y0, epochs, alpha, beta, gamma)
#      32     loss_vals[i*epochs : (i+1)*epochs] = loss
#      34     [next_x, next_y] = model(t_pred, training=True)
#
# Cell In[58], line 31, in PINNtrain(custom_model, custom_t, x0, y0, epochs, alpha_val, beta_val, gamma_val)
#      28 DEloss, IVloss, Vloss, grads = train_network(custom_model, custom_t, inits, alpha, beta, gamma)
#      30 # Gradient step
# ---> 31 opt.apply_gradients(zip(grads, custom_model.trainable_variables))
#      33 epoch_loss[i] += alpha*DEloss + beta*IVloss + gamma*Vloss
#      35 if (np.mod(i, 100)==0) :
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1140, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1138 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1139     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1140 return super().apply_gradients(grads_and_vars, name=name)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:634, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     632 self._apply_weight_decay(trainable_variables)
#     633 grads_and_vars = list(zip(grads, trainable_variables))
# --> 634 iteration = self._internal_apply_gradients(grads_and_vars)
#     636 # Apply variable constraints after applying gradients.
#     637 for variable in trainable_variables:
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1166, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1165 def _internal_apply_gradients(self, grads_and_vars):
# -> 1166     return tf.__internal__.distribute.interim.maybe_merge_call(
#    1167         self._distributed_apply_gradients_fn,
#    1168         self._distribution_strategy,
#    1169         grads_and_vars,
#    1170     )
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribution_strategy_context.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1216, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1213         return self._update_step(grad, var)
#    1215 for grad, var in grads_and_vars:
# -> 1216     distribution.extended.update(
#    1217         var, apply_grad_to_update_var, args=(grad,), group=False
#    1218     )
#    1220 if self.use_ema:
#    1221     _, var_list = zip(*grads_and_vars)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2637, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2634   fn = autograph.tf_convert(
#    2635       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2636   with self._container_strategy().scope():
# -> 2637     return self._update(var, fn, args, kwargs, group)
#    2638 else:
#    2639   return self._replica_ctx_update(
#    2640       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3710, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    3707 def _update(self, var, fn, args, kwargs, group):
#    3708   # The implementations of _update() and _update_non_slot() are identical
#    3709   # except _update() passes `var` as the first argument to `fn()`.
# -> 3710   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3716, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    3712 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    3713   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    3714   # once that value is used for something.
#    3715   with UpdateContext(colocate_with):
# -> 3716     result = fn(*args, **kwargs)
#    3717     if should_group:
#    3718       return result
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:1213, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1211     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1212 else:
# -> 1213     return self._update_step(grad, var)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\optimizer.py:224, in _BaseOptimizer._update_step(self, gradient, variable)
#     215 if self._var_key(variable) not in self._index_dict:
#     216     raise KeyError(
#     217         f"The optimizer cannot recognize variable {variable.name}. "
#     218         "This usually means you are trying to call the optimizer to "
#    (...)
#     222         "`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     223     )
# --> 224 self.update_step(gradient, variable)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\keras\optimizers\optimizer_experimental\adam.py:170, in Adam.update_step(self, gradient, variable)
#     167 m = self._momentums[self._index_dict[var_key]]
#     168 v = self._velocities[self._index_dict[var_key]]
# --> 170 alpha = lr * tf.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     172 if isinstance(gradient, tf.IndexedSlices):
#     173     # Sparse gradients.
#     174     m.assign_add(-m * (1 - self.beta_1))
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\math_ops.py:1407, in _OverrideBinaryOperatorHelper.<locals>.binary_op_wrapper(x, y)
#    1402 try:
#    1403   # force_same_dtype=False to preserve existing TF behavior
#    1404   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1405   #   r_binary_op_wrapper use different force_same_dtype values.
#    1406   x, y = maybe_promote_tensors(x, y)
# -> 1407   return func(x, y, name=name)
#    1408 except (TypeError, ValueError) as e:
#    1409   # Even if dispatching the op failed, the RHS may be a tensor aware
#    1410   # object that can implement the operator with knowledge of itself
#    (...)
#    1413   # original error from the LHS, because it may be more
#    1414   # informative.
#    1415   if hasattr(type(y), "__r%s__" % op_name):
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\math_ops.py:1590, in truediv(x, y, name)
#    1559 @tf_export("math.truediv", "truediv")
#    1560 @dispatch.register_binary_elementwise_api
#    1561 @dispatch.add_dispatch_support
#    1562 def truediv(x, y, name=None):
#    1563   """Divides x / y elementwise (using Python 3 division operator semantics).
#    1564
#    1565   NOTE: Prefer using the Tensor operator or tf.divide which obey Python
#    (...)
#    1588     TypeError: If `x` and `y` have different dtypes.
#    1589   """
# -> 1590   return _truediv_python3(x, y, name)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\math_ops.py:1528, in _truediv_python3(x, y, name)
#    1526   x = cast(x, dtype)
#    1527   y = cast(y, dtype)
# -> 1528 return gen_math_ops.real_div(x, y, name=name)
#
# File ~\anaconda3\envs\tf_2.11\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:8700, in real_div(x, y, name)
#    8698 if tld.is_eager:
#    8699   try:
# -> 8700     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    8701       _ctx, "RealDiv", name, x, y)
#    8702     return _result
#    8703   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
end = time.time()

print((end-start)/60)

# %%
#     2 3 4

# 20 0.05328786159898205, 0.03248169943505809, 0.014598205832759456
# 30 0.060848330988604774, 0.019430389301504553, 0.0069668703920268285
# 40 0.03672581839745748, 0.00413 ,0.004484866589899533
